# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to /home/pcorrea/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 71859
terminou = 80000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/sentimental_ds
# dados-curso.csv        main.txt           piloto-2.ipynb
# dataset-v2.dat         pc-dataset-v2.csv  prototype_sentimental_analyzer.ipynb
# first_code_test.ipynb  pc-dataset-v2.dat  README.md

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# WARNING: The directory '/home/pcorrea/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already satisfied: googletrans in /home/pcorrea/anaconda3/lib/python3.7/site-packages (2.4.0)
# Requirement already satisfied: requests in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from googletrans) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from requests->googletrans) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from requests->googletrans) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from requests->googletrans) (1.25.8)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 100000

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
for x in df['reviewBody']:
    ini = time.time()
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        #out = clean_tripadvisor("Recife: a beautiful city with a gorgeous culture. Beyond the beauties, we also have a really good food. So, do you really want to eat an awesome steak? If you love steak like I do, you need to know a perfect place. What’s the name of the place? Spettus! You’ll see more than 22 kinds of steaks, all of them prepared by excellent professionals. Steaks from Argentina and Uruguay, and you can choose any kind of steak you want. You’ll find japanese food, vegetables and delicious deserts too! What are you going to find there? A huge place (they fit 700 people), perfect for a good lunch, a dinner with the family and, of course, a happy hour with your friends. Do you like good music? Piano bar. Do you have kids? Playground. Everything you’ll find at Spettus! Do you drink? Be prepared to drink a good wine from France, Italy, Argentina and more! Oh! Do you want to surf on the internet while eating? Do you need an Internet Wi-fi? Spettus is the answer! I went there last year and it was perfect. I love steak and they have a really good variety. And, obvious, it’s delicious! Remember: Spettus!")
        out = clean_tripadvisor(x)
        #################################
        try:
            which = TextBlob(out)
            print("Tipo de which language: ",type(which))
            lang = which.detect_language()
            if lang == 'en':
                print("It is english")
                #################################
                #comentario_blob = TextBlob(out)
    #             print("comentario_blob ",type(which))

                comentario_blob_pt = which.translate(to='pt')
                comentario_blob_us = comentario_blob_pt.translate(to='en')
                print("tipo em english ", type(which))
                print("Original em Inglês: ",which)
                print("Traduzido para Português: ",comentario_blob_pt)
                time.sleep(5)

                for sentence_br, sentence in zip(comentario_blob_pt.sentences, comentario_blob_us.sentences):
                    print("sentence_br ",sentence_br)
                    print(" EN sentence.sentiment.polarity: ",sentence.sentiment.polarity)
                    print("EN sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
                    if sentence_br is None:
                        errou = errou + 1
                        print("errou em {} - {} {}".format(var,errou,x))
                        saveDocumentError(var,errou,x)

                    elif var > inicio and var <= terminou:
                        print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                        print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                        saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

                    else:
                        print("EN algum erro ocorreu em {}".format(var))
                ################################################

            elif lang == 'pt':
                print("It is portuguese")
                #################################
                comentario_blob = TextBlob(out)
                print("comentario_blob ",type(comentario_blob))

                comentario_blob_us = comentario_blob.translate(to='us')
                print("tipo em english ", type(comentario_blob_us))
                print("Inglês: ",comentario_blob_us)
                time.sleep(5)

                for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
                    print("sentence_br ",sentence_br)
                    print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
                    print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
                    if sentence_br is None:
                        errou = errou + 1
                        print("errou em {} - {} {}".format(var,errou,x))
                        saveDocumentError(var,errou,x)

                    elif var > inicio and var <= terminou:
                        print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                        print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                        saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

                    else:
                        print("PT algum erro ocorreu em {}".format(var))
                ################################################
            else:
                print("Not english")
        except TypeError:
            print("Errou não é tipo string")
            continue
        
    if var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.6689300537109375e-06
# tempo final foi  -3.0994415283203125e-06
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -1.6689300537109375e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.33514404296875e-05
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# ...
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# tempo final foi  -6.048635959625244
# **************
#
# var 71865 x Restaurante de muito bom gosto e agradável. Ótimo custo x benefício nos pratos e vinhos.
# Atendimento cordial e comida de boa qualidade. Música lounge muito boa, mas na minha opinião um pouco alta demais.
# Imperdível o mil folhas de doce de leite.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  Very tasteful and pleasant restaurant.
#  Great cost x benefit in the dishes and wines.
#
# Friendly service and good quality food.
#  Very good lounge music, but in my opinion a little too loud.
#
# The thousand sheets of dulce de leche are a must.
# sentence_br  Restaurante de muito bom gosto e agradável.
# sentence.sentiment.polarity:  0.4666666666666667
# sentence.sentiment.subjectivity:  0.6333333333333333
# Polaridade
#  Restaurante de muito bom gosto e agradável. : 0.4666666666666667
# subjetividade
#  Restaurante de muito bom gosto e agradável. : 0.6333333333333333
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Ótimo custo x benefício nos pratos e vinhos.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ótimo custo x benefício nos pratos e vinhos. : 0.8
# subjetividade
#  Ótimo custo x benefício nos pratos e vinhos. : 0.75
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Atendimento cordial e comida de boa qualidade.
# sentence.sentiment.polarity:  0.5375
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  Atendimento cordial e comida de boa qualidade. : 0.5375
# subjetividade
#  Atendimento cordial e comida de boa qualidade. : 0.55
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Música lounge muito boa, mas na minha opinião um pouco alta demais.
# sentence.sentiment.polarity:  0.2741666666666666
# sentence.sentiment.subjectivity:  0.6933333333333334
# Polaridade
#  Música lounge muito boa, mas na minha opinião um pouco alta demais. : 0.2741666666666666
# subjetividade
#  Música lounge muito boa, mas na minha opinião um pouco alta demais. : 0.6933333333333334
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Imperdível o mil folhas de doce de leite.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Imperdível o mil folhas de doce de leite. : 0.0
# subjetividade
#  Imperdível o mil folhas de doce de leite. : 0.0
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# tempo final foi  -5.784503936767578
# **************
#
# var 71866 x Restaurante bem conhecido e sempre cheio para almoço e jantar. Ambiente muito agradável, ótimo atendimento e pedidos atendidos com rapidez. Pratos muito bem feitos e muito bem servidos. Dependendo do apetite servem até 4 pessoas. Camarões de bom tamanho. Vale muito a pena. Custo benefício excelente!
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  Well-known and always full restaurant for lunch and dinner.
#  Very pleasant environment, great service and requests answered quickly.
#  Dishes very well done and very well served.
#  Depending on appetite, they serve up to 4 people.
#  Good sized prawns.
#  It's really worth it.
#  Excellent cost benefit!
# sentence_br  Restaurante bem conhecido e sempre cheio para almoço e jantar.
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  Restaurante bem conhecido e sempre cheio para almoço e jantar. : 0.35
# subjetividade
#  Restaurante bem conhecido e sempre cheio para almoço e jantar. : 0.55
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Ambiente muito agradável, ótimo atendimento e pedidos atendidos com rapidez.
# sentence.sentiment.polarity:  0.6955555555555556
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ambiente muito agradável, ótimo atendimento e pedidos atendidos com rapidez. : 0.6955555555555556
# subjetividade
#  Ambiente muito agradável, ótimo atendimento e pedidos atendidos com rapidez. : 0.75
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Pratos muito bem feitos e muito bem servidos.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Pratos muito bem feitos e muito bem servidos. : 0.2
# subjetividade
#  Pratos muito bem feitos e muito bem servidos. : 0.3
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Dependendo do apetite servem até 4 pessoas.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Dependendo do apetite servem até 4 pessoas. : 0.0
# subjetividade
#  Dependendo do apetite servem até 4 pessoas. : 0.0
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Camarões de bom tamanho.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Camarões de bom tamanho. : 0.7
# subjetividade
#  Camarões de bom tamanho. : 0.6000000000000001
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Vale muito a pena.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale muito a pena. : 0.3
# subjetividade
#  Vale muito a pena. : 0.1
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Custo benefício excelente!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Custo benefício excelente! : 1.0
# subjetividade
#  Custo benefício excelente! : 1.0
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# tempo final foi  -5.841981649398804
# **************
#
# var 71867 x Excelente atendimento e tudo muito gostoso, ambiente bem agradável.  Adorei serviram pastéis com geleia de pimenta maravilhoso.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  Excellent service and everything very tasty, very pleasant environment.
#   I loved they served pastries with wonderful pepper jam.
# sentence_br  Excelente atendimento e tudo muito gostoso, ambiente bem agradável.
# sentence.sentiment.polarity:  0.7177777777777777
# sentence.sentiment.subjectivity:  0.7666666666666666
# Polaridade
#  Excelente atendimento e tudo muito gostoso, ambiente bem agradável. : 0.7177777777777777
# subjetividade
#  Excelente atendimento e tudo muito gostoso, ambiente bem agradável. : 0.7666666666666666
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Adorei serviram pastéis com geleia de pimenta maravilhoso.
# sentence.sentiment.polarity:  0.85
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Adorei serviram pastéis com geleia de pimenta maravilhoso. : 0.85
# subjetividade
#  Adorei serviram pastéis com geleia de pimenta maravilhoso. : 0.9
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# tempo final foi  -6.024273157119751
# **************
#
# var 71868 x Adorei o ambiente, o atendimento e a comida. Tudo muito fresco, vc pode pedir quantas peças de sashimi quiser que eles cortam na hora, tendo inclusive a opção de maçaricar. Tudo incluso no mesmo preço do kilo, que é bastante atrativo.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  I loved the atmosphere, the service and the food.
#  Everything is very fresh, you can order as many pieces of sashimi as you want them to cut on the spot, even having the option to blow them.
#  All included at the same price as the kilo, which is very attractive.
# sentence_br  Adorei o ambiente, o atendimento e a comida.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Adorei o ambiente, o atendimento e a comida. : 0.7
# subjetividade
#  Adorei o ambiente, o atendimento e a comida. : 0.8
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Tudo muito fresco, vc pode pedir quantas peças de sashimi quiser que eles cortam na hora, tendo inclusive a opção de maçaricar.
# sentence.sentiment.polarity:  0.445
# sentence.sentiment.subjectivity:  0.575
# Polaridade
#  Tudo muito fresco, vc pode pedir quantas peças de sashimi quiser que eles cortam na hora, tendo inclusive a opção de maçaricar. : 0.445
# subjetividade
#  Tudo muito fresco, vc pode pedir quantas peças de sashimi quiser que eles cortam na hora, tendo inclusive a opção de maçaricar. : 0.575
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# sentence_br  Tudo incluso no mesmo preço do kilo, que é bastante atrativo.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5625
# Polaridade
#  Tudo incluso no mesmo preço do kilo, que é bastante atrativo. : 0.5
# subjetividade
#  Tudo incluso no mesmo preço do kilo, que é bastante atrativo. : 0.5625
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-70703-80000.txt
# tempo final foi  -6.3110740184783936
# **************
#
# var 71869 x Fui no La Mole para comer uma massa na noite anterior a Meia Maratona e foi uma excelente escolha. O cardápio tem ótimas opções de massas e pizzas. O prato é farto e serve tranquilamente para duas pessoas que não comem muito. Dividindo para dois fica até barato. Comendo sozinho o preço é justo, ponderando que é Rio. Fui no Botafogo, mas existem vários no Rio. O ambiente é agradável, com bom atendimento.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-32-10d8e9298ae7> in <module>
#      14             which = TextBlob(out)
#      15             print("Tipo de which language: ",type(which))
# ---> 16             lang = which.detect_language()
#      17             if lang == 'en':
#      18                 print("It is english")
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/blob.py in detect_language(self)
#     566         :rtype: str
#     567         """
# --> 568         return self.translator.detect(self.raw)
#     569
#     570     def correct(self):
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/translate.py in detect(self, source, host, type_)
#      70         data = {"q": source}
#      71         url = u'{url}&sl=auto&tk={tk}'.format(url=self.url, tk=_calculate_tk(source))
# ---> 72         response = self._request(url, host=host, type_=type_, data=data)
#      73         result, language = json.loads(response)
#      74         return language
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
