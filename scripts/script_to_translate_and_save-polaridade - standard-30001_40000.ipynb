# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to /home/pcorrea/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 31482
terminou = 40000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# Cloning into 'sentimental_ds'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 101 (delta 1), reused 6 (delta 1), pack-reused 95
# Receiving objects: 100% (101/101), 79.73 MiB | 1.30 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# Checking connectivity... done.
# Checking out files: 100% (12/12), done.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/sentimental_ds/sentimental_ds
# dados-curso.csv
# dataset-v2.dat
# first_code_test.ipynb
# main.txt
# pc-dataset-v2.csv
# pc-dataset-v2.dat
# piloto-2.ipynb
# prototype_sentimental_analyzer.ipynb
# README.md
# script_to_translate_and_save-polaridade - standard-0_10000 (copy).ipynb

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# WARNING: The directory '/home/pcorrea/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Requirement already satisfied: googletrans in /home/pcorrea/anaconda3/lib/python3.7/site-packages (2.4.0)
# Requirement already satisfied: requests in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from googletrans) (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from requests->googletrans) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from requests->googletrans) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pcorrea/anaconda3/lib/python3.7/site-packages (from requests->googletrans) (2019.11.28)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 100000

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
for x in df['reviewBody']:
    ini = time.time()
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        #out = clean_tripadvisor("Recife: a beautiful city with a gorgeous culture. Beyond the beauties, we also have a really good food. So, do you really want to eat an awesome steak? If you love steak like I do, you need to know a perfect place. What’s the name of the place? Spettus! You’ll see more than 22 kinds of steaks, all of them prepared by excellent professionals. Steaks from Argentina and Uruguay, and you can choose any kind of steak you want. You’ll find japanese food, vegetables and delicious deserts too! What are you going to find there? A huge place (they fit 700 people), perfect for a good lunch, a dinner with the family and, of course, a happy hour with your friends. Do you like good music? Piano bar. Do you have kids? Playground. Everything you’ll find at Spettus! Do you drink? Be prepared to drink a good wine from France, Italy, Argentina and more! Oh! Do you want to surf on the internet while eating? Do you need an Internet Wi-fi? Spettus is the answer! I went there last year and it was perfect. I love steak and they have a really good variety. And, obvious, it’s delicious! Remember: Spettus!")
        out = clean_tripadvisor(x)
        #################################
        try:
            which = TextBlob(out)
            print("Tipo de which language: ",type(which))
            lang = which.detect_language()
            if lang == 'en':
                print("It is english")
                #################################
                #comentario_blob = TextBlob(out)
    #             print("comentario_blob ",type(which))

                comentario_blob_pt = which.translate(to='pt')
                comentario_blob_us = comentario_blob_pt.translate(to='en')
                print("tipo em english ", type(which))
                print("Original em Inglês: ",which)
                print("Traduzido para Português: ",comentario_blob_pt)
                time.sleep(5)

                for sentence_br, sentence in zip(comentario_blob_pt.sentences, comentario_blob_us.sentences):
                    print("sentence_br ",sentence_br)
                    print(" EN sentence.sentiment.polarity: ",sentence.sentiment.polarity)
                    print("EN sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
                    if sentence_br is None:
                        errou = errou + 1
                        print("errou em {} - {} {}".format(var,errou,x))
                        saveDocumentError(var,errou,x)

                    elif var > inicio and var <= terminou:
                        print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                        print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                        saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

                    else:
                        print("EN algum erro ocorreu em {}".format(var))
                ################################################

            elif lang == 'pt':
                print("It is portuguese")
                #################################
                comentario_blob = TextBlob(out)
                print("comentario_blob ",type(comentario_blob))

                comentario_blob_us = comentario_blob.translate(to='us')
                print("tipo em english ", type(comentario_blob_us))
                print("Inglês: ",comentario_blob_us)
                time.sleep(5)

                for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
                    print("sentence_br ",sentence_br)
                    print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
                    print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
                    if sentence_br is None:
                        errou = errou + 1
                        print("errou em {} - {} {}".format(var,errou,x))
                        saveDocumentError(var,errou,x)

                    elif var > inicio and var <= terminou:
                        print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                        print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                        saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

                    else:
                        print("PT algum erro ocorreu em {}".format(var))
                ################################################
            else:
                print("Not english")
        except TypeError:
            print("Errou não é tipo string")
            continue
        
    if var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.6689300537109375e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -1.8835067749023438e-05
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -8.821487426757812e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.1457672119140625e-06
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -3.337860107421875e-06
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.1457672119140625e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.1457672119140625e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -5.245208740234375e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.6226043701171875e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.291534423828125e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -3.0994415283203125e-06
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -3.0994415283203125e-06
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -3.0994415283203125e-06
# tempo final foi  -4.76837158203125e-06
# tempo final foi  -3.0994415283203125e-06
# tempo final foi  -2.1457672119140625e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -1.6689300537109375e-06
# tempo final foi  -2.1457672119140625e-06
# tempo final foi  -2.6226043701171875e-06
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -1.9073486328125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -1.430511474609375e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.1457672119140625e-06
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -1.1920928955078125e-06
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -9.5367431640625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -7.152557373046875e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -4.76837158203125e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -2.384185791015625e-07
# tempo final foi  -4.76837158203125e-07
# ...
#
# I ended up taking just a little salad, 2 niguiris and the hot part, and I found the yakissoba sauce a bit tasteless.
#
# Cost x benefit - bad.
# sentence_br  Estivemos, novamente, neste restaurante japonês localizado na Rua Augusta.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Estivemos, novamente, neste restaurante japonês localizado na Rua Augusta. : 0.0
# subjetividade
#  Estivemos, novamente, neste restaurante japonês localizado na Rua Augusta. : 0.0
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  A primeira vez que fomos, no ano passado, era recém inaugurado e gostamos bastante, entretanto, desta vez não achamos muito bom.
# sentence.sentiment.polarity:  0.352
# sentence.sentiment.subjectivity:  0.446
# Polaridade
#  A primeira vez que fomos, no ano passado, era recém inaugurado e gostamos bastante, entretanto, desta vez não achamos muito bom. : 0.352
# subjetividade
#  A primeira vez que fomos, no ano passado, era recém inaugurado e gostamos bastante, entretanto, desta vez não achamos muito bom. : 0.446
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  O sistema, no almoço, é buffet por quilo (R$ 62,90/kg) ou preço único e repete quantas vezes quiser por R$ 49,90 (preços de maio de 15) e ganha um bolinho de banana caramelizado de sobremesa.
# sentence.sentiment.polarity:  0.2142857142857143
# sentence.sentiment.subjectivity:  0.35714285714285715
# Polaridade
#  O sistema, no almoço, é buffet por quilo (R$ 62,90/kg) ou preço único e repete quantas vezes quiser por R$ 49,90 (preços de maio de 15) e ganha um bolinho de banana caramelizado de sobremesa. : 0.2142857142857143
# subjetividade
#  O sistema, no almoço, é buffet por quilo (R$ 62,90/kg) ou preço único e repete quantas vezes quiser por R$ 49,90 (preços de maio de 15) e ganha um bolinho de banana caramelizado de sobremesa. : 0.35714285714285715
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  O buffet de saladas e pratos quentes estava ok, muita variedade e boa aparência, entretanto, a decepção ficou por conta da parte de sushis, que estavam meio vazias e sem expectativa de reposição e os sashimis que estavam meio mal cortados, o que não dava uma aparência apetitosa.
# sentence.sentiment.polarity:  -0.01893939393939392
# sentence.sentiment.subjectivity:  0.484090909090909
# Polaridade
#  O buffet de saladas e pratos quentes estava ok, muita variedade e boa aparência, entretanto, a decepção ficou por conta da parte de sushis, que estavam meio vazias e sem expectativa de reposição e os sashimis que estavam meio mal cortados, o que não dava uma aparência apetitosa. : -0.01893939393939392
# subjetividade
#  O buffet de saladas e pratos quentes estava ok, muita variedade e boa aparência, entretanto, a decepção ficou por conta da parte de sushis, que estavam meio vazias e sem expectativa de reposição e os sashimis que estavam meio mal cortados, o que não dava uma aparência apetitosa. : 0.484090909090909
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  Acabei pegando somente um pouco de salada, 2 niguiris e a parte quente, sendo que achei o molho do yakissoba meio insosso.
# sentence.sentiment.polarity:  -0.17916666666666667
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Acabei pegando somente um pouco de salada, 2 niguiris e a parte quente, sendo que achei o molho do yakissoba meio insosso. : -0.17916666666666667
# subjetividade
#  Acabei pegando somente um pouco de salada, 2 niguiris e a parte quente, sendo que achei o molho do yakissoba meio insosso. : 0.75
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  Custo x benefício - ruim.
# sentence.sentiment.polarity:  -0.6999999999999998
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Custo x benefício - ruim. : -0.6999999999999998
# subjetividade
#  Custo x benefício - ruim. : 0.6666666666666666
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# tempo final foi  -5.75805401802063
# **************
#
# var 31533 x Excelente lugar com ótima comida e chopp gelado. Servem massas com vários tipos de almondegas para escolher.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  Excellent place with great food and cold draft beer.
#  They serve pasta with various types of meatballs to choose from.
# sentence_br  Excelente lugar com ótima comida e chopp gelado.
# sentence.sentiment.polarity:  0.4000000000000001
# sentence.sentiment.subjectivity:  0.9166666666666666
# Polaridade
#  Excelente lugar com ótima comida e chopp gelado. : 0.4000000000000001
# subjetividade
#  Excelente lugar com ótima comida e chopp gelado. : 0.9166666666666666
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  Servem massas com vários tipos de almondegas para escolher.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Servem massas com vários tipos de almondegas para escolher. : 0.0
# subjetividade
#  Servem massas com vários tipos de almondegas para escolher. : 0.5
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# tempo final foi  -5.784428596496582
# **************
#
# var 31534 x Ótimo preço boa comida vale a pena conhecer as vezes um pouco cheio mas tudo que e bom tem fila gostei super recomendo
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  Great price good food worth getting to know a little crowded but everything that is good has a line I liked it super recommend
# sentence_br  Ótimo preço boa comida vale a pena conhecer as vezes um pouco cheio mas tudo que e bom tem fila gostei super recomendo
# sentence.sentiment.polarity:  0.4636904761904762
# sentence.sentiment.subjectivity:  0.5738095238095239
# Polaridade
#  Ótimo preço boa comida vale a pena conhecer as vezes um pouco cheio mas tudo que e bom tem fila gostei super recomendo : 0.4636904761904762
# subjetividade
#  Ótimo preço boa comida vale a pena conhecer as vezes um pouco cheio mas tudo que e bom tem fila gostei super recomendo : 0.5738095238095239
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# tempo final foi  -5.72901177406311
# **************
#
# var 31535 x Restaurante aconchegante, grande e com diversidade no café da manhã, muitas frutas, bolos e pães, além de frios,sucos dentre outras bebida. Almoço com bastante variedade e comida local,além de um preço conveniente.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  Cozy, large restaurant with diversity for breakfast, lots of fruits, cakes and breads, as well as cold cuts, juices and other drinks.
#  Lunch with plenty of variety and local food, as well as a convenient price.
# sentence_br  Restaurante aconchegante, grande e com diversidade no café da manhã, muitas frutas, bolos e pães, além de frios,sucos dentre outras bebida.
# sentence.sentiment.polarity:  -0.1776785714285714
# sentence.sentiment.subjectivity:  0.6383928571428572
# Polaridade
#  Restaurante aconchegante, grande e com diversidade no café da manhã, muitas frutas, bolos e pães, além de frios,sucos dentre outras bebida. : -0.1776785714285714
# subjetividade
#  Restaurante aconchegante, grande e com diversidade no café da manhã, muitas frutas, bolos e pães, além de frios,sucos dentre outras bebida. : 0.6383928571428572
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  Almoço com bastante variedade e comida local,além de um preço conveniente.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Almoço com bastante variedade e comida local,além de um preço conveniente. : 0.0
# subjetividade
#  Almoço com bastante variedade e comida local,além de um preço conveniente. : 0.0
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# tempo final foi  -5.756223678588867
# **************
#
# var 31536 x Não existe lugar que venda um tambaqui mais delicioso do que o Tambaqui de Banda. Acompanhado de um maravilhoso baião, não tem nada igual.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  There is no place that sells a more delicious tambaqui than Banda Tambaqui.
#  Accompanied by a wonderful baião, there is nothing like it.
# sentence_br  Não existe lugar que venda um tambaqui mais delicioso do que o Tambaqui de Banda.
# sentence.sentiment.polarity:  0.75
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Não existe lugar que venda um tambaqui mais delicioso do que o Tambaqui de Banda. : 0.75
# subjetividade
#  Não existe lugar que venda um tambaqui mais delicioso do que o Tambaqui de Banda. : 0.75
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  Acompanhado de um maravilhoso baião, não tem nada igual.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Acompanhado de um maravilhoso baião, não tem nada igual. : 1.0
# subjetividade
#  Acompanhado de um maravilhoso baião, não tem nada igual. : 1.0
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# tempo final foi  -6.160215377807617
# **************
#
# var 31537 x Decepção total.
#
# De entrada pedimos uma agulha que não tinha nada demais, encharcada no óleo.
# Pedimos também um peixe com um molho de camarão que ninguém da mesa gostou e uma cioba com farofa de camarão que tinha muito ovo e pouquíssimo camarão.
#
# O creme de papaya com cassis estava delicioso.
#
# Não voltarei.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-83-10d8e9298ae7> in <module>
#      14             which = TextBlob(out)
#      15             print("Tipo de which language: ",type(which))
# ---> 16             lang = which.detect_language()
#      17             if lang == 'en':
#      18                 print("It is english")
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/blob.py in detect_language(self)
#     566         :rtype: str
#     567         """
# --> 568         return self.translator.detect(self.raw)
#     569
#     570     def correct(self):
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/translate.py in detect(self, source, host, type_)
#      70         data = {"q": source}
#      71         url = u'{url}&sl=auto&tk={tk}'.format(url=self.url, tk=_calculate_tk(source))
# ---> 72         response = self._request(url, host=host, type_=type_, data=data)
#      73         result, language = json.loads(response)
#      74         return language
#
# ~/anaconda3/lib/python3.7/site-packages/textblob/translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
b = TextBlob("Ambiente inovador e aconchegante, um lugar para ir muitas vezes sem enjoar ")

lang = b.detect_language()
if lang == 'en':
    print("It is enlgish ",b)
elif lang == 'pt':
    print("It is portuguese ",b)
else:
    print("Not english is ", b)
# Out:
# It is portuguese  Ambiente inovador e aconchegante, um lugar para ir muitas vezes sem enjoar

# %%
lang = b.detect_language()

# %%
print(type(lang))
print(lang)
# Out:
# <class 'str'>
# pt

# %%
if lang == 'en':
    print("It is enlgish ",b)
elif lang == 'pt':
    print("It is portuguese ",b)
else:
    print("Not english is ", b)
# Out:
# It is portuguese  Ambiente inovador e aconchegante, um lugar para ir muitas vezes sem enjoar

# %%
var = 0
errou = 0
for x in df['reviewBody']:
    ini = time.time()
    var = var + 1
    if var > 0 and var <= 1:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        #out = clean_tripadvisor("Recife: a beautiful city with a gorgeous culture. Beyond the beauties, we also have a really good food. So, do you really want to eat an awesome steak? If you love steak like I do, you need to know a perfect place. What’s the name of the place? Spettus! You’ll see more than 22 kinds of steaks, all of them prepared by excellent professionals. Steaks from Argentina and Uruguay, and you can choose any kind of steak you want. You’ll find japanese food, vegetables and delicious deserts too! What are you going to find there? A huge place (they fit 700 people), perfect for a good lunch, a dinner with the family and, of course, a happy hour with your friends. Do you like good music? Piano bar. Do you have kids? Playground. Everything you’ll find at Spettus! Do you drink? Be prepared to drink a good wine from France, Italy, Argentina and more! Oh! Do you want to surf on the internet while eating? Do you need an Internet Wi-fi? Spettus is the answer! I went there last year and it was perfect. I love steak and they have a really good variety. And, obvious, it’s delicious! Remember: Spettus!")
        out = clean_tripadvisor(x)
        #################################
        
        which = TextBlob(out)
        print("Tipo de which language: ",type(which))
        lang = which.detect_language()
        if lang == 'en':
            print("It is english")
            #################################
            #comentario_blob = TextBlob(out)
#             print("comentario_blob ",type(which))

            comentario_blob_pt = which.translate(to='pt')
            comentario_blob_us = comentario_blob_pt.translate(to='en')
            print("tipo em english ", type(which))
            print("Original em Inglês: ",which)
            print("Traduzido para Português: ",comentario_blob_pt)
            time.sleep(5)

            for sentence_br, sentence in zip(comentario_blob_pt.sentences, comentario_blob_us.sentences):
                print("sentence_br ",sentence_br)
                print(" EN sentence.sentiment.polarity: ",sentence.sentiment.polarity)
                print("EN sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
                if sentence_br is None:
                    errou = errou + 1
                    print("errou em {} - {} {}".format(var,errou,x))
                    saveDocumentError(var,errou,x)

                elif var > 0 and var <= 1:
                    print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                    print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                    saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

                else:
                    print("EN algum erro ocorreu em {}".format(var))
            ################################################
            
        elif lang == 'pt':
            print("It is portuguese: ",b)
            #################################
            comentario_blob = TextBlob(out)
            print("comentario_blob ",type(comentario_blob))

            comentario_blob_us = comentario_blob.translate(to='us')
            print("tipo em english ", type(comentario_blob_us))
            print("Inglês: ",comentario_blob_us)
            time.sleep(5)

            for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
                print("sentence_br ",sentence_br)
                print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
                print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
                if sentence_br is None:
                    errou = errou + 1
                    print("errou em {} - {} {}".format(var,errou,x))
                    saveDocumentError(var,errou,x)

                elif var > 0 and var <= 1:
                    print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                    print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                    saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

                else:
                    print("PT algum erro ocorreu em {}".format(var))
            ################################################
        else:
            print("Not english is: ", b)
        
        
    if var == 1:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 1 x Comida maravilhosa, lugar do verdadeiro chiclete de camarão.
# O garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.
# **************
#
# Tipo de which language:  <class 'textblob.blob.TextBlob'>
# It is portuguese:  Recife: a beautiful city with a gorgeous culture.
#  Beyond the beauties, we also have a really good food.
#  So, do you really want to eat an awesome steak? If you love steak like I do, you need to know a perfect place.
#  What’s the name of the place? Spettus! You’ll see more than 22 kinds of steaks, all of them prepared by excellent professionals.
#  Steaks from Argentina and Uruguay, and you can choose any kind of steak you want.
#  You’ll find japanese food, vegetables and delicious deserts too! What are you going to find there? A huge place (they fit 700 people), perfect for a good lunch, a dinner with the family and, of course, a happy hour with your friends.
#  Do you like good music? Piano bar.
#  Do you have kids? Playground.
#  Everything you’ll find at Spettus! Do you drink? Be prepared to drink a good wine from France, Italy, Argentina and more! Oh! Do you want to surf on the internet while eating? Do you need an Internet Wi-fi? Spettus is the answer! I went there last year and it was perfect.
#  I love steak and they have a really good variety.
#  And, obvious, it’s delicious! Remember: Spettus!
# comentario_blob  <class 'textblob.blob.TextBlob'>
# tipo em english  <class 'textblob.blob.TextBlob'>
# Inglês:  Wonderful food, place for real shrimp gum.
#
# The waiter Éric Lima served us very well, we intend to return as soon as possible.
# sentence_br  Comida maravilhosa, lugar do verdadeiro chiclete de camarão.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Comida maravilhosa, lugar do verdadeiro chiclete de camarão. : 0.6
# subjetividade
#  Comida maravilhosa, lugar do verdadeiro chiclete de camarão. : 0.65
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# sentence_br  O garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  O garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível. : 0.1
# subjetividade
#  O garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível. : 0.65
# It was created result:  /home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-30934-40000.txt
# Finalizou em  1
