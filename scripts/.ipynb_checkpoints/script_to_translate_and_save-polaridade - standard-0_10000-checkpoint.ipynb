# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pcorrea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 0
terminou = 10000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# Cloning into 'sentimental_ds'...
# Updating files:  90% (10/11)
# Updating files: 100% (11/11)
# Updating files: 100% (11/11), done.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  128,783,089,664 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# Find Keys:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 100000

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
#     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
#     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
    tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
    tweet = re.sub(r"\b\.", '. \n', tweet)    
    return tweet

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
for x in df['reviewBody']:
    
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
# Out:
# **************
#
# var 1 x Comida maravilhosa, lugar do verdadeiro chiclete de camarão.
# O garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.
# **************
#
# Inglês:  Wonderful food, place for real shrimp gum.
#
# The waiter Éric Lima served us very well, we intend to return as soon as possible.
# sentence_br  Comida maravilhosa, lugar do verdadeiro chiclete de camarão.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Comida maravilhosa, lugar do verdadeiro chiclete de camarão. : 0.6
# subjetividade
#  Comida maravilhosa, lugar do verdadeiro chiclete de camarão. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  O garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  O garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível. : 0.1
# subjetividade
#  O garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 2 x Comida boa, drinks legais e um ambiente bem aconchegante.
# Provamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!
# **************
#
# Inglês:  Good food, nice drinks and a very cozy atmosphere.
#
# We tried many things and everything pleased us.
#  Especially a duck served in one of the house dishes, sensational!
# sentence_br  Comida boa, drinks legais e um ambiente bem aconchegante.
# sentence.sentiment.polarity:  0.3466666666666666
# sentence.sentiment.subjectivity:  0.8583333333333334
# Polaridade
#  Comida boa, drinks legais e um ambiente bem aconchegante. : 0.3466666666666666
# subjetividade
#  Comida boa, drinks legais e um ambiente bem aconchegante. : 0.8583333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Provamos muitas coisas e tudo nos agradou.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Provamos muitas coisas e tudo nos agradou. : 0.5
# subjetividade
#  Provamos muitas coisas e tudo nos agradou. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Principalmente um pato servido em um dos pratos da casa, sensacional!
# sentence.sentiment.polarity:  0.41666666666666663
# sentence.sentiment.subjectivity:  0.8333333333333333
# Polaridade
#  Principalmente um pato servido em um dos pratos da casa, sensacional! : 0.41666666666666663
# subjetividade
#  Principalmente um pato servido em um dos pratos da casa, sensacional! : 0.8333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 3 x Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer
# **************
#
# Inglês:  Excellent to go with the family! Great food, pleasant atmosphere, good service and parking.
#  worth knowing
# sentence_br  Excelente pra ir com a família!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Excelente pra ir com a família! : 1.0
# subjetividade
#  Excelente pra ir com a família! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Ótima Comida, ambiente agradável, bom atendimento e estacionamento.
# sentence.sentiment.polarity:  0.7444444444444445
# sentence.sentiment.subjectivity:  0.7722222222222223
# Polaridade
#  Ótima Comida, ambiente agradável, bom atendimento e estacionamento. : 0.7444444444444445
# subjetividade
#  Ótima Comida, ambiente agradável, bom atendimento e estacionamento. : 0.7722222222222223
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Vale a pena conhecer
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale a pena conhecer : 0.3
# subjetividade
#  Vale a pena conhecer : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 4 x Tomo sorvete na Visabor faz mais de 30 anos. Sabores de frutas ou artificiais. Casquinha crocante e ambiente simples. Preços muito bons. Recomendo
# **************
#
# Inglês:  I have had ice cream at Visabor for over 30 years.
#  Fruit or artificial flavors.
#  Crunchy cone and simple atmosphere.
#  Very good prices.
#  I recommend
# sentence_br  Tomo sorvete na Visabor faz mais de 30 anos.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tomo sorvete na Visabor faz mais de 30 anos. : 0.0
# subjetividade
#  Tomo sorvete na Visabor faz mais de 30 anos. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Sabores de frutas ou artificiais.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Sabores de frutas ou artificiais. : -0.6
# subjetividade
#  Sabores de frutas ou artificiais. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Casquinha crocante e ambiente simples.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.35714285714285715
# Polaridade
#  Casquinha crocante e ambiente simples. : 0.0
# subjetividade
#  Casquinha crocante e ambiente simples. : 0.35714285714285715
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Preços muito bons.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Preços muito bons. : 0.9099999999999999
# subjetividade
#  Preços muito bons. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Recomendo
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo : 0.0
# subjetividade
#  Recomendo : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 5 x O melhor hamburger que já comi! Excelente atendimento, a comida estava ótima. O restaurante é bem pequeno, mas agradável e divertido.
# **************
#
# Inglês:  The best hamburger I've ever eaten! Excellent service, the food was great.
#  The restaurant is quite small, but nice and fun.
# sentence_br  O melhor hamburger que já comi!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  O melhor hamburger que já comi! : 1.0
# subjetividade
#  O melhor hamburger que já comi! : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Excelente atendimento, a comida estava ótima.
# sentence.sentiment.polarity:  0.9
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  Excelente atendimento, a comida estava ótima. : 0.9
# subjetividade
#  Excelente atendimento, a comida estava ótima. : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  O restaurante é bem pequeno, mas agradável e divertido.
# sentence.sentiment.polarity:  0.21666666666666665
# sentence.sentiment.subjectivity:  0.5333333333333333
# Polaridade
#  O restaurante é bem pequeno, mas agradável e divertido. : 0.21666666666666665
# subjetividade
#  O restaurante é bem pequeno, mas agradável e divertido. : 0.5333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 6 x O restaurante é novo, super acolhedor e charmoso com um ótimo atendimento. As porções são generosas, saborosíssimas e com preço justo. Boa variedade de vinhos. Super recomendo o espaguete de frutos do mar, bolonhesa, carbonara e o risoto. O tiramisu também é fantástico.
# Todas as vezes fui com meu namorado, mas é um excelente ambiente para levar a família ou amigos.
# **************
#
# Inglês:  The restaurant is new, super cozy and charming with great service.
#  The portions are generous, very tasty and at a fair price.
#  Good selection of wines.
#  I highly recommend the seafood spaghetti, bolognese, carbonara and risotto.
#  The tiramisu is also fantastic.
#
# Every time I went with my boyfriend, but it is an excellent environment to take family or friends.
# sentence_br  O restaurante é novo, super acolhedor e charmoso com um ótimo atendimento.
# sentence.sentiment.polarity:  0.3539393939393939
# sentence.sentiment.subjectivity:  0.7242424242424242
# Polaridade
#  O restaurante é novo, super acolhedor e charmoso com um ótimo atendimento. : 0.3539393939393939
# subjetividade
#  O restaurante é novo, super acolhedor e charmoso com um ótimo atendimento. : 0.7242424242424242
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  As porções são generosas, saborosíssimas e com preço justo.
# sentence.sentiment.polarity:  0.44999999999999996
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  As porções são generosas, saborosíssimas e com preço justo. : 0.44999999999999996
# subjetividade
#  As porções são generosas, saborosíssimas e com preço justo. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Boa variedade de vinhos.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Boa variedade de vinhos. : 0.7
# subjetividade
#  Boa variedade de vinhos. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Super recomendo o espaguete de frutos do mar, bolonhesa, carbonara e o risoto.
# sentence.sentiment.polarity:  0.16
# sentence.sentiment.subjectivity:  0.5399999999999999
# Polaridade
#  Super recomendo o espaguete de frutos do mar, bolonhesa, carbonara e o risoto. : 0.16
# subjetividade
#  Super recomendo o espaguete de frutos do mar, bolonhesa, carbonara e o risoto. : 0.5399999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  O tiramisu também é fantástico.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  O tiramisu também é fantástico. : 0.4
# subjetividade
#  O tiramisu também é fantástico. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Todas as vezes fui com meu namorado, mas é um excelente ambiente para levar a família ou amigos.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Todas as vezes fui com meu namorado, mas é um excelente ambiente para levar a família ou amigos. : 1.0
# subjetividade
#  Todas as vezes fui com meu namorado, mas é um excelente ambiente para levar a família ou amigos. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 7 x Fomos num sábado, ambiente elegante, equipe gentil e simpática. Comemos um curry bem gostoso, mas o filé não era filé. A sobremesa (wonton de abacaxi com geléia de pimenta e sorvete) estava ótima.
# **************
#
# Inglês:  We went on a Saturday, elegant atmosphere, kind and friendly staff.
#  We ate a very tasty curry, but the filet was not filet.
#  The dessert (pineapple wonton with pepper jelly and ice cream) was great.
# sentence_br  Fomos num sábado, ambiente elegante, equipe gentil e simpática.
# sentence.sentiment.polarity:  0.4916666666666667
# sentence.sentiment.subjectivity:  0.7999999999999999
# Polaridade
#  Fomos num sábado, ambiente elegante, equipe gentil e simpática. : 0.4916666666666667
# subjetividade
#  Fomos num sábado, ambiente elegante, equipe gentil e simpática. : 0.7999999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Comemos um curry bem gostoso, mas o filé não era filé.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Comemos um curry bem gostoso, mas o filé não era filé. : 0.2
# subjetividade
#  Comemos um curry bem gostoso, mas o filé não era filé. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  A sobremesa (wonton de abacaxi com geléia de pimenta e sorvete) estava ótima.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  A sobremesa (wonton de abacaxi com geléia de pimenta e sorvete) estava ótima. : 0.8
# subjetividade
#  A sobremesa (wonton de abacaxi com geléia de pimenta e sorvete) estava ótima. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 8 x Comida ótima e com bom atediamento e com muita coisa boas e da para levar a esposa e a namorada e familia pois as porções de comidas são boas!
# Muito obrigado
# **************
#
# Inglês:  Great food with good attendance and with a lot of good things to take your wife and girlfriend and family because the food portions are good!
# thank you
# sentence_br  Comida ótima e com bom atediamento e com muita coisa boas e da para levar a esposa e a namorada e familia pois as porções de comidas são boas!
# sentence.sentiment.polarity:  0.76875
# sentence.sentiment.subjectivity:  0.6375000000000001
# Polaridade
#  Comida ótima e com bom atediamento e com muita coisa boas e da para levar a esposa e a namorada e familia pois as porções de comidas são boas! : 0.76875
# subjetividade
#  Comida ótima e com bom atediamento e com muita coisa boas e da para levar a esposa e a namorada e familia pois as porções de comidas são boas! : 0.6375000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Muito obrigado
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Muito obrigado : 0.0
# subjetividade
#  Muito obrigado : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 9 x Ambiente agradável, preço totalmente acessível, e adoro o cardápio de lá! Sem falar no atendimento maravilhoso! Voltarei sempre 😘
# **************
#
# Inglês:  Nice atmosphere, totally affordable price, and I love the menu there! Not to mention the wonderful service! I will always come back 😘
# sentence_br  Ambiente agradável, preço totalmente acessível, e adoro o cardápio de lá!
# sentence.sentiment.polarity:  0.4083333333333334
# sentence.sentiment.subjectivity:  0.7833333333333333
# Polaridade
#  Ambiente agradável, preço totalmente acessível, e adoro o cardápio de lá! : 0.4083333333333334
# subjetividade
#  Ambiente agradável, preço totalmente acessível, e adoro o cardápio de lá! : 0.7833333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Sem falar no atendimento maravilhoso!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Sem falar no atendimento maravilhoso! : 1.0
# subjetividade
#  Sem falar no atendimento maravilhoso! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Voltarei sempre 😘
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Voltarei sempre 😘 : 0.0
# subjetividade
#  Voltarei sempre 😘 : 0.0
# Error did file  'charmap' codec can't encode character '\U0001f618' in position 20: character maps to <undefined>
# **************
#
# var 10 x A pizzaria é a mais tradicional de Belo Horizonte. São várias opções. Além das pizzas também tem um excepicional parmeggiana, delicioso e suculento
# **************
#
# Inglês:  The pizzeria is the most traditional in Belo Horizonte.
#  There are several options.
#  In addition to the pizzas there is also an exceptional parmeggiana, delicious and juicy
# sentence_br  A pizzaria é a mais tradicional de Belo Horizonte.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.625
# Polaridade
#  A pizzaria é a mais tradicional de Belo Horizonte. : 0.25
# subjetividade
#  A pizzaria é a mais tradicional de Belo Horizonte. : 0.625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  São várias opções.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  São várias opções. : 0.0
# subjetividade
#  São várias opções. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Além das pizzas também tem um excepicional parmeggiana, delicioso e suculento
# sentence.sentiment.polarity:  0.8333333333333333
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Além das pizzas também tem um excepicional parmeggiana, delicioso e suculento : 0.8333333333333333
# subjetividade
#  Além das pizzas também tem um excepicional parmeggiana, delicioso e suculento : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 11 x Estive com minha família essa tarde pela primeira vez me deparei com um cenário lindo e aconchegante. Comprei 1 kg de camarão GRANDE, olhei bem o rapaz pesando e escolhendo meu camarão. A decepção veio na hora que sentei na barraca e pedi pra fritar (não quero citar o nome) O camarão chegou muito saboroso mas os camarões grandes( veio na parte de cima) Quando fomos comer os de dentro tinha apenas camarões minúsculos e murchos (velhos) Como se estivessem trocado uma boa parte. Até aí tudo bem, quando o camarão acabou percebi que tinha umas 20 cabeças sem o corpo como se fosse restos... Chamei o garçom disfarçadamente e ele simplesmente se fez que não escultou e foi atender outra mesa. Me senti uma trouxa mesmo. Enfim, peço que prestem atenção, o lugar é ótimo. Eu amei, voltarei sim, mas pra comer um peixe, porque camarão só compro pra levar e fritar na minha casa.
# **************
# Inglês:  I was with my family this afternoon for the first time I came across a beautiful and cozy setting.
#  I bought 1 kg of LARGE shrimp, looked at the boy weighing and choosing my shrimp.
#  The disappointment came when I sat at the stall and asked to fry it (I don't want to mention the name) The shrimp arrived very tasty but the big prawns (it came on top) When we went to eat the inside there were only tiny shriveled shrimp (old ones) ) As if they exchanged a good part.
#  So far so good, when the shrimp finished I realized that it had about 20 heads without the body as if it were leftovers.
# .. I called the waiter undercover and he just made sure he didn't listen and went to another table.
#  I really felt like a muggle.
#  Anyway, I ask you to pay attention, the place is great.
#  I loved it, I will be back, but to eat a fish, because shrimp I only buy to take and fry at my house.
# sentence_br  Estive com minha família essa tarde pela primeira vez me deparei com um cenário lindo e aconchegante.
# sentence.sentiment.polarity:  0.30000000000000004
# sentence.sentiment.subjectivity:  0.6944444444444443
# Polaridade
#  Estive com minha família essa tarde pela primeira vez me deparei com um cenário lindo e aconchegante. : 0.30000000000000004
# subjetividade
#  Estive com minha família essa tarde pela primeira vez me deparei com um cenário lindo e aconchegante. : 0.6944444444444443
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Comprei 1 kg de camarão GRANDE, olhei bem o rapaz pesando e escolhendo meu camarão.
# sentence.sentiment.polarity:  0.21428571428571427
# sentence.sentiment.subjectivity:  0.42857142857142855
# Polaridade
#  Comprei 1 kg de camarão GRANDE, olhei bem o rapaz pesando e escolhendo meu camarão. : 0.21428571428571427
# subjetividade
#  Comprei 1 kg de camarão GRANDE, olhei bem o rapaz pesando e escolhendo meu camarão. : 0.42857142857142855
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  A decepção veio na hora que sentei na barraca e pedi pra fritar (não quero citar o nome) O camarão chegou muito saboroso mas os camarões grandes( veio na parte de cima) Quando fomos comer os de dentro tinha apenas camarões minúsculos e murchos (velhos) Como se estivessem trocado uma boa parte.
# sentence.sentiment.polarity:  0.1125
# sentence.sentiment.subjectivity:  0.45
# Polaridade
#  A decepção veio na hora que sentei na barraca e pedi pra fritar (não quero citar o nome) O camarão chegou muito saboroso mas os camarões grandes( veio na parte de cima) Quando fomos comer os de dentro tinha apenas camarões minúsculos e murchos (velhos) Como se estivessem trocado uma boa parte. : 0.1125
# subjetividade
#  A decepção veio na hora que sentei na barraca e pedi pra fritar (não quero citar o nome) O camarão chegou muito saboroso mas os camarões grandes( veio na parte de cima) Quando fomos comer os de dentro tinha apenas camarões minúsculos e murchos (velhos) Como se estivessem trocado uma boa parte. : 0.45
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Até aí tudo bem, quando o camarão acabou percebi que tinha umas 20 cabeças sem o corpo como se fosse restos.
# sentence.sentiment.polarity:  0.39999999999999997
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Até aí tudo bem, quando o camarão acabou percebi que tinha umas 20 cabeças sem o corpo como se fosse restos. : 0.39999999999999997
# subjetividade
#  Até aí tudo bem, quando o camarão acabou percebi que tinha umas 20 cabeças sem o corpo como se fosse restos. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  .. Chamei o garçom disfarçadamente e ele simplesmente se fez que não escultou e foi atender outra mesa.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  .. Chamei o garçom disfarçadamente e ele simplesmente se fez que não escultou e foi atender outra mesa. : 0.0
# subjetividade
#  .. Chamei o garçom disfarçadamente e ele simplesmente se fez que não escultou e foi atender outra mesa. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Me senti uma trouxa mesmo.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.8888888888888888
# Polaridade
#  Me senti uma trouxa mesmo. : 0.5
# subjetividade
#  Me senti uma trouxa mesmo. : 0.8888888888888888
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Enfim, peço que prestem atenção, o lugar é ótimo.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Enfim, peço que prestem atenção, o lugar é ótimo. : 0.2
# subjetividade
#  Enfim, peço que prestem atenção, o lugar é ótimo. : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Eu amei, voltarei sim, mas pra comer um peixe, porque camarão só compro pra levar e fritar na minha casa.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Eu amei, voltarei sim, mas pra comer um peixe, porque camarão só compro pra levar e fritar na minha casa. : 0.8
# subjetividade
#  Eu amei, voltarei sim, mas pra comer um peixe, porque camarão só compro pra levar e fritar na minha casa. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 12 x Fui ao La Bocca depois de ler tantos comentários elogiosos e empolgados. Antes de tudo quero dizer que não entendo o porquê de alguns criticarem tanto a localização.  É uma rua calma, residencial, cujas casinhas lembram bastante os subúrbios cariocas. Uma graça! Agora falarei da comida. Pedi o tão elogiado gnocchi de banana da terra com ragu de ossobuco. A primeira garfada é deliciosa, mas, aos poucos, torna-se enjoativo dada a ausência de nuances, texturas e camadas de sabores. O molho de ossobuco peca pelo excesso de sal. No geral, um prato correto, mas nada esplendoroso. Ressalto, entretanto, que é um oásis comer uma massa fabricada na casa nesse Rio de Janeiro povoado de massas de salgadinho de terceira congeladas disfarçadas de gnocchi.
# **************
#
# Inglês:  I went to La Bocca after reading so many complimentary and excited comments.
#  First of all, I want to say that I don't understand why some criticize the location so much.
#   It is a quiet, residential street, whose houses are very reminiscent of Rio's suburbs.
#  A grace! Now I will talk about the food.
#  I ordered the highly praised plantain gnocchi with ossobuco ragout.
#  The first mouthful is delicious, but, little by little, it becomes nauseating given the absence of nuances, textures and layers of flavors.
#  The ossobuco sauce sins the excess salt.
#  Overall, a correct dish, but nothing splendid.
#  I emphasize, however, that it is an oasis to eat pasta made at home in that Rio de Janeiro populated with frozen third-party pasta disguised as gnocchi.
# sentence_br  Fui ao La Bocca depois de ler tantos comentários elogiosos e empolgados.
# sentence.sentiment.polarity:  0.39166666666666666
# sentence.sentiment.subjectivity:  0.5833333333333334
# Polaridade
#  Fui ao La Bocca depois de ler tantos comentários elogiosos e empolgados. : 0.39166666666666666
# subjetividade
#  Fui ao La Bocca depois de ler tantos comentários elogiosos e empolgados. : 0.5833333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Antes de tudo quero dizer que não entendo o porquê de alguns criticarem tanto a localização.
# sentence.sentiment.polarity:  0.225
# sentence.sentiment.subjectivity:  0.26666666666666666
# Polaridade
#  Antes de tudo quero dizer que não entendo o porquê de alguns criticarem tanto a localização. : 0.225
# subjetividade
#  Antes de tudo quero dizer que não entendo o porquê de alguns criticarem tanto a localização. : 0.26666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  É uma rua calma, residencial, cujas casinhas lembram bastante os subúrbios cariocas.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.4916666666666667
# Polaridade
#  É uma rua calma, residencial, cujas casinhas lembram bastante os subúrbios cariocas. : 0.0
# subjetividade
#  É uma rua calma, residencial, cujas casinhas lembram bastante os subúrbios cariocas. : 0.4916666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Uma graça!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Uma graça! : 0.0
# subjetividade
#  Uma graça! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Agora falarei da comida.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Agora falarei da comida. : 0.0
# subjetividade
#  Agora falarei da comida. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Pedi o tão elogiado gnocchi de banana da terra com ragu de ossobuco.
# sentence.sentiment.polarity:  0.16
# sentence.sentiment.subjectivity:  0.5399999999999999
# Polaridade
#  Pedi o tão elogiado gnocchi de banana da terra com ragu de ossobuco. : 0.16
# subjetividade
#  Pedi o tão elogiado gnocchi de banana da terra com ragu de ossobuco. : 0.5399999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  A primeira garfada é deliciosa, mas, aos poucos, torna-se enjoativo dada a ausência de nuances, texturas e camadas de sabores.
# sentence.sentiment.polarity:  0.17250000000000001
# sentence.sentiment.subjectivity:  0.4666666666666666
# Polaridade
#  A primeira garfada é deliciosa, mas, aos poucos, torna-se enjoativo dada a ausência de nuances, texturas e camadas de sabores. : 0.17250000000000001
# subjetividade
#  A primeira garfada é deliciosa, mas, aos poucos, torna-se enjoativo dada a ausência de nuances, texturas e camadas de sabores. : 0.4666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  O molho de ossobuco peca pelo excesso de sal.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  O molho de ossobuco peca pelo excesso de sal. : 0.0
# subjetividade
#  O molho de ossobuco peca pelo excesso de sal. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  No geral, um prato correto, mas nada esplendoroso.
# sentence.sentiment.polarity:  0.4166666666666667
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  No geral, um prato correto, mas nada esplendoroso. : 0.4166666666666667
# subjetividade
#  No geral, um prato correto, mas nada esplendoroso. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Ressalto, entretanto, que é um oásis comer uma massa fabricada na casa nesse Rio de Janeiro povoado de massas de salgadinho de terceira congeladas disfarçadas de gnocchi.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Ressalto, entretanto, que é um oásis comer uma massa fabricada na casa nesse Rio de Janeiro povoado de massas de salgadinho de terceira congeladas disfarçadas de gnocchi. : 0.0
# subjetividade
#  Ressalto, entretanto, que é um oásis comer uma massa fabricada na casa nesse Rio de Janeiro povoado de massas de salgadinho de terceira congeladas disfarçadas de gnocchi. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 13 x Excelente restaurante!
# A diversidade do self servisse de altíssimo bom gosto e sabores inigualáveis!
# O único restaurante q posso consumir sushi e saschimi com total segurança alimentar!
# Sou fá numero um e super indico!
#
# **************
# Inglês:  Excellent restaurant!
# The diversity of the self served very high taste and unmatched flavors!
# The only restaurant I can eat sushi and saschimi with total food security!
# I am number one and super recommended!
# sentence_br  Excelente restaurante!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Excelente restaurante! : 1.0
# subjetividade
#  Excelente restaurante! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  A diversidade do self servisse de altíssimo bom gosto e sabores inigualáveis!
# sentence.sentiment.polarity:  0.26
# sentence.sentiment.subjectivity:  0.702
# Polaridade
#  A diversidade do self servisse de altíssimo bom gosto e sabores inigualáveis! : 0.26
# subjetividade
#  A diversidade do self servisse de altíssimo bom gosto e sabores inigualáveis! : 0.702
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  O único restaurante q posso consumir sushi e saschimi com total segurança alimentar!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  O único restaurante q posso consumir sushi e saschimi com total segurança alimentar! : 0.0
# subjetividade
#  O único restaurante q posso consumir sushi e saschimi com total segurança alimentar! : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Sou fá numero um e super indico!
# sentence.sentiment.polarity:  0.41666666666666663
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Sou fá numero um e super indico! : 0.41666666666666663
# subjetividade
#  Sou fá numero um e super indico! : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 14 x gostei tanto da comida como do atendimento, o preço é bom e o local é razoável, não tenho do que reclamar, recomendo
# **************
#
# Inglês:  I liked the food as much as the service, the price is good and the location is reasonable, I have nothing to complain about, I recommend
# sentence_br  gostei tanto da comida como do atendimento, o preço é bom e o local é razoável, não tenho do que reclamar, recomendo
# sentence.sentiment.polarity:  0.425
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  gostei tanto da comida como do atendimento, o preço é bom e o local é razoável, não tenho do que reclamar, recomendo : 0.425
# subjetividade
#  gostei tanto da comida como do atendimento, o preço é bom e o local é razoável, não tenho do que reclamar, recomendo : 0.55
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 15 x Um dos melhores restaurantes com buffet vegetariano com opções de grelhados no centro de Porto Alegre. As opções são variadas e muito bem-feitas. Sopas, sobremesas e refrescos incluídos no preço. Custo-benefício muito bom!
# **************
#
# Inglês:  One of the best restaurants with vegetarian buffet with grill options in the center of Porto Alegre.
#  The options are varied and very well done.
#  Soups, desserts and refreshments included in the price.
#  Very good value for money!
# sentence_br  Um dos melhores restaurantes com buffet vegetariano com opções de grelhados no centro de Porto Alegre.
# sentence.sentiment.polarity:  0.45
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Um dos melhores restaurantes com buffet vegetariano com opções de grelhados no centro de Porto Alegre. : 0.45
# subjetividade
#  Um dos melhores restaurantes com buffet vegetariano com opções de grelhados no centro de Porto Alegre. : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  As opções são variadas e muito bem-feitas.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  As opções são variadas e muito bem-feitas. : 0.2
# subjetividade
#  As opções são variadas e muito bem-feitas. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Sopas, sobremesas e refrescos incluídos no preço.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Sopas, sobremesas e refrescos incluídos no preço. : 0.0
# subjetividade
#  Sopas, sobremesas e refrescos incluídos no preço. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Custo-benefício muito bom!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Custo-benefício muito bom! : 1.0
# subjetividade
#  Custo-benefício muito bom! : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 16 x Tudo é bom! O chef Juarez é ótimo e um amor. Ótimo atendimento. Ótima apresentação dos pratos. Comida maravilhosa. Sobremesas incríveis. Preço bom. Sem dúvidas o meu preferido.
# **************
#
# Inglês:  Everything is good! Chef Juarez is great and a love.
#  Great service.
#  Great presentation of the dishes.
#  Wonderful food.
#  Incredible desserts.
#  Good price.
#  Without a doubt my favorite.
# sentence_br  Tudo é bom!
# sentence.sentiment.polarity:  0.875
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Tudo é bom! : 0.875
# subjetividade
#  Tudo é bom! : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  O chef Juarez é ótimo e um amor.
# sentence.sentiment.polarity:  0.65
# sentence.sentiment.subjectivity:  0.675
# Polaridade
#  O chef Juarez é ótimo e um amor. : 0.65
# subjetividade
#  O chef Juarez é ótimo e um amor. : 0.675
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Ótimo atendimento.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ótimo atendimento. : 0.8
# subjetividade
#  Ótimo atendimento. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Ótima apresentação dos pratos.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ótima apresentação dos pratos. : 0.8
# subjetividade
#  Ótima apresentação dos pratos. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Comida maravilhosa.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Comida maravilhosa. : 1.0
# subjetividade
#  Comida maravilhosa. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Sobremesas incríveis.
# sentence.sentiment.polarity:  0.9
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Sobremesas incríveis. : 0.9
# subjetividade
#  Sobremesas incríveis. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Preço bom.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Preço bom. : 0.7
# subjetividade
#  Preço bom. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Sem dúvidas o meu preferido.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Sem dúvidas o meu preferido. : 0.5
# subjetividade
#  Sem dúvidas o meu preferido. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 17 x A Família DR LASER esteve no sábado para um almoço informal... Um Grelhado bem preparado e um Buffet bem variado com um preço ok, fazem do local uma boa opção para um almoço rápido de final de semana.
# **************
#
# Inglês:  The DR LASER Family was on Saturday for an informal lunch.
# .. A well-prepared grill and a varied buffet with an ok price, make the place a good option for a quick weekend lunch.
# sentence_br  A Família DR LASER esteve no sábado para um almoço informal.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  A Família DR LASER esteve no sábado para um almoço informal. : 0.0
# subjetividade
#  A Família DR LASER esteve no sábado para um almoço informal. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  .. Um Grelhado bem preparado e um Buffet bem variado com um preço ok, fazem do local uma boa opção para um almoço rápido de final de semana.
# sentence.sentiment.polarity:  0.5111111111111111
# sentence.sentiment.subjectivity:  0.5333333333333333
# Polaridade
#  .. Um Grelhado bem preparado e um Buffet bem variado com um preço ok, fazem do local uma boa opção para um almoço rápido de final de semana. : 0.5111111111111111
# subjetividade
#  .. Um Grelhado bem preparado e um Buffet bem variado com um preço ok, fazem do local uma boa opção para um almoço rápido de final de semana. : 0.5333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 18 x Indescritível, eu nunca havia comido tapioca e resolvi experimentar justamente em Natal-RN, comi em alguns lugares, mas de longe esse foi o melhor. O único lugar que em nossa estadia fizemos questão de repetir, mesmo sabendo que poderíamos perder outra atração, mas valeu o risco de perder uma nova atração, pois este lugar é simplesmente maravilhoso. Vá preparado, pois a porção é bem servida e a sobremesa imensa! Experimentamos algumas, mas a melhor foi a de Carne de Sol com Nata! ! !
# **************
# Inglês:  Indescribable, I had never eaten tapioca and decided to try it in Natal-RN, I ate in some places, but by far this was the best.
#  The only place in our stay that we made a point of repeating, even though we knew we could lose another attraction, but it was worth the risk of losing a new attraction, because this place is just wonderful.
#  Go prepared, because the portion is well served and the dessert is huge! We tried some, but the best was Carne de Sol with Cream! ! !
# sentence_br  Indescritível, eu nunca havia comido tapioca e resolvi experimentar justamente em Natal-RN, comi em alguns lugares, mas de longe esse foi o melhor.
# sentence.sentiment.polarity:  0.55
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Indescritível, eu nunca havia comido tapioca e resolvi experimentar justamente em Natal-RN, comi em alguns lugares, mas de longe esse foi o melhor. : 0.55
# subjetividade
#  Indescritível, eu nunca havia comido tapioca e resolvi experimentar justamente em Natal-RN, comi em alguns lugares, mas de longe esse foi o melhor. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  O único lugar que em nossa estadia fizemos questão de repetir, mesmo sabendo que poderíamos perder outra atração, mas valeu o risco de perder uma nova atração, pois este lugar é simplesmente maravilhoso.
# sentence.sentiment.polarity:  0.35909090909090907
# sentence.sentiment.subjectivity:  0.6386363636363637
# Polaridade
#  O único lugar que em nossa estadia fizemos questão de repetir, mesmo sabendo que poderíamos perder outra atração, mas valeu o risco de perder uma nova atração, pois este lugar é simplesmente maravilhoso. : 0.35909090909090907
# subjetividade
#  O único lugar que em nossa estadia fizemos questão de repetir, mesmo sabendo que poderíamos perder outra atração, mas valeu o risco de perder uma nova atração, pois este lugar é simplesmente maravilhoso. : 0.6386363636363637
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Vá preparado, pois a porção é bem servida e a sobremesa imensa!
# sentence.sentiment.polarity:  0.5000000000000001
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Vá preparado, pois a porção é bem servida e a sobremesa imensa! : 0.5000000000000001
# subjetividade
#  Vá preparado, pois a porção é bem servida e a sobremesa imensa! : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Experimentamos algumas, mas a melhor foi a de Carne de Sol com Nata!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Experimentamos algumas, mas a melhor foi a de Carne de Sol com Nata! : 1.0
# subjetividade
#  Experimentamos algumas, mas a melhor foi a de Carne de Sol com Nata! : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 19 x Tinha visto as críticas e realmente esperava mais. Atendimento foi bacana e tudo bem fresquinho, mas não foi o melhor ceviche que já comi. Bem gourmetizado. A porção bem pequena.
# **************
#
# Inglês:  He had seen the criticism and really expected more.
#  The service was great and everything was fresh, but it wasn't the best ceviche I've ever had.
#  Well gourmet.
#  The very small portion.
# sentence_br  Tinha visto as críticas e realmente esperava mais.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.45
# Polaridade
#  Tinha visto as críticas e realmente esperava mais. : 0.2
# subjetividade
#  Tinha visto as críticas e realmente esperava mais. : 0.45
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Atendimento foi bacana e tudo bem fresquinho, mas não foi o melhor ceviche que já comi.
# sentence.sentiment.polarity:  0.7000000000000001
# sentence.sentiment.subjectivity:  0.5166666666666667
# Polaridade
#  Atendimento foi bacana e tudo bem fresquinho, mas não foi o melhor ceviche que já comi. : 0.7000000000000001
# subjetividade
#  Atendimento foi bacana e tudo bem fresquinho, mas não foi o melhor ceviche que já comi. : 0.5166666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Bem gourmetizado.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Bem gourmetizado. : 0.0
# subjetividade
#  Bem gourmetizado. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  A porção bem pequena.
# sentence.sentiment.polarity:  -0.325
# sentence.sentiment.subjectivity:  0.52
# Polaridade
#  A porção bem pequena. : -0.325
# subjetividade
#  A porção bem pequena. : 0.52
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 20 x Esse restaurante está situado na avenida Conde, de fácil acesso a quem está pelo centro e imediações. Mistura pratos contemporâneos com uma tendência aos da península ibérica. Experimente as entradas, por exemplo o ragu. Excelente pedida também é o  mediterrâneo . Garçons atenciosos e ambiente acolhedor nos deixa um gosto de quero- mais. Vale a visita.
# **************
#
# Inglês:  This restaurant is located on Avenida Conde, easily accessible to those in the center and the surrounding area.
#  It mixes contemporary dishes with a tendency to those of the Iberian peninsula.
#  Try the starters, for example the ragout.
#  An excellent choice is also the Mediterranean. Attentive waiters and warm atmosphere leave us with a taste for more.
#  Worth the visit.
# sentence_br  Esse restaurante está situado na avenida Conde, de fácil acesso a quem está pelo centro e imediações.
# sentence.sentiment.polarity:  0.1375
# sentence.sentiment.subjectivity:  0.2375
# Polaridade
#  Esse restaurante está situado na avenida Conde, de fácil acesso a quem está pelo centro e imediações. : 0.1375
# subjetividade
#  Esse restaurante está situado na avenida Conde, de fácil acesso a quem está pelo centro e imediações. : 0.2375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Mistura pratos contemporâneos com uma tendência aos da península ibérica.
# sentence.sentiment.polarity:  0.16666666666666666
# sentence.sentiment.subjectivity:  0.16666666666666666
# Polaridade
#  Mistura pratos contemporâneos com uma tendência aos da península ibérica. : 0.16666666666666666
# subjetividade
#  Mistura pratos contemporâneos com uma tendência aos da península ibérica. : 0.16666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Experimente as entradas, por exemplo o ragu.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Experimente as entradas, por exemplo o ragu. : 0.0
# subjetividade
#  Experimente as entradas, por exemplo o ragu. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Excelente pedida também é o  mediterrâneo .
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Excelente pedida também é o  mediterrâneo . : 1.0
# subjetividade
#  Excelente pedida também é o  mediterrâneo . : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Garçons atenciosos e ambiente acolhedor nos deixa um gosto de quero- mais.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Garçons atenciosos e ambiente acolhedor nos deixa um gosto de quero- mais. : 0.5
# subjetividade
#  Garçons atenciosos e ambiente acolhedor nos deixa um gosto de quero- mais. : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Vale a visita.
# ...
# subjetividade
#  O serviço é bom, as entradas( empanadas, chorizo fatiado e linguiça)muito boas. : 0.6900000000000002
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Pedimos as carnes para 2 pessoas.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Pedimos as carnes para 2 pessoas. : 0.0
# subjetividade
#  Pedimos as carnes para 2 pessoas. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Como frequentamos outras parrillas, como Argentina, Pobre Juan etc, achei que o bife de chorizo viria conforme sempre comemos aqui e fora do país= corte alto.
# sentence.sentiment.polarity:  0.03375
# sentence.sentiment.subjectivity:  0.31625000000000003
# Polaridade
#  Como frequentamos outras parrillas, como Argentina, Pobre Juan etc, achei que o bife de chorizo viria conforme sempre comemos aqui e fora do país= corte alto. : 0.03375
# subjetividade
#  Como frequentamos outras parrillas, como Argentina, Pobre Juan etc, achei que o bife de chorizo viria conforme sempre comemos aqui e fora do país= corte alto. : 0.31625000000000003
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Para nossa surpresa, os cortes do chorizo e ancho para 2 são extremamente finos, tirando toda aquela empolgação da imagem que já levamos na cabeça ao pedir carne de parrilla.
# sentence.sentiment.polarity:  -0.4
# sentence.sentiment.subjectivity:  0.8500000000000001
# Polaridade
#  Para nossa surpresa, os cortes do chorizo e ancho para 2 são extremamente finos, tirando toda aquela empolgação da imagem que já levamos na cabeça ao pedir carne de parrilla. : -0.4
# subjetividade
#  Para nossa surpresa, os cortes do chorizo e ancho para 2 são extremamente finos, tirando toda aquela empolgação da imagem que já levamos na cabeça ao pedir carne de parrilla. : 0.8500000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Sempre imaginamos os cortes altos, com a crosta gelada e interior vermelho.
# sentence.sentiment.polarity:  -0.14666666666666664
# sentence.sentiment.subjectivity:  0.5133333333333333
# Polaridade
#  Sempre imaginamos os cortes altos, com a crosta gelada e interior vermelho. : -0.14666666666666664
# subjetividade
#  Sempre imaginamos os cortes altos, com a crosta gelada e interior vermelho. : 0.5133333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Nada disso.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Nada disso. : 0.0
# subjetividade
#  Nada disso. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  A carne vem fina igual aquela que fazemos em casa na frigideira.
# sentence.sentiment.polarity:  -0.4
# sentence.sentiment.subjectivity:  0.8500000000000001
# Polaridade
#  A carne vem fina igual aquela que fazemos em casa na frigideira. : -0.4
# subjetividade
#  A carne vem fina igual aquela que fazemos em casa na frigideira. : 0.8500000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Menos mal pois o sabor é bom.
# sentence.sentiment.polarity:  -0.055555555555555504
# sentence.sentiment.subjectivity:  0.4444444444444445
# Polaridade
#  Menos mal pois o sabor é bom. : -0.055555555555555504
# subjetividade
#  Menos mal pois o sabor é bom. : 0.4444444444444445
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Mas, sabemos que, de acordo com o jeito que cortamos, a carne muda o sabor.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Mas, sabemos que, de acordo com o jeito que cortamos, a carne muda o sabor. : 0.0
# subjetividade
#  Mas, sabemos que, de acordo com o jeito que cortamos, a carne muda o sabor. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Se forem visitar este restaurante, peça a carne com bife alto.
# sentence.sentiment.polarity:  0.16
# sentence.sentiment.subjectivity:  0.5399999999999999
# Polaridade
#  Se forem visitar este restaurante, peça a carne com bife alto. : 0.16
# subjetividade
#  Se forem visitar este restaurante, peça a carne com bife alto. : 0.5399999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Deu a impressão que eles pegaram meio chorizo e ainda cortaram ao meio na horizontal e cobraram preço de 2.
# sentence.sentiment.polarity:  -0.16666666666666666
# sentence.sentiment.subjectivity:  0.16666666666666666
# Polaridade
#  Deu a impressão que eles pegaram meio chorizo e ainda cortaram ao meio na horizontal e cobraram preço de 2. : -0.16666666666666666
# subjetividade
#  Deu a impressão que eles pegaram meio chorizo e ainda cortaram ao meio na horizontal e cobraram preço de 2. : 0.16666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 1342 x Comi um sanduba novo. O frango bacon sublime! é realmente sublime! muito saboroso. E ainda bebi uma coca delícia de 500ml
# **************
# Inglês:  I ate a new sanduba.
#  The sublime bacon chicken! it's really sublime! very tasty.
#  And I still drank a delicious 500ml coca
# sentence_br  Comi um sanduba novo.
# sentence.sentiment.polarity:  0.13636363636363635
# sentence.sentiment.subjectivity:  0.45454545454545453
# Polaridade
#  Comi um sanduba novo. : 0.13636363636363635
# subjetividade
#  Comi um sanduba novo. : 0.45454545454545453
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  O frango bacon sublime!
# sentence.sentiment.polarity:  -0.75
# sentence.sentiment.subjectivity:  0.95
# Polaridade
#  O frango bacon sublime! : -0.75
# subjetividade
#  O frango bacon sublime! : 0.95
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  é realmente sublime!
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  é realmente sublime! : 0.25
# subjetividade
#  é realmente sublime! : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  muito saboroso.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  muito saboroso. : 0.2
# subjetividade
#  muito saboroso. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  E ainda bebi uma coca delícia de 500ml
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  E ainda bebi uma coca delícia de 500ml : 1.0
# subjetividade
#  E ainda bebi uma coca delícia de 500ml : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 1343 x Atendimento excelente, o melhor sushi de campo grande e mais variado com ótima localização e o preço compensa muito 🌟👏👏👏
# **************
#
# Inglês:  Excellent service, the best large and varied sushi in a great location and the price is very worth it 🌟👏👏👏
# sentence_br  Atendimento excelente, o melhor sushi de campo grande e mais variado com ótima localização e o preço compensa muito 🌟👏👏👏
# sentence.sentiment.polarity:  0.6808571428571428
# sentence.sentiment.subjectivity:  0.5217142857142857
# Polaridade
#  Atendimento excelente, o melhor sushi de campo grande e mais variado com ótima localização e o preço compensa muito 🌟👏👏👏 : 0.6808571428571428
# subjetividade
#  Atendimento excelente, o melhor sushi de campo grande e mais variado com ótima localização e o preço compensa muito 🌟👏👏👏 : 0.5217142857142857
# Error did file  'charmap' codec can't encode characters in position 123-126: character maps to <undefined>
# **************
#
# var 1344 x Atendimento do Fernando muito bom e atencioso. Prato delicioso (Camarao internacional) e música aconchegante.
# **************
#
# Inglês:  Fernando's service was very good and attentive.
#  Delicious dish (Camarao internacional) and cozy music.
# sentence_br  Atendimento do Fernando muito bom e atencioso.
# sentence.sentiment.polarity:  0.655
# sentence.sentiment.subjectivity:  0.8400000000000001
# Polaridade
#  Atendimento do Fernando muito bom e atencioso. : 0.655
# subjetividade
#  Atendimento do Fernando muito bom e atencioso. : 0.8400000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Prato delicioso (Camarao internacional) e música aconchegante.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  Prato delicioso (Camarao internacional) e música aconchegante. : 0.4
# subjetividade
#  Prato delicioso (Camarao internacional) e música aconchegante. : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 1345 x Restaurante a beira mar, belo ambiente, atendimento correto. Pratos para duas pessoas são fartos e deliciosos. Comi uma carne de sol na abóbora que estava ótima. Quanto fui tinha música ao vivo.
# **************
#
# Inglês:  Restaurant by the sea, beautiful atmosphere, correct service.
#  Dishes for two are hearty and delicious.
#  I had some sun meat on the pumpkin which was great.
#  When I went there was live music.
# sentence_br  Restaurante a beira mar, belo ambiente, atendimento correto.
# sentence.sentiment.polarity:  0.85
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Restaurante a beira mar, belo ambiente, atendimento correto. : 0.85
# subjetividade
#  Restaurante a beira mar, belo ambiente, atendimento correto. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Pratos para duas pessoas são fartos e deliciosos.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Pratos para duas pessoas são fartos e deliciosos. : 1.0
# subjetividade
#  Pratos para duas pessoas são fartos e deliciosos. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Comi uma carne de sol na abóbora que estava ótima.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Comi uma carne de sol na abóbora que estava ótima. : 0.8
# subjetividade
#  Comi uma carne de sol na abóbora que estava ótima. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# sentence_br  Quanto fui tinha música ao vivo.
# sentence.sentiment.polarity:  0.13636363636363635
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Quanto fui tinha música ao vivo. : 0.13636363636363635
# subjetividade
#  Quanto fui tinha música ao vivo. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-0-10000.txt
# **************
#
# var 1346 x Ótimo restaurante. Boa comida, ambiente de alto padrão. Mas o que mais surpreendeu foram os sucos. Tem combinações incríveis e conseguem fazer eles virem com tons diferentes, de cada fruta, excelente!
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-22-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
