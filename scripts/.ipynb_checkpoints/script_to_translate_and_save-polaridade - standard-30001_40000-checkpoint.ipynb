# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pcorrea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 30000
terminou = 40000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  127,708,372,992 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 100000

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
for x in df['reviewBody']:
    ini = time.time()
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 30001 x Fui neste restaurante pelas avaliações, mas foi uma decepção. Assim que chegamos observamos um ambiente escuro e talheres colocados na mesa sem nenhuma proteção higiênica, o cardápio é de um papel grosso e estava sujo de provavelmente alguma comida, eles deviam pelo menos plastificar para manter a higiene, o garçom muito atencioso nos explicou o cardápio, pedimos uma entrada de queijo de cabra e presunto parma, mas recebemos outra entrada de pão italiano recheado com um creme de queijo com pedaços de carne, só que não tinha nenhum sabor de queijo, parecia um estrogonofe razoável. Em seguida chegou o prato principal, risoto com pera e gorgonzola e medalhões de filé, que pedimos para dividir e este estava razoável, quando pedimos a conta a mesma veio errada, cobrando as duas entradas, a de queijo e a do pão, e cobrando também uma taxa de divisão do prato, taxa esta que não foi mencionada pelo garçom.
# **************
#
# Inglês:  I went to this restaurant for the reviews, but it was a disappointment.
#  As soon as we arrived we observed a dark environment and cutlery placed on the table without any hygienic protection, the menu is made of thick paper and was dirty with probably some food, they should at least laminate to maintain hygiene, the very attentive waiter explained the menu to us , we ordered a starter of goat cheese and parma ham, but we received another starter of italian bread stuffed with a cream cheese with pieces of meat, only it had no cheese flavor, it seemed like a reasonable stroganoff.
#  Then came the main course, risotto with pear and gorgonzola and filet medallions, which we asked to share and this was reasonable, when we asked for the bill it came wrong, charging both starters, cheese and bread, and charging also a dish sharing fee, which was not mentioned by the waiter.
# sentence_br  Fui neste restaurante pelas avaliações, mas foi uma decepção.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Fui neste restaurante pelas avaliações, mas foi uma decepção. : -0.6
# subjetividade
#  Fui neste restaurante pelas avaliações, mas foi uma decepção. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Assim que chegamos observamos um ambiente escuro e talheres colocados na mesa sem nenhuma proteção higiênica, o cardápio é de um papel grosso e estava sujo de provavelmente alguma comida, eles deviam pelo menos plastificar para manter a higiene, o garçom muito atencioso nos explicou o cardápio, pedimos uma entrada de queijo de cabra e presunto parma, mas recebemos outra entrada de pão italiano recheado com um creme de queijo com pedaços de carne, só que não tinha nenhum sabor de queijo, parecia um estrogonofe razoável.
# sentence.sentiment.polarity:  -0.07875000000000001
# sentence.sentiment.subjectivity:  0.584375
# Polaridade
#  Assim que chegamos observamos um ambiente escuro e talheres colocados na mesa sem nenhuma proteção higiênica, o cardápio é de um papel grosso e estava sujo de provavelmente alguma comida, eles deviam pelo menos plastificar para manter a higiene, o garçom muito atencioso nos explicou o cardápio, pedimos uma entrada de queijo de cabra e presunto parma, mas recebemos outra entrada de pão italiano recheado com um creme de queijo com pedaços de carne, só que não tinha nenhum sabor de queijo, parecia um estrogonofe razoável. : -0.07875000000000001
# subjetividade
#  Assim que chegamos observamos um ambiente escuro e talheres colocados na mesa sem nenhuma proteção higiênica, o cardápio é de um papel grosso e estava sujo de provavelmente alguma comida, eles deviam pelo menos plastificar para manter a higiene, o garçom muito atencioso nos explicou o cardápio, pedimos uma entrada de queijo de cabra e presunto parma, mas recebemos outra entrada de pão italiano recheado com um creme de queijo com pedaços de carne, só que não tinha nenhum sabor de queijo, parecia um estrogonofe razoável. : 0.584375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Em seguida chegou o prato principal, risoto com pera e gorgonzola e medalhões de filé, que pedimos para dividir e este estava razoável, quando pedimos a conta a mesma veio errada, cobrando as duas entradas, a de queijo e a do pão, e cobrando também uma taxa de divisão do prato, taxa esta que não foi mencionada pelo garçom.
# sentence.sentiment.polarity:  -0.04444444444444443
# sentence.sentiment.subjectivity:  0.6111111111111112
# Polaridade
#  Em seguida chegou o prato principal, risoto com pera e gorgonzola e medalhões de filé, que pedimos para dividir e este estava razoável, quando pedimos a conta a mesma veio errada, cobrando as duas entradas, a de queijo e a do pão, e cobrando também uma taxa de divisão do prato, taxa esta que não foi mencionada pelo garçom. : -0.04444444444444443
# subjetividade
#  Em seguida chegou o prato principal, risoto com pera e gorgonzola e medalhões de filé, que pedimos para dividir e este estava razoável, quando pedimos a conta a mesma veio errada, cobrando as duas entradas, a de queijo e a do pão, e cobrando também uma taxa de divisão do prato, taxa esta que não foi mencionada pelo garçom. : 0.6111111111111112
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30002 x Ambiente agradável, atendimento atencioso e comida deliciosa. O polvo grelhado e a carne de cordeiro estavam uma delícia!
# **************
#
# Inglês:  Pleasant atmosphere, attentive service and delicious food.
#  The grilled octopus and lamb were delicious!
# sentence_br  Ambiente agradável, atendimento atencioso e comida deliciosa.
# sentence.sentiment.polarity:  0.7111111111111111
# sentence.sentiment.subjectivity:  0.9555555555555556
# Polaridade
#  Ambiente agradável, atendimento atencioso e comida deliciosa. : 0.7111111111111111
# subjetividade
#  Ambiente agradável, atendimento atencioso e comida deliciosa. : 0.9555555555555556
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  O polvo grelhado e a carne de cordeiro estavam uma delícia!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O polvo grelhado e a carne de cordeiro estavam uma delícia! : 1.0
# subjetividade
#  O polvo grelhado e a carne de cordeiro estavam uma delícia! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30003 x Lugar simples....sem estacionamento....comida boa todos os dias
# Boa variedade de pratos e saladas...com boas opcoes  de carnes...comida por kilo ...43.90 o kilo.... excelente opção para um almoco rapido..a gelatina é sobremesa grauita todos os fias....
# **************
#
# Inglês:  Simple place.
# ... without parking.
# ... good food every day
# Good range of dishes and salads.
# ..with good meat options.
# ..food by kilo ... 43.
# 90 kilo.
# ... excellent option for a quick lunch.
# .the gelatine is a dessert of all kinds.
# ...
# sentence_br  Lugar simples.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.35714285714285715
# Polaridade
#  Lugar simples. : 0.0
# subjetividade
#  Lugar simples. : 0.35714285714285715
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ...sem estacionamento.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ...sem estacionamento. : 0.0
# subjetividade
#  ...sem estacionamento. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ...comida boa todos os dias
# Boa variedade de pratos e saladas.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  ...comida boa todos os dias
# Boa variedade de pratos e saladas. : 0.7
# subjetividade
#  ...comida boa todos os dias
# Boa variedade de pratos e saladas. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ..com boas opcoes  de carnes.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  ..com boas opcoes  de carnes. : 0.7
# subjetividade
#  ..com boas opcoes  de carnes. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ..comida por kilo ...43.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ..comida por kilo ...43. : 0.0
# subjetividade
#  ..comida por kilo ...43. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  90 o kilo.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  90 o kilo. : 0.0
# subjetividade
#  90 o kilo. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ... excelente opção para um almoco rapido.
# sentence.sentiment.polarity:  0.6666666666666666
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  ... excelente opção para um almoco rapido. : 0.6666666666666666
# subjetividade
#  ... excelente opção para um almoco rapido. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  .a gelatina é sobremesa grauita todos os fias.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  .a gelatina é sobremesa grauita todos os fias. : 0.0
# subjetividade
#  .a gelatina é sobremesa grauita todos os fias. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ...
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ... : 0.0
# subjetividade
#  ... : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30004 x O sanduíche é bom e possui um bom custo, como em todas as lojas do Subway. O atendimento, porém, deixa bastante a desejar, o que também é muito comum em outras lojas do Subway. Em alguns horários, a fila chegar a se estender até a rua.
# **************
#
# Inglês:  The sandwich is good and has a good cost, as in all Subway stores.
#  The service, however, leaves a lot to be desired, which is also very common in other Subway stores.
#  At certain times, the queue can even reach the street.
# sentence_br  O sanduíche é bom e possui um bom custo, como em todas as lojas do Subway.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  O sanduíche é bom e possui um bom custo, como em todas as lojas do Subway. : 0.7
# subjetividade
#  O sanduíche é bom e possui um bom custo, como em todas as lojas do Subway. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  O atendimento, porém, deixa bastante a desejar, o que também é muito comum em outras lojas do Subway.
# sentence.sentiment.polarity:  -0.2575
# sentence.sentiment.subjectivity:  0.5125
# Polaridade
#  O atendimento, porém, deixa bastante a desejar, o que também é muito comum em outras lojas do Subway. : -0.2575
# subjetividade
#  O atendimento, porém, deixa bastante a desejar, o que também é muito comum em outras lojas do Subway. : 0.5125
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Em alguns horários, a fila chegar a se estender até a rua.
# sentence.sentiment.polarity:  0.21428571428571427
# sentence.sentiment.subjectivity:  0.5714285714285714
# Polaridade
#  Em alguns horários, a fila chegar a se estender até a rua. : 0.21428571428571427
# subjetividade
#  Em alguns horários, a fila chegar a se estender até a rua. : 0.5714285714285714
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30005 x Estive no restaurante durante a semana no almoço. Como já passava das 14h, fui atendida prontamente e a opção escolhida chegou rapidamente à mesa: filé mignon com arroz, feijão, salada e mandioca cremosa. Recomendo muito essa última opção, crocante por fora e incrivelmente cremosa por dentro. Realmente uma delicia!!! Não experimentei os espetos que dão nome à casa, mas o filé estava bem temperado, saboroso e no ponto que eu gosto, mais para o bem passado. Pedi também um suco de maracujá, que chegou bem gelado, conforme solicitado.
# O serviço é básico, não espere muito. Recomendo.
# **************
#
# Inglês:  I was at the restaurant during the week for lunch.
#  As it was after 2:00 pm, I was promptly answered and the chosen option quickly arrived at the table: filet mignon with rice, beans, salad and creamy cassava.
#  I highly recommend this last option, crispy on the outside and incredibly creamy on the inside.
#  Really a delight !!! I didn't try the skewers that give the house its name, but the filet was well seasoned, tasty and in the way I like it, more for the good past.
#  I also ordered a passion fruit juice, which arrived very cold, as requested.
#
# The service is basic, don't expect too much.
#  I recommend.
# sentence_br  Estive no restaurante durante a semana no almoço.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Estive no restaurante durante a semana no almoço. : 0.0
# subjetividade
#  Estive no restaurante durante a semana no almoço. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Como já passava das 14h, fui atendida prontamente e a opção escolhida chegou rapidamente à mesa: filé mignon com arroz, feijão, salada e mandioca cremosa.
# sentence.sentiment.polarity:  0.3333333333333333
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Como já passava das 14h, fui atendida prontamente e a opção escolhida chegou rapidamente à mesa: filé mignon com arroz, feijão, salada e mandioca cremosa. : 0.3333333333333333
# subjetividade
#  Como já passava das 14h, fui atendida prontamente e a opção escolhida chegou rapidamente à mesa: filé mignon com arroz, feijão, salada e mandioca cremosa. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Recomendo muito essa última opção, crocante por fora e incrivelmente cremosa por dentro.
# sentence.sentiment.polarity:  0.265
# sentence.sentiment.subjectivity:  0.38916666666666666
# Polaridade
#  Recomendo muito essa última opção, crocante por fora e incrivelmente cremosa por dentro. : 0.265
# subjetividade
#  Recomendo muito essa última opção, crocante por fora e incrivelmente cremosa por dentro. : 0.38916666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Realmente uma delicia!!!
# sentence.sentiment.polarity:  0.390625
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Realmente uma delicia!!! : 0.390625
# subjetividade
#  Realmente uma delicia!!! : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Não experimentei os espetos que dão nome à casa, mas o filé estava bem temperado, saboroso e no ponto que eu gosto, mais para o bem passado.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Não experimentei os espetos que dão nome à casa, mas o filé estava bem temperado, saboroso e no ponto que eu gosto, mais para o bem passado. : 0.3
# subjetividade
#  Não experimentei os espetos que dão nome à casa, mas o filé estava bem temperado, saboroso e no ponto que eu gosto, mais para o bem passado. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Pedi também um suco de maracujá, que chegou bem gelado, conforme solicitado.
# sentence.sentiment.polarity:  -0.78
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Pedi também um suco de maracujá, que chegou bem gelado, conforme solicitado. : -0.78
# subjetividade
#  Pedi também um suco de maracujá, que chegou bem gelado, conforme solicitado. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  O serviço é básico, não espere muito.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.1625
# Polaridade
#  O serviço é básico, não espere muito. : 0.1
# subjetividade
#  O serviço é básico, não espere muito. : 0.1625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Recomendo.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo. : 0.0
# subjetividade
#  Recomendo. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30006 x A comida deliciosa! Fiquei um bom tempo por lá e foi a melhor e mais barata refeição. Ar condicionado, atendimento excelente. Recomendo
# **************
# Inglês:  The food was delicious! I stayed there for a long time and it was the best and cheapest meal.
#  Air conditioning, excellent service.
#  I recommend
# sentence_br  A comida deliciosa!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  A comida deliciosa! : 1.0
# subjetividade
#  A comida deliciosa! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Fiquei um bom tempo por lá e foi a melhor e mais barata refeição.
# sentence.sentiment.polarity:  0.475
# sentence.sentiment.subjectivity:  0.35
# Polaridade
#  Fiquei um bom tempo por lá e foi a melhor e mais barata refeição. : 0.475
# subjetividade
#  Fiquei um bom tempo por lá e foi a melhor e mais barata refeição. : 0.35
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Ar condicionado, atendimento excelente.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Ar condicionado, atendimento excelente. : 1.0
# subjetividade
#  Ar condicionado, atendimento excelente. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Recomendo
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo : 0.0
# subjetividade
#  Recomendo : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30007 x Local de fácil acesso, seguro, discreto, comida muito boa e ótimo atendimento. Lembre-se de chegar com antecedência nos finais de semana, pois costuma ser muito cheio.
# **************
#
# Inglês:  Easy access, safe, discreet, very good food and great service.
#  Remember to arrive in advance on weekends, as it is usually very crowded.
# sentence_br  Local de fácil acesso, seguro, discreto, comida muito boa e ótimo atendimento.
# sentence.sentiment.polarity:  0.6608333333333334
# sentence.sentiment.subjectivity:  0.7158333333333334
# Polaridade
#  Local de fácil acesso, seguro, discreto, comida muito boa e ótimo atendimento. : 0.6608333333333334
# subjetividade
#  Local de fácil acesso, seguro, discreto, comida muito boa e ótimo atendimento. : 0.7158333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Lembre-se de chegar com antecedência nos finais de semana, pois costuma ser muito cheio.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Lembre-se de chegar com antecedência nos finais de semana, pois costuma ser muito cheio. : 0.2
# subjetividade
#  Lembre-se de chegar com antecedência nos finais de semana, pois costuma ser muito cheio. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30008 x Muito gostoso, uma fartura, achei muito barato pelo tanto de comida que vem nos combos que pode ser comido por 3 ou 5 pessoas. Muito bom mesmo.
# **************
#
# Inglês:  Very tasty, plentiful, I found it very cheap because of the amount of food that comes in combos that can be eaten by 3 or 5 people.
#  Really good.
# sentence_br  Muito gostoso, uma fartura, achei muito barato pelo tanto de comida que vem nos combos que pode ser comido por 3 ou 5 pessoas.
# sentence.sentiment.polarity:  0.36
# sentence.sentiment.subjectivity:  0.605
# Polaridade
#  Muito gostoso, uma fartura, achei muito barato pelo tanto de comida que vem nos combos que pode ser comido por 3 ou 5 pessoas. : 0.36
# subjetividade
#  Muito gostoso, uma fartura, achei muito barato pelo tanto de comida que vem nos combos que pode ser comido por 3 ou 5 pessoas. : 0.605
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Muito bom mesmo.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Muito bom mesmo. : 0.7
# subjetividade
#  Muito bom mesmo. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30009 x Massas, no plural, pq todas são deliciosas! O local é pequeno mas a atenção dos meninos compensa! Preço justo dos pratos com exceção do buffet de antepastos (delicioso) mas mto caro.
# **************
#
# Inglês:  Pasta, in the plural, because they are all delicious! The place is small but the boys' attention pays off! Fair price of the dishes with the exception of the antipasti buffet (delicious) but very expensive.
# sentence_br  Massas, no plural, pq todas são deliciosas!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Massas, no plural, pq todas são deliciosas! : 1.0
# subjetividade
#  Massas, no plural, pq todas são deliciosas! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  O local é pequeno mas a atenção dos meninos compensa!
# sentence.sentiment.polarity:  -0.3125
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  O local é pequeno mas a atenção dos meninos compensa! : -0.3125
# subjetividade
#  O local é pequeno mas a atenção dos meninos compensa! : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Preço justo dos pratos com exceção do buffet de antepastos (delicioso) mas mto caro.
# sentence.sentiment.polarity:  0.3499999999999999
# sentence.sentiment.subjectivity:  0.9366666666666665
# Polaridade
#  Preço justo dos pratos com exceção do buffet de antepastos (delicioso) mas mto caro. : 0.3499999999999999
# subjetividade
#  Preço justo dos pratos com exceção do buffet de antepastos (delicioso) mas mto caro. : 0.9366666666666665
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30010 x Comida boa, muitas variedades nos pratos, otimo atendimento, ambiente agradável. As vezes tem pianista para animar ainda mais.
# **************
#
# Inglês:  Good food, many varieties in the dishes, great service, pleasant atmosphere.
#  Sometimes there is a pianist to animate even more.
# sentence_br  Comida boa, muitas variedades nos pratos, otimo atendimento, ambiente agradável.
# sentence.sentiment.polarity:  0.6833333333333333
# sentence.sentiment.subjectivity:  0.7041666666666667
# Polaridade
#  Comida boa, muitas variedades nos pratos, otimo atendimento, ambiente agradável. : 0.6833333333333333
# subjetividade
#  Comida boa, muitas variedades nos pratos, otimo atendimento, ambiente agradável. : 0.7041666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  As vezes tem pianista para animar ainda mais.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  As vezes tem pianista para animar ainda mais. : 0.5
# subjetividade
#  As vezes tem pianista para animar ainda mais. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30011 x É o meu preferido da praça maior do Midway para almoço. Porém eles nunca variam o cardápio e, por isso, tenho evitado. O suco de laranja sempre esteve bom.
# **************
#
# Inglês:  It is my favorite of the largest square in the Midway for lunch.
#  However they never vary the menu and, therefore, I have avoided.
#  Orange juice has always been good.
# sentence_br  É o meu preferido da praça maior do Midway para almoço.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  É o meu preferido da praça maior do Midway para almoço. : 0.5
# subjetividade
#  É o meu preferido da praça maior do Midway para almoço. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Porém eles nunca variam o cardápio e, por isso, tenho evitado.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Porém eles nunca variam o cardápio e, por isso, tenho evitado. : 0.0
# subjetividade
#  Porém eles nunca variam o cardápio e, por isso, tenho evitado. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  O suco de laranja sempre esteve bom.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  O suco de laranja sempre esteve bom. : 0.7
# subjetividade
#  O suco de laranja sempre esteve bom. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30012 x O café é delicioso e todo desenhado com chantilly. Aconchegante e as meninas são super atenciosas. Vale a pena dar uma paradinha lá. E tem umas tortas maravilhosas
# **************
# Inglês:  The coffee is delicious and all designed with whipped cream.
#  Cozy and the girls are super attentive.
#  It's worth a stop there.
#  And there are wonderful pies
# sentence_br  O café é delicioso e todo desenhado com chantilly.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O café é delicioso e todo desenhado com chantilly. : 1.0
# subjetividade
#  O café é delicioso e todo desenhado com chantilly. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Aconchegante e as meninas são super atenciosas.
# sentence.sentiment.polarity:  0.17777777777777778
# sentence.sentiment.subjectivity:  0.7722222222222221
# Polaridade
#  Aconchegante e as meninas são super atenciosas. : 0.17777777777777778
# subjetividade
#  Aconchegante e as meninas são super atenciosas. : 0.7722222222222221
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Vale a pena dar uma paradinha lá.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale a pena dar uma paradinha lá. : 0.3
# subjetividade
#  Vale a pena dar uma paradinha lá. : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  E tem umas tortas maravilhosas
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  E tem umas tortas maravilhosas : 1.0
# subjetividade
#  E tem umas tortas maravilhosas : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30013 x Atendimento excelente, croissants fresquinhos, bem recheados e muito saborosos. O médio é um tamanho ótimo para o salgado e o pequeno é mais que suficiente pro doce. É caro mas vale cada centavo. Recomendo.
# **************
#
# Inglês:  Excellent service, fresh croissants, well stuffed and very tasty.
#  Medium is a great size for salty and small is more than enough for sweet.
#  It is expensive but worth every penny.
#  I recommend.
# sentence_br  Atendimento excelente, croissants fresquinhos, bem recheados e muito saborosos.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Atendimento excelente, croissants fresquinhos, bem recheados e muito saborosos. : 0.5
# subjetividade
#  Atendimento excelente, croissants fresquinhos, bem recheados e muito saborosos. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  O médio é um tamanho ótimo para o salgado e o pequeno é mais que suficiente pro doce.
# sentence.sentiment.polarity:  0.27999999999999997
# sentence.sentiment.subjectivity:  0.5599999999999999
# Polaridade
#  O médio é um tamanho ótimo para o salgado e o pequeno é mais que suficiente pro doce. : 0.27999999999999997
# subjetividade
#  O médio é um tamanho ótimo para o salgado e o pequeno é mais que suficiente pro doce. : 0.5599999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  É caro mas vale cada centavo.
# sentence.sentiment.polarity:  -0.1
# sentence.sentiment.subjectivity:  0.39999999999999997
# Polaridade
#  É caro mas vale cada centavo. : -0.1
# subjetividade
#  É caro mas vale cada centavo. : 0.39999999999999997
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Recomendo.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo. : 0.0
# subjetividade
#  Recomendo. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30014 x A Simplicidade de Juarez entra nos pratos com toda sofisticação embutida, deliciosa refeição e excelente ambiente para conversar e aproveitar o paladar que só o chef é capaz de criar com sus inusitadas misturas!!!
# **************
#
# Inglês:  The Simplicity of Juarez enters the dishes with all the sophistication built in, a delicious meal and an excellent atmosphere to chat and enjoy the taste that only the chef is able to create with his unusual mixes !!!
# sentence_br  A Simplicidade de Juarez entra nos pratos com toda sofisticação embutida, deliciosa refeição e excelente ambiente para conversar e aproveitar o paladar que só o chef é capaz de criar com sus inusitadas misturas!!
# sentence.sentiment.polarity:  0.5354166666666667
# sentence.sentiment.subjectivity:  0.8541666666666666
# Polaridade
#  A Simplicidade de Juarez entra nos pratos com toda sofisticação embutida, deliciosa refeição e excelente ambiente para conversar e aproveitar o paladar que só o chef é capaz de criar com sus inusitadas misturas!! : 0.5354166666666667
# subjetividade
#  A Simplicidade de Juarez entra nos pratos com toda sofisticação embutida, deliciosa refeição e excelente ambiente para conversar e aproveitar o paladar que só o chef é capaz de criar com sus inusitadas misturas!! : 0.8541666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30015 x O melhor rodízio de camarão do Brasil!!!!!!! Super recomendo!!!! Clima maravilhoso, vista privilegiada e todos os tipos de camarão que vocês podem imaginar! Perfeito!
# **************
#
# Inglês:  The best prawn carvery in Brazil !!!!!!! Super recommend !!!! Wonderful climate, privileged view and all kinds of shrimp you can imagine! Perfect!
# sentence_br  O melhor rodízio de camarão do Brasil!!!!!!!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  O melhor rodízio de camarão do Brasil!!!!!!! : 1.0
# subjetividade
#  O melhor rodízio de camarão do Brasil!!!!!!! : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Super recomendo!!!!
# sentence.sentiment.polarity:  0.8138020833333331
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Super recomendo!!!! : 0.8138020833333331
# subjetividade
#  Super recomendo!!!! : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Clima maravilhoso, vista privilegiada e todos os tipos de camarão que vocês podem imaginar!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Clima maravilhoso, vista privilegiada e todos os tipos de camarão que vocês podem imaginar! : 1.0
# subjetividade
#  Clima maravilhoso, vista privilegiada e todos os tipos de camarão que vocês podem imaginar! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Perfeito!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Perfeito! : 1.0
# subjetividade
#  Perfeito! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30016 x Excelente serviço , garçons atenciosos, várias opções de comidas, tempero delicioso, decoração bem criativa, bem localizado, estacionamento amplo é tudo de bom!!!!
# **************
#
# Inglês:  Excellent service, attentive waiters, several food options, delicious seasoning, very creative decor, well located, ample parking is all good !!!!
# sentence_br  Excelente serviço , garçons atenciosos, várias opções de comidas, tempero delicioso, decoração bem criativa, bem localizado, estacionamento amplo é tudo de bom!!!
# sentence.sentiment.polarity:  0.6749999999999999
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Excelente serviço , garçons atenciosos, várias opções de comidas, tempero delicioso, decoração bem criativa, bem localizado, estacionamento amplo é tudo de bom!!! : 0.6749999999999999
# subjetividade
#  Excelente serviço , garçons atenciosos, várias opções de comidas, tempero delicioso, decoração bem criativa, bem localizado, estacionamento amplo é tudo de bom!!! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30017 x Pedimos risoto de camarão que apesar de não estar no padrão italiano , estava bom e serviu 3 pessoas . O ambiente é acolhedor e ótimo atendimento . A mousse de bacuri estava excelente !
# **************
# Inglês:  We ordered shrimp risotto which, despite not being in the Italian standard, was good and served 3 people. The atmosphere is welcoming and great service. The bacuri mousse was excellent!
# sentence_br  Pedimos risoto de camarão que apesar de não estar no padrão italiano , estava bom e serviu 3 pessoas .
# sentence.sentiment.polarity:  0.2333333333333333
# sentence.sentiment.subjectivity:  0.20000000000000004
# Polaridade
#  Pedimos risoto de camarão que apesar de não estar no padrão italiano , estava bom e serviu 3 pessoas . : 0.2333333333333333
# subjetividade
#  Pedimos risoto de camarão que apesar de não estar no padrão italiano , estava bom e serviu 3 pessoas . : 0.20000000000000004
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  O ambiente é acolhedor e ótimo atendimento .
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  O ambiente é acolhedor e ótimo atendimento . : 0.8
# subjetividade
#  O ambiente é acolhedor e ótimo atendimento . : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  A mousse de bacuri estava excelente !
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  A mousse de bacuri estava excelente ! : 1.0
# subjetividade
#  A mousse de bacuri estava excelente ! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30018 x Ambiente climatizado, possui brinquedo pra criança,aceita cartão de crédito, sovertes finos o chocolate nevado é divino.,sem contar com o de tapioca e açaí...
# **************
#
# Inglês:  Air-conditioned environment, has a toy for children, accepts credit card, fine goods, snowy chocolate is divine.
# , not counting tapioca and açaí.
# ..
# sentence_br  Ambiente climatizado, possui brinquedo pra criança,aceita cartão de crédito, sovertes finos o chocolate nevado é divino.
# sentence.sentiment.polarity:  0.4166666666666667
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Ambiente climatizado, possui brinquedo pra criança,aceita cartão de crédito, sovertes finos o chocolate nevado é divino. : 0.4166666666666667
# subjetividade
#  Ambiente climatizado, possui brinquedo pra criança,aceita cartão de crédito, sovertes finos o chocolate nevado é divino. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ,sem contar com o de tapioca e açaí.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ,sem contar com o de tapioca e açaí. : 0.0
# subjetividade
#  ,sem contar com o de tapioca e açaí. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ..
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  .. : 0.0
# subjetividade
#  .. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30019 x Ambiente tão aconchegante que a gente nem se lembra estar dentro de um shopping. Cardápio incrível e atendimento idem. O risoto de arroz negro com camarões é simplesmente indescritível o sabor.
# **************
#
# Inglês:  Such a cozy atmosphere that we don't even remember being inside a mall.
#  Incredible menu and ditto service.
#  The risotto of black rice with prawns is simply indescribable the flavor.
# sentence_br  Ambiente tão aconchegante que a gente nem se lembra estar dentro de um shopping.
# sentence.sentiment.polarity:  -0.09999999999999999
# sentence.sentiment.subjectivity:  0.625
# Polaridade
#  Ambiente tão aconchegante que a gente nem se lembra estar dentro de um shopping. : -0.09999999999999999
# subjetividade
#  Ambiente tão aconchegante que a gente nem se lembra estar dentro de um shopping. : 0.625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Cardápio incrível e atendimento idem.
# sentence.sentiment.polarity:  0.9
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Cardápio incrível e atendimento idem. : 0.9
# subjetividade
#  Cardápio incrível e atendimento idem. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  O risoto de arroz negro com camarões é simplesmente indescritível o sabor.
# sentence.sentiment.polarity:  -0.08333333333333333
# sentence.sentiment.subjectivity:  0.3952380952380953
# Polaridade
#  O risoto de arroz negro com camarões é simplesmente indescritível o sabor. : -0.08333333333333333
# subjetividade
#  O risoto de arroz negro com camarões é simplesmente indescritível o sabor. : 0.3952380952380953
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30020 x atimo atendimento, limpeza nota 10, banheiro limpo e comida sabor caseira.. muito tempero e muito cheirosa tambem
# **************
#
# Inglês:  great service, clean note 10, clean bathroom and homemade food.
# . very spicy and very fragrant too
# sentence_br  atimo atendimento, limpeza nota 10, banheiro limpo e comida sabor caseira.
# sentence.sentiment.polarity:  0.5111111111111112
# sentence.sentiment.subjectivity:  0.7166666666666668
# Polaridade
#  atimo atendimento, limpeza nota 10, banheiro limpo e comida sabor caseira. : 0.5111111111111112
# subjetividade
#  atimo atendimento, limpeza nota 10, banheiro limpo e comida sabor caseira. : 0.7166666666666668
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  .
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  . : 0.0
# subjetividade
#  . : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  muito tempero e muito cheirosa tambem
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  muito tempero e muito cheirosa tambem : 0.2
# subjetividade
#  muito tempero e muito cheirosa tambem : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30021 x pão árabe muito gostoso e a maionese temperada uma das melhores que já comi  uma delicia super recomento, milkshake de ovomaltine também.
# **************
#
# Inglês:  very tasty Arab bread and spiced mayonnaise one of the best I've ever eaten, I recommend it, ovomaltine milkshake too.
# sentence_br  pão árabe muito gostoso e a maionese temperada uma das melhores que já comi  uma delicia super recomento, milkshake de ovomaltine também.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  pão árabe muito gostoso e a maionese temperada uma das melhores que já comi  uma delicia super recomento, milkshake de ovomaltine também. : 0.6
# subjetividade
#  pão árabe muito gostoso e a maionese temperada uma das melhores que já comi  uma delicia super recomento, milkshake de ovomaltine também. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30022 x Ótimo lugar, clima muito bom
# Ótimas bebidas, de quarta e domingo tem dança do ventre, fiquei no camarote vip, ótimo lugar, pois vc consegue ver tudo lá de cima, o teto abre, muito show.
# **************
#
# Inglês:  Great place, very good weather
# Great drinks, Wednesday and Sunday there is belly dancing, I stayed in the VIP box, great place, because you can see everything from up there, the roof opens, a lot of shows.
# sentence_br  Ótimo lugar, clima muito bom
# Ótimas bebidas, de quarta e domingo tem dança do ventre, fiquei no camarote vip, ótimo lugar, pois vc consegue ver tudo lá de cima, o teto abre, muito show.
# sentence.sentiment.polarity:  0.8274999999999999
# sentence.sentiment.subjectivity:  0.7575000000000001
# Polaridade
#  Ótimo lugar, clima muito bom
# Ótimas bebidas, de quarta e domingo tem dança do ventre, fiquei no camarote vip, ótimo lugar, pois vc consegue ver tudo lá de cima, o teto abre, muito show. : 0.8274999999999999
# subjetividade
#  Ótimo lugar, clima muito bom
# Ótimas bebidas, de quarta e domingo tem dança do ventre, fiquei no camarote vip, ótimo lugar, pois vc consegue ver tudo lá de cima, o teto abre, muito show. : 0.7575000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30023 x Otima decoracao, atendimento feito pelo gilson pereira exelente,comida muito saborosa vale o preço!!!!!
# **************
# Inglês:  Great decor, excellent service by gilson pereira, very tasty food is worth the price !!!!!
# sentence_br  Otima decoracao, atendimento feito pelo gilson pereira exelente,comida muito saborosa vale o preço!!!!
# sentence.sentiment.polarity:  0.68310546875
# sentence.sentiment.subjectivity:  0.5375
# Polaridade
#  Otima decoracao, atendimento feito pelo gilson pereira exelente,comida muito saborosa vale o preço!!!! : 0.68310546875
# subjetividade
#  Otima decoracao, atendimento feito pelo gilson pereira exelente,comida muito saborosa vale o preço!!!! : 0.5375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30024 x Fui comemorar meu aniversário lá com família e gostamos muito. Por estarem participando do week, estavam cheios, com fila de espera, mas prontamente conseguiram mais cadeiras, apesar de nosso grupo ser grande. Alguns garçons nem um pouco prestativos, mas outros sim, o que me deixou feliz. Destaque para o risoto de salmão, maravilhoso.
# **************
#
# Inglês:  I went to celebrate my birthday there with family and we really enjoyed it.
#  As they were participating in the week, they were full, with a queue, but they quickly got more seats, despite our large group.
#  Some waiters were not at all helpful, but others were, which made me happy.
#  Highlight for the salmon risotto, wonderful.
# sentence_br  Fui comemorar meu aniversário lá com família e gostamos muito.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  Fui comemorar meu aniversário lá com família e gostamos muito. : 0.5
# subjetividade
#  Fui comemorar meu aniversário lá com família e gostamos muito. : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Por estarem participando do week, estavam cheios, com fila de espera, mas prontamente conseguiram mais cadeiras, apesar de nosso grupo ser grande.
# sentence.sentiment.polarity:  0.3494047619047619
# sentence.sentiment.subjectivity:  0.49464285714285716
# Polaridade
#  Por estarem participando do week, estavam cheios, com fila de espera, mas prontamente conseguiram mais cadeiras, apesar de nosso grupo ser grande. : 0.3494047619047619
# subjetividade
#  Por estarem participando do week, estavam cheios, com fila de espera, mas prontamente conseguiram mais cadeiras, apesar de nosso grupo ser grande. : 0.49464285714285716
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Alguns garçons nem um pouco prestativos, mas outros sim, o que me deixou feliz.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Alguns garçons nem um pouco prestativos, mas outros sim, o que me deixou feliz. : 0.8
# subjetividade
#  Alguns garçons nem um pouco prestativos, mas outros sim, o que me deixou feliz. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Destaque para o risoto de salmão, maravilhoso.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Destaque para o risoto de salmão, maravilhoso. : 1.0
# subjetividade
#  Destaque para o risoto de salmão, maravilhoso. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30025 x Ambiente muito agradável, bem localizado, ótimo serviço. Cardápio bem bolado com sugestão  entradinhas legais. Nossa pedida foi brie c geleia ( pedimos uma cesta de pão já q não acompanhava ),   Brusqueta q estava boa só q pelo preço poderia ser mais bem servida ( veio apenas uma fatia grande ). Os pratos principais muito bem preparados, se não pedir entrada e estiver faminto, pode ser que ache pouca comida. Recomendo e volto.
# **************
#
# Inglês:  Very pleasant atmosphere, well located, great service.
#  Well thought out menu with a suggestion for cool entradinhas.
#  Our order was brie and jam (we asked for a basket of bread since it wasn’t enough), Brusqueta was good only for the price it could be better served (only a big slice came). The main dishes are very well prepared, if you do not ask for starter and you are hungry, you may find little food.
#  Recommend and come back.
# sentence_br  Ambiente muito agradável, bem localizado, ótimo serviço.
# sentence.sentiment.polarity:  0.8766666666666667
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  Ambiente muito agradável, bem localizado, ótimo serviço. : 0.8766666666666667
# subjetividade
#  Ambiente muito agradável, bem localizado, ótimo serviço. : 0.875
# ...
#  Estive no restaurante Tia Neuza para almoçar em Novembro/2015, num dia de semana com meu marido após verificar boas indicações aqui no Tripadvisor. : 0.7
# subjetividade
#  Estive no restaurante Tia Neuza para almoçar em Novembro/2015, num dia de semana com meu marido após verificar boas indicações aqui no Tripadvisor. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Foi um pouco difícil de localizá-lo, as placas não indicam ao certo onde é, tem que parar para perguntar.
# sentence.sentiment.polarity:  -0.3125
# sentence.sentiment.subjectivity:  0.7962962962962963
# Polaridade
#  Foi um pouco difícil de localizá-lo, as placas não indicam ao certo onde é, tem que parar para perguntar. : -0.3125
# subjetividade
#  Foi um pouco difícil de localizá-lo, as placas não indicam ao certo onde é, tem que parar para perguntar. : 0.7962962962962963
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Estava vazio, ficamos um pouco apreensivos de parar mesmo ali, mas ao ver a vista que o local proporcionava, nos apaixonamos.
# sentence.sentiment.polarity:  0.12455357142857143
# sentence.sentiment.subjectivity:  0.5339285714285714
# Polaridade
#  Estava vazio, ficamos um pouco apreensivos de parar mesmo ali, mas ao ver a vista que o local proporcionava, nos apaixonamos. : 0.12455357142857143
# subjetividade
#  Estava vazio, ficamos um pouco apreensivos de parar mesmo ali, mas ao ver a vista que o local proporcionava, nos apaixonamos. : 0.5339285714285714
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Linda vista, cor do mar incrível, ondas não muito agitadas e praia super vazia.
# sentence.sentiment.polarity:  0.35666666666666663
# sentence.sentiment.subjectivity:  0.6533333333333333
# Polaridade
#  Linda vista, cor do mar incrível, ondas não muito agitadas e praia super vazia. : 0.35666666666666663
# subjetividade
#  Linda vista, cor do mar incrível, ondas não muito agitadas e praia super vazia. : 0.6533333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  A comida estava muito gostosa, um prato serve muito bem até 3 pessoas , suave no sal e preço acessível.
# sentence.sentiment.polarity:  0.43333333333333335
# sentence.sentiment.subjectivity:  0.5499999999999999
# Polaridade
#  A comida estava muito gostosa, um prato serve muito bem até 3 pessoas , suave no sal e preço acessível. : 0.43333333333333335
# subjetividade
#  A comida estava muito gostosa, um prato serve muito bem até 3 pessoas , suave no sal e preço acessível. : 0.5499999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Atendimento simples, mas nada a reclamar.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.35714285714285715
# Polaridade
#  Atendimento simples, mas nada a reclamar. : 0.0
# subjetividade
#  Atendimento simples, mas nada a reclamar. : 0.35714285714285715
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30932 x Fala pessoal tudo bem ?
# Nós gostamos muito do restaurante! Muito bom , Não temos o que falar  ....gostaríamos de ir todos os dias ! Atendimento 100%
# Comida 100%
#  Parabéns....
# **************
# Inglês:  Hey guys, how are you?
# We really like the restaurant! Very good, we have nothing to say .... we would like to go every day! Service 100%
# Food 100%
#  Congratulations.
# ...
# sentence_br  Fala pessoal tudo bem ?
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Fala pessoal tudo bem ? : 0.0
# subjetividade
#  Fala pessoal tudo bem ? : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Nós gostamos muito do restaurante!
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Nós gostamos muito do restaurante! : 0.25
# subjetividade
#  Nós gostamos muito do restaurante! : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Muito bom , Não temos o que falar  ....gostaríamos de ir todos os dias !
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Muito bom , Não temos o que falar  ....gostaríamos de ir todos os dias ! : 1.0
# subjetividade
#  Muito bom , Não temos o que falar  ....gostaríamos de ir todos os dias ! : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Atendimento 100%
# Comida 100%
#  Parabéns.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Atendimento 100%
# Comida 100%
#  Parabéns. : 0.0
# subjetividade
#  Atendimento 100%
# Comida 100%
#  Parabéns. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  ...
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ... : 0.0
# subjetividade
#  ... : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30933 x Restaurante bom para passar uma noite e ir com a família. Mas ainda tem como melhorar e sofisticar o espaço.
# **************
#
# Inglês:  Good restaurant to spend an evening and go with the family.
#  But there is still room to improve and sophisticate the space.
# sentence_br  Restaurante bom para passar uma noite e ir com a família.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Restaurante bom para passar uma noite e ir com a família. : 0.7
# subjetividade
#  Restaurante bom para passar uma noite e ir com a família. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Mas ainda tem como melhorar e sofisticar o espaço.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Mas ainda tem como melhorar e sofisticar o espaço. : 0.0
# subjetividade
#  Mas ainda tem como melhorar e sofisticar o espaço. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30934 x Atendimento atencioso, pratos sempre com a mesma ótima qualidade. Inclusive antes de colocar o couvert na mesa perguntam se queremos. Idem p a inclusão do serviço na conta. Belo exemplo a ser seguido por outros restaurantes que se propõe a ser do mesmo padrão. Preços muito honestos. Enfim, se explica porque a tradição existe há tantos anos. Percebe-se que é daqueles restaurantes onde a proposta é ser profissional. Diferentes daqueles que abrem como novidade pra ver se emplaca .
# **************
#
# Inglês:  Attentive service, dishes always with the same great quality.
#  Even before putting the cover on the table, they ask if we want it.
#  Ditto p the inclusion of the service in the account.
#  Beautiful example to be followed by other restaurants that are set to be of the same standard.
#  Very honest prices.
#  Finally, it explains why the tradition has existed for so many years.
#  It is noticed that it is one of those restaurants where the proposal is to be professional.
#  Different from the ones that open as a novelty to see if it is available.
# sentence_br  Atendimento atencioso, pratos sempre com a mesma ótima qualidade.
# sentence.sentiment.polarity:  0.4000000000000001
# sentence.sentiment.subjectivity:  0.5916666666666667
# Polaridade
#  Atendimento atencioso, pratos sempre com a mesma ótima qualidade. : 0.4000000000000001
# subjetividade
#  Atendimento atencioso, pratos sempre com a mesma ótima qualidade. : 0.5916666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Inclusive antes de colocar o couvert na mesa perguntam se queremos.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Inclusive antes de colocar o couvert na mesa perguntam se queremos. : 0.0
# subjetividade
#  Inclusive antes de colocar o couvert na mesa perguntam se queremos. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Idem p a inclusão do serviço na conta.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Idem p a inclusão do serviço na conta. : 0.0
# subjetividade
#  Idem p a inclusão do serviço na conta. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Belo exemplo a ser seguido por outros restaurantes que se propõe a ser do mesmo padrão.
# sentence.sentiment.polarity:  0.18125
# sentence.sentiment.subjectivity:  0.375
# Polaridade
#  Belo exemplo a ser seguido por outros restaurantes que se propõe a ser do mesmo padrão. : 0.18125
# subjetividade
#  Belo exemplo a ser seguido por outros restaurantes que se propõe a ser do mesmo padrão. : 0.375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Preços muito honestos.
# sentence.sentiment.polarity:  0.78
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Preços muito honestos. : 0.78
# subjetividade
#  Preços muito honestos. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Enfim, se explica porque a tradição existe há tantos anos.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Enfim, se explica porque a tradição existe há tantos anos. : 0.25
# subjetividade
#  Enfim, se explica porque a tradição existe há tantos anos. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Percebe-se que é daqueles restaurantes onde a proposta é ser profissional.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Percebe-se que é daqueles restaurantes onde a proposta é ser profissional. : 0.1
# subjetividade
#  Percebe-se que é daqueles restaurantes onde a proposta é ser profissional. : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# sentence_br  Diferentes daqueles que abrem como novidade pra ver se emplaca .
# sentence.sentiment.polarity:  0.13333333333333333
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Diferentes daqueles que abrem como novidade pra ver se emplaca . : 0.13333333333333333
# subjetividade
#  Diferentes daqueles que abrem como novidade pra ver se emplaca . : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-30000-40000.txt
# **************
#
# var 30935 x Nos indicaram este restaurante para fazer um pit stop antes de irmos assistir o jogo do Brasil x Itália na copa das confederações e fomos surpreendidos com o sabor e a qualidade da comida. Tem varias opções de comida caseira e também de entradas onde destaco o pastel e tem também a famosa cachaça de gengibre como aperitivo.O atendimento foi bom a cerveja estava bem gelada,gostamos muito tanto que voltamos outras vezes.
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
