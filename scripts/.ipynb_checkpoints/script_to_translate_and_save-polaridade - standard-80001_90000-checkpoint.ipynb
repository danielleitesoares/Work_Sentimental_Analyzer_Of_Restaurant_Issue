# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pcorrea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 80000
terminou = 90000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  123,352,125,440 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 164522

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
ini = time.time()
for x in df['reviewBody']:
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 80001 x Lugar ótimo para ir com os amigos e familiares, sanduíches deliciosos e acompanhados de molhos divinos, indicado para gosta de comer pois os sanduíches são gigantes.
# **************
#
# Inglês:  Great place to go with friends and family, delicious sandwiches and accompanied by divine sauces, suitable for people who like to eat because the sandwiches are huge.
# sentence_br  Lugar ótimo para ir com os amigos e familiares, sanduíches deliciosos e acompanhados de molhos divinos, indicado para gosta de comer pois os sanduíches são gigantes.
# sentence.sentiment.polarity:  0.6875
# sentence.sentiment.subjectivity:  0.85
# Polaridade
#  Lugar ótimo para ir com os amigos e familiares, sanduíches deliciosos e acompanhados de molhos divinos, indicado para gosta de comer pois os sanduíches são gigantes. : 0.6875
# subjetividade
#  Lugar ótimo para ir com os amigos e familiares, sanduíches deliciosos e acompanhados de molhos divinos, indicado para gosta de comer pois os sanduíches são gigantes. : 0.85
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80002 x Outback no Pátio Savassi é o melhor de Belo Horizonte. Os atendentes são super educados, indicam os melhores pratos e bebidas. Além de tudo o pedido não demora para chegar! Recomendo demais!
# **************
#
# Inglês:  Outback at Pátio Savassi is the best in Belo Horizonte.
#  The attendants are super polite, indicate the best dishes and drinks.
#  After all, the order does not take long to arrive! I highly recommend it!
# sentence_br  Outback no Pátio Savassi é o melhor de Belo Horizonte.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Outback no Pátio Savassi é o melhor de Belo Horizonte. : 1.0
# subjetividade
#  Outback no Pátio Savassi é o melhor de Belo Horizonte. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Os atendentes são super educados, indicam os melhores pratos e bebidas.
# sentence.sentiment.polarity:  0.6666666666666666
# sentence.sentiment.subjectivity:  0.4833333333333333
# Polaridade
#  Os atendentes são super educados, indicam os melhores pratos e bebidas. : 0.6666666666666666
# subjetividade
#  Os atendentes são super educados, indicam os melhores pratos e bebidas. : 0.4833333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Além de tudo o pedido não demora para chegar!
# sentence.sentiment.polarity:  -0.0625
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Além de tudo o pedido não demora para chegar! : -0.0625
# subjetividade
#  Além de tudo o pedido não demora para chegar! : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Recomendo demais!
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.5399999999999999
# Polaridade
#  Recomendo demais! : 0.2
# subjetividade
#  Recomendo demais! : 0.5399999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80003 x Um dos melhores lugares que conheci em Fortaleza.
# Para mim que era turista não foi tão fácil de encontrar, pois a pizzaria não fica tão próximo a orla de iracema, onde estava hospedado. Mas no fim deu tudo certo.
#
# O serviço é de primeira, os garçons atenciosos e sempre disponíveis para repor a bebida ou servir o cliente. O grande diferencial é que nela come-se utilizando as mãos (com luvas de plástico) como do modo original italiano. A pizza estava uma delícia (camarão e peperoni).
# Ficou a vontade de ter retornado lá.
# **************
#
# Inglês:  One of the best places I met in Fortaleza.
#
# For me as a tourist it was not so easy to find, because the pizzeria is not so close to the edge of iracema, where I was staying.
#  But in the end everything worked out.
#
#
# The service is top notch, the waiters are attentive and always available to replace the drink or serve the customer.
#  The big difference is that it is eaten using the hands (with plastic gloves) as in the original Italian way.
#  The pizza was delicious (shrimp and peperoni).
# He wanted to have returned there.
# sentence_br  Um dos melhores lugares que conheci em Fortaleza.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Um dos melhores lugares que conheci em Fortaleza. : 1.0
# subjetividade
#  Um dos melhores lugares que conheci em Fortaleza. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Para mim que era turista não foi tão fácil de encontrar, pois a pizzaria não fica tão próximo a orla de iracema, onde estava hospedado.
# sentence.sentiment.polarity:  0.43333333333333335
# sentence.sentiment.subjectivity:  0.8333333333333334
# Polaridade
#  Para mim que era turista não foi tão fácil de encontrar, pois a pizzaria não fica tão próximo a orla de iracema, onde estava hospedado. : 0.43333333333333335
# subjetividade
#  Para mim que era turista não foi tão fácil de encontrar, pois a pizzaria não fica tão próximo a orla de iracema, onde estava hospedado. : 0.8333333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Mas no fim deu tudo certo.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Mas no fim deu tudo certo. : 0.0
# subjetividade
#  Mas no fim deu tudo certo. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  O serviço é de primeira, os garçons atenciosos e sempre disponíveis para repor a bebida ou servir o cliente.
# sentence.sentiment.polarity:  0.43333333333333335
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  O serviço é de primeira, os garçons atenciosos e sempre disponíveis para repor a bebida ou servir o cliente. : 0.43333333333333335
# subjetividade
#  O serviço é de primeira, os garçons atenciosos e sempre disponíveis para repor a bebida ou servir o cliente. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  O grande diferencial é que nela come-se utilizando as mãos (com luvas de plástico) como do modo original italiano.
# sentence.sentiment.polarity:  0.125
# sentence.sentiment.subjectivity:  0.2833333333333333
# Polaridade
#  O grande diferencial é que nela come-se utilizando as mãos (com luvas de plástico) como do modo original italiano. : 0.125
# subjetividade
#  O grande diferencial é que nela come-se utilizando as mãos (com luvas de plástico) como do modo original italiano. : 0.2833333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  A pizza estava uma delícia (camarão e peperoni).
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  A pizza estava uma delícia (camarão e peperoni). : 1.0
# subjetividade
#  A pizza estava uma delícia (camarão e peperoni). : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Ficou a vontade de ter retornado lá.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Ficou a vontade de ter retornado lá. : 0.0
# subjetividade
#  Ficou a vontade de ter retornado lá. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80004 x Ambiente bem romântico, atendimento um pouco lento mas atencioso.
# Comida japonesa abrasileirada de forma equilibrada, sem se deixar dominar por goiabada ou calda de maracujá!
# Provei deus sobremesas e ambas eram boas :)
# **************
#
# Inglês:  Very romantic atmosphere, service a little slow but attentive.
#
# Japanese food in a balanced way, without being dominated by guava or passion fruit syrup!
# I tasted god desserts and both were good :)
# sentence_br  Ambiente bem romântico, atendimento um pouco lento mas atencioso.
# sentence.sentiment.polarity:  -0.021875000000000006
# sentence.sentiment.subjectivity:  0.6124999999999999
# Polaridade
#  Ambiente bem romântico, atendimento um pouco lento mas atencioso. : -0.021875000000000006
# subjetividade
#  Ambiente bem romântico, atendimento um pouco lento mas atencioso. : 0.6124999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Comida japonesa abrasileirada de forma equilibrada, sem se deixar dominar por goiabada ou calda de maracujá!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Comida japonesa abrasileirada de forma equilibrada, sem se deixar dominar por goiabada ou calda de maracujá! : 0.0
# subjetividade
#  Comida japonesa abrasileirada de forma equilibrada, sem se deixar dominar por goiabada ou calda de maracujá! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Provei deus sobremesas e ambas eram boas :)
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Provei deus sobremesas e ambas eram boas :) : 0.6
# subjetividade
#  Provei deus sobremesas e ambas eram boas :) : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80005 x O restaurante é bonito e bem decorado, o atendimento foi excelente, tanto dos garçons, recepcionista, maître. Todos atenciosos e eficientes. A bruscheta de entrada estava perfeita e os pratos muito saborosos. A carta de vinhos é boa! Recomendo a visita!!!
# **************
# Inglês:  The restaurant is beautiful and well decorated, the service was excellent, both from the waiters, receptionist, maitre d '.
#  All attentive and efficient.
#  The starter bruschetta was perfect and the dishes very tasty.
#  The wine list is good! Highly recommend the visit !!!
# sentence_br  O restaurante é bonito e bem decorado, o atendimento foi excelente, tanto dos garçons, recepcionista, maître.
# sentence.sentiment.polarity:  0.925
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O restaurante é bonito e bem decorado, o atendimento foi excelente, tanto dos garçons, recepcionista, maître. : 0.925
# subjetividade
#  O restaurante é bonito e bem decorado, o atendimento foi excelente, tanto dos garçons, recepcionista, maître. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Todos atenciosos e eficientes.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Todos atenciosos e eficientes. : 0.4
# subjetividade
#  Todos atenciosos e eficientes. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  A bruscheta de entrada estava perfeita e os pratos muito saborosos.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  A bruscheta de entrada estava perfeita e os pratos muito saborosos. : 0.6
# subjetividade
#  A bruscheta de entrada estava perfeita e os pratos muito saborosos. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  A carta de vinhos é boa!
# sentence.sentiment.polarity:  0.875
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  A carta de vinhos é boa! : 0.875
# subjetividade
#  A carta de vinhos é boa! : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Recomendo a visita!!
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.5399999999999999
# Polaridade
#  Recomendo a visita!! : 0.25
# subjetividade
#  Recomendo a visita!! : 0.5399999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80006 x Churrascaria com um ótimo buffet quente e frio, com várias opções, inclusive sobremesa.
# As carnes de ótima qualidade e muito bem assadas! O galeto muito bem temperado e o pernil de cordeiro também!
# Variedade bacana, sem muitas invenções, mas trazendo o necessário para um bom churrasco.
# Atendimento muito bom, com garçons educados e gerência preocupada com o bem estar do cliente.
# Preço justo pela qualidade e atendimento.
# **************
#
# Inglês:  Steakhouse with a great hot and cold buffet, with several options, including dessert.
#
# The meat of great quality and very well roasted! The well seasoned chicken and the lamb shank too!
# Nice variety, without many inventions, but bringing the necessary for a good barbecue.
#
# Very good service, with polite waiters and management concerned with the well being of the customer.
#
# Fair price for quality and service.
# sentence_br  Churrascaria com um ótimo buffet quente e frio, com várias opções, inclusive sobremesa.
# sentence.sentiment.polarity:  0.11250000000000002
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Churrascaria com um ótimo buffet quente e frio, com várias opções, inclusive sobremesa. : 0.11250000000000002
# subjetividade
#  Churrascaria com um ótimo buffet quente e frio, com várias opções, inclusive sobremesa. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  As carnes de ótima qualidade e muito bem assadas!
# sentence.sentiment.polarity:  0.525
# sentence.sentiment.subjectivity:  0.525
# Polaridade
#  As carnes de ótima qualidade e muito bem assadas! : 0.525
# subjetividade
#  As carnes de ótima qualidade e muito bem assadas! : 0.525
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  O galeto muito bem temperado e o pernil de cordeiro também!
# sentence.sentiment.polarity:  -0.25
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  O galeto muito bem temperado e o pernil de cordeiro também! : -0.25
# subjetividade
#  O galeto muito bem temperado e o pernil de cordeiro também! : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Variedade bacana, sem muitas invenções, mas trazendo o necessário para um bom churrasco.
# sentence.sentiment.polarity:  0.45
# sentence.sentiment.subjectivity:  0.775
# Polaridade
#  Variedade bacana, sem muitas invenções, mas trazendo o necessário para um bom churrasco. : 0.45
# subjetividade
#  Variedade bacana, sem muitas invenções, mas trazendo o necessário para um bom churrasco. : 0.775
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Atendimento muito bom, com garçons educados e gerência preocupada com o bem estar do cliente.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Atendimento muito bom, com garçons educados e gerência preocupada com o bem estar do cliente. : 0.9099999999999999
# subjetividade
#  Atendimento muito bom, com garçons educados e gerência preocupada com o bem estar do cliente. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Preço justo pela qualidade e atendimento.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Preço justo pela qualidade e atendimento. : 0.7
# subjetividade
#  Preço justo pela qualidade e atendimento. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80007 x Excelente saber, excelente preço, execelente atendimento! Otima localizaçao e nao demora para ficar pronta
# **************
#
# Inglês:  Excellent to know, excellent price, excellent service! Great location and don't delay to get ready
# sentence_br  Excelente saber, excelente preço, execelente atendimento!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Excelente saber, excelente preço, execelente atendimento! : 1.0
# subjetividade
#  Excelente saber, excelente preço, execelente atendimento! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Otima localizaçao e nao demora para ficar pronta
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.625
# Polaridade
#  Otima localizaçao e nao demora para ficar pronta : 0.5
# subjetividade
#  Otima localizaçao e nao demora para ficar pronta : 0.625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80008 x É um ótimo restaurante, dos meus preferidos. As mesas de 2 lugares são bem próximas umas das outras sendo desconfortável para conversas a 2. Tive a péssima experiência de, apesar da disponibilidade de pelo menos 10
# mesas de 4 lugares, ser proibido pelo gerente Fernando Lelis de ocupar uma mesa de 4 lugares. Ponto perdido pelo estabelecimento em que dentro das possibilidades não preza pelo bem estar do cliente.
# **************
#
# Inglês:  It is a great restaurant, one of my favorites.
#  The 2-seater tables are very close to each other making it uncomfortable for 2-person conversations.
#  I had the bad experience of, despite the availability of at least 10
# 4-seater tables, be prohibited by the manager Fernando Lelis from occupying a 4-seater table.
#  Point lost by the establishment where, within the possibilities, it does not value the client's well being.
# sentence_br  É um ótimo restaurante, dos meus preferidos.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  É um ótimo restaurante, dos meus preferidos. : 0.8
# subjetividade
#  É um ótimo restaurante, dos meus preferidos. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  As mesas de 2 lugares são bem próximas umas das outras sendo desconfortável para conversas a 2.
# sentence.sentiment.polarity:  -0.14166666666666666
# sentence.sentiment.subjectivity:  0.5583333333333333
# Polaridade
#  As mesas de 2 lugares são bem próximas umas das outras sendo desconfortável para conversas a 2. : -0.14166666666666666
# subjetividade
#  As mesas de 2 lugares são bem próximas umas das outras sendo desconfortável para conversas a 2. : 0.5583333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Tive a péssima experiência de, apesar da disponibilidade de pelo menos 10
# mesas de 4 lugares, ser proibido pelo gerente Fernando Lelis de ocupar uma mesa de 4 lugares.
# sentence.sentiment.polarity:  -0.4999999999999999
# sentence.sentiment.subjectivity:  0.5333333333333333
# Polaridade
#  Tive a péssima experiência de, apesar da disponibilidade de pelo menos 10
# mesas de 4 lugares, ser proibido pelo gerente Fernando Lelis de ocupar uma mesa de 4 lugares. : -0.4999999999999999
# subjetividade
#  Tive a péssima experiência de, apesar da disponibilidade de pelo menos 10
# mesas de 4 lugares, ser proibido pelo gerente Fernando Lelis de ocupar uma mesa de 4 lugares. : 0.5333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Ponto perdido pelo estabelecimento em que dentro das possibilidades não preza pelo bem estar do cliente.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Ponto perdido pelo estabelecimento em que dentro das possibilidades não preza pelo bem estar do cliente. : 0.0
# subjetividade
#  Ponto perdido pelo estabelecimento em que dentro das possibilidades não preza pelo bem estar do cliente. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80009 x Casa ótima, cerveja gelada e comida gostosa! Acho que poderiam investir numa musica ao vivo, o local é grande e pede uma musica animada!
# P.S: nesse friozinho, nao podiam ter deixado faltar o vinho... mesmo assim tudo muito bom!
# **************
# Inglês:  Great house, cold beer and delicious food! I think they could invest in live music, the venue is large and asks for lively music!
# P.
# S: in that cold weather, they couldn't have missed the wine.
# .. still all very good!
# sentence_br  Casa ótima, cerveja gelada e comida gostosa!
# sentence.sentiment.polarity:  0.4000000000000001
# sentence.sentiment.subjectivity:  0.9166666666666666
# Polaridade
#  Casa ótima, cerveja gelada e comida gostosa! : 0.4000000000000001
# subjetividade
#  Casa ótima, cerveja gelada e comida gostosa! : 0.9166666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Acho que poderiam investir numa musica ao vivo, o local é grande e pede uma musica animada!
# sentence.sentiment.polarity:  0.1737012987012987
# sentence.sentiment.subjectivity:  0.4761904761904762
# Polaridade
#  Acho que poderiam investir numa musica ao vivo, o local é grande e pede uma musica animada! : 0.1737012987012987
# subjetividade
#  Acho que poderiam investir numa musica ao vivo, o local é grande e pede uma musica animada! : 0.4761904761904762
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  P.
# S: nesse friozinho, nao podiam ter deixado faltar o vinho.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  P.
# S: nesse friozinho, nao podiam ter deixado faltar o vinho. : -0.6
# subjetividade
#  P.
# S: nesse friozinho, nao podiam ter deixado faltar o vinho. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  .. mesmo assim tudo muito bom!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  .. mesmo assim tudo muito bom! : 1.0
# subjetividade
#  .. mesmo assim tudo muito bom! : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80010 x Deliocioso como todos os restaurantes coco bambu e muuuito bem atendida pelo garçom Henrique no shopping recife.
# **************
#
# Inglês:  Delightful like all coconut bamboo restaurants and soooo well attended by waiter Henrique at the Recife shopping mall.
# sentence_br  Deliocioso como todos os restaurantes coco bambu e muuuito bem atendida pelo garçom Henrique no shopping recife.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Deliocioso como todos os restaurantes coco bambu e muuuito bem atendida pelo garçom Henrique no shopping recife. : 1.0
# subjetividade
#  Deliocioso como todos os restaurantes coco bambu e muuuito bem atendida pelo garçom Henrique no shopping recife. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80011 x Para mim, é o melhor restaurante do Brasil. Cerveja mais gelada. Picanha a preço justo. Ambiente agradável. Música agradável. Perfeito.
# **************
#
# Inglês:  For me, it is the best restaurant in Brazil.
#  Colder beer.
#  Picanha at a fair price.
#  Pleasant environment.
#  Pleasant music.
#  Perfect.
# sentence_br  Para mim, é o melhor restaurante do Brasil.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Para mim, é o melhor restaurante do Brasil. : 1.0
# subjetividade
#  Para mim, é o melhor restaurante do Brasil. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Cerveja mais gelada.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Cerveja mais gelada. : 0.0
# subjetividade
#  Cerveja mais gelada. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Picanha a preço justo.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Picanha a preço justo. : 0.7
# subjetividade
#  Picanha a preço justo. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Ambiente agradável.
# sentence.sentiment.polarity:  0.7333333333333333
# sentence.sentiment.subjectivity:  0.9666666666666667
# Polaridade
#  Ambiente agradável. : 0.7333333333333333
# subjetividade
#  Ambiente agradável. : 0.9666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Música agradável.
# sentence.sentiment.polarity:  0.7333333333333333
# sentence.sentiment.subjectivity:  0.9666666666666667
# Polaridade
#  Música agradável. : 0.7333333333333333
# subjetividade
#  Música agradável. : 0.9666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Perfeito.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Perfeito. : 1.0
# subjetividade
#  Perfeito. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80012 x Ambiente agradável e a pizza é muito saborosa. Situada na Praia do cabo Branco e com mesas externas tem a bela vista do mar e deliciosa brisa.
# **************
#
# Inglês:  Nice atmosphere and the pizza is very tasty.
#  Located on Cabo Branco Beach and with outdoor tables it has a beautiful view of the sea and a delicious breeze.
# sentence_br  Ambiente agradável e a pizza é muito saborosa.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Ambiente agradável e a pizza é muito saborosa. : 0.4
# subjetividade
#  Ambiente agradável e a pizza é muito saborosa. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Situada na Praia do cabo Branco e com mesas externas tem a bela vista do mar e deliciosa brisa.
# sentence.sentiment.polarity:  0.925
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Situada na Praia do cabo Branco e com mesas externas tem a bela vista do mar e deliciosa brisa. : 0.925
# subjetividade
#  Situada na Praia do cabo Branco e com mesas externas tem a bela vista do mar e deliciosa brisa. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80013 x O local é muito agradável e com decoração temática e as carnes vem no ponto argentino, um pouco mais mal passadas. Os acompanhamentos são maravilhosos, como o arroz Bárbaro e a batata com alho e salsa salpicados.
# O ponto alto é o Clericot, um ponche de vinho branco ou rosé, com frutas e gelo, preparados à mesa. Maravilhoso! E de quebra, vc ainda ganha um mini alfajor junto com a conta. Delícia!
# **************
#
# Inglês:  The place is very pleasant and with thematic decoration and the meat comes in the Argentine point, a little more rare.
#  The side dishes are wonderful, like the Bárbaro rice and the potato with garlic and sprinkled parsley.
#
# The highlight is Clericot, a punch of white or rosé wine, with fruits and ice, prepared at the table.
#  Wonderful! And of course, you still get a mini alfajor along with the account.
#  Delicious!
# sentence_br  O local é muito agradável e com decoração temática e as carnes vem no ponto argentino, um pouco mais mal passadas.
# sentence.sentiment.polarity:  0.31316666666666665
# sentence.sentiment.subjectivity:  0.58
# Polaridade
#  O local é muito agradável e com decoração temática e as carnes vem no ponto argentino, um pouco mais mal passadas. : 0.31316666666666665
# subjetividade
#  O local é muito agradável e com decoração temática e as carnes vem no ponto argentino, um pouco mais mal passadas. : 0.58
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Os acompanhamentos são maravilhosos, como o arroz Bárbaro e a batata com alho e salsa salpicados.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Os acompanhamentos são maravilhosos, como o arroz Bárbaro e a batata com alho e salsa salpicados. : 1.0
# subjetividade
#  Os acompanhamentos são maravilhosos, como o arroz Bárbaro e a batata com alho e salsa salpicados. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  O ponto alto é o Clericot, um ponche de vinho branco ou rosé, com frutas e gelo, preparados à mesa.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  O ponto alto é o Clericot, um ponche de vinho branco ou rosé, com frutas e gelo, preparados à mesa. : 0.0
# subjetividade
#  O ponto alto é o Clericot, um ponche de vinho branco ou rosé, com frutas e gelo, preparados à mesa. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Maravilhoso!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Maravilhoso! : 1.0
# subjetividade
#  Maravilhoso! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  E de quebra, vc ainda ganha um mini alfajor junto com a conta.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  E de quebra, vc ainda ganha um mini alfajor junto com a conta. : 0.0
# subjetividade
#  E de quebra, vc ainda ganha um mini alfajor junto com a conta. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Delícia!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Delícia! : 1.0
# subjetividade
#  Delícia! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80014 x Estava em passeio pela cidade e vi que esse restaurante havia aderido ao restaurante week e resolvi experimentar. Uma delicia é o que define! Ótimo atendimento, pratos muito bem feitos e fartos! Retornarei!
# **************
# Inglês:  I was walking around town and saw that this restaurant had joined the restaurant week and decided to try it out.
#  A delight is what defines! Great service, very well done and full dishes! I will return!
# sentence_br  Estava em passeio pela cidade e vi que esse restaurante havia aderido ao restaurante week e resolvi experimentar.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Estava em passeio pela cidade e vi que esse restaurante havia aderido ao restaurante week e resolvi experimentar. : 0.0
# subjetividade
#  Estava em passeio pela cidade e vi que esse restaurante havia aderido ao restaurante week e resolvi experimentar. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Uma delicia é o que define!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Uma delicia é o que define! : 0.0
# subjetividade
#  Uma delicia é o que define! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Ótimo atendimento, pratos muito bem feitos e fartos!
# sentence.sentiment.polarity:  0.4791666666666667
# sentence.sentiment.subjectivity:  0.5333333333333333
# Polaridade
#  Ótimo atendimento, pratos muito bem feitos e fartos! : 0.4791666666666667
# subjetividade
#  Ótimo atendimento, pratos muito bem feitos e fartos! : 0.5333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Retornarei!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Retornarei! : 0.0
# subjetividade
#  Retornarei! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80015 x Existem duas opções de tamanho de dog's. Pedi pelo delivery e chegou rápido, porém achei muito gorduroso e desde então nunca mais comi novamente.
# **************
#
# Inglês:  There are two dog size options.
#  I asked for delivery and it arrived quickly, but I found it very greasy and since then I never ate again.
# sentence_br  Existem duas opções de tamanho de dog's.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Existem duas opções de tamanho de dog's. : 0.0
# subjetividade
#  Existem duas opções de tamanho de dog's. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Pedi pelo delivery e chegou rápido, porém achei muito gorduroso e desde então nunca mais comi novamente.
# sentence.sentiment.polarity:  0.26666666666666666
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Pedi pelo delivery e chegou rápido, porém achei muito gorduroso e desde então nunca mais comi novamente. : 0.26666666666666666
# subjetividade
#  Pedi pelo delivery e chegou rápido, porém achei muito gorduroso e desde então nunca mais comi novamente. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80016 x O restaurante é muito bonito e bem decorado, com um excelente ambiente.
# As carnes são absolutamente perfeitas, tanto no tempero quanto no ponto.
# Entretanto, não gostei do sistema de acompanhamentos em rodízio. Seria mais interessante escolher um acompanhamento, com opção de salada.
# Fique decepcionado com a cobrança de couvert sem pedido, o que infelizmente tem sido costume  neste tipo de restaurante.
# **************
#
# Inglês:  The restaurant is very beautiful and well decorated, with an excellent atmosphere.
#
# The meats are absolutely perfect, both in seasoning and in point.
#
# However, I did not like the system of rotating accompaniments.
#  It would be more interesting to choose a side dish, with a salad option.
#
# Be disappointed with the cover charge without order, which unfortunately has been the custom in this type of restaurant.
# sentence_br  O restaurante é muito bonito e bem decorado, com um excelente ambiente.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O restaurante é muito bonito e bem decorado, com um excelente ambiente. : 1.0
# subjetividade
#  O restaurante é muito bonito e bem decorado, com um excelente ambiente. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  As carnes são absolutamente perfeitas, tanto no tempero quanto no ponto.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  As carnes são absolutamente perfeitas, tanto no tempero quanto no ponto. : 1.0
# subjetividade
#  As carnes são absolutamente perfeitas, tanto no tempero quanto no ponto. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Entretanto, não gostei do sistema de acompanhamentos em rodízio.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Entretanto, não gostei do sistema de acompanhamentos em rodízio. : 0.0
# subjetividade
#  Entretanto, não gostei do sistema de acompanhamentos em rodízio. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Seria mais interessante escolher um acompanhamento, com opção de salada.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Seria mais interessante escolher um acompanhamento, com opção de salada. : 0.5
# subjetividade
#  Seria mais interessante escolher um acompanhamento, com opção de salada. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Fique decepcionado com a cobrança de couvert sem pedido, o que infelizmente tem sido costume  neste tipo de restaurante.
# sentence.sentiment.polarity:  -0.625
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  Fique decepcionado com a cobrança de couvert sem pedido, o que infelizmente tem sido costume  neste tipo de restaurante. : -0.625
# subjetividade
#  Fique decepcionado com a cobrança de couvert sem pedido, o que infelizmente tem sido costume  neste tipo de restaurante. : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80017 x Estive no Giraffas do Outlet Premium Brasília - Rodovia 060, km 22 - Alexânia/GO. Comida boa, preço justo, ambiente amplo, arejado apesar de muito movimentado. O atendimento é ótimo, mas é demorado receber o pedido (talvez porque era domingo).
# **************
#
# Inglês:  I was at Giraffas at Outlet Premium Brasília - Rodovia 060, km 22 - Alexânia / GO.
#  Good food, fair price, spacious, airy despite being very busy.
#  The service is great, but it takes time to receive the order (maybe because it was Sunday).
# sentence_br  Estive no Giraffas do Outlet Premium Brasília - Rodovia 060, km 22 - Alexânia/GO.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Estive no Giraffas do Outlet Premium Brasília - Rodovia 060, km 22 - Alexânia/GO. : 0.0
# subjetividade
#  Estive no Giraffas do Outlet Premium Brasília - Rodovia 060, km 22 - Alexânia/GO. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Comida boa, preço justo, ambiente amplo, arejado apesar de muito movimentado.
# sentence.sentiment.polarity:  0.5099999999999999
# sentence.sentiment.subjectivity:  0.63
# Polaridade
#  Comida boa, preço justo, ambiente amplo, arejado apesar de muito movimentado. : 0.5099999999999999
# subjetividade
#  Comida boa, preço justo, ambiente amplo, arejado apesar de muito movimentado. : 0.63
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  O atendimento é ótimo, mas é demorado receber o pedido (talvez porque era domingo).
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  O atendimento é ótimo, mas é demorado receber o pedido (talvez porque era domingo). : 0.8
# subjetividade
#  O atendimento é ótimo, mas é demorado receber o pedido (talvez porque era domingo). : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80018 x Ambiente moderno e bem frequentado, atendimento mto bom e um menu diferenciado. A comida é simplesmente maravilhosaaaa. Amei!!!
# **************
# Inglês:  Modern and well attended atmosphere, very good service and a differentiated menu.
#  The food is just wonderful.
#  Loved it!!!
# sentence_br  Ambiente moderno e bem frequentado, atendimento mto bom e um menu diferenciado.
# sentence.sentiment.polarity:  0.5549999999999999
# sentence.sentiment.subjectivity:  0.54
# Polaridade
#  Ambiente moderno e bem frequentado, atendimento mto bom e um menu diferenciado. : 0.5549999999999999
# subjetividade
#  Ambiente moderno e bem frequentado, atendimento mto bom e um menu diferenciado. : 0.54
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  A comida é simplesmente maravilhosaaaa.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  A comida é simplesmente maravilhosaaaa. : 1.0
# subjetividade
#  A comida é simplesmente maravilhosaaaa. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Amei!!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Amei!! : 1.0
# subjetividade
#  Amei!! : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80019 x Lugar agradável, muito bem servido, pedimos Crostine de camarões como entra e depois Bosa Nova. Muito bom !!! Preço justo . Gostei muito . Super recomendo !!
# **************
#
# Inglês:  Nice place, very well served, we ordered Shrimp Crostine as it enters and then Bosa Nova.
#  Very good !!! Fair price . Really enjoyed . Super recommend !!
# sentence_br  Lugar agradável, muito bem servido, pedimos Crostine de camarões como entra e depois Bosa Nova.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Lugar agradável, muito bem servido, pedimos Crostine de camarões como entra e depois Bosa Nova. : 0.4
# subjetividade
#  Lugar agradável, muito bem servido, pedimos Crostine de camarões como entra e depois Bosa Nova. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Muito bom !!!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Muito bom !!! : 1.0
# subjetividade
#  Muito bom !!! : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Preço justo .
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Preço justo . : 0.7
# subjetividade
#  Preço justo . : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Gostei muito .
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  Gostei muito . : 0.5
# subjetividade
#  Gostei muito . : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Super recomendo !
# sentence.sentiment.polarity:  0.41666666666666663
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Super recomendo ! : 0.41666666666666663
# subjetividade
#  Super recomendo ! : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80020 x Tem o quiosque e o restaurante Olho de Lula! Aqui estou falando do QUIOSQUE! Sem dúvida um dos melhores onde estive na cidade. Bem localizado, bem frequentado, bons pratos tanto de aperitivos, porções ou refeições, bom atendimento. Vale a pena.
# **************
#
# Inglês:  There's the kiosk and the Olho de Lula restaurant! Here I am talking about the KIOSK! Without a doubt one of the best I've been to in the city.
#  Well located, well frequented, good dishes, appetizers, portions or meals, good service.
#  Worth it.
# sentence_br  Tem o quiosque e o restaurante Olho de Lula!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tem o quiosque e o restaurante Olho de Lula! : 0.0
# subjetividade
#  Tem o quiosque e o restaurante Olho de Lula! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Aqui estou falando do QUIOSQUE!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Aqui estou falando do QUIOSQUE! : 0.0
# subjetividade
#  Aqui estou falando do QUIOSQUE! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Sem dúvida um dos melhores onde estive na cidade.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Sem dúvida um dos melhores onde estive na cidade. : 1.0
# subjetividade
#  Sem dúvida um dos melhores onde estive na cidade. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Bem localizado, bem frequentado, bons pratos tanto de aperitivos, porções ou refeições, bom atendimento.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Bem localizado, bem frequentado, bons pratos tanto de aperitivos, porções ou refeições, bom atendimento. : 0.7
# subjetividade
#  Bem localizado, bem frequentado, bons pratos tanto de aperitivos, porções ou refeições, bom atendimento. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Vale a pena.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale a pena. : 0.3
# subjetividade
#  Vale a pena. : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80021 x Provei do camarão internacional, moqueca de camarão e peixe com camarão. Tudo bom. Só não gostei do camarão flambado.
# **************
#
# Inglês:  I tried international prawns, shrimp stew and fish with shrimp.
#  It's OK.
#  I just didn't like the flambéed shrimp.
# sentence_br  Provei do camarão internacional, moqueca de camarão e peixe com camarão.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Provei do camarão internacional, moqueca de camarão e peixe com camarão. : 0.0
# subjetividade
#  Provei do camarão internacional, moqueca de camarão e peixe com camarão. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Tudo bom.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Tudo bom. : 0.5
# subjetividade
#  Tudo bom. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Só não gostei do camarão flambado.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Só não gostei do camarão flambado. : 0.0
# subjetividade
#  Só não gostei do camarão flambado. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80022 x Após retirarem minha bandeja eu e minha mãe estávamos decidindo se iríamos querer mais alguma coisa, nesse instante o hostess chegou e perguntou se nós poderíamos fazer a gentileza de sair dali para que outras 4 pessoas pudessem sentar. Obviamente não sai. Não estou pagando pra comer em um lugar onde eu tenha que fazer gentilezas e não ser bem atendida e bem vinda. Após isso vi o mesmo hostess pedindo para que o garçom finalizasse logo outra mesa e os mandasse embora ( fazendo um gesto com as mãos) para que a pessoa vaza-se. Se querem atender mais cliente , tenham uma estrutra maior. Nunca mais volto nessa palhaçada.
# **************
#
# Inglês:  After removing my tray my mother and I were deciding if we would like anything else, at that moment the hostess arrived and asked if we could be kind enough to leave so that 4 other people could sit.
#  It obviously doesn't come out.
#  I'm not paying to eat in a place where I have to be kind and not be well attended and welcome.
#  After that I saw the same hostess asking the waiter to finish another table and send them away (making a gesture with his hands) so that the person leaks.
#  If you want to serve more customers, have a bigger structure.
#  I'll never be back in that antics.
# sentence_br  Após retirarem minha bandeja eu e minha mãe estávamos decidindo se iríamos querer mais alguma coisa, nesse instante o hostess chegou e perguntou se nós poderíamos fazer a gentileza de sair dali para que outras 4 pessoas pudessem sentar.
# sentence.sentiment.polarity:  0.15833333333333333
# sentence.sentiment.subjectivity:  0.5916666666666667
# Polaridade
#  Após retirarem minha bandeja eu e minha mãe estávamos decidindo se iríamos querer mais alguma coisa, nesse instante o hostess chegou e perguntou se nós poderíamos fazer a gentileza de sair dali para que outras 4 pessoas pudessem sentar. : 0.15833333333333333
# subjetividade
# ...
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Vale conferir, principalmente em fins de semana, mas chegue cedo, o local dispõe de Estacionamento.
# sentence.sentiment.polarity:  0.13333333333333333
# sentence.sentiment.subjectivity:  0.46666666666666673
# Polaridade
#  Vale conferir, principalmente em fins de semana, mas chegue cedo, o local dispõe de Estacionamento. : 0.13333333333333333
# subjetividade
#  Vale conferir, principalmente em fins de semana, mas chegue cedo, o local dispõe de Estacionamento. : 0.46666666666666673
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80699 x O prato do dia servido veio com 2 pedaços de frango muito grandes , sem tempero e molho. Sugiro trocar um pedaço de carne por uma porção de salada ou outro acompanhamento. Bom atendimento e ambiente agradável.
# **************
#
# Inglês:  The dish of the day served came with 2 very large pieces of chicken, without seasoning and sauce.
#  I suggest exchanging a piece of meat for a portion of salad or other side dishes.
#  Good service and pleasant atmosphere.
# sentence_br  O prato do dia servido veio com 2 pedaços de frango muito grandes , sem tempero e molho.
# sentence.sentiment.polarity:  -0.1607142857142857
# sentence.sentiment.subjectivity:  0.7535714285714286
# Polaridade
#  O prato do dia servido veio com 2 pedaços de frango muito grandes , sem tempero e molho. : -0.1607142857142857
# subjetividade
#  O prato do dia servido veio com 2 pedaços de frango muito grandes , sem tempero e molho. : 0.7535714285714286
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Sugiro trocar um pedaço de carne por uma porção de salada ou outro acompanhamento.
# sentence.sentiment.polarity:  -0.125
# sentence.sentiment.subjectivity:  0.375
# Polaridade
#  Sugiro trocar um pedaço de carne por uma porção de salada ou outro acompanhamento. : -0.125
# subjetividade
#  Sugiro trocar um pedaço de carne por uma porção de salada ou outro acompanhamento. : 0.375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Bom atendimento e ambiente agradável.
# sentence.sentiment.polarity:  0.7166666666666666
# sentence.sentiment.subjectivity:  0.7833333333333334
# Polaridade
#  Bom atendimento e ambiente agradável. : 0.7166666666666666
# subjetividade
#  Bom atendimento e ambiente agradável. : 0.7833333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80700 x Tudo é bom! O chef Juarez é ótimo e um amor. Ótimo atendimento. Ótima apresentação dos pratos. Comida maravilhosa. Sobremesas incríveis. Preço bom. Sem dúvidas o meu preferido.
# **************
# Inglês:  Everything is good! Chef Juarez is great and a love.
#  Great service.
#  Great presentation of the dishes.
#  Wonderful food.
#  Incredible desserts.
#  Good price.
#  Without a doubt my favorite.
# sentence_br  Tudo é bom!
# sentence.sentiment.polarity:  0.875
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Tudo é bom! : 0.875
# subjetividade
#  Tudo é bom! : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  O chef Juarez é ótimo e um amor.
# sentence.sentiment.polarity:  0.65
# sentence.sentiment.subjectivity:  0.675
# Polaridade
#  O chef Juarez é ótimo e um amor. : 0.65
# subjetividade
#  O chef Juarez é ótimo e um amor. : 0.675
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Ótimo atendimento.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ótimo atendimento. : 0.8
# subjetividade
#  Ótimo atendimento. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Ótima apresentação dos pratos.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ótima apresentação dos pratos. : 0.8
# subjetividade
#  Ótima apresentação dos pratos. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Comida maravilhosa.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Comida maravilhosa. : 1.0
# subjetividade
#  Comida maravilhosa. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Sobremesas incríveis.
# sentence.sentiment.polarity:  0.9
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Sobremesas incríveis. : 0.9
# subjetividade
#  Sobremesas incríveis. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Preço bom.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Preço bom. : 0.7
# subjetividade
#  Preço bom. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Sem dúvidas o meu preferido.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Sem dúvidas o meu preferido. : 0.5
# subjetividade
#  Sem dúvidas o meu preferido. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80701 x O ambiente é ótimo. O atendimento também. A comida é excelente, tanto as entradas como os pratos principais.
# **************
#
# Inglês:  The atmosphere is great.
#  The service too.
#  The food is excellent, both the starters and the main dishes.
# sentence_br  O ambiente é ótimo.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  O ambiente é ótimo. : 0.8
# subjetividade
#  O ambiente é ótimo. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  O atendimento também.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  O atendimento também. : 0.0
# subjetividade
#  O atendimento também. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  A comida é excelente, tanto as entradas como os pratos principais.
# sentence.sentiment.polarity:  0.5833333333333334
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  A comida é excelente, tanto as entradas como os pratos principais. : 0.5833333333333334
# subjetividade
#  A comida é excelente, tanto as entradas como os pratos principais. : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80702 x Peixe bem servido, mas sem personalidade. Sem sabor,  molho aguado. Única coisa que lembrava um bom peixe na telha foi o pirão. Tive que fazer uma alquimia para tentar dar algum sabor ao prato. Interessante é que havia comido este prato em um tempo atrás e me pareceu bem elaborado. O que será que aconteceu? Outro aspecto, tem que rezar para os garçons olhar, ver que sua garrafa fora do isopor significa que vc quer outra cerveja e eram 14:30 h, o bar não estava cheio.
# **************
#
# Inglês:  Fish well served, but without personality.
#  No flavor, watery sauce.
#  The only thing that resembled a good fish on the tile was the pirão.
#  I had to make an alchemy to try to add some flavor to the dish.
#  Interesting is that I had eaten this dish a while ago and it seemed to me well prepared.
#  What happened? Another aspect, you have to pray for the waiters to look, to see that your bottle out of Styrofoam means that you want another beer and it was 2:30 pm, the bar was not full.
# sentence_br  Peixe bem servido, mas sem personalidade.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Peixe bem servido, mas sem personalidade. : 0.0
# subjetividade
#  Peixe bem servido, mas sem personalidade. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Sem sabor,  molho aguado.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Sem sabor,  molho aguado. : 0.0
# subjetividade
#  Sem sabor,  molho aguado. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Única coisa que lembrava um bom peixe na telha foi o pirão.
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Única coisa que lembrava um bom peixe na telha foi o pirão. : 0.35
# subjetividade
#  Única coisa que lembrava um bom peixe na telha foi o pirão. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Tive que fazer uma alquimia para tentar dar algum sabor ao prato.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tive que fazer uma alquimia para tentar dar algum sabor ao prato. : 0.0
# subjetividade
#  Tive que fazer uma alquimia para tentar dar algum sabor ao prato. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Interessante é que havia comido este prato em um tempo atrás e me pareceu bem elaborado.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Interessante é que havia comido este prato em um tempo atrás e me pareceu bem elaborado. : 0.5
# subjetividade
#  Interessante é que havia comido este prato em um tempo atrás e me pareceu bem elaborado. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  O que será que aconteceu?
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  O que será que aconteceu? : 0.0
# subjetividade
#  O que será que aconteceu? : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# sentence_br  Outro aspecto, tem que rezar para os garçons olhar, ver que sua garrafa fora do isopor significa que vc quer outra cerveja e eram 14:30 h, o bar não estava cheio.
# sentence.sentiment.polarity:  -0.175
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  Outro aspecto, tem que rezar para os garçons olhar, ver que sua garrafa fora do isopor significa que vc quer outra cerveja e eram 14:30 h, o bar não estava cheio. : -0.175
# subjetividade
#  Outro aspecto, tem que rezar para os garçons olhar, ver que sua garrafa fora do isopor significa que vc quer outra cerveja e eram 14:30 h, o bar não estava cheio. : 0.55
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-80000-90000.txt
# **************
#
# var 80703 x Ótima localização, aconchegante, com uma caracterização típica do nordeste. Animado com forró de qualidade ao vivo (cobra cover artístico). Comida de qualidade, mas poderia custar um pouco menos. Com um salão de dança que funciona de sexta a domingo a partir das 10h que cobra R$25 por pessoa. Poderia ser mais espaçoso, pois é muito frequentado nos fins de semana e se a pessoa chegar após as 10h provavelmente não encontrará mesa disponível.
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-23-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
