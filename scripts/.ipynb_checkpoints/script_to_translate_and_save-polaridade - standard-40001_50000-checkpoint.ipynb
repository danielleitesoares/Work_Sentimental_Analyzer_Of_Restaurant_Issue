# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path

# %%
inicio = 40715
terminou = 50000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  125,533,478,912 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 200000

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
ini = time.time()
for x in df['reviewBody']:
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 40001 x Muito bom o atendimento dono muito simpatico, os pratos são bem servidos e deliciosos ambiente muito agradável
# **************
#
# Inglês:  Very good service very friendly owner, dishes are well served and delicious very pleasant atmosphere
# sentence_br  Muito bom o atendimento dono muito simpatico, os pratos são bem servidos e deliciosos ambiente muito agradável
# sentence.sentiment.polarity:  0.8377083333333333
# sentence.sentiment.subjectivity:  0.8575
# Polaridade
#  Muito bom o atendimento dono muito simpatico, os pratos são bem servidos e deliciosos ambiente muito agradável : 0.8377083333333333
# subjetividade
#  Muito bom o atendimento dono muito simpatico, os pratos são bem servidos e deliciosos ambiente muito agradável : 0.8575
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40002 x Além do atendimento, o clima do restaurante é muito bom.
# Escolhi a massa que foi feita na hora.
# Simplesmente fantástico.
# Próximo ao hospital São Luís, torna-se uma ótima opção para alimentação.
#
#
# **************
#
# Inglês:  In addition to the service, the restaurant's atmosphere is very good.
#
# I chose the pasta that was made on the spot.
#
# Simply amazing.
#
# Next to São Luís hospital, it becomes a great option for food.
# sentence_br  Além do atendimento, o clima do restaurante é muito bom.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Além do atendimento, o clima do restaurante é muito bom. : 0.9099999999999999
# subjetividade
#  Além do atendimento, o clima do restaurante é muito bom. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Escolhi a massa que foi feita na hora.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Escolhi a massa que foi feita na hora. : 0.0
# subjetividade
#  Escolhi a massa que foi feita na hora. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Simplesmente fantástico.
# sentence.sentiment.polarity:  0.6000000000000001
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Simplesmente fantástico. : 0.6000000000000001
# subjetividade
#  Simplesmente fantástico. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Próximo ao hospital São Luís, torna-se uma ótima opção para alimentação.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.375
# Polaridade
#  Próximo ao hospital São Luís, torna-se uma ótima opção para alimentação. : 0.4
# subjetividade
#  Próximo ao hospital São Luís, torna-se uma ótima opção para alimentação. : 0.375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40003 x A picanha é fabulosa, a cerveja é gelada e o ambiente é o que se quer a acompanhar tudo resto. Barulhento e Animado. Aconselho TOP
# **************
#
# Inglês:  The picanha is fabulous, the beer is cold and the ambience is what you want to accompany everything else.
#  Noisy and Lively.
#  I advise TOP
# sentence_br  A picanha é fabulosa, a cerveja é gelada e o ambiente é o que se quer a acompanhar tudo resto.
# sentence.sentiment.polarity:  -0.09999999999999998
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  A picanha é fabulosa, a cerveja é gelada e o ambiente é o que se quer a acompanhar tudo resto. : -0.09999999999999998
# subjetividade
#  A picanha é fabulosa, a cerveja é gelada e o ambiente é o que se quer a acompanhar tudo resto. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Barulhento e Animado.
# sentence.sentiment.polarity:  0.13636363636363635
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Barulhento e Animado. : 0.13636363636363635
# subjetividade
#  Barulhento e Animado. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Aconselho TOP
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Aconselho TOP : 0.5
# subjetividade
#  Aconselho TOP : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40004 x Atendimento de qualidade e rapidez com o garçom Robson Costa, excelente!!! Comida muito saborosa!!!!
# **************
#
# Inglês:  Quality service and speed with the waiter Robson Costa, excellent !!! Very tasty food !!!!
# sentence_br  Atendimento de qualidade e rapidez com o garçom Robson Costa, excelente!!!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Atendimento de qualidade e rapidez com o garçom Robson Costa, excelente!!! : 1.0
# subjetividade
#  Atendimento de qualidade e rapidez com o garçom Robson Costa, excelente!!! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Comida muito saborosa!!!
# sentence.sentiment.polarity:  0.390625
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Comida muito saborosa!!! : 0.390625
# subjetividade
#  Comida muito saborosa!!! : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40005 x Tem uma boa cozinha, mais acho caro o preço do Kilo, R$ 69,00. É bem variada com diversos tipos de carna, massa, e comidas regionais, além de feijoada.
# O local é muito quente, pois a praça de alimentação fica super lotada.
# É preferível fazer um lanche . . . .
# **************
#
# Inglês:  It has a good kitchen, but I think the price of Kilo, R $ 69.00, is expensive.
#  It is very varied with different types of meat, pasta, and regional foods, in addition to feijoada.
#
# The place is very hot, because the food court is very crowded.
#
# It is preferable to have a snack. . . .
# sentence_br  Tem uma boa cozinha, mais acho caro o preço do Kilo, R$ 69,00.
# sentence.sentiment.polarity:  0.09999999999999998
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Tem uma boa cozinha, mais acho caro o preço do Kilo, R$ 69,00. : 0.09999999999999998
# subjetividade
#  Tem uma boa cozinha, mais acho caro o preço do Kilo, R$ 69,00. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  É bem variada com diversos tipos de carna, massa, e comidas regionais, além de feijoada.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.44999999999999996
# Polaridade
#  É bem variada com diversos tipos de carna, massa, e comidas regionais, além de feijoada. : 0.1
# subjetividade
#  É bem variada com diversos tipos de carna, massa, e comidas regionais, além de feijoada. : 0.44999999999999996
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  O local é muito quente, pois a praça de alimentação fica super lotada.
# sentence.sentiment.polarity:  0.2625
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  O local é muito quente, pois a praça de alimentação fica super lotada. : 0.2625
# subjetividade
#  O local é muito quente, pois a praça de alimentação fica super lotada. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  É preferível fazer um lanche .
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  É preferível fazer um lanche . : 0.0
# subjetividade
#  É preferível fazer um lanche . : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  .
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  . : 0.0
# subjetividade
#  . : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  .
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  . : 0.0
# subjetividade
#  . : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  .
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  . : 0.0
# subjetividade
#  . : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40006 x É um lugar bacana, com ambiente bem decorado, tudo retro. Tem até uma sala meio anos 70 que você pode reservar para eventos. O problema é que está muito caro. Estive lá essa semana e pedi um clericot que veio cheio de gelo e  bolinho de abóbora com carne seca que veio gelado. Então o custo benefício já não está valendo a pena.
# **************
# Inglês:  It's a nice place, with a well-decorated atmosphere, all retro.
#  There is even a 70's room that you can book for events.
#  The problem is that it is very expensive.
#  I was there this week and ordered a clericot that came full of ice and a pumpkin dumpling with dried meat that came cold.
#  So the cost benefit is no longer worth it.
# sentence_br  É um lugar bacana, com ambiente bem decorado, tudo retro.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  É um lugar bacana, com ambiente bem decorado, tudo retro. : 0.6
# subjetividade
#  É um lugar bacana, com ambiente bem decorado, tudo retro. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Tem até uma sala meio anos 70 que você pode reservar para eventos.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tem até uma sala meio anos 70 que você pode reservar para eventos. : 0.0
# subjetividade
#  Tem até uma sala meio anos 70 que você pode reservar para eventos. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  O problema é que está muito caro.
# sentence.sentiment.polarity:  -0.65
# sentence.sentiment.subjectivity:  0.9099999999999999
# Polaridade
#  O problema é que está muito caro. : -0.65
# subjetividade
#  O problema é que está muito caro. : 0.9099999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Estive lá essa semana e pedi um clericot que veio cheio de gelo e  bolinho de abóbora com carne seca que veio gelado.
# sentence.sentiment.polarity:  -0.15
# sentence.sentiment.subjectivity:  0.7166666666666667
# Polaridade
#  Estive lá essa semana e pedi um clericot que veio cheio de gelo e  bolinho de abóbora com carne seca que veio gelado. : -0.15
# subjetividade
#  Estive lá essa semana e pedi um clericot que veio cheio de gelo e  bolinho de abóbora com carne seca que veio gelado. : 0.7166666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Então o custo benefício já não está valendo a pena.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Então o custo benefício já não está valendo a pena. : 0.3
# subjetividade
#  Então o custo benefício já não está valendo a pena. : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40007 x Restaurante descolado, comida boa, atendimento bom, não tenho nada a reclamar!
# As comidas são leves e muito saborosas!
# Vale a visita!
# **************
#
# Inglês:  Cool restaurant, good food, good service, I have nothing to complain about!
# The foods are light and very tasty!
# Worth the visit!
# sentence_br  Restaurante descolado, comida boa, atendimento bom, não tenho nada a reclamar!
# sentence.sentiment.polarity:  0.6416666666666666
# sentence.sentiment.subjectivity:  0.6166666666666667
# Polaridade
#  Restaurante descolado, comida boa, atendimento bom, não tenho nada a reclamar! : 0.6416666666666666
# subjetividade
#  Restaurante descolado, comida boa, atendimento bom, não tenho nada a reclamar! : 0.6166666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  As comidas são leves e muito saborosas!
# sentence.sentiment.polarity:  0.325
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  As comidas são leves e muito saborosas! : 0.325
# subjetividade
#  As comidas são leves e muito saborosas! : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Vale a visita!
# sentence.sentiment.polarity:  0.375
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale a visita! : 0.375
# subjetividade
#  Vale a visita! : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40008 x Maravilhoso, adoro o restaurante os pratos variados e todos delicioso, ambiente agradável, excelente atendimento. adorei!
# **************
#
# Inglês:  Wonderful, I love the restaurant, the varied dishes and all delicious, pleasant atmosphere, excellent service.
#  I loved it!
# sentence_br  Maravilhoso, adoro o restaurante os pratos variados e todos delicioso, ambiente agradável, excelente atendimento.
# sentence.sentiment.polarity:  0.8466666666666667
# sentence.sentiment.subjectivity:  0.9133333333333333
# Polaridade
#  Maravilhoso, adoro o restaurante os pratos variados e todos delicioso, ambiente agradável, excelente atendimento. : 0.8466666666666667
# subjetividade
#  Maravilhoso, adoro o restaurante os pratos variados e todos delicioso, ambiente agradável, excelente atendimento. : 0.9133333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  adorei!
# sentence.sentiment.polarity:  0.875
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  adorei! : 0.875
# subjetividade
#  adorei! : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40009 x O lugar porreta, as meninas da recepção são uma graça, muito feliz, a variedade de comida excelente, o sabor inigualável, o camarão com requeijão foi o melhor sabor que já provei.
# **************
#
# Inglês:  The friendly place, the reception girls are cute, very happy, the variety of food is excellent, the flavor is second to none, the shrimp with curd was the best flavor I have ever tasted.
# sentence_br  O lugar porreta, as meninas da recepção são uma graça, muito feliz, a variedade de comida excelente, o sabor inigualável, o camarão com requeijão foi o melhor sabor que já provei.
# sentence.sentiment.polarity:  0.6458333333333334
# sentence.sentiment.subjectivity:  0.6333333333333333
# Polaridade
#  O lugar porreta, as meninas da recepção são uma graça, muito feliz, a variedade de comida excelente, o sabor inigualável, o camarão com requeijão foi o melhor sabor que já provei. : 0.6458333333333334
# subjetividade
#  O lugar porreta, as meninas da recepção são uma graça, muito feliz, a variedade de comida excelente, o sabor inigualável, o camarão com requeijão foi o melhor sabor que já provei. : 0.6333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40010 x Incomparável cachorro-quente. Ele não vem só com salsicha. Tem carne moída com tempero gostoso e verdura picada. Fica na rua de frente ao Hotel Tambaú.
# **************
#
# Inglês:  Incomparable hot dog.
#  It doesn't just come with sausage.
#  It has ground beef with tasty seasoning and chopped vegetables.
#  It is on the street in front of the Hotel Tambaú.
# sentence_br  Incomparável cachorro-quente.
# sentence.sentiment.polarity:  0.325
# sentence.sentiment.subjectivity:  0.7250000000000001
# Polaridade
#  Incomparável cachorro-quente. : 0.325
# subjetividade
#  Incomparável cachorro-quente. : 0.7250000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Ele não vem só com salsicha.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Ele não vem só com salsicha. : 0.0
# subjetividade
#  Ele não vem só com salsicha. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Tem carne moída com tempero gostoso e verdura picada.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tem carne moída com tempero gostoso e verdura picada. : 0.0
# subjetividade
#  Tem carne moída com tempero gostoso e verdura picada. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Fica na rua de frente ao Hotel Tambaú.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Fica na rua de frente ao Hotel Tambaú. : 0.0
# subjetividade
#  Fica na rua de frente ao Hotel Tambaú. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40011 x Adoro esse restaurante.
# A comida é caprichada, diferenciada e os garçons muito atenciosos.
# Os risotos são muito bons, a carne macia as combinações certas. Sobremesas muito gostosas. Vale ir, seja para um almoço de trabalho, seja com a família e amigos.
# **************
# Inglês:  I love this restaurant.
#
# The food is neat, different and the waiters are very attentive.
#
# The risottos are very good, the tender meat the right combinations.
#  Very delicious desserts.
#  It is worth going, either for a business lunch, or with family and friends.
# sentence_br  Adoro esse restaurante.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Adoro esse restaurante. : 0.5
# subjetividade
#  Adoro esse restaurante. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  A comida é caprichada, diferenciada e os garçons muito atenciosos.
# sentence.sentiment.polarity:  0.26
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  A comida é caprichada, diferenciada e os garçons muito atenciosos. : 0.26
# subjetividade
#  A comida é caprichada, diferenciada e os garçons muito atenciosos. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Os risotos são muito bons, a carne macia as combinações certas.
# sentence.sentiment.polarity:  0.5978571428571429
# sentence.sentiment.subjectivity:  0.6578571428571429
# Polaridade
#  Os risotos são muito bons, a carne macia as combinações certas. : 0.5978571428571429
# subjetividade
#  Os risotos são muito bons, a carne macia as combinações certas. : 0.6578571428571429
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Sobremesas muito gostosas.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Sobremesas muito gostosas. : 1.0
# subjetividade
#  Sobremesas muito gostosas. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Vale ir, seja para um almoço de trabalho, seja com a família e amigos.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale ir, seja para um almoço de trabalho, seja com a família e amigos. : 0.3
# subjetividade
#  Vale ir, seja para um almoço de trabalho, seja com a família e amigos. : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40012 x Ambiente agradável, calmo com decoração mto bacana. Comida possui temperos diferentes mas mto gostoso os pratos.
# Boa Localização e fácil acesso.
# **************
#
# Inglês:  Pleasant, calm environment with very nice decor.
#  Food has different spices but very tasty dishes.
#
# Good location and easy access.
# sentence_br  Ambiente agradável, calmo com decoração mto bacana.
# sentence.sentiment.polarity:  0.6044444444444445
# sentence.sentiment.subjectivity:  0.9055555555555556
# Polaridade
#  Ambiente agradável, calmo com decoração mto bacana. : 0.6044444444444445
# subjetividade
#  Ambiente agradável, calmo com decoração mto bacana. : 0.9055555555555556
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Comida possui temperos diferentes mas mto gostoso os pratos.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.44999999999999996
# Polaridade
#  Comida possui temperos diferentes mas mto gostoso os pratos. : 0.1
# subjetividade
#  Comida possui temperos diferentes mas mto gostoso os pratos. : 0.44999999999999996
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Boa Localização e fácil acesso.
# sentence.sentiment.polarity:  0.5666666666666667
# sentence.sentiment.subjectivity:  0.7166666666666668
# Polaridade
#  Boa Localização e fácil acesso. : 0.5666666666666667
# subjetividade
#  Boa Localização e fácil acesso. : 0.7166666666666668
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40013 x Pra quem gosta de comida japonesa aqui está uma ótima opção! Com um diferencial difícil de achar em restaurantes japoneses, a comida é por kilo, o que dá mais liberdade de escolha aos clientes. Os sushis também são feitos num tamanho menor, o que facilita na hora de comer! O preço é ótimo!
# **************
#
# Inglês:  For those who like Japanese food here is a great option! With a difference difficult to find in Japanese restaurants, the food is per kilo, which gives customers more freedom of choice.
#  Sushi are also made in a smaller size, which makes eating easier! The price is great!
# sentence_br  Pra quem gosta de comida japonesa aqui está uma ótima opção!
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.375
# Polaridade
#  Pra quem gosta de comida japonesa aqui está uma ótima opção! : 0.5
# subjetividade
#  Pra quem gosta de comida japonesa aqui está uma ótima opção! : 0.375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Com um diferencial difícil de achar em restaurantes japoneses, a comida é por kilo, o que dá mais liberdade de escolha aos clientes.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Com um diferencial difícil de achar em restaurantes japoneses, a comida é por kilo, o que dá mais liberdade de escolha aos clientes. : 0.0
# subjetividade
#  Com um diferencial difícil de achar em restaurantes japoneses, a comida é por kilo, o que dá mais liberdade de escolha aos clientes. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Os sushis também são feitos num tamanho menor, o que facilita na hora de comer!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Os sushis também são feitos num tamanho menor, o que facilita na hora de comer! : 0.0
# subjetividade
#  Os sushis também são feitos num tamanho menor, o que facilita na hora de comer! : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  O preço é ótimo!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  O preço é ótimo! : 1.0
# subjetividade
#  O preço é ótimo! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40014 x visitei pela primeira vez o restaurante na segunda, dia 01/05, acompanhada do meu marido e minha filha.
# Optamos por um prato com bife ancho, mas a decepção foi enorme, pois quando cortei o bife ele estava duro e ao comê-lo, tinha um gosto de carne de sol, só se sentia um sabor de sal.
# Pedimos para substituí-los por outros mais macios, mas nada deu certo, pois além de demorar 20 minutos para nos servirem os bifes novos, ainda continuavam duros e nossa comida já estava fria.
# Aquilo não passa de um contra filé do mais barato! Não eram macios nem saborosos!
# Além de tudo, o preço não é nada compatível com o que nos ofereceram.
# Não volto mais!
# **************
#
# Inglês:  I visited the restaurant for the first time on Monday, 01/05, accompanied by my husband and my daughter.
#
# We opted for a dish with ancho steak, but the disappointment was huge, because when I cut the steak it was tough and when eating it, it tasted like sun meat, it just felt like salt.
#
# We asked to replace them with softer ones, but nothing worked, because besides taking 20 minutes to serve us the new steaks, they were still tough and our food was already cold.
#
# That is just a cheap steak! They were neither soft nor tasty!
# After all, the price is not at all compatible with what we were offered.
#
# I won't be back!
# sentence_br  visitei pela primeira vez o restaurante na segunda, dia 01/05, acompanhada do meu marido e minha filha.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.3333333333333333
# Polaridade
#  visitei pela primeira vez o restaurante na segunda, dia 01/05, acompanhada do meu marido e minha filha. : 0.25
# subjetividade
#  visitei pela primeira vez o restaurante na segunda, dia 01/05, acompanhada do meu marido e minha filha. : 0.3333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Optamos por um prato com bife ancho, mas a decepção foi enorme, pois quando cortei o bife ele estava duro e ao comê-lo, tinha um gosto de carne de sol, só se sentia um sabor de sal.
# sentence.sentiment.polarity:  -0.19629629629629627
# sentence.sentiment.subjectivity:  0.7111111111111111
# Polaridade
#  Optamos por um prato com bife ancho, mas a decepção foi enorme, pois quando cortei o bife ele estava duro e ao comê-lo, tinha um gosto de carne de sol, só se sentia um sabor de sal. : -0.19629629629629627
# subjetividade
#  Optamos por um prato com bife ancho, mas a decepção foi enorme, pois quando cortei o bife ele estava duro e ao comê-lo, tinha um gosto de carne de sol, só se sentia um sabor de sal. : 0.7111111111111111
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Pedimos para substituí-los por outros mais macios, mas nada deu certo, pois além de demorar 20 minutos para nos servirem os bifes novos, ainda continuavam duros e nossa comida já estava fria.
# sentence.sentiment.polarity:  -0.28417508417508414
# sentence.sentiment.subjectivity:  0.7626262626262627
# Polaridade
#  Pedimos para substituí-los por outros mais macios, mas nada deu certo, pois além de demorar 20 minutos para nos servirem os bifes novos, ainda continuavam duros e nossa comida já estava fria. : -0.28417508417508414
# subjetividade
#  Pedimos para substituí-los por outros mais macios, mas nada deu certo, pois além de demorar 20 minutos para nos servirem os bifes novos, ainda continuavam duros e nossa comida já estava fria. : 0.7626262626262627
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Aquilo não passa de um contra filé do mais barato!
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  Aquilo não passa de um contra filé do mais barato! : 0.5
# subjetividade
#  Aquilo não passa de um contra filé do mais barato! : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Não eram macios nem saborosos!
# sentence.sentiment.polarity:  0.125
# sentence.sentiment.subjectivity:  0.35
# Polaridade
#  Não eram macios nem saborosos! : 0.125
# subjetividade
#  Não eram macios nem saborosos! : 0.35
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Além de tudo, o preço não é nada compatível com o que nos ofereceram.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Além de tudo, o preço não é nada compatível com o que nos ofereceram. : 0.0
# subjetividade
#  Além de tudo, o preço não é nada compatível com o que nos ofereceram. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Não volto mais!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Não volto mais! : 0.0
# subjetividade
#  Não volto mais! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40015 x Na praia de pajuçara, otima localização, comida farta. O atendimento é rapido, apesar de fila na entrada. Chopp super gelado e petiscos variados. Ambiente descontraido,
# **************
# Inglês:  On pajuçara beach, great location, abundant food.
#  Service is fast, despite the queue at the entrance.
#  Super cold draft beer and varied snacks.
#  Relaxed atmosphere,
# sentence_br  Na praia de pajuçara, otima localização, comida farta.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.85
# Polaridade
#  Na praia de pajuçara, otima localização, comida farta. : 0.7
# subjetividade
#  Na praia de pajuçara, otima localização, comida farta. : 0.85
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  O atendimento é rapido, apesar de fila na entrada.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  O atendimento é rapido, apesar de fila na entrada. : 0.2
# subjetividade
#  O atendimento é rapido, apesar de fila na entrada. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Chopp super gelado e petiscos variados.
# sentence.sentiment.polarity:  -0.13333333333333333
# sentence.sentiment.subjectivity:  0.8333333333333333
# Polaridade
#  Chopp super gelado e petiscos variados. : -0.13333333333333333
# subjetividade
#  Chopp super gelado e petiscos variados. : 0.8333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Ambiente descontraido,
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Ambiente descontraido, : 0.0
# subjetividade
#  Ambiente descontraido, : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40016 x Esse restaurante é muito delicioso. Tudo do cardápio é muito saboroso e fresco. O ambiente é limpo e muito agradável. Os pratos são bem servidos para 2 pessoas e o atendimento é muito bom. Os funcionários são simpáticos e atenciosos. Sempre que vou à Salvador vou no Irmanjá.
# **************
#
# Inglês:  This restaurant is very delicious.
#  Everything on the menu is very tasty and fresh.
#  The environment is clean and very pleasant.
#  The dishes are well served for 2 people and the service is very good.
#  The staff are friendly and attentive.
#  Whenever I go to Salvador I go to Irmanjá.
# sentence_br  Esse restaurante é muito delicioso.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Esse restaurante é muito delicioso. : 1.0
# subjetividade
#  Esse restaurante é muito delicioso. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Tudo do cardápio é muito saboroso e fresco.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Tudo do cardápio é muito saboroso e fresco. : 0.25
# subjetividade
#  Tudo do cardápio é muito saboroso e fresco. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  O ambiente é limpo e muito agradável.
# sentence.sentiment.polarity:  0.6599999999999999
# sentence.sentiment.subjectivity:  0.8500000000000001
# Polaridade
#  O ambiente é limpo e muito agradável. : 0.6599999999999999
# subjetividade
#  O ambiente é limpo e muito agradável. : 0.8500000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Os pratos são bem servidos para 2 pessoas e o atendimento é muito bom.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Os pratos são bem servidos para 2 pessoas e o atendimento é muito bom. : 0.9099999999999999
# subjetividade
#  Os pratos são bem servidos para 2 pessoas e o atendimento é muito bom. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Os funcionários são simpáticos e atenciosos.
# sentence.sentiment.polarity:  0.3875
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  Os funcionários são simpáticos e atenciosos. : 0.3875
# subjetividade
#  Os funcionários são simpáticos e atenciosos. : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Sempre que vou à Salvador vou no Irmanjá.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Sempre que vou à Salvador vou no Irmanjá. : 0.0
# subjetividade
#  Sempre que vou à Salvador vou no Irmanjá. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40017 x Atendimento nota 1.000, lugar agradável, e comida maravilhosa!!!
# Uma carta de bebidas barbara, varias opções de peixes e frutos do mar, sem falar na qualidade da comida. Realmente o Coco Bambu superou nossas expectativas, ate mesmo por ter inaugurado a pouco tempo, esperávamos um lugar meio perdido, como sempre acontece em restaurantes novos. Mas no Coco Bambu não houve nada disso, tudo foi muito perfeito!
# **************
#
# Inglês:  Service note 1.
# 000, nice place, and wonderful food !!!
# A barbara drinks menu, several options of fish and seafood, not to mention the quality of the food.
#  Coco Bambu really exceeded our expectations, even because it opened a short time ago, we expected a little lost place, as always happens in new restaurants.
#  But at Coco Bambu there was none of that, everything was very perfect!
# sentence_br  Atendimento nota 1.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Atendimento nota 1. : 0.0
# subjetividade
#  Atendimento nota 1. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  000, lugar agradável, e comida maravilhosa!!!
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  000, lugar agradável, e comida maravilhosa!!! : 0.8
# subjetividade
#  000, lugar agradável, e comida maravilhosa!!! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Uma carta de bebidas barbara, varias opções de peixes e frutos do mar, sem falar na qualidade da comida.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Uma carta de bebidas barbara, varias opções de peixes e frutos do mar, sem falar na qualidade da comida. : 0.0
# subjetividade
#  Uma carta de bebidas barbara, varias opções de peixes e frutos do mar, sem falar na qualidade da comida. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Realmente o Coco Bambu superou nossas expectativas, ate mesmo por ter inaugurado a pouco tempo, esperávamos um lugar meio perdido, como sempre acontece em restaurantes novos.
# sentence.sentiment.polarity:  0.009772727272727271
# sentence.sentiment.subjectivity:  0.3709090909090909
# Polaridade
#  Realmente o Coco Bambu superou nossas expectativas, ate mesmo por ter inaugurado a pouco tempo, esperávamos um lugar meio perdido, como sempre acontece em restaurantes novos. : 0.009772727272727271
# subjetividade
#  Realmente o Coco Bambu superou nossas expectativas, ate mesmo por ter inaugurado a pouco tempo, esperávamos um lugar meio perdido, como sempre acontece em restaurantes novos. : 0.3709090909090909
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Mas no Coco Bambu não houve nada disso, tudo foi muito perfeito!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Mas no Coco Bambu não houve nada disso, tudo foi muito perfeito! : 1.0
# subjetividade
#  Mas no Coco Bambu não houve nada disso, tudo foi muito perfeito! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40018 x O melhor restaurante para um almoço em família! Comemos o prato da sugestão "Riso ai Ragu di Agnello" que estava fantástico, e o tradicional Petit Gateau de Chocolate, que sem dúvidas é o melhor da cidade!
# **************
#
# Inglês:  The best restaurant for a family lunch! We ate the "Riso ai Ragu di Agnello" suggestion dish, which was fantastic, and the traditional Petit Gateau de Chocolate, which is undoubtedly the best in town!
# sentence_br  O melhor restaurante para um almoço em família!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  O melhor restaurante para um almoço em família! : 1.0
# subjetividade
#  O melhor restaurante para um almoço em família! : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Comemos o prato da sugestão "Riso ai Ragu di Agnello" que estava fantástico, e o tradicional Petit Gateau de Chocolate, que sem dúvidas é o melhor da cidade!
# sentence.sentiment.polarity:  0.4666666666666666
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Comemos o prato da sugestão "Riso ai Ragu di Agnello" que estava fantástico, e o tradicional Petit Gateau de Chocolate, que sem dúvidas é o melhor da cidade! : 0.4666666666666666
# subjetividade
#  Comemos o prato da sugestão "Riso ai Ragu di Agnello" que estava fantástico, e o tradicional Petit Gateau de Chocolate, que sem dúvidas é o melhor da cidade! : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40019 x uma delicia de Restaurante , creio que é o melhor em comparação côco Bambu de outros Estados que ja fui, a decoração é maravilhosa e o cardapio tambem , a sobremesa de  banana flambada com sorvete é uma delicia ,
# **************
#
# Inglês:  a restaurant delight, I think it's the best compared to Bamboo from other states I've been to, the decor is wonderful and the menu too, the banana dessert flambéed with ice cream is a delight,
# sentence_br  uma delicia de Restaurante , creio que é o melhor em comparação côco Bambu de outros Estados que ja fui, a decoração é maravilhosa e o cardapio tambem , a sobremesa de  banana flambada com sorvete é uma delicia ,
# sentence.sentiment.polarity:  0.625
# sentence.sentiment.subjectivity:  0.5583333333333333
# Polaridade
#  uma delicia de Restaurante , creio que é o melhor em comparação côco Bambu de outros Estados que ja fui, a decoração é maravilhosa e o cardapio tambem , a sobremesa de  banana flambada com sorvete é uma delicia , : 0.625
# subjetividade
#  uma delicia de Restaurante , creio que é o melhor em comparação côco Bambu de outros Estados que ja fui, a decoração é maravilhosa e o cardapio tambem , a sobremesa de  banana flambada com sorvete é uma delicia , : 0.5583333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40020 x Se for ao Rio de Janeiro em Copacabana, precisa comer no "o Caranguejo", pratos bem servidos, o restaurante é apertado, mas os garçons são simpáticos e a comida de ótima qualidade.
# **************
#
# Inglês:  If you go to Rio de Janeiro in Copacabana, you need to eat at "o Caranguejo", dishes well served, the restaurant is tight, but the waiters are friendly and the food is of great quality.
# sentence_br  Se for ao Rio de Janeiro em Copacabana, precisa comer no "o Caranguejo", pratos bem servidos, o restaurante é apertado, mas os garçons são simpáticos e a comida de ótima qualidade.
# sentence.sentiment.polarity:  0.33214285714285713
# sentence.sentiment.subjectivity:  0.5119047619047619
# Polaridade
#  Se for ao Rio de Janeiro em Copacabana, precisa comer no "o Caranguejo", pratos bem servidos, o restaurante é apertado, mas os garçons são simpáticos e a comida de ótima qualidade. : 0.33214285714285713
# subjetividade
#  Se for ao Rio de Janeiro em Copacabana, precisa comer no "o Caranguejo", pratos bem servidos, o restaurante é apertado, mas os garçons são simpáticos e a comida de ótima qualidade. : 0.5119047619047619
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40021 x O suco estava maravilhoso mas o crepe de queijo com tomate e manjericao nao estava bom. O queijo nao era bom e estava em grande, enorme quantidade que fez o crepe ficar super pesado. Passei muito mal a noite toda.
# **************
#
# Inglês:  The juice was wonderful but the cheese crepe with tomato and basil was not good.
#  The cheese was not good and it was in large, huge quantities that made the crepe super heavy.
#  I was very ill all night.
# sentence_br  O suco estava maravilhoso mas o crepe de queijo com tomate e manjericao nao estava bom.
# sentence.sentiment.polarity:  0.325
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  O suco estava maravilhoso mas o crepe de queijo com tomate e manjericao nao estava bom. : 0.325
# subjetividade
#  O suco estava maravilhoso mas o crepe de queijo com tomate e manjericao nao estava bom. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  O queijo nao era bom e estava em grande, enorme quantidade que fez o crepe ficar super pesado.
# sentence.sentiment.polarity:  0.07952380952380954
# sentence.sentiment.subjectivity:  0.6190476190476191
# Polaridade
#  O queijo nao era bom e estava em grande, enorme quantidade que fez o crepe ficar super pesado. : 0.07952380952380954
# subjetividade
#  O queijo nao era bom e estava em grande, enorme quantidade que fez o crepe ficar super pesado. : 0.6190476190476191
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Passei muito mal a noite toda.
# sentence.sentiment.polarity:  -0.65
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Passei muito mal a noite toda. : -0.65
# subjetividade
#  Passei muito mal a noite toda. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40022 x O lugar é bom. Sempre tem música ao vivo e na maioria das vezes é pop rock/rock. A comida é excelente e os preços são justos. Mas é bom chegar cedo pra pegar um bom lugar. Geralmente fica bem lotado.
# **************
#
# Inglês:  The place is good.
#  There is always live music and most of the time it is pop rock / rock.
#  The food is excellent and the prices are fair.
#  But it's good to get there early to get a good seat.
#  It usually gets very crowded.
# sentence_br  O lugar é bom.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  O lugar é bom. : 0.7
# subjetividade
#  O lugar é bom. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Sempre tem música ao vivo e na maioria das vezes é pop rock/rock.
# sentence.sentiment.polarity:  0.3181818181818182
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Sempre tem música ao vivo e na maioria das vezes é pop rock/rock. : 0.3181818181818182
# subjetividade
#  Sempre tem música ao vivo e na maioria das vezes é pop rock/rock. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  A comida é excelente e os preços são justos.
# sentence.sentiment.polarity:  0.85
# sentence.sentiment.subjectivity:  0.95
# Polaridade
#  A comida é excelente e os preços são justos. : 0.85
# subjetividade
#  A comida é excelente e os preços são justos. : 0.95
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Mas é bom chegar cedo pra pegar um bom lugar.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5000000000000001
# Polaridade
#  Mas é bom chegar cedo pra pegar um bom lugar. : 0.5
# subjetividade
#  Mas é bom chegar cedo pra pegar um bom lugar. : 0.5000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Geralmente fica bem lotado.
# sentence.sentiment.polarity:  -0.024999999999999994
# sentence.sentiment.subjectivity:  0.275
# Polaridade
#  Geralmente fica bem lotado. : -0.024999999999999994
# subjetividade
#  Geralmente fica bem lotado. : 0.275
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40023 x Ambiente charmoso e elegante, cardapio com boas opções, a comida é boa, minha carne na verdade não estava das melhores, esperava mais, a carta de vinhos é boa... porém gostaria de destacar q nesse lugar o q nos conquistou foi a simpatia dos funcionários, os garçons e o maître que são generosamente agradáveis. De uma benevolência inestimável. Exercem com louvor suas funções. Parabéns!!! Recomendo, voltaria e daria a oportunidade de me preparem uma carne melhor.
# **************
# Inglês:  Charming and elegant atmosphere, menu with good options, the food is good, my meat was not really the best, I expected more, the wine list is good.
# .. but I would like to highlight that in this place what won us over was the friendliness of the staff, the waiters and the maître d 'who are generously pleasant.
#  Of priceless benevolence.
#  They exercise their functions with praise.
#  Congratulations!!! I recommend, would go back and give the opportunity to prepare me a better meat.
# sentence_br  Ambiente charmoso e elegante, cardapio com boas opções, a comida é boa, minha carne na verdade não estava das melhores, esperava mais, a carta de vinhos é boa.
# sentence.sentiment.polarity:  0.5111111111111111
# sentence.sentiment.subjectivity:  0.577777777777778
# Polaridade
#  Ambiente charmoso e elegante, cardapio com boas opções, a comida é boa, minha carne na verdade não estava das melhores, esperava mais, a carta de vinhos é boa. : 0.5111111111111111
# subjetividade
#  Ambiente charmoso e elegante, cardapio com boas opções, a comida é boa, minha carne na verdade não estava das melhores, esperava mais, a carta de vinhos é boa. : 0.577777777777778
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  .. porém gostaria de destacar q nesse lugar o q nos conquistou foi a simpatia dos funcionários, os garçons e o maître que são generosamente agradáveis.
# sentence.sentiment.polarity:  0.7333333333333333
# sentence.sentiment.subjectivity:  0.9666666666666667
# Polaridade
#  .. porém gostaria de destacar q nesse lugar o q nos conquistou foi a simpatia dos funcionários, os garçons e o maître que são generosamente agradáveis. : 0.7333333333333333
# subjetividade
#  .. porém gostaria de destacar q nesse lugar o q nos conquistou foi a simpatia dos funcionários, os garçons e o maître que são generosamente agradáveis. : 0.9666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  De uma benevolência inestimável.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  De uma benevolência inestimável. : 1.0
# subjetividade
#  De uma benevolência inestimável. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Exercem com louvor suas funções.
# sentence.sentiment.polarity:  0.0
# ...
# subjetividade
#  O restante possui uma decoração bem aconchegante, com iluminação baixa o que traz um clima bem romântico. : 0.6416666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Recomendo para comemorações de casal.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo para comemorações de casal. : 0.0
# subjetividade
#  Recomendo para comemorações de casal. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  A comida é excelente, muito bem servida e o cardápio possui uma boa diversidade de massas, frutos do mar e carnes.
# sentence.sentiment.polarity:  0.6333333333333333
# sentence.sentiment.subjectivity:  0.6333333333333334
# Polaridade
#  A comida é excelente, muito bem servida e o cardápio possui uma boa diversidade de massas, frutos do mar e carnes. : 0.6333333333333333
# subjetividade
#  A comida é excelente, muito bem servida e o cardápio possui uma boa diversidade de massas, frutos do mar e carnes. : 0.6333333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  O atendimento é muito bom, os garçons são bem atenciosos.
# sentence.sentiment.polarity:  0.715
# sentence.sentiment.subjectivity:  0.8900000000000001
# Polaridade
#  O atendimento é muito bom, os garçons são bem atenciosos. : 0.715
# subjetividade
#  O atendimento é muito bom, os garçons são bem atenciosos. : 0.8900000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  O único ponto negativo é o estacionamento, pois tem poucas vagas disponiveis (em torno de 4) em frente ao restaurante.
# sentence.sentiment.polarity:  -0.024999999999999994
# sentence.sentiment.subjectivity:  0.475
# Polaridade
#  O único ponto negativo é o estacionamento, pois tem poucas vagas disponiveis (em torno de 4) em frente ao restaurante. : -0.024999999999999994
# subjetividade
#  O único ponto negativo é o estacionamento, pois tem poucas vagas disponiveis (em torno de 4) em frente ao restaurante. : 0.475
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40711 x muito bom gostei comida muito boa e saborosa lugar muito tranquilo bem agradável com ambiente muito bom atendimento bom
# **************
#
# Inglês:  very good I liked very good and tasty food very quiet place very pleasant with very good atmosphere good service
# sentence_br  muito bom gostei comida muito boa e saborosa lugar muito tranquilo bem agradável com ambiente muito bom atendimento bom
# sentence.sentiment.polarity:  0.7119047619047619
# sentence.sentiment.subjectivity:  0.7390476190476191
# Polaridade
#  muito bom gostei comida muito boa e saborosa lugar muito tranquilo bem agradável com ambiente muito bom atendimento bom : 0.7119047619047619
# subjetividade
#  muito bom gostei comida muito boa e saborosa lugar muito tranquilo bem agradável com ambiente muito bom atendimento bom : 0.7390476190476191
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40712 x A estrutura da pizzaria é ótima, tem uma ótima área de lazer para crianças e a pizza é boa. No entanto o atendimento é péssimo! Já fui 3 vezes e todas as vezes fui mal atendida! A última vez, foi no meio da semana e a pizzaria estava vazia, mas precisei pedir ao garcon 5 vezes pra que ele trouxesse um refrigerante, que demorou 1 hora pra chegar. Lamentável uma estrutura tão linda, com um atendimento dessa qualidade.
# **************
# Inglês:  The structure of the pizzeria is great, it has a great play area for children and the pizza is good.
#  However the service is terrible! I've been 3 times and every time I was poorly attended! The last time, it was in the middle of the week and the pizzeria was empty, but I had to ask the waiter 5 times for him to bring a soft drink, which took 1 hour to arrive.
#  Such a beautiful structure, with such quality service, is unfortunate.
# sentence_br  A estrutura da pizzaria é ótima, tem uma ótima área de lazer para crianças e a pizza é boa.
# sentence.sentiment.polarity:  0.7666666666666666
# sentence.sentiment.subjectivity:  0.7000000000000001
# Polaridade
#  A estrutura da pizzaria é ótima, tem uma ótima área de lazer para crianças e a pizza é boa. : 0.7666666666666666
# subjetividade
#  A estrutura da pizzaria é ótima, tem uma ótima área de lazer para crianças e a pizza é boa. : 0.7000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  No entanto o atendimento é péssimo!
# sentence.sentiment.polarity:  -1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  No entanto o atendimento é péssimo! : -1.0
# subjetividade
#  No entanto o atendimento é péssimo! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Já fui 3 vezes e todas as vezes fui mal atendida!
# sentence.sentiment.polarity:  -0.5
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Já fui 3 vezes e todas as vezes fui mal atendida! : -0.5
# subjetividade
#  Já fui 3 vezes e todas as vezes fui mal atendida! : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  A última vez, foi no meio da semana e a pizzaria estava vazia, mas precisei pedir ao garcon 5 vezes pra que ele trouxesse um refrigerante, que demorou 1 hora pra chegar.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.22916666666666666
# Polaridade
#  A última vez, foi no meio da semana e a pizzaria estava vazia, mas precisei pedir ao garcon 5 vezes pra que ele trouxesse um refrigerante, que demorou 1 hora pra chegar. : 0.0
# subjetividade
#  A última vez, foi no meio da semana e a pizzaria estava vazia, mas precisei pedir ao garcon 5 vezes pra que ele trouxesse um refrigerante, que demorou 1 hora pra chegar. : 0.22916666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Lamentável uma estrutura tão linda, com um atendimento dessa qualidade.
# sentence.sentiment.polarity:  0.0875
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Lamentável uma estrutura tão linda, com um atendimento dessa qualidade. : 0.0875
# subjetividade
#  Lamentável uma estrutura tão linda, com um atendimento dessa qualidade. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40713 x Garçom Alan muito atencioso. Pratos de excelente qualidade. Ambiente agradável. Batata deliciosa e carne suculento
#
# **************
#
# Inglês:  Waiter Alan very attentive.
#  Excellent quality dishes.
#  Pleasant environment.
#  Delicious potato and juicy meat
# sentence_br  Garçom Alan muito atencioso.
# sentence.sentiment.polarity:  0.52
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Garçom Alan muito atencioso. : 0.52
# subjetividade
#  Garçom Alan muito atencioso. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Pratos de excelente qualidade.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Pratos de excelente qualidade. : 1.0
# subjetividade
#  Pratos de excelente qualidade. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Ambiente agradável.
# sentence.sentiment.polarity:  0.7333333333333333
# sentence.sentiment.subjectivity:  0.9666666666666667
# Polaridade
#  Ambiente agradável. : 0.7333333333333333
# subjetividade
#  Ambiente agradável. : 0.9666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Batata deliciosa e carne suculento
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Batata deliciosa e carne suculento : 1.0
# subjetividade
#  Batata deliciosa e carne suculento : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40714 x Comida bem saborosa e bem servida, ambiente agradável  e atendimento excelente! Super recomendo!!!!!!
# **************
#
# Inglês:  Very tasty and well served food, pleasant atmosphere and excellent service! Super recommend !!!!!!
# sentence_br  Comida bem saborosa e bem servida, ambiente agradável  e atendimento excelente!
# sentence.sentiment.polarity:  0.6444444444444445
# sentence.sentiment.subjectivity:  0.7555555555555555
# Polaridade
#  Comida bem saborosa e bem servida, ambiente agradável  e atendimento excelente! : 0.6444444444444445
# subjetividade
#  Comida bem saborosa e bem servida, ambiente agradável  e atendimento excelente! : 0.7555555555555555
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  Super recomendo!!!!!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Super recomendo!!!!! : 1.0
# subjetividade
#  Super recomendo!!!!! : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40715 x Fui em razão dele ter saído na veja, vale realmente à pena, apesar do meu drink ter chegado não tão gelado, o bar tem um ótimo ambiente, estava bem animado e a comida estava deliciosa, pedimos um mexido muito bacana.
# **************
#
# Inglês:  I went because he went out to see it, it is really worth it, although my drink arrived not so cold, the bar has a great atmosphere, it was very lively and the food was delicious, we ordered a very nice stir.
# sentence_br  Fui em razão dele ter saído na veja, vale realmente à pena, apesar do meu drink ter chegado não tão gelado, o bar tem um ótimo ambiente, estava bem animado e a comida estava deliciosa, pedimos um mexido muito bacana.
# sentence.sentiment.polarity:  0.4095454545454545
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Fui em razão dele ter saído na veja, vale realmente à pena, apesar do meu drink ter chegado não tão gelado, o bar tem um ótimo ambiente, estava bem animado e a comida estava deliciosa, pedimos um mexido muito bacana. : 0.4095454545454545
# subjetividade
#  Fui em razão dele ter saído na veja, vale realmente à pena, apesar do meu drink ter chegado não tão gelado, o bar tem um ótimo ambiente, estava bem animado e a comida estava deliciosa, pedimos um mexido muito bacana. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-40000-50000.txt
# **************
#
# var 40716 x Excelente! Entrecot com geléia de pimenta é sensaciona! Lugar aconchegante, ótimo atendimento! Não deixe de experimentar o feijão mexido! Boa carta de vinhos e cerveja gelada! Aos finais de semana, lota! Melhor chegar cedo para escolher um bom lugar.
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
