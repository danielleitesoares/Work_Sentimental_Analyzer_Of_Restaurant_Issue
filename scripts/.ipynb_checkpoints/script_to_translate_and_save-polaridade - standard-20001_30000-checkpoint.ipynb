# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pcorrea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 20000
terminou = 30000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  127,709,433,856 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 100000

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("Errou no tipo no regex")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
for x in df['reviewBody']:
    ini = ti
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 20001 x Pra quem gosta de andar com a família, vale a pena conferir, gastronomia de qualidade, sempre quando viajo frequento este local.
# **************
#
# Inglês:  For those who like to walk with the family, it is worth checking out, quality cuisine, always when I travel I frequent this place.
# sentence_br  Pra quem gosta de andar com a família, vale a pena conferir, gastronomia de qualidade, sempre quando viajo frequento este local.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Pra quem gosta de andar com a família, vale a pena conferir, gastronomia de qualidade, sempre quando viajo frequento este local. : 0.2
# subjetividade
#  Pra quem gosta de andar com a família, vale a pena conferir, gastronomia de qualidade, sempre quando viajo frequento este local. : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
: 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20004 x A simplicidade da culinária regional se une ao requinte dos grandes chefes de cozinha. Peixe delicioso à moda amazônica Uma experiência gastronômica inesquecível.
# **************
#
# Inglês:  The simplicity of regional cuisine is combined with the refinement of great chefs.
#  Delicious fish in the Amazonian style An unforgettable gastronomic experience.
# sentence_br  A simplicidade da culinária regional se une ao requinte dos grandes chefes de cozinha.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  A simplicidade da culinária regional se une ao requinte dos grandes chefes de cozinha. : 0.8
# subjetividade
#  A simplicidade da culinária regional se une ao requinte dos grandes chefes de cozinha. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Peixe delicioso à moda amazônica Uma experiência gastronômica inesquecível.
# sentence.sentiment.polarity:  0.9
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Peixe delicioso à moda amazônica Uma experiência gastronômica inesquecível. : 0.9
# subjetividade
#  Peixe delicioso à moda amazônica Uma experiência gastronômica inesquecível. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20005 x Para um almoço rápido e saudável. Opções de salada, legumes, quiches e pratos quentes, comida gostosa mas faltou um tempero e estar mais quente.
# Lugar e simples mas gostoso.
# **************
#
# Inglês:  For a quick and healthy lunch.
#  Salad options, vegetables, quiches and hot dishes, delicious food but lacking a seasoning and being hotter.
#
# Place and simple but tasty.
# sentence_br  Para um almoço rápido e saudável.
# sentence.sentiment.polarity:  0.41666666666666663
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Para um almoço rápido e saudável. : 0.41666666666666663
# subjetividade
#  Para um almoço rápido e saudável. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Opções de salada, legumes, quiches e pratos quentes, comida gostosa mas faltou um tempero e estar mais quente.
# sentence.sentiment.polarity:  0.625
# sentence.sentiment.subjectivity:  0.925
# Polaridade
#  Opções de salada, legumes, quiches e pratos quentes, comida gostosa mas faltou um tempero e estar mais quente. : 0.625
# subjetividade
#  Opções de salada, legumes, quiches e pratos quentes, comida gostosa mas faltou um tempero e estar mais quente. : 0.925
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Lugar e simples mas gostoso.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.35714285714285715
# Polaridade
#  Lugar e simples mas gostoso. : 0.0
# subjetividade
#  Lugar e simples mas gostoso. : 0.35714285714285715
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20006 x A comida é sempre muito boa, mas nunca sei como avaliar o atendimento, pois de alguns garçons/garçonetes são muito atenciosos e outros não! da última vez tivemos que esperar muito pois um prato principal veio primeiro que o outro e as entradas com o prato principal! Achei um pouco desorganizado! Mas depende do dia!
# **************
# Inglês:  The food is always very good, but I never know how to evaluate the service, because some waiters / waitresses are very attentive and others are not! the last time we had to wait too long as one main course came first than the other and the starters with the main course! I found it a little disorganized! But it depends on the day!
# sentence_br  A comida é sempre muito boa, mas nunca sei como avaliar o atendimento, pois de alguns garçons/garçonetes são muito atenciosos e outros não!
# sentence.sentiment.polarity:  0.78
# sentence.sentiment.subjectivity:  0.8900000000000001
# Polaridade
#  A comida é sempre muito boa, mas nunca sei como avaliar o atendimento, pois de alguns garçons/garçonetes são muito atenciosos e outros não! : 0.78
# subjetividade
#  A comida é sempre muito boa, mas nunca sei como avaliar o atendimento, pois de alguns garçons/garçonetes são muito atenciosos e outros não! : 0.8900000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  da última vez tivemos que esperar muito pois um prato principal veio primeiro que o outro e as entradas com o prato principal!
# sentence.sentiment.polarity:  0.075
# sentence.sentiment.subjectivity:  0.3069444444444444
# Polaridade
#  da última vez tivemos que esperar muito pois um prato principal veio primeiro que o outro e as entradas com o prato principal! : 0.075
# subjetividade
#  da última vez tivemos que esperar muito pois um prato principal veio primeiro que o outro e as entradas com o prato principal! : 0.3069444444444444
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Achei um pouco desorganizado!
# sentence.sentiment.polarity:  -0.234375
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Achei um pouco desorganizado! : -0.234375
# subjetividade
#  Achei um pouco desorganizado! : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Mas depende do dia!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Mas depende do dia! : 0.0
# subjetividade
#  Mas depende do dia! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20007 x Franquia de sorvetes que frequentamos em muitas cidades. Em Curitiba o atendimento é muito bom, ambiente agradável e familiar. Central. Produtos seguem o padrão nacional e nós aprovamos. Problemas encontrados foram o som alto da TV (que diminuímos) e o ar condicionado... Muito gelado para uma sorveteria, ainda mais em Curitiba... rsrsrs.
# **************
#
# Inglês:  Ice cream franchise that we frequent in many cities.
#  In Curitiba the service is very good, pleasant and familiar.
#  Central.
#  Products follow the national standard and we approve.
#  Problems encountered were the loud sound of the TV (which we reduced) and the air conditioning.
# .. Too cold for an ice cream parlor, especially in Curitiba.
# .. lol.
# sentence_br  Franquia de sorvetes que frequentamos em muitas cidades.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Franquia de sorvetes que frequentamos em muitas cidades. : 0.3
# subjetividade
#  Franquia de sorvetes que frequentamos em muitas cidades. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Em Curitiba o atendimento é muito bom, ambiente agradável e familiar.
# sentence.sentiment.polarity:  0.6727777777777777
# sentence.sentiment.subjectivity:  0.748888888888889
# Polaridade
#  Em Curitiba o atendimento é muito bom, ambiente agradável e familiar. : 0.6727777777777777
# subjetividade
#  Em Curitiba o atendimento é muito bom, ambiente agradável e familiar. : 0.748888888888889
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Central.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.25
# Polaridade
#  Central. : 0.0
# subjetividade
#  Central. : 0.25
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Produtos seguem o padrão nacional e nós aprovamos.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Produtos seguem o padrão nacional e nós aprovamos. : 0.0
# subjetividade
#  Produtos seguem o padrão nacional e nós aprovamos. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Problemas encontrados foram o som alto da TV (que diminuímos) e o ar condicionado.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Problemas encontrados foram o som alto da TV (que diminuímos) e o ar condicionado. : 0.25
# subjetividade
#  Problemas encontrados foram o som alto da TV (que diminuímos) e o ar condicionado. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  .. Muito gelado para uma sorveteria, ainda mais em Curitiba.
# sentence.sentiment.polarity:  -0.3
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  .. Muito gelado para uma sorveteria, ainda mais em Curitiba. : -0.3
# subjetividade
#  .. Muito gelado para uma sorveteria, ainda mais em Curitiba. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  .. rsrsrs.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  .. rsrsrs. : 0.8
# subjetividade
#  .. rsrsrs. : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20008 x Péssima opção de Mc, o atendimento é horrível, sempre demorado e com poucos caixas. É uma das opções para comer de madrugada, pós balada, então esta sempre cheio!
# Apesar de que, em qualquer horário é cheio e a limpeza do lugar é inexistente.
# Os banheiros estão sempre sujos, o chão e as mesas também.
# Até para realizar pedido pelo Drive Thru é demorado!
# **************
#
# Inglês:  Mc's lousy option, the service is horrible, always time consuming and with few boxes.
#  It is one of the options to eat at dawn, after a party, so it is always full!
# Although, at any time it is full and the cleanliness of the place is non-existent.
#
# The bathrooms are always dirty, the floor and the tables too.
#
# Even ordering through Drive Thru takes time!
# sentence_br  Péssima opção de Mc, o atendimento é horrível, sempre demorado e com poucos caixas.
# sentence.sentiment.polarity:  -0.5666666666666667
# sentence.sentiment.subjectivity:  0.5333333333333333
# Polaridade
#  Péssima opção de Mc, o atendimento é horrível, sempre demorado e com poucos caixas. : -0.5666666666666667
# subjetividade
#  Péssima opção de Mc, o atendimento é horrível, sempre demorado e com poucos caixas. : 0.5333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  É uma das opções para comer de madrugada, pós balada, então esta sempre cheio!
# sentence.sentiment.polarity:  0.4375
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  É uma das opções para comer de madrugada, pós balada, então esta sempre cheio! : 0.4375
# subjetividade
#  É uma das opções para comer de madrugada, pós balada, então esta sempre cheio! : 0.55
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Apesar de que, em qualquer horário é cheio e a limpeza do lugar é inexistente.
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  Apesar de que, em qualquer horário é cheio e a limpeza do lugar é inexistente. : 0.35
# subjetividade
#  Apesar de que, em qualquer horário é cheio e a limpeza do lugar é inexistente. : 0.55
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Os banheiros estão sempre sujos, o chão e as mesas também.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Os banheiros estão sempre sujos, o chão e as mesas também. : -0.6
# subjetividade
#  Os banheiros estão sempre sujos, o chão e as mesas também. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Até para realizar pedido pelo Drive Thru é demorado!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Até para realizar pedido pelo Drive Thru é demorado! : 0.0
# subjetividade
#  Até para realizar pedido pelo Drive Thru é demorado! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20009 x Adoramos! Comida muito saborosa, porções bem.servidas, excelente atendimento, ambiente agradável. Recomendamos!
# **************
# Inglês:  We love it! Very tasty food, portions as well.
# served, excellent service, pleasant atmosphere.
#  We recommend!
# sentence_br  Adoramos!
# sentence.sentiment.polarity:  0.625
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Adoramos! : 0.625
# subjetividade
#  Adoramos! : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Comida muito saborosa, porções bem.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Comida muito saborosa, porções bem. : 0.2
# subjetividade
#  Comida muito saborosa, porções bem. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  servidas, excelente atendimento, ambiente agradável.
# sentence.sentiment.polarity:  0.8666666666666667
# sentence.sentiment.subjectivity:  0.9833333333333334
# Polaridade
#  servidas, excelente atendimento, ambiente agradável. : 0.8666666666666667
# subjetividade
#  servidas, excelente atendimento, ambiente agradável. : 0.9833333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Recomendamos!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendamos! : 0.0
# subjetividade
#  Recomendamos! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20010 x O ambiente e sua comida é pura satisfação.  Um lugar aonde vc se sente aconchego em pequenos detalhes que faz toda a diferença.  Sabores e texturas divino. A chef está de parabéns.  O preço é justo.  Vale muito a pena
# **************
#
# Inglês:  The environment and its food is pure satisfaction.
#   A place where you feel cozy in small details that makes all the difference.
#   Divine flavors and textures.
#  The chef is to be congratulated.
#   The price is right.
#   It's really worth it
# sentence_br  O ambiente e sua comida é pura satisfação.
# sentence.sentiment.polarity:  0.21428571428571427
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  O ambiente e sua comida é pura satisfação. : 0.21428571428571427
# subjetividade
#  O ambiente e sua comida é pura satisfação. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Um lugar aonde vc se sente aconchego em pequenos detalhes que faz toda a diferença.
# sentence.sentiment.polarity:  -0.22499999999999998
# sentence.sentiment.subjectivity:  0.575
# Polaridade
#  Um lugar aonde vc se sente aconchego em pequenos detalhes que faz toda a diferença. : -0.22499999999999998
# subjetividade
#  Um lugar aonde vc se sente aconchego em pequenos detalhes que faz toda a diferença. : 0.575
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Sabores e texturas divino.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Sabores e texturas divino. : 0.0
# subjetividade
#  Sabores e texturas divino. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  A chef está de parabéns.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  A chef está de parabéns. : 0.0
# subjetividade
#  A chef está de parabéns. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  O preço é justo.
# sentence.sentiment.polarity:  0.2857142857142857
# sentence.sentiment.subjectivity:  0.5357142857142857
# Polaridade
#  O preço é justo. : 0.2857142857142857
# subjetividade
#  O preço é justo. : 0.5357142857142857
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Vale muito a pena
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale muito a pena : 0.3
# subjetividade
#  Vale muito a pena : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20011 x Ótima experiência!!
# Quando chegamos, sentimos um cheiro forte de madeira, achei que ia me incomodar, mas acostumei em 5 minutos!
# Os moveis e arrumação é bem rústica, mas bem confortável!
# Pedimos um bobó de camarão. Inexplicavelmente bom!! Bem servido! Recomendo!!
# **************
#
# Inglês:  Great experience !!
# When we arrived, we felt a strong smell of wood, I thought it would bother me, but I got used to it in 5 minutes!
# The furniture and storage is very rustic, but very comfortable!
# We ordered a prawn bobó.
#  Inexplicably good !! Well served! I recommend!!
# sentence_br  Ótima experiência!!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ótima experiência!! : 1.0
# subjetividade
#  Ótima experiência!! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Quando chegamos, sentimos um cheiro forte de madeira, achei que ia me incomodar, mas acostumei em 5 minutos!
# sentence.sentiment.polarity:  0.5416666666666666
# sentence.sentiment.subjectivity:  0.7333333333333333
# Polaridade
#  Quando chegamos, sentimos um cheiro forte de madeira, achei que ia me incomodar, mas acostumei em 5 minutos! : 0.5416666666666666
# subjetividade
#  Quando chegamos, sentimos um cheiro forte de madeira, achei que ia me incomodar, mas acostumei em 5 minutos! : 0.7333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Também conta com um excelente espaço kids.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Também conta com um excelente espaço kids. : 1.0
# subjetividade
#  Também conta com um excelente espaço kids. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20014 x Comida muito boa, atendimento diferenciado e o translado é perfeito com pontualidade plena.
# O ambiente é simples, apenas um incômodo com barulho das crianças!
# **************
#
# Inglês:  Very good food, differentiated service and the transfer is perfect with full punctuality.
#
# The environment is simple, just a nuisance with the noise of children!
# sentence_br  Comida muito boa, atendimento diferenciado e o translado é perfeito com pontualidade plena.
# sentence.sentiment.polarity:  0.7533333333333333
# sentence.sentiment.subjectivity:  0.7766666666666667
# Polaridade
#  Comida muito boa, atendimento diferenciado e o translado é perfeito com pontualidade plena. : 0.7533333333333333
# subjetividade
#  Comida muito boa, atendimento diferenciado e o translado é perfeito com pontualidade plena. : 0.7766666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  O ambiente é simples, apenas um incômodo com barulho das crianças!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.35714285714285715
# Polaridade
#  O ambiente é simples, apenas um incômodo com barulho das crianças! : 0.0
# subjetividade
#  O ambiente é simples, apenas um incômodo com barulho das crianças! : 0.35714285714285715
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20015 x Já fui várias vezes a este restaurante que é uma Pizzaria e serve também refeições. O filé a parmegiana é ótimo e a porção é grande. Pedimos um para 2 pessoas, que serve 3 tranquilamente. As pizzas são bem gostosas. O restaurante tem ar condicionado e para famílias com crianças (que é o meu caso) tem um playground enorme, com vídeo game, balanço, escorregador, pula-pula, casinha e vários outros brinquedos. Meu filho adora o local. Recomendo. Tem também um local que pode ser reservado para aniversários, sem cobrança de adicional.
# **************
#
# Inglês:  I have been to this restaurant that is a Pizzeria several times and also serves meals.
#  The parmigiana fillet is great and the portion is big.
#  We ordered one for 2 people, serving 3 quietly.
#  The pizzas are very tasty.
#  The restaurant is air conditioned and for families with children (which is my case) it has a huge playground, with video game, swing, slide, pogo stick, little house and several other toys.
#  My son loves the place.
#  I recommend.
#  There is also a place that can be reserved for birthdays, without additional charges.
# sentence_br  Já fui várias vezes a este restaurante que é uma Pizzaria e serve também refeições.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Já fui várias vezes a este restaurante que é uma Pizzaria e serve também refeições. : 0.0
# subjetividade
#  Já fui várias vezes a este restaurante que é uma Pizzaria e serve também refeições. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  O filé a parmegiana é ótimo e a porção é grande.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.425
# Polaridade
#  O filé a parmegiana é ótimo e a porção é grande. : 0.4
# subjetividade
#  O filé a parmegiana é ótimo e a porção é grande. : 0.425
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Pedimos um para 2 pessoas, que serve 3 tranquilamente.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.3333333333333333
# Polaridade
#  Pedimos um para 2 pessoas, que serve 3 tranquilamente. : 0.0
# subjetividade
#  Pedimos um para 2 pessoas, que serve 3 tranquilamente. : 0.3333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  As pizzas são bem gostosas.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  As pizzas são bem gostosas. : 0.2
# subjetividade
#  As pizzas são bem gostosas. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  O restaurante tem ar condicionado e para famílias com crianças (que é o meu caso) tem um playground enorme, com vídeo game, balanço, escorregador, pula-pula, casinha e vários outros brinquedos.
# sentence.sentiment.polarity:  -0.062499999999999986
# sentence.sentiment.subjectivity:  0.43499999999999994
# Polaridade
#  O restaurante tem ar condicionado e para famílias com crianças (que é o meu caso) tem um playground enorme, com vídeo game, balanço, escorregador, pula-pula, casinha e vários outros brinquedos. : -0.062499999999999986
# subjetividade
#  O restaurante tem ar condicionado e para famílias com crianças (que é o meu caso) tem um playground enorme, com vídeo game, balanço, escorregador, pula-pula, casinha e vários outros brinquedos. : 0.43499999999999994
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Meu filho adora o local.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Meu filho adora o local. : 0.0
# subjetividade
#  Meu filho adora o local. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Recomendo.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo. : 0.0
# subjetividade
#  Recomendo. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Tem também um local que pode ser reservado para aniversários, sem cobrança de adicional.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tem também um local que pode ser reservado para aniversários, sem cobrança de adicional. : 0.0
# subjetividade
#  Tem também um local que pode ser reservado para aniversários, sem cobrança de adicional. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20016 x O restaurante oferece uma diversidade de pratos incríveis, fica difícil escolher um só! a finalização do spaghetti al formaggio no salão é um diferencial positivo, pois possibilita ao cliente acompanhar de perto o processo de preparação do prato, e aprender algumas dicas ali utilizadas.
# Achei o atendimento rápido, tanto para os pratos finalizados no salão como para os outros pratos.
# O maior problema foi referente a carta de vinhos e o cardápio de bebidas, não sei se foi algo pontual ou se é um problema recorrente, mas pelo menos 4 vinhos do não estavam disponíveis, então optei pela limonada, que também estava em falta diversos sabores.
# O atendimento é excelente, todos funcionários são muito atenciosos.
# **************
# Inglês:  The restaurant offers a variety of incredible dishes, it is difficult to choose just one! the completion of spaghetti al formaggio in the salon is a positive differentiator, as it allows the customer to closely follow the process of preparing the dish, and learn some tips used there.
#
# I found the service quick, both for the dishes finished in the salon and for the other dishes.
#
# The biggest problem was related to the wine list and the drinks menu, I don't know if it was something punctual or if it is a recurring problem, but at least 4 wines were not available, so I opted for the lemonade, which was also missing several flavors .
#
# The service is excellent, all the staff are very attentive.
# sentence_br  O restaurante oferece uma diversidade de pratos incríveis, fica difícil escolher um só!
# sentence.sentiment.polarity:  0.125
# sentence.sentiment.subjectivity:  0.6333333333333333
# Polaridade
#  O restaurante oferece uma diversidade de pratos incríveis, fica difícil escolher um só! : 0.125
# subjetividade
#  O restaurante oferece uma diversidade de pratos incríveis, fica difícil escolher um só! : 0.6333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  a finalização do spaghetti al formaggio no salão é um diferencial positivo, pois possibilita ao cliente acompanhar de perto o processo de preparação do prato, e aprender algumas dicas ali utilizadas.
# sentence.sentiment.polarity:  0.22727272727272727
# sentence.sentiment.subjectivity:  0.5454545454545454
# Polaridade
#  a finalização do spaghetti al formaggio no salão é um diferencial positivo, pois possibilita ao cliente acompanhar de perto o processo de preparação do prato, e aprender algumas dicas ali utilizadas. : 0.22727272727272727
# subjetividade
#  a finalização do spaghetti al formaggio no salão é um diferencial positivo, pois possibilita ao cliente acompanhar de perto o processo de preparação do prato, e aprender algumas dicas ali utilizadas. : 0.5454545454545454
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20018 x Anda meio caro, os sanduíches são bons, mas não excelentes.... o sorvete com calda de chocolate é muito bom, tortas de maça e de banana muito boas ....Melhorou muito trocando a batata frita pela salada....
# **************
#
# Inglês:  It's kind of expensive, the sandwiches are good, but not great.
# ... the ice cream with chocolate sauce is very good, apple and banana tarts very good .... It has improved a lot by changing the fries for the salad.
# ...
# sentence_br  Anda meio caro, os sanduíches são bons, mas não excelentes.
# sentence.sentiment.polarity:  0.09999999999999998
# sentence.sentiment.subjectivity:  0.7375
# Polaridade
#  Anda meio caro, os sanduíches são bons, mas não excelentes. : 0.09999999999999998
# subjetividade
#  Anda meio caro, os sanduíches são bons, mas não excelentes. : 0.7375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  ... o sorvete com calda de chocolate é muito bom, tortas de maça e de banana muito boas ....Melhorou muito trocando a batata frita pela salada.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  ... o sorvete com calda de chocolate é muito bom, tortas de maça e de banana muito boas ....Melhorou muito trocando a batata frita pela salada. : 0.9099999999999999
# subjetividade
#  ... o sorvete com calda de chocolate é muito bom, tortas de maça e de banana muito boas ....Melhorou muito trocando a batata frita pela salada. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  ...
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ... : 0.0
# subjetividade
#  ... : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20019 x Estive lá por duas vezes para almoçar. No almoço servem excelentes galetos e uma costelinha de porco divina. Outro ponto positivo é o atendimento, os garçons são muito atenciosos. Só não gosto quando os funcionários do restaurante baixam o toldo que dá acesso ao bloco, acho até que isso vai contra o projeto urbanístico da Cidade.
# **************
# Inglês:  I have been there twice for lunch.
#  For lunch they serve excellent chicken and a divine pork rib.
#  Another positive point is the service, the waiters are very attentive.
#  I just don't like it when the restaurant employees lower the awning that gives access to the block, I think it even goes against the city's urban project.
# sentence_br  Estive lá por duas vezes para almoçar.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Estive lá por duas vezes para almoçar. : 0.0
# subjetividade
#  Estive lá por duas vezes para almoçar. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  No almoço servem excelentes galetos e uma costelinha de porco divina.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.975
# Polaridade
#  No almoço servem excelentes galetos e uma costelinha de porco divina. : 0.2
# subjetividade
#  No almoço servem excelentes galetos e uma costelinha de porco divina. : 0.975
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Outro ponto positivo é o atendimento, os garçons são muito atenciosos.
# sentence.sentiment.polarity:  0.37363636363636366
# sentence.sentiment.subjectivity:  0.7727272727272727
# Polaridade
#  Outro ponto positivo é o atendimento, os garçons são muito atenciosos. : 0.37363636363636366
# subjetividade
#  Outro ponto positivo é o atendimento, os garçons são muito atenciosos. : 0.7727272727272727
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Só não gosto quando os funcionários do restaurante baixam o toldo que dá acesso ao bloco, acho até que isso vai contra o projeto urbanístico da Cidade.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Só não gosto quando os funcionários do restaurante baixam o toldo que dá acesso ao bloco, acho até que isso vai contra o projeto urbanístico da Cidade. : 0.0
# subjetividade
#  Só não gosto quando os funcionários do restaurante baixam o toldo que dá acesso ao bloco, acho até que isso vai contra o projeto urbanístico da Cidade. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20020 x Espaço muito bem planejado, aconchegante e com um atendimento nota 10. Recomendo, pois a comida é saborosa demais.
# **************
#
# Inglês:  Space very well planned, cozy and with a service note 10.
#  I recommend it because the food is too tasty.
# sentence_br  Espaço muito bem planejado, aconchegante e com um atendimento nota 10.
# sentence.sentiment.polarity:  1.3877787807814457e-17
# sentence.sentiment.subjectivity:  0.525
# Polaridade
#  Espaço muito bem planejado, aconchegante e com um atendimento nota 10. : 1.3877787807814457e-17
# subjetividade
#  Espaço muito bem planejado, aconchegante e com um atendimento nota 10. : 0.525
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Recomendo, pois a comida é saborosa demais.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo, pois a comida é saborosa demais. : 0.0
# subjetividade
#  Recomendo, pois a comida é saborosa demais. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 20021 x Passo sempre em frente, consta em sua fachada “desde 1973” então fiquei curioso em conhecer. Nesta semana enfim, fui lá pegar uns lanches para viagem: pedi um hamburger vegetariano com queijo e salada e um Beirute especial (filé mignon, presunto, queijo, alface, tomate e molho tártaro, tem ovo também, mas pedi sem). Não sou fã de coisa vegetariana, mas como não era para mim, experimentei um pouquinho, não tenho muito o que dizer sobre esse hambúrguer. Com relação ao Beirute, não agradou, o filet estava meio duro e o molho tártaro azedo, não combinou... o queijo massudo e duro.... eu que gosto muito de Beirute de filet, e gosto de maionese, molho tártaro e derivados, comi decepcionado. Pode ser que comendo na hora e não levando para viagem como fiz, seja melhor... a casa existe há décadas e num país onde a maioria da empresas quebra nos primeiros anos, temos que levar isso em consideração. Minha experiência não foi positiva, mas como disse, pelo tempo que a casa existe dou um crédito, talvez eu tenha dado azar, não sei... considero voltar novamente para experimentar outro sanduíche.
# **************
#
# Inglês:  I always go ahead, it appears on its facade “since 1973” so I was curious to know.
# ...
# **************
#
# var 21122 x Ambiente super atrativo, ótimo atendimento e comida adorável.
# Em uma nova pegada restaurante/pub gostei como o Moony conseguiu unir as duas modalidades.
# Aconselho chegar cedo (19-20 horas) sem reserva ou reservar antes (acho que o horário para reservar começa às 19:00 horas) e também recomendo o bolinho da vovó de entrada!! Muito bom!
# **************
#
# Inglês:  Super attractive atmosphere, great service and lovely food.
#
# In a new footprint restaurant / pub I liked how Moony managed to unite the two modalities.
#
# I advise you to arrive early (19-20 hours) without reservation or to book early (I think the time to book starts at 7:00 pm) and I also recommend Grandma's cupcake at the beginning !! Very good!
# sentence_br  Ambiente super atrativo, ótimo atendimento e comida adorável.
# sentence.sentiment.polarity:  0.6083333333333334
# sentence.sentiment.subjectivity:  0.7916666666666666
# Polaridade
#  Ambiente super atrativo, ótimo atendimento e comida adorável. : 0.6083333333333334
# subjetividade
#  Ambiente super atrativo, ótimo atendimento e comida adorável. : 0.7916666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Em uma nova pegada restaurante/pub gostei como o Moony conseguiu unir as duas modalidades.
# sentence.sentiment.polarity:  0.36818181818181817
# sentence.sentiment.subjectivity:  0.6272727272727273
# Polaridade
#  Em uma nova pegada restaurante/pub gostei como o Moony conseguiu unir as duas modalidades. : 0.36818181818181817
# subjetividade
#  Em uma nova pegada restaurante/pub gostei como o Moony conseguiu unir as duas modalidades. : 0.6272727272727273
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br
000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# sentence_br  Não pude experimentar nenhuma sobremesa, mas pareciam apetitosas.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Não pude experimentar nenhuma sobremesa, mas pareciam apetitosas. : 0.2
# subjetividade
#  Não pude experimentar nenhuma sobremesa, mas pareciam apetitosas. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-20000-30000.txt
# **************
#
# var 21125 x Muito bom eles servem o melhor escaldado da região o atendimento é de primeira bem localizado bem frequentado eu recomendo
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-19-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
