# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pcorrea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 90000
terminou = 100000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  123,356,323,840 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 138127

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
ini = time.time()
for x in df['reviewBody']:
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 90001 x Sempre Uso os serviços deles , acho excelente , atendimento é maravilhoso eu recomendo a todos , o pessoal é nota 10 .
# **************
#
# Inglês:  I always use their services, I think it is excellent, the service is wonderful, I recommend it to everyone, the staff is rated 10.
# sentence_br  Sempre Uso os serviços deles , acho excelente , atendimento é maravilhoso eu recomendo a todos , o pessoal é nota 10 .
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Sempre Uso os serviços deles , acho excelente , atendimento é maravilhoso eu recomendo a todos , o pessoal é nota 10 . : 1.0
# subjetividade
#  Sempre Uso os serviços deles , acho excelente , atendimento é maravilhoso eu recomendo a todos , o pessoal é nota 10 . : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90002 x Excelente restaurante. Ambiente aconchegante e ótimo atendimento. Pratos muito bem elaborados, variados e de excelente custo beneficio. O proprietário e o pessoal são muito atenciosos. Pratos saborosos e na medida. Sobremesas no mesmo nível: o suflê de chocolate é imperdível.
# **************
#
# Inglês:  Excellent restaurant.
#  Cozy atmosphere and great service.
#  Very well prepared dishes, varied and of excellent cost benefit.
#  The owner and staff are very attentive.
#  Tasty and tailored dishes.
#  Desserts on the same level: the chocolate souffle is a must.
# sentence_br  Excelente restaurante.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Excelente restaurante. : 1.0
# subjetividade
#  Excelente restaurante. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Ambiente aconchegante e ótimo atendimento.
# sentence.sentiment.polarity:  0.30000000000000004
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ambiente aconchegante e ótimo atendimento. : 0.30000000000000004
# subjetividade
#  Ambiente aconchegante e ótimo atendimento. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Pratos muito bem elaborados, variados e de excelente custo beneficio.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Pratos muito bem elaborados, variados e de excelente custo beneficio. : 0.6
# subjetividade
#  Pratos muito bem elaborados, variados e de excelente custo beneficio. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  O proprietário e o pessoal são muito atenciosos.
# sentence.sentiment.polarity:  0.52
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O proprietário e o pessoal são muito atenciosos. : 0.52
# subjetividade
#  O proprietário e o pessoal são muito atenciosos. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Pratos saborosos e na medida.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Pratos saborosos e na medida. : 0.0
# subjetividade
#  Pratos saborosos e na medida. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Sobremesas no mesmo nível: o suflê de chocolate é imperdível.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.125
# Polaridade
#  Sobremesas no mesmo nível: o suflê de chocolate é imperdível. : 0.0
# subjetividade
#  Sobremesas no mesmo nível: o suflê de chocolate é imperdível. : 0.125
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90003 x Instalado em uma casa no bairro do Rio Vermelho. Ambiente espaçoso, decoração de casa antiga, bonita, pitoresca. Ótima comida. De entrada, optamos por um misto de pequenos abarás (delicados) e acarajés. Acompanhamento de farofa de dendê, farofa de manteiga, vinagrete e molho de pimenta, todos ótimos. De prato principal, optamos pelo arroz de hauçá, que era o prato da boa lembrança, de cuja associação de restaurantes a casa faz parte. Um prato decorado com nome do restaurante, nome da comida e ano vem de brinde como lembrança. Comida de origem africana (incorporada à culinária baiana), trazida para o Brasil por negros escravos do povo hauçá, que viviam na região subsaariana, eram cultos, alfabetizados, de religião muçulmana. Gastronomia também é cultura. A comida é surpreendente e deliciosa. Sobre uma cama de arroz cozido com leite de coco, vem a carne seca, cozida, desfiada e refogada no azeite de dendê com camarão seco. Por cima ainda vinham camarões frescos também refogados no dendê. Registre-se que este é um dos raros restaurantes no Brasil que serve este prato. De sobremesa, outra iguaria saborosa: uma cocada de forno, pouco doce, acompanhada de uma mistura cozida, de cachaça, espumante e gengibre, com textura semelhante a um melaço. Obrigado à chef Tereza Paim, pelo seu resgate e extraordinária recriação de pratos da culinária baiana. Cerveja gelada. Atendimento excelente. Boa refrigeração.
# **************
#
# Inglês:  Installed in a house in the neighborhood of Rio Vermelho.
#  Spacious ambience, old, beautiful, picturesque home decor.
#  Great food.
#  At the beginning, we opted for a mix of small (delicate) abarás and acarajés.
#  Accompaniment of palm oil flour, butter flour, vinaigrette and pepper sauce, all great.
#  As the main dish, we opted for hauçá rice, which was the dish of good memories, of which the restaurant association is a part.
#  A plate decorated with the name of the restaurant, name of the food and year comes as a gift as a souvenir.
#  Food of African origin (incorporated into Bahian cuisine), brought to Brazil by black slaves of the Hausa people, who lived in the sub-Saharan region, were educated, literate, of Muslim religion.
#  Gastronomy is also culture.
#  The food is surprising and delicious.
#  On a bed of rice cooked with coconut milk comes dried meat, cooked, shredded and sautéed in palm oil with dry shrimp.
#  On top of it came fresh prawns also sautéed in oil palm.
#  Register that this is one of the rare restaurants in Brazil that serves this dish.
#  For dessert, another tasty delicacy: an oven-baked coconut, not very sweet, accompanied by a cooked mixture of cachaça, sparkling wine and ginger, with a texture similar to molasses.
#  Thanks to chef Tereza Paim, for her rescue and extraordinary recreation of dishes from Bahian cuisine.
#  Cold beer.
#  Excelent reception.
#  Good cooling.
# sentence_br  Instalado em uma casa no bairro do Rio Vermelho.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Instalado em uma casa no bairro do Rio Vermelho. : 0.0
# subjetividade
#  Instalado em uma casa no bairro do Rio Vermelho. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Ambiente espaçoso, decoração de casa antiga, bonita, pitoresca.
# sentence.sentiment.polarity:  0.475
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Ambiente espaçoso, decoração de casa antiga, bonita, pitoresca. : 0.475
# subjetividade
#  Ambiente espaçoso, decoração de casa antiga, bonita, pitoresca. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Ótima comida.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ótima comida. : 0.8
# subjetividade
#  Ótima comida. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  De entrada, optamos por um misto de pequenos abarás (delicados) e acarajés.
# sentence.sentiment.polarity:  -0.275
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  De entrada, optamos por um misto de pequenos abarás (delicados) e acarajés. : -0.275
# subjetividade
#  De entrada, optamos por um misto de pequenos abarás (delicados) e acarajés. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Acompanhamento de farofa de dendê, farofa de manteiga, vinagrete e molho de pimenta, todos ótimos.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Acompanhamento de farofa de dendê, farofa de manteiga, vinagrete e molho de pimenta, todos ótimos. : 0.8
# subjetividade
#  Acompanhamento de farofa de dendê, farofa de manteiga, vinagrete e molho de pimenta, todos ótimos. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  De prato principal, optamos pelo arroz de hauçá, que era o prato da boa lembrança, de cuja associação de restaurantes a casa faz parte.
# sentence.sentiment.polarity:  0.4333333333333333
# sentence.sentiment.subjectivity:  0.4666666666666667
# Polaridade
#  De prato principal, optamos pelo arroz de hauçá, que era o prato da boa lembrança, de cuja associação de restaurantes a casa faz parte. : 0.4333333333333333
# subjetividade
#  De prato principal, optamos pelo arroz de hauçá, que era o prato da boa lembrança, de cuja associação de restaurantes a casa faz parte. : 0.4666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Um prato decorado com nome do restaurante, nome da comida e ano vem de brinde como lembrança.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Um prato decorado com nome do restaurante, nome da comida e ano vem de brinde como lembrança. : 0.0
# subjetividade
#  Um prato decorado com nome do restaurante, nome da comida e ano vem de brinde como lembrança. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Comida de origem africana (incorporada à culinária baiana), trazida para o Brasil por negros escravos do povo hauçá, que viviam na região subsaariana, eram cultos, alfabetizados, de religião muçulmana.
# sentence.sentiment.polarity:  -0.08333333333333333
# sentence.sentiment.subjectivity:  0.21666666666666667
# Polaridade
#  Comida de origem africana (incorporada à culinária baiana), trazida para o Brasil por negros escravos do povo hauçá, que viviam na região subsaariana, eram cultos, alfabetizados, de religião muçulmana. : -0.08333333333333333
# subjetividade
#  Comida de origem africana (incorporada à culinária baiana), trazida para o Brasil por negros escravos do povo hauçá, que viviam na região subsaariana, eram cultos, alfabetizados, de religião muçulmana. : 0.21666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Gastronomia também é cultura.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Gastronomia também é cultura. : 0.0
# subjetividade
#  Gastronomia também é cultura. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  A comida é surpreendente e deliciosa.
# sentence.sentiment.polarity:  0.85
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  A comida é surpreendente e deliciosa. : 0.85
# subjetividade
#  A comida é surpreendente e deliciosa. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Sobre uma cama de arroz cozido com leite de coco, vem a carne seca, cozida, desfiada e refogada no azeite de dendê com camarão seco.
# sentence.sentiment.polarity:  -0.13333333333333333
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Sobre uma cama de arroz cozido com leite de coco, vem a carne seca, cozida, desfiada e refogada no azeite de dendê com camarão seco. : -0.13333333333333333
# subjetividade
#  Sobre uma cama de arroz cozido com leite de coco, vem a carne seca, cozida, desfiada e refogada no azeite de dendê com camarão seco. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Por cima ainda vinham camarões frescos também refogados no dendê.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Por cima ainda vinham camarões frescos também refogados no dendê. : 0.4
# subjetividade
#  Por cima ainda vinham camarões frescos também refogados no dendê. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Registre-se que este é um dos raros restaurantes no Brasil que serve este prato.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Registre-se que este é um dos raros restaurantes no Brasil que serve este prato. : 0.3
# subjetividade
#  Registre-se que este é um dos raros restaurantes no Brasil que serve este prato. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  De sobremesa, outra iguaria saborosa: uma cocada de forno, pouco doce, acompanhada de uma mistura cozida, de cachaça, espumante e gengibre, com textura semelhante a um melaço.
# sentence.sentiment.polarity:  -0.06730769230769229
# sentence.sentiment.subjectivity:  0.45
# Polaridade
#  De sobremesa, outra iguaria saborosa: uma cocada de forno, pouco doce, acompanhada de uma mistura cozida, de cachaça, espumante e gengibre, com textura semelhante a um melaço. : -0.06730769230769229
# subjetividade
#  De sobremesa, outra iguaria saborosa: uma cocada de forno, pouco doce, acompanhada de uma mistura cozida, de cachaça, espumante e gengibre, com textura semelhante a um melaço. : 0.45
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Obrigado à chef Tereza Paim, pelo seu resgate e extraordinária recriação de pratos da culinária baiana.
# sentence.sentiment.polarity:  0.26666666666666666
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Obrigado à chef Tereza Paim, pelo seu resgate e extraordinária recriação de pratos da culinária baiana. : 0.26666666666666666
# subjetividade
#  Obrigado à chef Tereza Paim, pelo seu resgate e extraordinária recriação de pratos da culinária baiana. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Cerveja gelada.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Cerveja gelada. : -0.6
# subjetividade
#  Cerveja gelada. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Atendimento excelente.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Atendimento excelente. : 0.0
# subjetividade
#  Atendimento excelente. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Boa refrigeração.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Boa refrigeração. : 0.7
# subjetividade
#  Boa refrigeração. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90004 x Sem duvidas o melhor açaí que já comi.
# Atendimento excepcional, frequentado por boas pessoal, super limpo e bem localizado.
# Frutas, sucos e lichens naturais! Muito bom!
# 🔝🔝😍🍏🍐🍌🥑🥝🍇
# **************
# Inglês:  Without a doubt the best açaí I've ever eaten.
#
# Exceptional service, attended by good staff, super clean and well located.
#
# Natural fruits, juices and lichens! Very good!
# 🔝🔝😍🍏🍐🍌🥑🥝🍇
# sentence_br  Sem duvidas o melhor açaí que já comi.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Sem duvidas o melhor açaí que já comi. : 1.0
# subjetividade
#  Sem duvidas o melhor açaí que já comi. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Atendimento excepcional, frequentado por boas pessoal, super limpo e bem localizado.
# sentence.sentiment.polarity:  0.5166666666666666
# sentence.sentiment.subjectivity:  0.7416666666666667
# Polaridade
#  Atendimento excepcional, frequentado por boas pessoal, super limpo e bem localizado. : 0.5166666666666666
# subjetividade
#  Atendimento excepcional, frequentado por boas pessoal, super limpo e bem localizado. : 0.7416666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Frutas, sucos e lichens naturais!
# sentence.sentiment.polarity:  0.125
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Frutas, sucos e lichens naturais! : 0.125
# subjetividade
#  Frutas, sucos e lichens naturais! : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Muito bom!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Muito bom! : 1.0
# subjetividade
#  Muito bom! : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  🔝🔝😍🍏🍐🍌🥑🥝🍇
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  🔝🔝😍🍏🍐🍌🥑🥝🍇 : 0.0
# subjetividade
#  🔝🔝😍🍏🍐🍌🥑🥝🍇 : 0.0
# Error did file  'charmap' codec can't encode characters in position 8-16: character maps to <undefined>
# **************
#
# var 90005 x Vale a pena conferir e saborear os lanches do Germinio!! Nota 10 para eles! Muito saborosos, preço execelente!!
# **************
#
# Inglês:  It is worth checking out and enjoying Germinio snacks !! Grade 10 for them! Very tasty, excellent price !!
# sentence_br  Vale a pena conferir e saborear os lanches do Germinio!!
# sentence.sentiment.polarity:  0.540625
# sentence.sentiment.subjectivity:  0.35
# Polaridade
#  Vale a pena conferir e saborear os lanches do Germinio!! : 0.540625
# subjetividade
#  Vale a pena conferir e saborear os lanches do Germinio!! : 0.35
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Nota 10 para eles!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Nota 10 para eles! : 0.0
# subjetividade
#  Nota 10 para eles! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Muito saborosos, preço execelente!
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  Muito saborosos, preço execelente! : 0.6
# subjetividade
#  Muito saborosos, preço execelente! : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90006 x Bom dia,
#
# Costumo dizer que atendimento é a alma do negócio.
#
# Sei muito bem que o estabelecimento só abre as 12:00 porém os clientes sempre irão chegar antes e cabe ao pessoas gerir isso.
#
# Cheguei as 11:30 as portas estavam abertas e mesas disponíveis, Tive dois contatos com funcionárias diferentes. Primeira não deu nem bom dia e nem respondeu ao meu, nem falou. A Segunda nos falou pra aguardar pois só abria as 12h bem educada porém foi enfática tem que esperar aqui embaixo após abertura veremos a mesa que vocês podem ficar.
#
# * a visão da cozinha não foi das melhores
#
# *Tinha outros clientes que acredito tiveram a mesma impressão
#
# Não fiquei para almoçar e nem ter mais avaliação do local. A primeira impressão foi das piores!!
#
# Mardson Ramos
# **************
#
# Inglês:  Good Morning,
#
# I often say that customer service is the lifeblood of the business.
#
#
# I know very well that the establishment only opens at 12:00 but customers will always arrive early and it is up to people to manage it.
#
#
# I arrived at 11:30 am the doors were open and tables were available, I had two contacts with different employees.
#  First he said neither good morning nor answered mine, nor spoke.
#  Monday told us to wait because it only opened at 12pm well polite but it was emphatic you have to wait down here after opening we will see the table that you can stay at.
#
#
# * the view of the kitchen was not the best
#
# * I had other customers that I believe had the same impression
#
# I didn’t stay to have lunch and have no more evaluation of the place.
#  The first impression was the worst !!
#
# Mardson Ramos
# sentence_br  Bom dia,
#
# Costumo dizer que atendimento é a alma do negócio.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Bom dia,
#
# Costumo dizer que atendimento é a alma do negócio. : 0.7
# subjetividade
#  Bom dia,
#
# Costumo dizer que atendimento é a alma do negócio. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Sei muito bem que o estabelecimento só abre as 12:00 porém os clientes sempre irão chegar antes e cabe ao pessoas gerir isso.
# sentence.sentiment.polarity:  0.10000000000000002
# sentence.sentiment.subjectivity:  0.5333333333333333
# Polaridade
#  Sei muito bem que o estabelecimento só abre as 12:00 porém os clientes sempre irão chegar antes e cabe ao pessoas gerir isso. : 0.10000000000000002
# subjetividade
#  Sei muito bem que o estabelecimento só abre as 12:00 porém os clientes sempre irão chegar antes e cabe ao pessoas gerir isso. : 0.5333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Cheguei as 11:30 as portas estavam abertas e mesas disponíveis, Tive dois contatos com funcionárias diferentes.
# sentence.sentiment.polarity:  0.13333333333333333
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Cheguei as 11:30 as portas estavam abertas e mesas disponíveis, Tive dois contatos com funcionárias diferentes. : 0.13333333333333333
# subjetividade
#  Cheguei as 11:30 as portas estavam abertas e mesas disponíveis, Tive dois contatos com funcionárias diferentes. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Primeira não deu nem bom dia e nem respondeu ao meu, nem falou.
# sentence.sentiment.polarity:  0.475
# sentence.sentiment.subjectivity:  0.4666666666666667
# Polaridade
#  Primeira não deu nem bom dia e nem respondeu ao meu, nem falou. : 0.475
# subjetividade
#  Primeira não deu nem bom dia e nem respondeu ao meu, nem falou. : 0.4666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  A Segunda nos falou pra aguardar pois só abria as 12h bem educada porém foi enfática tem que esperar aqui embaixo após abertura veremos a mesa que vocês podem ficar.
# sentence.sentiment.polarity:  -0.07777777777777779
# sentence.sentiment.subjectivity:  0.6444444444444445
# Polaridade
#  A Segunda nos falou pra aguardar pois só abria as 12h bem educada porém foi enfática tem que esperar aqui embaixo após abertura veremos a mesa que vocês podem ficar. : -0.07777777777777779
# subjetividade
#  A Segunda nos falou pra aguardar pois só abria as 12h bem educada porém foi enfática tem que esperar aqui embaixo após abertura veremos a mesa que vocês podem ficar. : 0.6444444444444445
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  * a visão da cozinha não foi das melhores
#
# *Tinha outros clientes que acredito tiveram a mesma impressão
#
# Não fiquei para almoçar e nem ter mais avaliação do local.
# sentence.sentiment.polarity:  0.15625
# sentence.sentiment.subjectivity:  0.325
# Polaridade
#  * a visão da cozinha não foi das melhores
#
# *Tinha outros clientes que acredito tiveram a mesma impressão
#
# Não fiquei para almoçar e nem ter mais avaliação do local. : 0.15625
# subjetividade
#  * a visão da cozinha não foi das melhores
#
# *Tinha outros clientes que acredito tiveram a mesma impressão
#
# Não fiquei para almoçar e nem ter mais avaliação do local. : 0.325
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  A primeira impressão foi das piores!!
# sentence.sentiment.polarity:  -0.375
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  A primeira impressão foi das piores!! : -0.375
# subjetividade
#  A primeira impressão foi das piores!! : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Mardson Ramos
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Mardson Ramos : 0.0
# subjetividade
#  Mardson Ramos : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90007 x A vista do lugar para uma espécie de lagoa é bonita e é agradável ficar numa das mesas ao longo do pier .... // tem vários restaurantes de moqueca que concorrem entre si. .... os atendentes são simpáticos e atenciosos // a comida deixa a desejar ... comemos no Teresão e a moqueca não tinha sabor nenhum... só a caipira de graviola é que era boa.  o preço é alto pelo que oferecem // Fica numa comunidade carente da cidade, é bom você ir com Waze, GPS ou com alguém que saiba chegar.
# **************
# Inglês:  The view from the place to a kind of lagoon is beautiful and it is pleasant to stay at one of the tables along the pier .... // there are several competing moqueca restaurants.
#  .... the attendants are friendly and attentive // ​​the food leaves something to be desired ... we ate in Teresão and the moqueca had no flavor at all.
# .. only the soursop hillbilly was good.
#   the price is high for what they offer // Stay in a poor community in the city, you better go with Waze, GPS or someone who knows how to get there.
# sentence_br  A vista do lugar para uma espécie de lagoa é bonita e é agradável ficar numa das mesas ao longo do pier .... // tem vários restaurantes de moqueca que concorrem entre si.
# sentence.sentiment.polarity:  0.5458333333333333
# sentence.sentiment.subjectivity:  0.7166666666666667
# Polaridade
#  A vista do lugar para uma espécie de lagoa é bonita e é agradável ficar numa das mesas ao longo do pier .... // tem vários restaurantes de moqueca que concorrem entre si. : 0.5458333333333333
# subjetividade
#  A vista do lugar para uma espécie de lagoa é bonita e é agradável ficar numa das mesas ao longo do pier .... // tem vários restaurantes de moqueca que concorrem entre si. : 0.7166666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  .... os atendentes são simpáticos e atenciosos // a comida deixa a desejar ... comemos no Teresão e a moqueca não tinha sabor nenhum.
# sentence.sentiment.polarity:  0.3875
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  .... os atendentes são simpáticos e atenciosos // a comida deixa a desejar ... comemos no Teresão e a moqueca não tinha sabor nenhum. : 0.3875
# subjetividade
#  .... os atendentes são simpáticos e atenciosos // a comida deixa a desejar ... comemos no Teresão e a moqueca não tinha sabor nenhum. : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  .. só a caipira de graviola é que era boa.
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  .. só a caipira de graviola é que era boa. : 0.35
# subjetividade
#  .. só a caipira de graviola é que era boa. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  o preço é alto pelo que oferecem // Fica numa comunidade carente da cidade, é bom você ir com Waze, GPS ou com alguém que saiba chegar.
# sentence.sentiment.polarity:  0.08666666666666667
# sentence.sentiment.subjectivity:  0.5466666666666666
# Polaridade
#  o preço é alto pelo que oferecem // Fica numa comunidade carente da cidade, é bom você ir com Waze, GPS ou com alguém que saiba chegar. : 0.08666666666666667
# subjetividade
#  o preço é alto pelo que oferecem // Fica numa comunidade carente da cidade, é bom você ir com Waze, GPS ou com alguém que saiba chegar. : 0.5466666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90008 x Restaurante bem localizado e com uma estrutura realmente excelente.
#
# Cheguei às 21:30 de uma quarta-feira e fiquei cerca de 15 minutos na fila de espera - muito bem organizada, por sinal.
#
# Cerveja gelada.
#
# Cardápio surpreendente (do regional ao “tradicional Brasileiro”).
#
# Do momento do pedido até a chegada do prato, foram menos de 15 minutos.
#
# Pedi o “Dira Paes” e foi paidégua! Serve duas pessoas tranquilamente ao custo médio de 70 reais o prato.
#
# Voltarei com certeza.
# **************
#
# Inglês:  Restaurant well located and with a really excellent structure.
#
#
# I arrived at 9:30 pm on a Wednesday and stayed in the queue for about 15 minutes - very well organized, by the way.
#
#
# Cold beer.
#
#
# Surprising menu (from regional to “traditional Brazilian”).
#
# From the moment the order was made until the dish arrived, it took less than 15 minutes.
#
#
# I asked for “Dira Paes” and it was paidégua! Serves two people peacefully at an average cost of 70 reais a dish.
#
#
# I will be back for sure.
# sentence_br  Restaurante bem localizado e com uma estrutura realmente excelente.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Restaurante bem localizado e com uma estrutura realmente excelente. : 1.0
# subjetividade
#  Restaurante bem localizado e com uma estrutura realmente excelente. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Cheguei às 21:30 de uma quarta-feira e fiquei cerca de 15 minutos na fila de espera - muito bem organizada, por sinal.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Cheguei às 21:30 de uma quarta-feira e fiquei cerca de 15 minutos na fila de espera - muito bem organizada, por sinal. : 0.2
# subjetividade
#  Cheguei às 21:30 de uma quarta-feira e fiquei cerca de 15 minutos na fila de espera - muito bem organizada, por sinal. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Cerveja gelada.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Cerveja gelada. : -0.6
# subjetividade
#  Cerveja gelada. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Cardápio surpreendente (do regional ao “tradicional Brasileiro”).
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.625
# Polaridade
#  Cardápio surpreendente (do regional ao “tradicional Brasileiro”). : 0.35
# subjetividade
#  Cardápio surpreendente (do regional ao “tradicional Brasileiro”). : 0.625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Do momento do pedido até a chegada do prato, foram menos de 15 minutos.
# sentence.sentiment.polarity:  -0.16666666666666666
# sentence.sentiment.subjectivity:  0.06666666666666667
# Polaridade
#  Do momento do pedido até a chegada do prato, foram menos de 15 minutos. : -0.16666666666666666
# subjetividade
#  Do momento do pedido até a chegada do prato, foram menos de 15 minutos. : 0.06666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Pedi o “Dira Paes” e foi paidégua!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Pedi o “Dira Paes” e foi paidégua! : 0.0
# subjetividade
#  Pedi o “Dira Paes” e foi paidégua! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Serve duas pessoas tranquilamente ao custo médio de 70 reais o prato.
# sentence.sentiment.polarity:  -0.15
# sentence.sentiment.subjectivity:  0.39999999999999997
# Polaridade
#  Serve duas pessoas tranquilamente ao custo médio de 70 reais o prato. : -0.15
# subjetividade
#  Serve duas pessoas tranquilamente ao custo médio de 70 reais o prato. : 0.39999999999999997
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Voltarei com certeza.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.4444444444444444
# Polaridade
#  Voltarei com certeza. : 0.25
# subjetividade
#  Voltarei com certeza. : 0.4444444444444444
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90009 x Garçom Wemerson e Sandro, comida excelente e atendimento impecável.
# Ambiente familiar e aconchegante.
# **************
#
# Inglês:  Waiter Wemerson and Sandro, excellent food and impeccable service.
#
# Familiar and cozy atmosphere.
# sentence_br  Garçom Wemerson e Sandro, comida excelente e atendimento impecável.
# sentence.sentiment.polarity:  0.875
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  Garçom Wemerson e Sandro, comida excelente e atendimento impecável. : 0.875
# subjetividade
#  Garçom Wemerson e Sandro, comida excelente e atendimento impecável. : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Ambiente familiar e aconchegante.
# sentence.sentiment.polarity:  0.08750000000000001
# sentence.sentiment.subjectivity:  0.625
# Polaridade
#  Ambiente familiar e aconchegante. : 0.08750000000000001
# subjetividade
#  Ambiente familiar e aconchegante. : 0.625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90010 x Pelo amor de Deus, tragam uma franquia desse lugar para São Paulo!
# Quero voltar lá pra jantar TODOS os dias.
# É bom demais! TUDO é bom demais, inclusive o preço. Pela qualidade e o que serve, é barato. Em São Paulo custaria o dobro.
# Eu sou muito chata e criteriosa com comida, mas nesse lugar, não dá pra reclamar de nada.
# Atendimento pode melhorar, mas como a casa está sempre cheia, dá pra entender a demora.
# **************
# Inglês:  For the love of God, bring a franchise from this place to São Paulo!
# I want to go back there for dinner EVERY day.
#
# Is too good! EVERYTHING is too good, including the price.
#  For the quality and what it serves, it is cheap.
#  In São Paulo it would cost twice as much.
#
# I'm very boring and judicious about food, but in this place, you can't complain about anything.
#
# Service can improve, but as the house is always full, you can understand the delay.
# sentence_br  Pelo amor de Deus, tragam uma franquia desse lugar para São Paulo!
# sentence.sentiment.polarity:  0.625
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Pelo amor de Deus, tragam uma franquia desse lugar para São Paulo! : 0.625
# subjetividade
#  Pelo amor de Deus, tragam uma franquia desse lugar para São Paulo! : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Quero voltar lá pra jantar TODOS os dias.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Quero voltar lá pra jantar TODOS os dias. : 0.0
# subjetividade
#  Quero voltar lá pra jantar TODOS os dias. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  É bom demais!
# sentence.sentiment.polarity:  0.875
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  É bom demais! : 0.875
# subjetividade
#  É bom demais! : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  TUDO é bom demais, inclusive o preço.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  TUDO é bom demais, inclusive o preço. : 0.7
# subjetividade
#  TUDO é bom demais, inclusive o preço. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Pela qualidade e o que serve, é barato.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  Pela qualidade e o que serve, é barato. : 0.4
# subjetividade
#  Pela qualidade e o que serve, é barato. : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Em São Paulo custaria o dobro.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Em São Paulo custaria o dobro. : 0.2
# subjetividade
#  Em São Paulo custaria o dobro. : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Eu sou muito chata e criteriosa com comida, mas nesse lugar, não dá pra reclamar de nada.
# sentence.sentiment.polarity:  -1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Eu sou muito chata e criteriosa com comida, mas nesse lugar, não dá pra reclamar de nada. : -1.0
# subjetividade
#  Eu sou muito chata e criteriosa com comida, mas nesse lugar, não dá pra reclamar de nada. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Atendimento pode melhorar, mas como a casa está sempre cheia, dá pra entender a demora.
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  Atendimento pode melhorar, mas como a casa está sempre cheia, dá pra entender a demora. : 0.35
# subjetividade
#  Atendimento pode melhorar, mas como a casa está sempre cheia, dá pra entender a demora. : 0.55
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90011 x Sou um amante de pizzas, praticamente como 1 toda semana. Pedi pro Taxista me levar numa boa pizzaria, e ele me indicou essa, dizendo que era a pizzaria onde o Cazuza frequentava. Bom, pensei comigo "a pizza deve ser boa". Mas na primeira garfada, percebi que não era lá tudo isso, mas como tava com fome, foi tudo. O Choppe Amstel é muito bom, estava muito gelado! Os garçons não eram tão simpáticos, acho que estou acostumado com o atendimento em Campinas, vai ver sou eu que estava muito exigente.
# **************
#
# Inglês:  I'm a pizza lover, almost like 1 every week.
#  I asked the taxi driver to take me to a good pizzeria, and he indicated this to me, saying it was the pizzeria where Cazuza used to go.
#  Well, I thought to myself "the pizza must be good". But in the first mouthful, I realized that it wasn't all that, but as I was hungry, it was everything.
#  Choppe Amstel is very good, it was very cold! The waiters were not so friendly, I think I am used to the service in Campinas, you see, I was very demanding.
# sentence_br  Sou um amante de pizzas, praticamente como 1 toda semana.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Sou um amante de pizzas, praticamente como 1 toda semana. : 0.0
# subjetividade
#  Sou um amante de pizzas, praticamente como 1 toda semana. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Pedi pro Taxista me levar numa boa pizzaria, e ele me indicou essa, dizendo que era a pizzaria onde o Cazuza frequentava.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Pedi pro Taxista me levar numa boa pizzaria, e ele me indicou essa, dizendo que era a pizzaria onde o Cazuza frequentava. : 0.7
# subjetividade
#  Pedi pro Taxista me levar numa boa pizzaria, e ele me indicou essa, dizendo que era a pizzaria onde o Cazuza frequentava. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Bom, pensei comigo "a pizza deve ser boa".
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Bom, pensei comigo "a pizza deve ser boa". : 0.7
# subjetividade
#  Bom, pensei comigo "a pizza deve ser boa". : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Mas na primeira garfada, percebi que não era lá tudo isso, mas como tava com fome, foi tudo.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.3333333333333333
# Polaridade
#  Mas na primeira garfada, percebi que não era lá tudo isso, mas como tava com fome, foi tudo. : 0.25
# subjetividade
#  Mas na primeira garfada, percebi que não era lá tudo isso, mas como tava com fome, foi tudo. : 0.3333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  O Choppe Amstel é muito bom, estava muito gelado!
# sentence.sentiment.polarity:  -0.032500000000000084
# sentence.sentiment.subjectivity:  0.8900000000000001
# Polaridade
#  O Choppe Amstel é muito bom, estava muito gelado! : -0.032500000000000084
# subjetividade
#  O Choppe Amstel é muito bom, estava muito gelado! : 0.8900000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Os garçons não eram tão simpáticos, acho que estou acostumado com o atendimento em Campinas, vai ver sou eu que estava muito exigente.
# sentence.sentiment.polarity:  0.2875
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Os garçons não eram tão simpáticos, acho que estou acostumado com o atendimento em Campinas, vai ver sou eu que estava muito exigente. : 0.2875
# subjetividade
#  Os garçons não eram tão simpáticos, acho que estou acostumado com o atendimento em Campinas, vai ver sou eu que estava muito exigente. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90012 x Já fui algumas vezes neste restaurante e ele vai de bom a Excelente. Esta flata de regularidade incomoda um pouco mas é melhor alternar entre bom e excelente do entre ruim e bom.
# Carnes boas por um preço justo e serviço atencioso.
# **************
#
# Inglês:  I have been to this restaurant a few times and it goes from good to excellent.
#  This flata of regularity bothers a little but it is better to alternate between good and excellent than between bad and good.
#
# Good meats at a fair price and attentive service.
# sentence_br  Já fui algumas vezes neste restaurante e ele vai de bom a Excelente.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5666666666666668
# Polaridade
#  Já fui algumas vezes neste restaurante e ele vai de bom a Excelente. : 0.5
# subjetividade
#  Já fui algumas vezes neste restaurante e ele vai de bom a Excelente. : 0.5666666666666668
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Esta flata de regularidade incomoda um pouco mas é melhor alternar entre bom e excelente do entre ruim e bom.
# sentence.sentiment.polarity:  0.28750000000000003
# sentence.sentiment.subjectivity:  0.5523809523809524
# Polaridade
#  Esta flata de regularidade incomoda um pouco mas é melhor alternar entre bom e excelente do entre ruim e bom. : 0.28750000000000003
# subjetividade
#  Esta flata de regularidade incomoda um pouco mas é melhor alternar entre bom e excelente do entre ruim e bom. : 0.5523809523809524
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Carnes boas por um preço justo e serviço atencioso.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.7999999999999999
# Polaridade
#  Carnes boas por um preço justo e serviço atencioso. : 0.6
# subjetividade
#  Carnes boas por um preço justo e serviço atencioso. : 0.7999999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90013 x Gostei muito da decoração, atendimento e comida! Tem estacionamento na lateral e na rua. Recomendo p almoço e jantar! Pratos grandes que servem 3 pessoas!
# **************
# Inglês:  I really liked the decor, service and food! It has parking on the side and on the street.
#  I recommend lunch and dinner! Large dishes that serve 3 people!
# sentence_br  Gostei muito da decoração, atendimento e comida!
# sentence.sentiment.polarity:  0.75
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Gostei muito da decoração, atendimento e comida! : 0.75
# subjetividade
#  Gostei muito da decoração, atendimento e comida! : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Tem estacionamento na lateral e na rua.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tem estacionamento na lateral e na rua. : 0.0
# subjetividade
#  Tem estacionamento na lateral e na rua. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Recomendo p almoço e jantar!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo p almoço e jantar! : 0.0
# subjetividade
#  Recomendo p almoço e jantar! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Pratos grandes que servem 3 pessoas!
# sentence.sentiment.polarity:  0.26785714285714285
# sentence.sentiment.subjectivity:  0.42857142857142855
# Polaridade
#  Pratos grandes que servem 3 pessoas! : 0.26785714285714285
# subjetividade
#  Pratos grandes que servem 3 pessoas! : 0.42857142857142855
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90014 x Ambiente muito bom, apesar de dentro do Shopping Iguatemi, otimo atendimento. Os comidas escolhidas estavam otimas
# **************
#
# Inglês:  Very good atmosphere, although inside the Iguatemi Shopping Center, great service.
#  The chosen foods were great
# sentence_br  Ambiente muito bom, apesar de dentro do Shopping Iguatemi, otimo atendimento.
# sentence.sentiment.polarity:  0.5366666666666666
# sentence.sentiment.subjectivity:  0.5433333333333333
# Polaridade
#  Ambiente muito bom, apesar de dentro do Shopping Iguatemi, otimo atendimento. : 0.5366666666666666
# subjetividade
#  Ambiente muito bom, apesar de dentro do Shopping Iguatemi, otimo atendimento. : 0.5433333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Os comidas escolhidas estavam otimas
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Os comidas escolhidas estavam otimas : 0.8
# subjetividade
#  Os comidas escolhidas estavam otimas : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90015 x Para quem quer sentir o ar de Curitiba em meio ao Largo da Ordem o bar do Alemão é um tradicional Happy hour. Minha sugestão é experimentar os Submarinos, bebida  típica do lugar.
# **************
#
# Inglês:  For those who want to feel the air of Curitiba in the middle of Largo da Ordem the bar do Alemão is a traditional Happy hour.
#  My suggestion is to try Submarinos, a typical drink of the place.
# sentence_br  Para quem quer sentir o ar de Curitiba em meio ao Largo da Ordem o bar do Alemão é um tradicional Happy hour.
# sentence.sentiment.polarity:  0.26666666666666666
# sentence.sentiment.subjectivity:  0.5833333333333334
# Polaridade
#  Para quem quer sentir o ar de Curitiba em meio ao Largo da Ordem o bar do Alemão é um tradicional Happy hour. : 0.26666666666666666
# subjetividade
#  Para quem quer sentir o ar de Curitiba em meio ao Largo da Ordem o bar do Alemão é um tradicional Happy hour. : 0.5833333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Minha sugestão é experimentar os Submarinos, bebida  típica do lugar.
# ...
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  A comida é farta, então considero o preço justo.
# sentence.sentiment.polarity:  0.2857142857142857
# sentence.sentiment.subjectivity:  0.5357142857142857
# Polaridade
#  A comida é farta, então considero o preço justo. : 0.2857142857142857
# subjetividade
#  A comida é farta, então considero o preço justo. : 0.5357142857142857
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Comemos um dos pratos mais famosos da casa: o Camarão Internacional.
# sentence.sentiment.polarity:  0.3333333333333333
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Comemos um dos pratos mais famosos da casa: o Camarão Internacional. : 0.3333333333333333
# subjetividade
#  Comemos um dos pratos mais famosos da casa: o Camarão Internacional. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Muito bom mesmo!
# sentence.sentiment.polarity:  0.875
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Muito bom mesmo! : 0.875
# subjetividade
#  Muito bom mesmo! : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Serve facilmente 4 adultos.
# sentence.sentiment.polarity:  0.43333333333333335
# sentence.sentiment.subjectivity:  0.8333333333333334
# Polaridade
#  Serve facilmente 4 adultos. : 0.43333333333333335
# subjetividade
#  Serve facilmente 4 adultos. : 0.8333333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  E as sobremesas?
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  E as sobremesas? : 0.0
# subjetividade
#  E as sobremesas? : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Hummm!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Hummm! : 0.0
# subjetividade
#  Hummm! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Comi a cocada ao forno com sorvete de creme.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Comi a cocada ao forno com sorvete de creme. : 0.0
# subjetividade
#  Comi a cocada ao forno com sorvete de creme. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Forte concorrente do meu restaurante favorito na cidade.
# sentence.sentiment.polarity:  0.4666666666666667
# sentence.sentiment.subjectivity:  0.8666666666666667
# Polaridade
#  Forte concorrente do meu restaurante favorito na cidade. : 0.4666666666666667
# subjetividade
#  Forte concorrente do meu restaurante favorito na cidade. : 0.8666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Possui estacionamento com manobrista (R$ 10,00) ou sem (R$ 5,00).
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Possui estacionamento com manobrista (R$ 10,00) ou sem (R$ 5,00). : 0.0
# subjetividade
#  Possui estacionamento com manobrista (R$ 10,00) ou sem (R$ 5,00). : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  E ainda algumas poucas vagas na rua ao redor.
# sentence.sentiment.polarity:  -0.2
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  E ainda algumas poucas vagas na rua ao redor. : -0.2
# subjetividade
#  E ainda algumas poucas vagas na rua ao redor. : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Durante o dia possui vista para o mar nos dois andares superiores.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Durante o dia possui vista para o mar nos dois andares superiores. : 0.5
# subjetividade
#  Durante o dia possui vista para o mar nos dois andares superiores. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90723 x Gostei muito do atendimento,  fui com a família e alguns amigos,  excelente atendimento,  e pretendo voltar mais vezes.
# **************
# Inglês:  I really enjoyed the service, I went with family and some friends, excellent service, and I intend to come back more often.
# sentence_br  Gostei muito do atendimento,  fui com a família e alguns amigos,  excelente atendimento,  e pretendo voltar mais vezes.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  Gostei muito do atendimento,  fui com a família e alguns amigos,  excelente atendimento,  e pretendo voltar mais vezes. : 0.5
# subjetividade
#  Gostei muito do atendimento,  fui com a família e alguns amigos,  excelente atendimento,  e pretendo voltar mais vezes. : 0.55
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90724 x Sou fã deste restaurante para lanches no final da tarde, leves  e saborosos, o cardápio foi elaborado  pensando na combinação de sabores e cores, resultando em delícias como a tapioca de frango com requeijão, os sucos e açaí batido com morango!
# **************
#
# Inglês:  I'm a fan of this restaurant for snacks in the late afternoon, light and tasty, the menu was designed with the combination of flavors and colors in mind, resulting in delights such as chicken tapioca with curd, juices and açaí with strawberry!
# sentence_br  Sou fã deste restaurante para lanches no final da tarde, leves  e saborosos, o cardápio foi elaborado  pensando na combinação de sabores e cores, resultando em delícias como a tapioca de frango com requeijão, os sucos e açaí batido com morango!
# sentence.sentiment.polarity:  -0.16249999999999998
# sentence.sentiment.subjectivity:  0.6875
# Polaridade
#  Sou fã deste restaurante para lanches no final da tarde, leves  e saborosos, o cardápio foi elaborado  pensando na combinação de sabores e cores, resultando em delícias como a tapioca de frango com requeijão, os sucos e açaí batido com morango! : -0.16249999999999998
# subjetividade
#  Sou fã deste restaurante para lanches no final da tarde, leves  e saborosos, o cardápio foi elaborado  pensando na combinação de sabores e cores, resultando em delícias como a tapioca de frango com requeijão, os sucos e açaí batido com morango! : 0.6875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90725 x Ótima opção para quem gosta de camarão ( no abacaxi ) extremamente decorado , fica um prato muito bonito além de gostoso
# **************
#
# Inglês:  Great option for those who like shrimp (pineapple) extremely decorated, it is a very beautiful dish besides tasty
# sentence_br  Ótima opção para quem gosta de camarão ( no abacaxi ) extremamente decorado , fica um prato muito bonito além de gostoso
# sentence.sentiment.polarity:  0.5583333333333333
# sentence.sentiment.subjectivity:  0.9166666666666666
# Polaridade
#  Ótima opção para quem gosta de camarão ( no abacaxi ) extremamente decorado , fica um prato muito bonito além de gostoso : 0.5583333333333333
# subjetividade
#  Ótima opção para quem gosta de camarão ( no abacaxi ) extremamente decorado , fica um prato muito bonito além de gostoso : 0.9166666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90726 x O ambiente e agradavel e a comida e bem apresentada alem de saborosa. Recomendavel fazer reserva, mesmo em dia de semana.
# **************
#
# Inglês:  The atmosphere is pleasant and the food is well presented in addition to being tasty.
#  Reservations are recommended, even on weekdays.
# sentence_br  O ambiente e agradavel e a comida e bem apresentada alem de saborosa.
# sentence.sentiment.polarity:  0.7333333333333333
# sentence.sentiment.subjectivity:  0.9666666666666667
# Polaridade
#  O ambiente e agradavel e a comida e bem apresentada alem de saborosa. : 0.7333333333333333
# subjetividade
#  O ambiente e agradavel e a comida e bem apresentada alem de saborosa. : 0.9666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Recomendavel fazer reserva, mesmo em dia de semana.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendavel fazer reserva, mesmo em dia de semana. : 0.0
# subjetividade
#  Recomendavel fazer reserva, mesmo em dia de semana. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90727 x O sushi é justo, nada de extraordinário, preço normal, mas o serviço muito lento, chega a encher o saco. Poucos garçons no atendimento, por esse quesito não vale a pena ir, pois não tem nada demais e você fica irritado com o atendimento.
# **************
#
# Inglês:  The sushi is fair, nothing extraordinary, normal price, but the service is very slow, it pisses you off.
#  Few waiters in attendance, for that reason it is not worth going, as there is nothing too much and you get annoyed with the service.
# sentence_br  O sushi é justo, nada de extraordinário, preço normal, mas o serviço muito lento, chega a encher o saco.
# sentence.sentiment.polarity:  0.19833333333333325
# sentence.sentiment.subjectivity:  0.7675
# Polaridade
#  O sushi é justo, nada de extraordinário, preço normal, mas o serviço muito lento, chega a encher o saco. : 0.19833333333333325
# subjetividade
#  O sushi é justo, nada de extraordinário, preço normal, mas o serviço muito lento, chega a encher o saco. : 0.7675
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# sentence_br  Poucos garçons no atendimento, por esse quesito não vale a pena ir, pois não tem nada demais e você fica irritado com o atendimento.
# sentence.sentiment.polarity:  -0.1375
# sentence.sentiment.subjectivity:  0.30000000000000004
# Polaridade
#  Poucos garçons no atendimento, por esse quesito não vale a pena ir, pois não tem nada demais e você fica irritado com o atendimento. : -0.1375
# subjetividade
#  Poucos garçons no atendimento, por esse quesito não vale a pena ir, pois não tem nada demais e você fica irritado com o atendimento. : 0.30000000000000004
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-90000-100000.txt
# **************
#
# var 90728 x Fomos à pizzaria Santa Pizza para um jantar. Chegando lá, olhamos o cardapio na porta e, apesar do preço ser um pouco elevado, a qualidade da pizza parecia boa.
# Esperamos uns 5 minutos até que o recepcionista  (um pouco perdido) nos colocou numa mesa.
# Recebemos o cardápio e escolhemos o que pediriamos....o problema é que NENHUM garçom voltou para pegar nossos pedidos. Tentamos chamar a atenção de algum garçom, mas foi inútil
# Levantamos e fomos embora
# Me parece inadmissível uma pizzaria que cobra um preço médio de R$ 75,00 por uma pizza, não oferecer treinamento aos funcionários
# Lamento muito e não recomendo
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
