# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pcorrea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 50000
terminou = 60000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  125,533,302,784 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 192857

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
ini = time.time()
for x in df['reviewBody']:
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 50001 x Péssimo bolo passado pesou no estômago de quem comeu atendimento horrível atendimento da pior qualidade não volto jamais não recomendo nunca
# **************
#
# Inglês:  Lousy past cake weighed on the stomach of those who ate horrible service poor quality service I will never come back I never recommend
# sentence_br  Péssimo bolo passado pesou no estômago de quem comeu atendimento horrível atendimento da pior qualidade não volto jamais não recomendo nunca
# sentence.sentiment.polarity:  -0.43
# sentence.sentiment.subjectivity:  0.47000000000000003
# Polaridade
#  Péssimo bolo passado pesou no estômago de quem comeu atendimento horrível atendimento da pior qualidade não volto jamais não recomendo nunca : -0.43
# subjetividade
#  Péssimo bolo passado pesou no estômago de quem comeu atendimento horrível atendimento da pior qualidade não volto jamais não recomendo nunca : 0.47000000000000003
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50002 x Não existe nada igual no Nordeste.
# Simplesmente fantástico desde a decoração até os pratos e petiscos.
# Atendimento impecável!
# Um pouco difícil de estacionar
# **************
#
# Inglês:  There is nothing like it in the Northeast.
#
# Simply fantastic from the decor to the dishes and snacks.
#
# Impeccable service!
# A little difficult to park
# sentence_br  Não existe nada igual no Nordeste.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Não existe nada igual no Nordeste. : 0.0
# subjetividade
#  Não existe nada igual no Nordeste. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Simplesmente fantástico desde a decoração até os pratos e petiscos.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Simplesmente fantástico desde a decoração até os pratos e petiscos. : 0.4
# subjetividade
#  Simplesmente fantástico desde a decoração até os pratos e petiscos. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Atendimento impecável!
# sentence.sentiment.polarity:  0.9375
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Atendimento impecável! : 0.9375
# subjetividade
#  Atendimento impecável! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Um pouco difícil de estacionar
# sentence.sentiment.polarity:  -0.34375
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Um pouco difícil de estacionar : -0.34375
# subjetividade
#  Um pouco difícil de estacionar : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50003 x Lugar bem decorado, tem um lado de bar , lugar para música ao vivo, estacionamento ao lado. O atendimento foi ótimo, pratos saborosos e bem elaborados no visual, fui em dia de menu, cardápio aprovado.
# **************
#
# Inglês:  Well decorated place, it has a bar side, place for live music, parking next door.
#  The service was great, the dishes were tasty and well prepared in the visual, I went on a menu day, approved menu.
# sentence_br  Lugar bem decorado, tem um lado de bar , lugar para música ao vivo, estacionamento ao lado.
# sentence.sentiment.polarity:  0.06818181818181818
# sentence.sentiment.subjectivity:  0.25
# Polaridade
#  Lugar bem decorado, tem um lado de bar , lugar para música ao vivo, estacionamento ao lado. : 0.06818181818181818
# subjetividade
#  Lugar bem decorado, tem um lado de bar , lugar para música ao vivo, estacionamento ao lado. : 0.25
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  O atendimento foi ótimo, pratos saborosos e bem elaborados no visual, fui em dia de menu, cardápio aprovado.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.375
# Polaridade
#  O atendimento foi ótimo, pratos saborosos e bem elaborados no visual, fui em dia de menu, cardápio aprovado. : 0.4
# subjetividade
#  O atendimento foi ótimo, pratos saborosos e bem elaborados no visual, fui em dia de menu, cardápio aprovado. : 0.375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50004 x Se você gosta muito de carnes, esta á a churrascaria ideal para saborear um bom assado. As opções de saladas e apetrechos são limitadas, mas vale a experiência.
# **************
#
# Inglês:  If you love meat, this is the ideal steakhouse to enjoy a good roast.
#  The options for salads and paraphernalia are limited, but worth the experience.
# sentence_br  Se você gosta muito de carnes, esta á a churrascaria ideal para saborear um bom assado.
# sentence.sentiment.polarity:  0.625
# sentence.sentiment.subjectivity:  0.675
# Polaridade
#  Se você gosta muito de carnes, esta á a churrascaria ideal para saborear um bom assado. : 0.625
# subjetividade
#  Se você gosta muito de carnes, esta á a churrascaria ideal para saborear um bom assado. : 0.675
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  As opções de saladas e apetrechos são limitadas, mas vale a experiência.
# sentence.sentiment.polarity:  0.11428571428571428
# sentence.sentiment.subjectivity:  0.12142857142857143
# Polaridade
#  As opções de saladas e apetrechos são limitadas, mas vale a experiência. : 0.11428571428571428
# subjetividade
#  As opções de saladas e apetrechos são limitadas, mas vale a experiência. : 0.12142857142857143
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50005 x Local bem agradável e divertido, perfeito para um happy hour com os amigos. Comida ótima e muito saborosa!
# **************
#
# Inglês:  Very nice and fun place, perfect for a happy hour with friends.
#  Great and very tasty food!
# sentence_br  Local bem agradável e divertido, perfeito para um happy hour com os amigos.
# sentence.sentiment.polarity:  0.72
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Local bem agradável e divertido, perfeito para um happy hour com os amigos. : 0.72
# subjetividade
#  Local bem agradável e divertido, perfeito para um happy hour com os amigos. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Comida ótima e muito saborosa!
# sentence.sentiment.polarity:  0.525
# sentence.sentiment.subjectivity:  0.525
# Polaridade
#  Comida ótima e muito saborosa! : 0.525
# subjetividade
#  Comida ótima e muito saborosa! : 0.525
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50006 x Escolhi um combinado de brisas (sashimis cortados com perfeição e molho cítrico delicioso), que custava R$ 65. A garçonete, muito solícita, sugeriu que eu trocasse por outra porção das mesmas brisas, que não estava no cardápio, por R$ 90, mas com quantidade bem maior. Topei, já que adoro sashimi! Na hora da conta o prato era R$ 120 e não os R$ 90. Ela argumentou que eu havia colocado o peixe. Como assim?! Nem escolhi o peixe, nem existia no cardápio. Tudo sugestão dela. Todos muito educados, queriam me dar uma sobremesa para acalmar minha indignação. Não quero sobremesa, só quero respeito. Já havia sido sugerido que eu trocasse meu saque da casa, delicioso, por outro maior, só que bem mais caro. Muito feio isso! Não combina com o charme da casa.
# **************
#
# Inglês:  I chose a combination of breezes (sashimis perfectly cut and delicious citrus sauce), which cost R $ 65.
#  The waitress, very helpful, suggested that I exchange for another portion of the same breezes, which was not on the menu, for R $ 90, but with a much larger amount.
#  I agreed, since I love sashimi! At the time of check, the dish was R $ 120 and not R $ 90.
#  She argued that I had put the fish.
#  As well?! I didn't even choose the fish, nor did it exist on the menu.
#  Everything her suggestion.
#  All very polite, wanted to give me a dessert to calm my indignation.
#  I don't want dessert, I just want respect.
#  It had already been suggested that I exchange my delicious home serve for a bigger one, only much more expensive.
#  Too ugly! It doesn't match the charm of the house.
# sentence_br  Escolhi um combinado de brisas (sashimis cortados com perfeição e molho cítrico delicioso), que custava R$ 65.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Escolhi um combinado de brisas (sashimis cortados com perfeição e molho cítrico delicioso), que custava R$ 65. : 1.0
# subjetividade
#  Escolhi um combinado de brisas (sashimis cortados com perfeição e molho cítrico delicioso), que custava R$ 65. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  A garçonete, muito solícita, sugeriu que eu trocasse por outra porção das mesmas brisas, que não estava no cardápio, por R$ 90, mas com quantidade bem maior.
# sentence.sentiment.polarity:  0.06666666666666667
# sentence.sentiment.subjectivity:  0.30833333333333335
# Polaridade
#  A garçonete, muito solícita, sugeriu que eu trocasse por outra porção das mesmas brisas, que não estava no cardápio, por R$ 90, mas com quantidade bem maior. : 0.06666666666666667
# subjetividade
#  A garçonete, muito solícita, sugeriu que eu trocasse por outra porção das mesmas brisas, que não estava no cardápio, por R$ 90, mas com quantidade bem maior. : 0.30833333333333335
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Topei, já que adoro sashimi!
# sentence.sentiment.polarity:  0.625
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Topei, já que adoro sashimi! : 0.625
# subjetividade
#  Topei, já que adoro sashimi! : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Na hora da conta o prato era R$ 120 e não os R$ 90.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Na hora da conta o prato era R$ 120 e não os R$ 90. : 0.0
# subjetividade
#  Na hora da conta o prato era R$ 120 e não os R$ 90. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Ela argumentou que eu havia colocado o peixe.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Ela argumentou que eu havia colocado o peixe. : 0.0
# subjetividade
#  Ela argumentou que eu havia colocado o peixe. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Como assim?!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Como assim?! : 0.0
# subjetividade
#  Como assim?! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Nem escolhi o peixe, nem existia no cardápio.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Nem escolhi o peixe, nem existia no cardápio. : 0.0
# subjetividade
#  Nem escolhi o peixe, nem existia no cardápio. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Tudo sugestão dela.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tudo sugestão dela. : 0.0
# subjetividade
#  Tudo sugestão dela. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Todos muito educados, queriam me dar uma sobremesa para acalmar minha indignação.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.525
# Polaridade
#  Todos muito educados, queriam me dar uma sobremesa para acalmar minha indignação. : 0.25
# subjetividade
#  Todos muito educados, queriam me dar uma sobremesa para acalmar minha indignação. : 0.525
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br
000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Acho que se o atendimento melhorar fica um restaurante TOP.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Acho que se o atendimento melhorar fica um restaurante TOP. : 0.5
# subjetividade
#  Acho que se o atendimento melhorar fica um restaurante TOP. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50009 x Quando resolvemos ir para Maceió,  vimos sobre esse restaurante /clube. Achei interessante mas não tanto quanto imaginava e havia lido. O local é  bonito.  A praia é boa para banho.  O atendimento é excelente.  A música também foi excelente.  Porém o que não nos agradou foi o almoço.  O nosso pedido chegou frio e também não estava bom. Achamos também exagerado o valor cobrado para entrada,  que deveria ser descontado caso a pessoa consumisse.
# **************
# Inglês:  When we decided to go to Maceió, we saw about this restaurant / club.
#  I found it interesting but not as much as I imagined and had read.
#  The location is beautiful.
#   The beach is good for swimming.
#   The service is excellent.
#   The music was also excellent.
#   However, what did not please us was lunch.
#   Our order arrived cold and it was also not good.
#  We also think that the amount charged for entry is exaggerated, which should be discounted if the person consumes it.
# sentence_br  Quando resolvemos ir para Maceió,  vimos sobre esse restaurante /clube.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Quando resolvemos ir para Maceió,  vimos sobre esse restaurante /clube. : 0.0
# subjetividade
#  Quando resolvemos ir para Maceió,  vimos sobre esse restaurante /clube. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Achei interessante mas não tanto quanto imaginava e havia lido.
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.35
# Polaridade
#  Achei interessante mas não tanto quanto imaginava e havia lido. : 0.35
# subjetividade
#  Achei interessante mas não tanto quanto imaginava e havia lido. : 0.35
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  O local é  bonito.
# sentence.sentiment.polarity:  0.85
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O local é  bonito. : 0.85
# subjetividade
#  O local é  bonito. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  A praia é boa para banho.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  A praia é boa para banho. : 0.7
# subjetividade
#  A praia é boa para banho. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  O atendimento é excelente.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O atendimento é excelente. : 1.0
# subjetividade
#  O atendimento é excelente. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  A música também foi excelente.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  A música também foi excelente. : 1.0
# subjetividade
#  A música também foi excelente. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Porém o que não nos agradou foi o almoço.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Porém o que não nos agradou foi o almoço. : 0.0
# subjetividade
#  Porém o que não nos agradou foi o almoço. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  O nosso pedido chegou frio e também não estava bom.
# sentence.sentiment.polarity:  -0.475
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  O nosso pedido chegou frio e também não estava bom. : -0.475
# subjetividade
#  O nosso pedido chegou frio e também não estava bom. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Achamos também exagerado o valor cobrado para entrada,  que deveria ser descontado caso a pessoa consumisse.
# sentence.sentiment.polarity:  -0.5
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Achamos também exagerado o valor cobrado para entrada,  que deveria ser descontado caso a pessoa consumisse. : -0.5
# subjetividade
#  Achamos também exagerado o valor cobrado para entrada,  que deveria ser descontado caso a pessoa consumisse. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Pedi a especialidade da casa - file Salento - e recebi um bom grelhado com salada fresca e crocante por apenas R$32,98.
# sentence.sentiment.polarity:  0.3333333333333333
# sentence.sentiment.subjectivity:  0.7000000000000001
# Polaridade
#  Pedi a especialidade da casa - file Salento - e recebi um bom grelhado com salada fresca e crocante por apenas R$32,98. : 0.3333333333333333
# subjetividade
#  Pedi a especialidade da casa - file Salento - e recebi um bom grelhado com salada fresca e crocante por apenas R$32,98. : 0.7000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Uma ótima relação custo/beneficio para Brasília.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Uma ótima relação custo/beneficio para Brasília. : 0.8
# subjetividade
#  Uma ótima relação custo/beneficio para Brasília. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Acabei com o meu preco0nceito!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Acabei com o meu preco0nceito! : 0.0
# subjetividade
#  Acabei com o meu preco0nceito! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50012 x Estivemos recentemente em João Pessoa. Apesar de já conhecer a reputação do restaurante NAU, optamos pela proximidade do local em que ficamos e, por avaliações feitas aqui e pelo pessoal do hotel resolvemos provar da comida deste restaurante. Foi decepcionante! A comida veio fria e numa proporção que não justificou o preço. Existem lugares melhores para quem gosta de frutos do mar em JAMPA.
# **************
# Inglês:  We were recently in João Pessoa.
#  Despite already knowing the reputation of the NAU restaurant, we opted for the proximity of the place where we stayed and, due to reviews made here and by the hotel staff, we decided to taste the food in this restaurant.
#  It was disappointing! The food came cold and in a proportion that did not justify the price.
#  There are better places for those who like seafood in JAMPA.
# sentence_br  Estivemos recentemente em João Pessoa.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.25
# Polaridade
#  Estivemos recentemente em João Pessoa. : 0.0
# subjetividade
#  Estivemos recentemente em João Pessoa. : 0.25
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Apesar de já conhecer a reputação do restaurante NAU, optamos pela proximidade do local em que ficamos e, por avaliações feitas aqui e pelo pessoal do hotel resolvemos provar da comida deste restaurante.
# sentence.sentiment.polarity:  -0.125
# sentence.sentiment.subjectivity:  0.375
# Polaridade
#  Apesar de já conhecer a reputação do restaurante NAU, optamos pela proximidade do local em que ficamos e, por avaliações feitas aqui e pelo pessoal do hotel resolvemos provar da comida deste restaurante. : -0.125
# subjetividade
#  Apesar de já conhecer a reputação do restaurante NAU, optamos pela proximidade do local em que ficamos e, por avaliações feitas aqui e pelo pessoal do hotel resolvemos provar da comida deste restaurante. : 0.375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Foi decepcionante!
# sentence.sentiment.polarity:  -0.75
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  Foi decepcionante! : -0.75
# subjetividade
#  Foi decepcionante! : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  A comida veio fria e numa proporção que não justificou o preço.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  A comida veio fria e numa proporção que não justificou o preço. : -0.6
# subjetividade
#  A comida veio fria e numa proporção que não justificou o preço. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Existem lugares melhores para quem gosta de frutos do mar em JAMPA.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Existem lugares melhores para quem gosta de frutos do mar em JAMPA. : 0.5
# subjetividade
#  Existem lugares melhores para quem gosta de frutos do mar em JAMPA. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50013 x Maravilhoso! Um prato que não podemos deixar de apreciar neste restaurante. Ambiente agradável e excelentes opções.
# **************
#
# Inglês:  Wonderful! A dish that we cannot fail to appreciate in this restaurant.
#  Nice atmosphere and excellent options.
# sentence_br  Maravilhoso!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Maravilhoso! : 1.0
# subjetividade
#  Maravilhoso! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Um prato que não podemos deixar de apreciar neste restaurante.
# sentence.sentiment.polarity:  -0.5
# sentence.sentiment.subjectivity:  0.29999999999999993
# Polaridade
#  Um prato que não podemos deixar de apreciar neste restaurante. : -0.5
# subjetividade
#  Um prato que não podemos deixar de apreciar neste restaurante. : 0.29999999999999993
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Ambiente agradável e excelentes opções.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Ambiente agradável e excelentes opções. : 0.8
# subjetividade
#  Ambiente agradável e excelentes opções. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50014 x O Carlota, da chef Carla Pernambuco é excelente. Comida ótima, atendimento atencioso, ambiente muito agradável.
# **************
#
# Inglês:  Carlota, by chef Carla Pernambuco is excellent.
#  Great food, attentive service, very pleasant atmosphere.
# sentence_br  O Carlota, da chef Carla Pernambuco é excelente.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O Carlota, da chef Carla Pernambuco é excelente. : 1.0
# subjetividade
#  O Carlota, da chef Carla Pernambuco é excelente. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Comida ótima, atendimento atencioso, ambiente muito agradável.
# sentence.sentiment.polarity:  0.7177777777777777
# sentence.sentiment.subjectivity:  0.8833333333333333
# Polaridade
#  Comida ótima, atendimento atencioso, ambiente muito agradável. : 0.7177777777777777
# subjetividade
#  Comida ótima, atendimento atencioso, ambiente muito agradável. : 0.8833333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50015 x Baita produto, foco na qualidade e não na quantidade de sabores. Atendimento atencioso e bem feito. Local casual e sem frescura, como o convite à pizza deve ser.
# **************
#
# Inglês:  Great product, focus on quality and not on quantity of flavors.
#  Attentive and well done service.
#  Casual and no frills place, as the pizza invitation should be.
# sentence_br  Baita produto, foco na qualidade e não na quantidade de sabores.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Baita produto, foco na qualidade e não na quantidade de sabores. : 0.8
# subjetividade
#  Baita produto, foco na qualidade e não na quantidade de sabores. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Atendimento atencioso e bem feito.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Atendimento atencioso e bem feito. : 0.4
# subjetividade
#  Atendimento atencioso e bem feito. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Local casual e sem frescura, como o convite à pizza deve ser.
# sentence.sentiment.polarity:  -0.5000000000000001
# sentence.sentiment.subjectivity:  0.8666666666666667
# Polaridade
#  Local casual e sem frescura, como o convite à pizza deve ser. : -0.5000000000000001
# subjetividade
#  Local casual e sem frescura, como o convite à pizza deve ser. : 0.8666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50016 x Adoro a comida , sempre que possível vou comer lá,  os garçons são excelentes,  gosto muito do Ailton , a única coisa mais chata é que os preços são meio salgadinhos mas mesmo assim a qualidade é muito boa
# **************
#
# Inglês:  I love the food, whenever possible I will eat there, the waiters are excellent, I really like Ailton, the only thing that is more annoying is that the prices are a bit salty but the quality is still very good
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50021 x O ambiente é uma gracinha, além do bom atendimento a comida é uma delícia, sou freqüentadora assídua!! Ótima opção para quem está próximo ao aeroporto de Goiania.
# **************
#
# Inglês:  The environment is cute, in addition to the good service the food is delicious, I am a frequent visitor !! Great option for those who are close to the airport of Goiania.
# sentence_br  O ambiente é uma gracinha, além do bom atendimento a comida é uma delícia, sou freqüentadora assídua!!
# sentence.sentiment.polarity:  0.5890625
# sentence.sentiment.subjectivity:  0.725
# Polaridade
#  O ambiente é uma gracinha, além do bom atendimento a comida é uma delícia, sou freqüentadora assídua!! : 0.5890625
# subjetividade
#  O ambiente é uma gracinha, além do bom atendimento a comida é uma delícia, sou freqüentadora assídua!! : 0.725
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Ótima opção para quem está próximo ao aeroporto de Goiania.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Ótima opção para quem está próximo ao aeroporto de Goiania. : 0.8
# subjetividade
#  Ótima opção para quem está próximo ao aeroporto de Goiania. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50022 x Toda equipe muito compenetrares e atenciosa. Comidas e drinks uma delícia. Reginaldo, que nos atendeu nota mil!!!!
# **************
# Inglês:  All staff very understanding and helpful.
#  Food and drinks are delicious.
#  Reginaldo, who attended us note thousand !!!!
# sentence_br  Toda equipe muito compenetrares e atenciosa.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Toda equipe muito compenetrares e atenciosa. : 0.2
# subjetividade
#  Toda equipe muito compenetrares e atenciosa. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Comidas e drinks uma delícia.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Comidas e drinks uma delícia. : 1.0
# subjetividade
#  Comidas e drinks uma delícia. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Reginaldo, que nos atendeu nota mil!!!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Reginaldo, que nos atendeu nota mil!!! : 0.0
# subjetividade
#  Reginaldo, que nos atendeu nota mil!!! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50023 x Um restaurante italiano que serve um dos melhores hambúrgueres da cidade. Com massa de pizza e queijo cheddar este prato é simplesmente sensacional . Vale a pena
# **************
#
# Inglês:  An Italian restaurant serving one of the best burgers in the city.
#  With pizza dough and cheddar cheese this dish is simply amazing. worth it
# sentence_br  Um restaurante italiano que serve um dos melhores hambúrgueres da cidade.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.15
# Polaridade
#  Um restaurante italiano que serve um dos melhores hambúrgueres da cidade. : 0.5
# subjetividade
#  Um restaurante italiano que serve um dos melhores hambúrgueres da cidade. : 0.15
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Com massa de pizza e queijo cheddar este prato é simplesmente sensacional .
# sentence.sentiment.polarity:  0.6000000000000001
# sentence.sentiment.subjectivity:  0.9
# Polaridade
# ...
# sentence.sentiment.polarity:  0.15000000000000002
# sentence.sentiment.subjectivity:  0.44999999999999996
# Polaridade
#  A dica é: nos finais de semana chegue cedo, porque enche rápido. : 0.15000000000000002
# subjetividade
#  A dica é: nos finais de semana chegue cedo, porque enche rápido. : 0.44999999999999996
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Comida brasileira da melhor qualidade.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Comida brasileira da melhor qualidade. : 1.0
# subjetividade
#  Comida brasileira da melhor qualidade. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50693 x Um lugar que já teve batatas fritas na hora e o chopp especial da Kudd e agora me vem com batata pre cozida e não tem mais chopp.  Vergonha. Fecha e muda o nome pra Sanduíche da esquina com preço gourmet
# **************
# Inglês:  A place that already had fries on the spot and Kudd's special draft beer and now comes with pre-cooked potatoes and no more draft beer.
#   Shame.
#  Close and change the name for Corner sandwich with gourmet price
# sentence_br  Um lugar que já teve batatas fritas na hora e o chopp especial da Kudd e agora me vem com batata pre cozida e não tem mais chopp.
# sentence.sentiment.polarity:  0.053571428571428575
# sentence.sentiment.subjectivity:  0.5357142857142857
# Polaridade
#  Um lugar que já teve batatas fritas na hora e o chopp especial da Kudd e agora me vem com batata pre cozida e não tem mais chopp. : 0.053571428571428575
# subjetividade
#  Um lugar que já teve batatas fritas na hora e o chopp especial da Kudd e agora me vem com batata pre cozida e não tem mais chopp. : 0.5357142857142857
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Vergonha.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Vergonha. : 0.0
# subjetividade
#  Vergonha. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Fecha e muda o nome pra Sanduíche da esquina com preço gourmet
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Fecha e muda o nome pra Sanduíche da esquina com preço gourmet : 0.0
# subjetividade
#  Fecha e muda o nome pra Sanduíche da esquina com preço gourmet : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50694 x Uma ótima picanha, com pão de alho, uma carne de carneiro assado com geléia de menta..Recomendadissimo
# **************
#
# Inglês:  A great picanha, with garlic bread, a roasted mutton with mint jam.
# .Recommendadissimo
# sentence_br  Uma ótima picanha, com pão de alho, uma carne de carneiro assado com geléia de menta.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Uma ótima picanha, com pão de alho, uma carne de carneiro assado com geléia de menta. : 0.8
# subjetividade
#  Uma ótima picanha, com pão de alho, uma carne de carneiro assado com geléia de menta. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  .Recomendadissimo
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  .Recomendadissimo : 0.0
# subjetividade
#  .Recomendadissimo : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50695 x Atendimento de ótima qualidade, ambiente super agradável, e o principal a comida estava perfeita. Atendimento do “Jean e Thiago” top de alta qualidade! - Recomendo!
# **************
#
# Inglês:  Great quality service, super pleasant atmosphere, and the main thing was the food was perfect.
#  Top quality “Jean e Thiago” service! - I recommend!
# sentence_br  Atendimento de ótima qualidade, ambiente super agradável, e o principal a comida estava perfeita.
# sentence.sentiment.polarity:  0.6066666666666667
# sentence.sentiment.subjectivity:  0.7433333333333334
# Polaridade
#  Atendimento de ótima qualidade, ambiente super agradável, e o principal a comida estava perfeita. : 0.6066666666666667
# subjetividade
#  Atendimento de ótima qualidade, ambiente super agradável, e o principal a comida estava perfeita. : 0.7433333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Atendimento do “Jean e Thiago” top de alta qualidade!
# sentence.sentiment.polarity:  0.625
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Atendimento do “Jean e Thiago” top de alta qualidade! : 0.625
# subjetividade
#  Atendimento do “Jean e Thiago” top de alta qualidade! : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  - Recomendo!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  - Recomendo! : 0.0
# subjetividade
#  - Recomendo! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50696 x Cortes nobres...
# Cerveja gelada...
# Ambiente agradavel...
# Excelente atendinento Sérgio
# Parabéns pelo sercivo de excelência.
# **************
#
# Inglês:  Noble cuts.
# ..
# Cold beer.
# ..
# Pleasant environment.
# ..
# Excellent service Sérgio
# Congratulations on the excellent service.
# sentence_br  Cortes nobres.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Cortes nobres. : 0.6
# subjetividade
#  Cortes nobres. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  ..
# Cerveja gelada.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ..
# Cerveja gelada. : 0.0
# subjetividade
#  ..
# Cerveja gelada. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  ..
# Ambiente agradavel.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  ..
# Ambiente agradavel. : -0.6
# subjetividade
#  ..
# Ambiente agradavel. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  ..
# Excelente atendinento Sérgio
# Parabéns pelo sercivo de excelência.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ..
# Excelente atendinento Sérgio
# Parabéns pelo sercivo de excelência. : 0.0
# subjetividade
#  ..
# Excelente atendinento Sérgio
# Parabéns pelo sercivo de excelência. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50697 x NYC Burguer e batata frita com pastrami são a pedida!! O clima é muito descontraído e o atendimento impecável!!
# **************
#
# Inglês:  NYC Burger and french fries with pastrami are the order !! The atmosphere is very relaxed and the service is impeccable !!
# sentence_br  NYC Burguer e batata frita com pastrami são a pedida!!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  NYC Burguer e batata frita com pastrami são a pedida!! : 0.0
# subjetividade
#  NYC Burguer e batata frita com pastrami são a pedida!! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  O clima é muito descontraído e o atendimento impecável!
# sentence.sentiment.polarity:  0.56875
# sentence.sentiment.subjectivity:  0.525
# Polaridade
#  O clima é muito descontraído e o atendimento impecável! : 0.56875
# subjetividade
#  O clima é muito descontraído e o atendimento impecável! : 0.525
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50698 x Como qualquer Bobs. Não gosto muitos dos sanduíches do Bobs mas como era o mais perto do hotel foi ali mesmo que comi algumas vezes..
# **************
#
# Inglês:  Like any Bobs.
#  I don't like many of the Bobs sandwiches but as it was the closest to the hotel it was right there that I ate a few times.
# .
# sentence_br  Como qualquer Bobs.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Como qualquer Bobs. : 0.0
# subjetividade
#  Como qualquer Bobs. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Não gosto muitos dos sanduíches do Bobs mas como era o mais perto do hotel foi ali mesmo que comi algumas vezes.
# sentence.sentiment.polarity:  0.1952380952380952
# sentence.sentiment.subjectivity:  0.37857142857142856
# Polaridade
#  Não gosto muitos dos sanduíches do Bobs mas como era o mais perto do hotel foi ali mesmo que comi algumas vezes. : 0.1952380952380952
# subjetividade
#  Não gosto muitos dos sanduíches do Bobs mas como era o mais perto do hotel foi ali mesmo que comi algumas vezes. : 0.37857142857142856
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  .
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  . : 0.0
# subjetividade
#  . : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50699 x O prato superou nossas expectativas, camarão com arroz, comemos em três adultos e três crianças e saímos muito satisfeitas e ainda voltamos no dia seguinte. Excelente!!
# **************
# Inglês:  The dish exceeded our expectations, shrimp with rice, we ate with three adults and three children and we left very satisfied and still came back the next day.
#  Great!!
# sentence_br  O prato superou nossas expectativas, camarão com arroz, comemos em três adultos e três crianças e saímos muito satisfeitas e ainda voltamos no dia seguinte.
# sentence.sentiment.polarity:  0.1625
# sentence.sentiment.subjectivity:  0.25
# Polaridade
#  O prato superou nossas expectativas, camarão com arroz, comemos em três adultos e três crianças e saímos muito satisfeitas e ainda voltamos no dia seguinte. : 0.1625
# subjetividade
#  O prato superou nossas expectativas, camarão com arroz, comemos em três adultos e três crianças e saímos muito satisfeitas e ainda voltamos no dia seguinte. : 0.25
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  Excelente!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Excelente! : 1.0
# subjetividade
#  Excelente! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-50000-60000.txt
# **************
#
# var 50700 x Muito bem localizado, ótimo atendimento, local agradável e aconchegante, hambúrgueres e chopp excelentes.
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
