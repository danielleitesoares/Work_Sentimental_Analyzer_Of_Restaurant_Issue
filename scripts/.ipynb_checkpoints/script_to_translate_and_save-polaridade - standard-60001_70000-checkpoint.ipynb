# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path

# %%
inicio = 60000
terminou = 70000

# %%
! git clone https://github.com/paulordie/sentimental_ds

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  125,533,110,272 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 185890

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
ini = time.time()
for x in df['reviewBody']:
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 60001 x Excelente atendimento. O almoço executivo é composto de grande variedade de massas, dentre as quais destaco o excelente canelone de presunto e queijo, e carnes. Os garçons são muito solícitos e educados.
# **************
#
# Inglês:  Excellent service.
#  The executive lunch consists of a wide variety of pastas, among which I highlight the excellent ham and cheese cannelloni and meats.
#  The waiters are very helpful and polite.
# sentence_br  Excelente atendimento.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Excelente atendimento. : 1.0
# subjetividade
#  Excelente atendimento. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  O almoço executivo é composto de grande variedade de massas, dentre as quais destaco o excelente canelone de presunto e queijo, e carnes.
# sentence.sentiment.polarity:  0.45
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  O almoço executivo é composto de grande variedade de massas, dentre as quais destaco o excelente canelone de presunto e queijo, e carnes. : 0.45
# subjetividade
#  O almoço executivo é composto de grande variedade de massas, dentre as quais destaco o excelente canelone de presunto e queijo, e carnes. : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Os garçons são muito solícitos e educados.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Os garçons são muito solícitos e educados. : 0.2
# subjetividade
#  Os garçons são muito solícitos e educados. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60002 x Festival de lagosta é imperdível, Carme maravilhosa, bufê delicioso, atendimento nota 10, adoro !!!!
# **************
#
# Inglês:  Lobster festival is a must, Carme wonderful, delicious buffet, service note 10, I love it !!!!
# sentence_br  Festival de lagosta é imperdível, Carme maravilhosa, bufê delicioso, atendimento nota 10, adoro !!!
# sentence.sentiment.polarity:  0.9921875
# sentence.sentiment.subjectivity:  0.8666666666666667
# Polaridade
#  Festival de lagosta é imperdível, Carme maravilhosa, bufê delicioso, atendimento nota 10, adoro !!! : 0.9921875
# subjetividade
#  Festival de lagosta é imperdível, Carme maravilhosa, bufê delicioso, atendimento nota 10, adoro !!! : 0.8666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60003 x Eu e minha família adoramos o cardápio e os sucos regionais do restaurante, mas achamos inadimissivel o uso de copos descartáveis pra servir os sucos. Em tempos de crise ambiental, não dá pra entender como um empreendimento como esse, com estrutura suficiente para lavagem de copos, ainda faz isso. Já falamos com os funcionários, e esperamos que mudem para realmente fazer jus à proposta e aí sim ganhar avaliação 5. :)
# **************
#
# Inglês:  My family and I love the restaurant's menu and regional juices, but we found the use of disposable cups to serve the juices inadmissible.
#  In times of environmental crisis, it is impossible to understand how a project like this, with enough structure for washing glasses, still does that.
#  We have already spoken to the employees, and we hope that they will change to really live up to the proposal and then gain an evaluation 5.
#  :)
# sentence_br  Eu e minha família adoramos o cardápio e os sucos regionais do restaurante, mas achamos inadimissivel o uso de copos descartáveis pra servir os sucos.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Eu e minha família adoramos o cardápio e os sucos regionais do restaurante, mas achamos inadimissivel o uso de copos descartáveis pra servir os sucos. : 0.5
# subjetividade
#  Eu e minha família adoramos o cardápio e os sucos regionais do restaurante, mas achamos inadimissivel o uso de copos descartáveis pra servir os sucos. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Em tempos de crise ambiental, não dá pra entender como um empreendimento como esse, com estrutura suficiente para lavagem de copos, ainda faz isso.
# sentence.sentiment.polarity:  -0.3333333333333333
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Em tempos de crise ambiental, não dá pra entender como um empreendimento como esse, com estrutura suficiente para lavagem de copos, ainda faz isso. : -0.3333333333333333
# subjetividade
#  Em tempos de crise ambiental, não dá pra entender como um empreendimento como esse, com estrutura suficiente para lavagem de copos, ainda faz isso. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Já falamos com os funcionários, e esperamos que mudem para realmente fazer jus à proposta e aí sim ganhar avaliação 5.
#  :)
# sentence.sentiment.polarity:  0.3181818181818182
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Já falamos com os funcionários, e esperamos que mudem para realmente fazer jus à proposta e aí sim ganhar avaliação 5.
#  :) : 0.3181818181818182
# subjetividade
#  Já falamos com os funcionários, e esperamos que mudem para realmente fazer jus à proposta e aí sim ganhar avaliação 5.
#  :) : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60004 x Depois de uma amiga ter falado tanto desse restaurante e após ter ido duas vezes e não conseguir entrar, resolvemos tentar outra vez .
# Para começar a entrada não é maravilhosa, porém o pai que acompanha é bem aquecido.
# O atendimento é adequado, pois ser educado com os clientes deve ser o padrão.
# Os pratos, carne de porco e macarrão estavam gostosos.
# A sobremesa também estava boa.
# Enfim , uma comida semples, porém de alta qualidade é bem feita .
# **************
#
# Inglês:  After a friend talked so much about this restaurant and after going twice and being unable to get in, we decided to try again.
# To start the entry is not wonderful, but the accompanying father is very warm.
#
# Service is adequate, as being polite to customers should be the standard.
#
# The dishes, pork and pasta were delicious.
#
# The dessert was also good.
#
# Anyway, simple but high quality food is well made.
# sentence_br  Depois de uma amiga ter falado tanto desse restaurante e após ter ido duas vezes e não conseguir entrar, resolvemos tentar outra vez .
# sentence.sentiment.polarity:  -0.15
# sentence.sentiment.subjectivity:  0.35
# Polaridade
#  Depois de uma amiga ter falado tanto desse restaurante e após ter ido duas vezes e não conseguir entrar, resolvemos tentar outra vez . : -0.15
# subjetividade
#  Depois de uma amiga ter falado tanto desse restaurante e após ter ido duas vezes e não conseguir entrar, resolvemos tentar outra vez . : 0.35
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Para começar a entrada não é maravilhosa, porém o pai que acompanha é bem aquecido.
# sentence.sentiment.polarity:  0.14
# sentence.sentiment.subjectivity:  0.89
# Polaridade
#  Para começar a entrada não é maravilhosa, porém o pai que acompanha é bem aquecido. : 0.14
# subjetividade
#  Para começar a entrada não é maravilhosa, porém o pai que acompanha é bem aquecido. : 0.89
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  O atendimento é adequado, pois ser educado com os clientes deve ser o padrão.
# sentence.sentiment.polarity:  0.16666666666666666
# sentence.sentiment.subjectivity:  0.16666666666666666
# Polaridade
#  O atendimento é adequado, pois ser educado com os clientes deve ser o padrão. : 0.16666666666666666
# subjetividade
#  O atendimento é adequado, pois ser educado com os clientes deve ser o padrão. : 0.16666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Os pratos, carne de porco e macarrão estavam gostosos.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Os pratos, carne de porco e macarrão estavam gostosos. : 1.0
# subjetividade
#  Os pratos, carne de porco e macarrão estavam gostosos. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  A sobremesa também estava boa.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  A sobremesa também estava boa. : 0.7
# subjetividade
#  A sobremesa também estava boa. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Enfim , uma comida semples, porém de alta qualidade é bem feita .
# sentence.sentiment.polarity:  0.08
# sentence.sentiment.subjectivity:  0.4485714285714285
# Polaridade
#  Enfim , uma comida semples, porém de alta qualidade é bem feita . : 0.08
# subjetividade
#  Enfim , uma comida semples, porém de alta qualidade é bem feita . : 0.4485714285714285
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60005 x Local simples com um cardápio de churrasco sem frescuras.
# Parece churrasco feito em casa.
# Cerveja sempre gelada.
# Também oferece serviço de frango assado para viagem.
#
# **************
# Inglês:  Simple place with a no-frills barbecue menu.
#
# It looks like homemade barbecue.
#
# Always cold beer.
#
# It also offers roast chicken takeout service.
# sentence_br  Local simples com um cardápio de churrasco sem frescuras.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.35714285714285715
# Polaridade
#  Local simples com um cardápio de churrasco sem frescuras. : 0.0
# subjetividade
#  Local simples com um cardápio de churrasco sem frescuras. : 0.35714285714285715
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Parece churrasco feito em casa.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Parece churrasco feito em casa. : 0.0
# subjetividade
#  Parece churrasco feito em casa. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Cerveja sempre gelada.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Cerveja sempre gelada. : -0.6
# subjetividade
#  Cerveja sempre gelada. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Também oferece serviço de frango assado para viagem.
# sentence.sentiment.polarity:  -0.25
# sentence.sentiment.subjectivity:  0.475
# Polaridade
#  Também oferece serviço de frango assado para viagem. : -0.25
# subjetividade
#  Também oferece serviço de frango assado para viagem. : 0.475
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60006 x Fui  um dia apos o dia dos namorado. E achei o pocal interessante. Na entrada voce escolhe o vinho que quer.beber tem um somelier para lhe orientar. Os pratos sao indivuais e algo caro, mais aqui tudo e caro, em torno  de 70 reais. Mais muitos saborosos.. indico para casais. $$$$$.
# **************
#
# Inglês:  I went one day after boyfriends day.
#  And I found the pocal interesting.
#  At the entrance you choose the wine you want.
# drinking has a somelier to guide you.
#  The dishes are individual and something expensive, but here everything is expensive, around 70 reais.
#  Many more tasty.
# . I recommend for couples.
#  $$$$$.
# sentence_br  Fui  um dia apos o dia dos namorado.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Fui  um dia apos o dia dos namorado. : 0.0
# subjetividade
#  Fui  um dia apos o dia dos namorado. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  E achei o pocal interessante.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  E achei o pocal interessante. : 0.5
# subjetividade
#  E achei o pocal interessante. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Na entrada voce escolhe o vinho que quer.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Na entrada voce escolhe o vinho que quer. : 0.0
# subjetividade
#  Na entrada voce escolhe o vinho que quer. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  beber tem um somelier para lhe orientar.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  beber tem um somelier para lhe orientar. : 0.0
# subjetividade
#  beber tem um somelier para lhe orientar. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Os pratos sao indivuais e algo caro, mais aqui tudo e caro, em torno  de 70 reais.
# sentence.sentiment.polarity:  -0.3333333333333333
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Os pratos sao indivuais e algo caro, mais aqui tudo e caro, em torno  de 70 reais. : -0.3333333333333333
# subjetividade
#  Os pratos sao indivuais e algo caro, mais aqui tudo e caro, em torno  de 70 reais. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Mais muitos saborosos.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Mais muitos saborosos. : 0.5
# subjetividade
#  Mais muitos saborosos. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  .
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  . : 0.0
# subjetividade
#  . : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  indico para casais.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  indico para casais. : 0.0
# subjetividade
#  indico para casais. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  $$$$$.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  $$$$$. : 0.0
# subjetividade
#  $$$$$. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60007 x Atendimento muito bom.
# Diversidade de pratos e ótima localização.
# Melhor caranguejo e casquinha de Siri de Vitória!
#
# Banheiros poderiam ser mais limpos!
# **************
#
# Inglês:  Very good service.
#
# Diversity of dishes and great location.
#
# Best crab and crab shell in Vitória!
#
# Bathrooms could be cleaner!
# sentence_br  Atendimento muito bom.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Atendimento muito bom. : 0.9099999999999999
# subjetividade
#  Atendimento muito bom. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Diversidade de pratos e ótima localização.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Diversidade de pratos e ótima localização. : 0.8
# subjetividade
#  Diversidade de pratos e ótima localização. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Melhor caranguejo e casquinha de Siri de Vitória!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Melhor caranguejo e casquinha de Siri de Vitória! : 1.0
# subjetividade
#  Melhor caranguejo e casquinha de Siri de Vitória! : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Banheiros poderiam ser mais limpos!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Banheiros poderiam ser mais limpos! : 0.0
# subjetividade
#  Banheiros poderiam ser mais limpos! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60008 x Adoro a comida de lá, entretanto, algumas pessoas já relataram mal atendimento dos garçons!
# Tirando isso a comida é perfeita.
# **************
#
# Inglês:  I love the food there, however, some people have already reported poor service from the waiters!
# Other than that the food is perfect.
# sentence_br  Adoro a comida de lá, entretanto, algumas pessoas já relataram mal atendimento dos garçons!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Adoro a comida de lá, entretanto, algumas pessoas já relataram mal atendimento dos garçons! : 0.0
# subjetividade
#  Adoro a comida de lá, entretanto, algumas pessoas já relataram mal atendimento dos garçons! : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Tirando isso a comida é perfeita.
# sentence.sentiment.polarity:  0.4375
# sentence.sentiment.subjectivity:  0.6875
# Polaridade
#  Tirando isso a comida é perfeita. : 0.4375
# subjetividade
#  Tirando isso a comida é perfeita. : 0.6875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60009 x O local é agradável com ótimo atendimento. Fecha cedo (1am), mas oferecem credenciais para quem quiser “esticar” a balada em uma boate parceira próxima. Música sertaneja ao vivo no estilo banda mesmo... Para entrar, homem paga 30,00, mulher é free (não sei se há limitação de horário). Vc recebe um cartão individual ao se registrar e todos os seus pedidos são gravados nele, onde vc acerta na saída. Têm alguns poucos lugares para sentar; alguns bistrôs, pois é mais estilo “boate” (eu achava que era um restaurante ‘tradicional’)...rsrsrs
# **************
# Inglês:  The place is nice with great service.
#  It closes early (1am), but offers credentials for those who want to "stretch" the club at a partner nightclub nearby.
#  Live country music in the same band style.
# .. To enter, man pays 30.00, woman is free (I don't know if there is a time limit). You receive an individual card when you register and all your orders are recorded on it, where you get it right at the exit.
#  They have a few places to sit; some bistros, because it’s more like a “nightclub” style (I thought it was a ‘traditional’ restaurant) ... lol
# sentence_br  O local é agradável com ótimo atendimento.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  O local é agradável com ótimo atendimento. : 0.7
# subjetividade
#  O local é agradável com ótimo atendimento. : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Fecha cedo (1am), mas oferecem credenciais para quem quiser “esticar” a balada em uma boate parceira próxima.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.15
# Polaridade
#  Fecha cedo (1am), mas oferecem credenciais para quem quiser “esticar” a balada em uma boate parceira próxima. : 0.1
# subjetividade
#  Fecha cedo (1am), mas oferecem credenciais para quem quiser “esticar” a balada em uma boate parceira próxima. : 0.15
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Música sertaneja ao vivo no estilo banda mesmo.
# sentence.sentiment.polarity:  0.06818181818181818
# sentence.sentiment.subjectivity:  0.3125
# Polaridade
#  Música sertaneja ao vivo no estilo banda mesmo. : 0.06818181818181818
# subjetividade
#  Música sertaneja ao vivo no estilo banda mesmo. : 0.3125
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  .. Para entrar, homem paga 30,00, mulher é free (não sei se há limitação de horário).
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  .. Para entrar, homem paga 30,00, mulher é free (não sei se há limitação de horário). : 0.4
# subjetividade
#  .. Para entrar, homem paga 30,00, mulher é free (não sei se há limitação de horário). : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Vc recebe um cartão individual ao se registrar e todos os seus pedidos são gravados nele, onde vc acerta na saída.
# sentence.sentiment.polarity:  0.14285714285714285
# sentence.sentiment.subjectivity:  0.46785714285714286
# Polaridade
#  Vc recebe um cartão individual ao se registrar e todos os seus pedidos são gravados nele, onde vc acerta na saída. : 0.14285714285714285
# subjetividade
#  Vc recebe um cartão individual ao se registrar e todos os seus pedidos são gravados nele, onde vc acerta na saída. : 0.46785714285714286
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Têm alguns poucos lugares para sentar; alguns bistrôs, pois é mais estilo “boate” (eu achava que era um restaurante ‘tradicional’)...rsrsrs
# sentence.sentiment.polarity:  0.275
# sentence.sentiment.subjectivity:  0.5125
# Polaridade
#  Têm alguns poucos lugares para sentar; alguns bistrôs, pois é mais estilo “boate” (eu achava que era um restaurante ‘tradicional’)...rsrsrs : 0.275
# subjetividade
#  Têm alguns poucos lugares para sentar; alguns bistrôs, pois é mais estilo “boate” (eu achava que era um restaurante ‘tradicional’)...rsrsrs : 0.5125
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60010 x Fui jantar como meu namorado tudo maravilhoso alysson nos atendeu exelete o trio de macaxeira amei voultari sim viuh
# **************
#
# Inglês:  I went to dinner as my boyfriend everything wonderful alysson met us exelete the trio of cassava loved voultari yes saw
# sentence_br  Fui jantar como meu namorado tudo maravilhoso alysson nos atendeu exelete o trio de macaxeira amei voultari sim viuh
# sentence.sentiment.polarity:  0.85
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Fui jantar como meu namorado tudo maravilhoso alysson nos atendeu exelete o trio de macaxeira amei voultari sim viuh : 0.85
# subjetividade
#  Fui jantar como meu namorado tudo maravilhoso alysson nos atendeu exelete o trio de macaxeira amei voultari sim viuh : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60011 x O Hambúrguer é realmente muito bom, mas 60 minutos de espera foi um absurdo, quando o lanche ficou pronto confesso que nem consegui aproveitar mais o paladar, tamanha irritação pelo tempo de espera. Poderiam melhorar isso.
# **************
#
# Inglês:  The Hamburger is really good, but 60 minutes of waiting was absurd, when the snack was ready I confess that I couldn't even enjoy the taste anymore, so much irritation by the waiting time.
#  They could improve that.
# sentence_br  O Hambúrguer é realmente muito bom, mas 60 minutos de espera foi um absurdo, quando o lanche ficou pronto confesso que nem consegui aproveitar mais o paladar, tamanha irritação pelo tempo de espera.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.56
# Polaridade
#  O Hambúrguer é realmente muito bom, mas 60 minutos de espera foi um absurdo, quando o lanche ficou pronto confesso que nem consegui aproveitar mais o paladar, tamanha irritação pelo tempo de espera. : 0.2
# subjetividade
#  O Hambúrguer é realmente muito bom, mas 60 minutos de espera foi um absurdo, quando o lanche ficou pronto confesso que nem consegui aproveitar mais o paladar, tamanha irritação pelo tempo de espera. : 0.56
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Poderiam melhorar isso.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Poderiam melhorar isso. : 0.0
# subjetividade
#  Poderiam melhorar isso. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60012 x Singelo restaurante a kilo de comida árabe do lado da estação de metrô fraldiqueira Coutinho , não deixe de experimentar a coalhada , as carnes macias e saborosas
# **************
#
# Inglês:  Simple restaurant a kilo of Arabic food next to the Coutinho subway station, be sure to try the curds, soft and tasty meats
# sentence_br  Singelo restaurante a kilo de comida árabe do lado da estação de metrô fraldiqueira Coutinho , não deixe de experimentar a coalhada , as carnes macias e saborosas
# sentence.sentiment.polarity:  0.15
# sentence.sentiment.subjectivity:  0.39900793650793653
# Polaridade
#  Singelo restaurante a kilo de comida árabe do lado da estação de metrô fraldiqueira Coutinho , não deixe de experimentar a coalhada , as carnes macias e saborosas : 0.15
# subjetividade
#  Singelo restaurante a kilo de comida árabe do lado da estação de metrô fraldiqueira Coutinho , não deixe de experimentar a coalhada , as carnes macias e saborosas : 0.39900793650793653
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60013 x Melhor pizza da cidade, ambiente excelente, aconchegante, perfeito. E pra melhorar, o preço é muito bom. Vocês precisam conhecer!!!!
# **************
#
# Inglês:  Best pizza in town, excellent atmosphere, cozy, perfect.
#  And to improve, the price is very good.
#  You need to know !!!!
# sentence_br  Melhor pizza da cidade, ambiente excelente, aconchegante, perfeito.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.7625
# Polaridade
#  Melhor pizza da cidade, ambiente excelente, aconchegante, perfeito. : 0.7
# subjetividade
#  Melhor pizza da cidade, ambiente excelente, aconchegante, perfeito. : 0.7625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  E pra melhorar, o preço é muito bom.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  E pra melhorar, o preço é muito bom. : 0.9099999999999999
# subjetividade
#  E pra melhorar, o preço é muito bom. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Vocês precisam conhecer!!!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Vocês precisam conhecer!!! : 0.0
# subjetividade
#  Vocês precisam conhecer!!! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60014 x Café sem igual! Lugar aconchegante e lindo, vale muito a pena experimentar os cafés diferenciados que a casa oferece e suas comidinhas muito gostosas!! Atendimento ótimo! Tudo muito bom e de muita qualidade! Amei e vou voltar sempre!
# **************
# Inglês:  Unique coffee! Cozy and beautiful place, it is very worthwhile to try the different coffees that the house offers and its delicious food !! Great service! All very good and very quality! I loved it and will always come back!
# sentence_br  Café sem igual!
# sentence.sentiment.polarity:  0.46875
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Café sem igual! : 0.46875
# subjetividade
#  Café sem igual! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Lugar aconchegante e lindo, vale muito a pena experimentar os cafés diferenciados que a casa oferece e suas comidinhas muito gostosas!!
# sentence.sentiment.polarity:  0.4000000000000001
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Lugar aconchegante e lindo, vale muito a pena experimentar os cafés diferenciados que a casa oferece e suas comidinhas muito gostosas!! : 0.4000000000000001
# subjetividade
#  Lugar aconchegante e lindo, vale muito a pena experimentar os cafés diferenciados que a casa oferece e suas comidinhas muito gostosas!! : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Atendimento ótimo!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Atendimento ótimo! : 1.0
# subjetividade
#  Atendimento ótimo! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Tudo muito bom e de muita qualidade!
# sentence.sentiment.polarity:  0.58
# sentence.sentiment.subjectivity:  0.54
# Polaridade
#  Tudo muito bom e de muita qualidade! : 0.58
# subjetividade
#  Tudo muito bom e de muita qualidade! : 0.54
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Amei e vou voltar sempre!
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Amei e vou voltar sempre! : 0.35
# subjetividade
#  Amei e vou voltar sempre! : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60015 x Comi um T-bone e minha esposa um bife de tira (Picanha). Tanto as carnes como os acompanhamentos estavam maravilhosos. Recomendo muito este restaurante, o melhor de carnes de Fortaleza, bom ambiente e atendimento. O churros com doce de leite uruguaio é uma sobremesa imperdível. O preço é justo!
# **************
#
# Inglês:  I ate a T-bone and my wife a strip steak (Picanha). Both the meat and the side dishes were wonderful.
#  I highly recommend this restaurant, the best meat in Fortaleza, good atmosphere and service.
#  The churros with Uruguayan dulce de leche is an unmissable dessert.
#  The price is right!
# sentence_br  Comi um T-bone e minha esposa um bife de tira (Picanha).
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Comi um T-bone e minha esposa um bife de tira (Picanha). : 0.0
# subjetividade
#  Comi um T-bone e minha esposa um bife de tira (Picanha). : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Tanto as carnes como os acompanhamentos estavam maravilhosos.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Tanto as carnes como os acompanhamentos estavam maravilhosos. : 1.0
# subjetividade
#  Tanto as carnes como os acompanhamentos estavam maravilhosos. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Recomendo muito este restaurante, o melhor de carnes de Fortaleza, bom ambiente e atendimento.
# sentence.sentiment.polarity:  0.62
# sentence.sentiment.subjectivity:  0.48
# Polaridade
#  Recomendo muito este restaurante, o melhor de carnes de Fortaleza, bom ambiente e atendimento. : 0.62
# subjetividade
#  Recomendo muito este restaurante, o melhor de carnes de Fortaleza, bom ambiente e atendimento. : 0.48
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  O churros com doce de leite uruguaio é uma sobremesa imperdível.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  O churros com doce de leite uruguaio é uma sobremesa imperdível. : 0.0
# subjetividade
#  O churros com doce de leite uruguaio é uma sobremesa imperdível. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  O preço é justo!
# sentence.sentiment.polarity:  0.3571428571428571
# sentence.sentiment.subjectivity:  0.5357142857142857
# Polaridade
#  O preço é justo! : 0.3571428571428571
# subjetividade
#  O preço é justo! : 0.5357142857142857
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60016 x Atendimento muito ruim, apenas uma pessoa para anotar os pedidos em uma casa cheia. Aliás cheia por causa dos brinquedos para a criançada com uma boa variedade para o espaço disponível. A pizza não é das melhores. Não foi uma boa experiência.
# **************
#
# Inglês:  Very bad service, only one person to take orders in a full house.
#  In fact full because of the toys for the children with a good variety for the space available.
#  The pizza is not the best.
#  It was not a good experience.
# sentence_br  Atendimento muito ruim, apenas uma pessoa para anotar os pedidos em uma casa cheia.
# sentence.sentiment.polarity:  -0.18666666666666662
# sentence.sentiment.subjectivity:  0.8055555555555557
# Polaridade
#  Atendimento muito ruim, apenas uma pessoa para anotar os pedidos em uma casa cheia. : -0.18666666666666662
# subjetividade
#  Atendimento muito ruim, apenas uma pessoa para anotar os pedidos em uma casa cheia. : 0.8055555555555557
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Aliás cheia por causa dos brinquedos para a criançada com uma boa variedade para o espaço disponível.
# sentence.sentiment.polarity:  0.4833333333333332
# sentence.sentiment.subjectivity:  0.5166666666666667
# Polaridade
#  Aliás cheia por causa dos brinquedos para a criançada com uma boa variedade para o espaço disponível. : 0.4833333333333332
# subjetividade
#  Aliás cheia por causa dos brinquedos para a criançada com uma boa variedade para o espaço disponível. : 0.5166666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  A pizza não é das melhores.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  A pizza não é das melhores. : 1.0
# subjetividade
#  A pizza não é das melhores. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Não foi uma boa experiência.
# sentence.sentiment.polarity:  -0.35
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Não foi uma boa experiência. : -0.35
# subjetividade
#  Não foi uma boa experiência. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60017 x Cantina Italiana bem tradicional.
# Receitas originais da Itália.
# Preços para casal com entrada e bebida vão de R$80 à R$ 100,00.
# O prato principal da casa é a lasanha por R$49,00 que servem duas pessoas tranquilamente.
# **************
#
# Inglês:  Very traditional Italian canteen.
#
# Original recipes from Italy.
#
# Prices for couples with admission and drinks range from R $ 80 to R $ 100.00.
#
# The main dish of the house is lasagna for R $ 49.00 that serve two people peacefully.
# sentence_br  Cantina Italiana bem tradicional.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.48750000000000004
# Polaridade
#  Cantina Italiana bem tradicional. : 0.0
# subjetividade
#  Cantina Italiana bem tradicional. : 0.48750000000000004
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Receitas originais da Itália.
# sentence.sentiment.polarity:  0.375
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Receitas originais da Itália. : 0.375
# subjetividade
#  Receitas originais da Itália. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Preços para casal com entrada e bebida vão de R$80 à R$ 100,00.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Preços para casal com entrada e bebida vão de R$80 à R$ 100,00. : 0.0
# subjetividade
#  Preços para casal com entrada e bebida vão de R$80 à R$ 100,00. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  O prato principal da casa é a lasanha por R$49,00 que servem duas pessoas tranquilamente.
# sentence.sentiment.polarity:  0.20833333333333331
# sentence.sentiment.subjectivity:  0.41666666666666663
# Polaridade
#  O prato principal da casa é a lasanha por R$49,00 que servem duas pessoas tranquilamente. : 0.20833333333333331
# subjetividade
#  O prato principal da casa é a lasanha por R$49,00 que servem duas pessoas tranquilamente. : 0.41666666666666663
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60018 x Estive com a minha família almoçando na sexta feira santa, não vale a pena o custo beneficio o rodízio não tem qualidade, variedade tão pouco apresentação, interessante é liberar o consumo de bebidas não alcoólicas e oferecer a sobremesa por R$ 65,00 já com os 10%.
# Não recomendo!
# **************
# Inglês:  I was with my family having lunch on Good Friday, it is not worth the cost benefit the carvery has no quality, variety so little presentation, it is interesting to release the consumption of non-alcoholic drinks and offer dessert for R $ 65.00 already with the 10%.
# I do not recommend!
# sentence_br  Estive com a minha família almoçando na sexta feira santa, não vale a pena o custo beneficio o rodízio não tem qualidade, variedade tão pouco apresentação, interessante é liberar o consumo de bebidas não alcoólicas e oferecer a sobremesa por R$ 65,00 já com os 10%.
# sentence.sentiment.polarity:  0.21562499999999998
# sentence.sentiment.subjectivity:  0.42500000000000004
# Polaridade
#  Estive com a minha família almoçando na sexta feira santa, não vale a pena o custo beneficio o rodízio não tem qualidade, variedade tão pouco apresentação, interessante é liberar o consumo de bebidas não alcoólicas e oferecer a sobremesa por R$ 65,00 já com os 10%. : 0.21562499999999998
# subjetividade
#  Estive com a minha família almoçando na sexta feira santa, não vale a pena o custo beneficio o rodízio não tem qualidade, variedade tão pouco apresentação, interessante é liberar o consumo de bebidas não alcoólicas e oferecer a sobremesa por R$ 65,00 já com os 10%. : 0.42500000000000004
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Não recomendo!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Não recomendo! : 0.0
# subjetividade
#  Não recomendo! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60019 x Gostei da experiência que tive com minha família nesse restaurante , achei variado com boas opções e sabor
# Senti falta de sashimi , mas nem por isso sai decepcionado
# Comida boa , bom chopp e preço justo
# Recomendo
# **************
#
# Inglês:  I enjoyed the experience I had with my family at this restaurant, I found it varied with good options and flavor
# I missed sashimi, but I am not disappointed
# Good food, good draft beer and fair price
# I recommend
# sentence_br  Gostei da experiência que tive com minha família nesse restaurante , achei variado com boas opções e sabor
# Senti falta de sashimi , mas nem por isso sai decepcionado
# Comida boa , bom chopp e preço justo
# Recomendo
# sentence.sentiment.polarity:  0.6124999999999999
# sentence.sentiment.subjectivity:  0.6916666666666668
# Polaridade
#  Gostei da experiência que tive com minha família nesse restaurante , achei variado com boas opções e sabor
# Senti falta de sashimi , mas nem por isso sai decepcionado
# Comida boa , bom chopp e preço justo
# Recomendo : 0.6124999999999999
# subjetividade
#  Gostei da experiência que tive com minha família nesse restaurante , achei variado com boas opções e sabor
# Senti falta de sashimi , mas nem por isso sai decepcionado
# Comida boa , bom chopp e preço justo
# Recomendo : 0.6916666666666668
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60020 x Comida muito boa, é excelente atendimento do Eduardo,experimentei a rede de pescador q é um excelente prato
# **************
#
# Inglês:  Very good food, excellent service from Eduardo, I tried the fisherman's net which is an excellent dish
# sentence_br  Comida muito boa, é excelente atendimento do Eduardo,experimentei a rede de pescador q é um excelente prato
# sentence.sentiment.polarity:  0.7275
# sentence.sentiment.subjectivity:  0.6950000000000001
# Polaridade
#  Comida muito boa, é excelente atendimento do Eduardo,experimentei a rede de pescador q é um excelente prato : 0.7275
# subjetividade
#  Comida muito boa, é excelente atendimento do Eduardo,experimentei a rede de pescador q é um excelente prato : 0.6950000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60021 x Esse restaurante já foi um dos melhores de comida a quilo aqui de Recife. Hoje está horrível. Não é a toa que vive vazio nos fins de semana. Não dou um ano para essa porcaria fechar as portas se continuar assim. Cheguei no sábado por volta das 13:20 e a comida já parecia que não era reposta há um bom tempo. Qualidade ruim. Não percam seu tempo e dinheiro indo aí.
# **************
#
# Inglês:  This restaurant was once one of the best kilo meals here in Recife.
#  Today is horrible.
#  It is not for nothing that lives empty on weekends.
#  I won't give this crap a year to close the doors if it continues like this.
#  I arrived on Saturday around 1:20 pm and the food looked like it hadn't been replenished in a while.
#  Bad quality.
#  Don't waste your time and money going there.
# sentence_br  Esse restaurante já foi um dos melhores de comida a quilo aqui de Recife.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Esse restaurante já foi um dos melhores de comida a quilo aqui de Recife. : 1.0
# subjetividade
#  Esse restaurante já foi um dos melhores de comida a quilo aqui de Recife. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Hoje está horrível.
# sentence.sentiment.polarity:  -1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Hoje está horrível. : -1.0
# subjetividade
#  Hoje está horrível. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Não é a toa que vive vazio nos fins de semana.
# sentence.sentiment.polarity:  -0.1
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Não é a toa que vive vazio nos fins de semana. : -0.1
# subjetividade
#  Não é a toa que vive vazio nos fins de semana. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Não dou um ano para essa porcaria fechar as portas se continuar assim.
# sentence.sentiment.polarity:  -0.8
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Não dou um ano para essa porcaria fechar as portas se continuar assim. : -0.8
# subjetividade
#  Não dou um ano para essa porcaria fechar as portas se continuar assim. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Cheguei no sábado por volta das 13:20 e a comida já parecia que não era reposta há um bom tempo.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Cheguei no sábado por volta das 13:20 e a comida já parecia que não era reposta há um bom tempo. : 0.0
# subjetividade
#  Cheguei no sábado por volta das 13:20 e a comida já parecia que não era reposta há um bom tempo. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Qualidade ruim.
# sentence.sentiment.polarity:  -0.6999999999999998
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Qualidade ruim. : -0.6999999999999998
# subjetividade
#  Qualidade ruim. : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Não percam seu tempo e dinheiro indo aí.
# sentence.sentiment.polarity:  -0.2
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Não percam seu tempo e dinheiro indo aí. : -0.2
# subjetividade
#  Não percam seu tempo e dinheiro indo aí. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60022 x Pontos positivos: Estrutura aconchegante. Cardápio recheado de opções atrativas. Pedimos um risoto de frutos do mar: prato bem elaborado, boa apresentação, temperatura ideal, delicioso! Bom custo-benefício (o risoto serve duas pessoas por 89 reais). Boa carta de vinhos, contemplando todos os gostos e bolsos. Com certeza voltaremos para experimentar outros pratos.
#
# Pontos negativos: o atendimento deixou a desejar. O garçom não soube explicar detalhes sobre os pratos e o pior, teve muita dificuldade para abrir as garrafas de vinho. Pedimos duas sobremesas e estavam sinceramente HORRÍVEIS. Mal preparadas, totalmente desproporcionais ao padrão do restaurante.
# **************
#
# Inglês:  Positives: Cozy structure.
#  Menu full of attractive options.
#  We ordered a seafood risotto: well prepared dish, good presentation, ideal temperature, delicious! Good value for money (the risotto serves two people for 89 reais). Good wine list, covering all tastes and budgets.
#  We will definitely be back to try other dishes.
#
#
# Negative points: the service left something to be desired.
#  The waiter did not know how to explain details about the dishes and, worse, he had great difficulty opening the wine bottles.
#  We ordered two desserts and they were truly HORRIBLE.
#  Poorly prepared, totally out of proportion to the standard of the restaurant.
# sentence_br  Pontos positivos: Estrutura aconchegante.
# sentence.sentiment.polarity:  -0.19999999999999998
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Pontos positivos: Estrutura aconchegante. : -0.19999999999999998
# subjetividade
#  Pontos positivos: Estrutura aconchegante. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Cardápio recheado de opções atrativas.
# sentence.sentiment.polarity:  0.575
# sentence.sentiment.subjectivity:  0.775
# Polaridade
#  Cardápio recheado de opções atrativas. : 0.575
# subjetividade
#  Cardápio recheado de opções atrativas. : 0.775
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Pedimos um risoto de frutos do mar: prato bem elaborado, boa apresentação, temperatura ideal, delicioso!
# sentence.sentiment.polarity:  0.8666666666666667
# sentence.sentiment.subjectivity:  0.8666666666666667
# Polaridade
#  Pedimos um risoto de frutos do mar: prato bem elaborado, boa apresentação, temperatura ideal, delicioso! : 0.8666666666666667
# subjetividade
#  Pedimos um risoto de frutos do mar: prato bem elaborado, boa apresentação, temperatura ideal, delicioso! : 0.8666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Bom custo-benefício (o risoto serve duas pessoas por 89 reais).
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Bom custo-benefício (o risoto serve duas pessoas por 89 reais). : 0.7
# subjetividade
#  Bom custo-benefício (o risoto serve duas pessoas por 89 reais). : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Boa carta de vinhos, contemplando todos os gostos e bolsos.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Boa carta de vinhos, contemplando todos os gostos e bolsos. : 0.7
# subjetividade
# ...
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  É super crocante o frango e ainda tem um gostinho apimentado que faz jus às calorias.
# sentence.sentiment.polarity:  -0.13333333333333333
# sentence.sentiment.subjectivity:  0.8083333333333333
# Polaridade
#  É super crocante o frango e ainda tem um gostinho apimentado que faz jus às calorias. : -0.13333333333333333
# subjetividade
#  É super crocante o frango e ainda tem um gostinho apimentado que faz jus às calorias. : 0.8083333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  O pão é um pão de hambúrguer normal, nada de espetacular, mas também não me pareceu um pão industrializado.
# sentence.sentiment.polarity:  0.375
# sentence.sentiment.subjectivity:  0.7749999999999999
# Polaridade
#  O pão é um pão de hambúrguer normal, nada de espetacular, mas também não me pareceu um pão industrializado. : 0.375
# subjetividade
#  O pão é um pão de hambúrguer normal, nada de espetacular, mas também não me pareceu um pão industrializado. : 0.7749999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Ou seja, boa comida, despretensiosa e servida rápido, sem frescuras.
# sentence.sentiment.polarity:  0.44999999999999996
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Ou seja, boa comida, despretensiosa e servida rápido, sem frescuras. : 0.44999999999999996
# subjetividade
#  Ou seja, boa comida, despretensiosa e servida rápido, sem frescuras. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  A um preço honestíssimo.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  A um preço honestíssimo. : 0.6
# subjetividade
#  A um preço honestíssimo. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60699 x Restaurante temático bacana, atendimento bom, rápido e simpático. Hambúrguer recheado com queijo cheddar plus bacon muito bom :)
# **************
#
# Inglês:  Nice themed restaurant, good service, fast and friendly.
#  Hamburger stuffed with cheddar cheese plus bacon very good :)
# sentence_br  Restaurante temático bacana, atendimento bom, rápido e simpático.
# sentence.sentiment.polarity:  0.46874999999999994
# sentence.sentiment.subjectivity:  0.675
# Polaridade
#  Restaurante temático bacana, atendimento bom, rápido e simpático. : 0.46874999999999994
# subjetividade
#  Restaurante temático bacana, atendimento bom, rápido e simpático. : 0.675
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Hambúrguer recheado com queijo cheddar plus bacon muito bom :)
# sentence.sentiment.polarity:  0.705
# sentence.sentiment.subjectivity:  0.8900000000000001
# Polaridade
#  Hambúrguer recheado com queijo cheddar plus bacon muito bom :) : 0.705
# subjetividade
#  Hambúrguer recheado com queijo cheddar plus bacon muito bom :) : 0.8900000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60700 x Comi uma massa com algum molho que tinha gosto de caldo de galinha. E a cobrança dos 10% não fez sentido nenhum também (até porque a comida foi pedida no caixa).
# **************
# Inglês:  I ate a pasta with some sauce that tasted like chicken broth.
#  And the 10% charge didn't make any sense either (especially because the food was ordered at the checkout).
# sentence_br  Comi uma massa com algum molho que tinha gosto de caldo de galinha.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  0.95
# Polaridade
#  Comi uma massa com algum molho que tinha gosto de caldo de galinha. : -0.6
# subjetividade
#  Comi uma massa com algum molho que tinha gosto de caldo de galinha. : 0.95
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  E a cobrança dos 10% não fez sentido nenhum também (até porque a comida foi pedida no caixa).
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  E a cobrança dos 10% não fez sentido nenhum também (até porque a comida foi pedida no caixa). : 0.0
# subjetividade
#  E a cobrança dos 10% não fez sentido nenhum também (até porque a comida foi pedida no caixa). : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60701 x O restaurante fica mto próximo ao Farol da Barra, com uma lista vista para a praia. Há a opção de ficar na parte interna com ar condicionado ou na parte externa com uma deliciosa brisa e som ambiente. Fomos para o almoço, numa terça-feira. Optamos pelo buffet livre por 32 reais por pessoa. A comida estava deliciosa!!! Atendimento ótimo! Com certeza voltaremos!!
# **************
#
# Inglês:  The restaurant is very close to Farol da Barra, with a list overlooking the beach.
#  There is the option of staying indoors with air conditioning or outside with a delicious breeze and ambient sound.
#  We went for lunch on a Tuesday.
#  We opted for the free buffet for 32 reais per person.
#  The food was delicious!!! Great service! We will definitely be back !!
# sentence_br  O restaurante fica mto próximo ao Farol da Barra, com uma lista vista para a praia.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  O restaurante fica mto próximo ao Farol da Barra, com uma lista vista para a praia. : 0.2
# subjetividade
#  O restaurante fica mto próximo ao Farol da Barra, com uma lista vista para a praia. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Há a opção de ficar na parte interna com ar condicionado ou na parte externa com uma deliciosa brisa e som ambiente.
# sentence.sentiment.polarity:  0.4666666666666666
# sentence.sentiment.subjectivity:  0.4833333333333334
# Polaridade
#  Há a opção de ficar na parte interna com ar condicionado ou na parte externa com uma deliciosa brisa e som ambiente. : 0.4666666666666666
# subjetividade
#  Há a opção de ficar na parte interna com ar condicionado ou na parte externa com uma deliciosa brisa e som ambiente. : 0.4833333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Fomos para o almoço, numa terça-feira.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Fomos para o almoço, numa terça-feira. : 0.0
# subjetividade
#  Fomos para o almoço, numa terça-feira. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Optamos pelo buffet livre por 32 reais por pessoa.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Optamos pelo buffet livre por 32 reais por pessoa. : 0.4
# subjetividade
#  Optamos pelo buffet livre por 32 reais por pessoa. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  A comida estava deliciosa!!!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  A comida estava deliciosa!!! : 1.0
# subjetividade
#  A comida estava deliciosa!!! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Atendimento ótimo!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Atendimento ótimo! : 1.0
# subjetividade
#  Atendimento ótimo! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Com certeza voltaremos!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Com certeza voltaremos! : 0.0
# subjetividade
#  Com certeza voltaremos! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60702 x Silvia e Neide! Excelente prato camarões bem frescos e saborosos! Melhor restaurante de fortaleza,recomendo a todos meus familiares
# **************
#
# Inglês:  Silvia and Neide! Excellent fresh and tasty prawns dish! Best restaurant in Fortaleza, I recommend it to all my family
# sentence_br  Silvia e Neide!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Silvia e Neide! : 0.0
# subjetividade
#  Silvia e Neide! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Excelente prato camarões bem frescos e saborosos!
# sentence.sentiment.polarity:  0.6875
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Excelente prato camarões bem frescos e saborosos! : 0.6875
# subjetividade
#  Excelente prato camarões bem frescos e saborosos! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Melhor restaurante de fortaleza,recomendo a todos meus familiares
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Melhor restaurante de fortaleza,recomendo a todos meus familiares : 1.0
# subjetividade
#  Melhor restaurante de fortaleza,recomendo a todos meus familiares : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60703 x Restaurante tradicional e de ótima qualidade! Comida ótima,serviço muito bom. Um pouco caro, mas vale a pena!
# **************
#
# Inglês:  Traditional and great quality restaurant! Great food, very good service.
#  A little expensive, but worth it!
# sentence_br  Restaurante tradicional e de ótima qualidade!
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  Restaurante tradicional e de ótima qualidade! : 0.5
# subjetividade
#  Restaurante tradicional e de ótima qualidade! : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Comida ótima,serviço muito bom.
# sentence.sentiment.polarity:  0.855
# sentence.sentiment.subjectivity:  0.7650000000000001
# Polaridade
#  Comida ótima,serviço muito bom. : 0.855
# subjetividade
#  Comida ótima,serviço muito bom. : 0.7650000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# sentence_br  Um pouco caro, mas vale a pena!
# sentence.sentiment.polarity:  -0.10416666666666667
# sentence.sentiment.subjectivity:  0.43333333333333335
# Polaridade
#  Um pouco caro, mas vale a pena! : -0.10416666666666667
# subjetividade
#  Um pouco caro, mas vale a pena! : 0.43333333333333335
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-60000-70000.txt
# **************
#
# var 60704 x Comida e ambiente gostoso, mas só gostoso. Não Gostei do acrescimo de 20% só pq dividimos um prato. Vale experimentar a sobremesa de crepe de maçã caramelizada.
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
