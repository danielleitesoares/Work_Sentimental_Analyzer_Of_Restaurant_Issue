# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pcorrea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 70000
terminou = 80000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  124,438,495,232 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# Find Keys:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 174463

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TypeError:
        print("errou no tipo")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
ini = time.time()
for x in df['reviewBody']:
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 70001 x Lugar bacana, comida boa, com exceção do hambúrguer um pouco seco!
# Carta de cerveja impecável, super bem montada, já o mojito... Kd o rum....
# Mas... Passa lá
# **************
#
# Inglês:  Nice place, good food, with the exception of the slightly dry hamburger!
# Flawless beer list, super well assembled, already the mojito.
# .. Kd the rum.
# ...
# But.
# .. pass there
# sentence_br  Lugar bacana, comida boa, com exceção do hambúrguer um pouco seco!
# sentence.sentiment.polarity:  0.4055555555555555
# sentence.sentiment.subjectivity:  0.7333333333333334
# Polaridade
#  Lugar bacana, comida boa, com exceção do hambúrguer um pouco seco! : 0.4055555555555555
# subjetividade
#  Lugar bacana, comida boa, com exceção do hambúrguer um pouco seco! : 0.7333333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Carta de cerveja impecável, super bem montada, já o mojito.
# sentence.sentiment.polarity:  0.6666666666666666
# sentence.sentiment.subjectivity:  0.8333333333333333
# Polaridade
#  Carta de cerveja impecável, super bem montada, já o mojito. : 0.6666666666666666
# subjetividade
#  Carta de cerveja impecável, super bem montada, já o mojito. : 0.8333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  .. Kd o rum.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  .. Kd o rum. : 0.0
# subjetividade
#  .. Kd o rum. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  ...
# Mas.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ...
# Mas. : 0.0
# subjetividade
#  ...
# Mas. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  .. Passa lá
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  .. Passa lá : 0.0
# subjetividade
#  .. Passa lá : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70002 x O Bobs de campo grande fica em frente a a praça do radio clube. Lá tem um potão de milk shake gigante na decoração que dá vontade de cair dentro! Gosto dos lanches do Bobs mas o que mais gosto mesmo é o inigualável milk shake de ovomaltine!
# **************
#
# Inglês:  Bobs de campo grande is in front of the radio club square.
#  There is a giant milk shake pot in the decoration that makes you want to fall inside! I like the Bobs snacks but what I really like is the unmatched ovomaltine milk shake!
# sentence_br  O Bobs de campo grande fica em frente a a praça do radio clube.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  O Bobs de campo grande fica em frente a a praça do radio clube. : 0.0
# subjetividade
#  O Bobs de campo grande fica em frente a a praça do radio clube. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Lá tem um potão de milk shake gigante na decoração que dá vontade de cair dentro!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Lá tem um potão de milk shake gigante na decoração que dá vontade de cair dentro! : 0.0
# subjetividade
#  Lá tem um potão de milk shake gigante na decoração que dá vontade de cair dentro! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Gosto dos lanches do Bobs mas o que mais gosto mesmo é o inigualável milk shake de ovomaltine!
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Gosto dos lanches do Bobs mas o que mais gosto mesmo é o inigualável milk shake de ovomaltine! : 0.25
# subjetividade
#  Gosto dos lanches do Bobs mas o que mais gosto mesmo é o inigualável milk shake de ovomaltine! : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70003 x Pizza perfeita para os amantes de massas finas crocantes . Ambiente familiar , tradicional e ótimo para um bom bate papo .
# **************
#
# Inglês:  Perfect pizza for lovers of thin crunchy pasta. Family atmosphere, traditional and great for a good chat.
# sentence_br  Pizza perfeita para os amantes de massas finas crocantes .
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.925
# Polaridade
#  Pizza perfeita para os amantes de massas finas crocantes . : 0.3
# subjetividade
#  Pizza perfeita para os amantes de massas finas crocantes . : 0.925
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Ambiente familiar , tradicional e ótimo para um bom bate papo .
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.7000000000000001
# Polaridade
#  Ambiente familiar , tradicional e ótimo para um bom bate papo . : 0.5
# subjetividade
#  Ambiente familiar , tradicional e ótimo para um bom bate papo . : 0.7000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70004 x Eu e minha esposa fomos almoçar no sábado no Alemão. Deve ser a terceira vez que comemos lá. O Atendimento é correto, mas não muito atencioso. O ambiente se esforça para parecer uma cabana alemã e acaba convencendo.
# O problema é a comida, que tem nomes em alemão mas que, na verdade, são apenas pratos caseiros feitos com os mesmo ingredientes da culinária alemã. Comemos um eisbein que não não fica devendo nada ao bom joelho de porco assado nordestino. Os acompanhamentos não têm parentesco com a cozinha teutônica: são batatas fritas ou souté, nada que lembre uma refeição na Alemanha. Pedimos mostarda escura e o garçon foi ver se tinha na cozinha. Espanto!
# A comida é boa, mas não é germânica. Ou seja, Fortaleza ainda precisa de um restaurante alemão, de verdade.
# **************
#
# Inglês:  My wife and I went to lunch on Saturday at Alemão.
#  It must be the third time we've eaten there.
#  The service is correct, but not very attentive.
#  The environment strives to look like a German cabin and ends up convincing.
#
# The problem is the food, which has names in German but, in fact, are just homemade dishes made with the same ingredients as German cuisine.
#  We ate an eisbein that owes nothing to the good roast pork knee from the Northeast.
#  The side dishes are not related to the Teutonic cuisine: they are french fries or bra, nothing that resembles a meal in Germany.
#  We ordered dark mustard and the waiter went to see if it was in the kitchen.
#  Astonishment!
# The food is good, but it is not Germanic.
#  In other words, Fortaleza still needs a German restaurant, really.
# sentence_br  Eu e minha esposa fomos almoçar no sábado no Alemão.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Eu e minha esposa fomos almoçar no sábado no Alemão. : 0.0
# subjetividade
#  Eu e minha esposa fomos almoçar no sábado no Alemão. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Deve ser a terceira vez que comemos lá.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Deve ser a terceira vez que comemos lá. : 0.0
# subjetividade
#  Deve ser a terceira vez que comemos lá. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O Atendimento é correto, mas não muito atencioso.
# sentence.sentiment.polarity:  -0.15384615384615385
# sentence.sentiment.subjectivity:  0.6923076923076923
# Polaridade
#  O Atendimento é correto, mas não muito atencioso. : -0.15384615384615385
# subjetividade
#  O Atendimento é correto, mas não muito atencioso. : 0.6923076923076923
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O ambiente se esforça para parecer uma cabana alemã e acaba convencendo.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  O ambiente se esforça para parecer uma cabana alemã e acaba convencendo. : 0.25
# subjetividade
#  O ambiente se esforça para parecer uma cabana alemã e acaba convencendo. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O problema é a comida, que tem nomes em alemão mas que, na verdade, são apenas pratos caseiros feitos com os mesmo ingredientes da culinária alemã.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.041666666666666664
# Polaridade
#  O problema é a comida, que tem nomes em alemão mas que, na verdade, são apenas pratos caseiros feitos com os mesmo ingredientes da culinária alemã. : 0.0
# subjetividade
#  O problema é a comida, que tem nomes em alemão mas que, na verdade, são apenas pratos caseiros feitos com os mesmo ingredientes da culinária alemã. : 0.041666666666666664
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Comemos um eisbein que não não fica devendo nada ao bom joelho de porco assado nordestino.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Comemos um eisbein que não não fica devendo nada ao bom joelho de porco assado nordestino. : 0.7
# subjetividade
#  Comemos um eisbein que não não fica devendo nada ao bom joelho de porco assado nordestino. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Os acompanhamentos não têm parentesco com a cozinha teutônica: são batatas fritas ou souté, nada que lembre uma refeição na Alemanha.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Os acompanhamentos não têm parentesco com a cozinha teutônica: são batatas fritas ou souté, nada que lembre uma refeição na Alemanha. : 0.0
# subjetividade
#  Os acompanhamentos não têm parentesco com a cozinha teutônica: são batatas fritas ou souté, nada que lembre uma refeição na Alemanha. : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Pedimos mostarda escura e o garçon foi ver se tinha na cozinha.
# sentence.sentiment.polarity:  -0.15
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Pedimos mostarda escura e o garçon foi ver se tinha na cozinha. : -0.15
# subjetividade
#  Pedimos mostarda escura e o garçon foi ver se tinha na cozinha. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Espanto!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Espanto! : 0.0
# subjetividade
#  Espanto! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  A comida é boa, mas não é germânica.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  A comida é boa, mas não é germânica. : 0.7
# subjetividade
#  A comida é boa, mas não é germânica. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Ou seja, Fortaleza ainda precisa de um restaurante alemão, de verdade.
# sentence.sentiment.polarity:  0.025000000000000005
# sentence.sentiment.subjectivity:  0.19166666666666665
# Polaridade
#  Ou seja, Fortaleza ainda precisa de um restaurante alemão, de verdade. : 0.025000000000000005
# subjetividade
#  Ou seja, Fortaleza ainda precisa de um restaurante alemão, de verdade. : 0.19166666666666665
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70005 x Ótima comida e excelente cervejas. Várias on Tap e em garrafas. Muito bom atendimento e agora tem almoço.
# **************
# Inglês:  Great food and excellent beers.
#  Several on tap and in bottles.
#  Very good service and now has lunch.
# sentence_br  Ótima comida e excelente cervejas.
# sentence.sentiment.polarity:  0.9
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  Ótima comida e excelente cervejas. : 0.9
# subjetividade
#  Ótima comida e excelente cervejas. : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Várias on Tap e em garrafas.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Várias on Tap e em garrafas. : 0.0
# subjetividade
#  Várias on Tap e em garrafas. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Muito bom atendimento e agora tem almoço.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Muito bom atendimento e agora tem almoço. : 0.9099999999999999
# subjetividade
#  Muito bom atendimento e agora tem almoço. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70006 x Excelente restaurante. Bons pratos, ótima carta de vinhos. Serve algumas massas que são algo de comer contemplando, como uma recheado com queijo brie e molho de figo. Vale a pena
# **************
#
# Inglês:  Excellent restaurant.
#  Good dishes, great wine list.
#  It serves some pasta that is something to eat contemplating, like a stuffed with brie cheese and fig sauce.
#  worth it
# sentence_br  Excelente restaurante.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Excelente restaurante. : 1.0
# subjetividade
#  Excelente restaurante. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Bons pratos, ótima carta de vinhos.
# sentence.sentiment.polarity:  0.75
# sentence.sentiment.subjectivity:  0.675
# Polaridade
#  Bons pratos, ótima carta de vinhos. : 0.75
# subjetividade
#  Bons pratos, ótima carta de vinhos. : 0.675
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Serve algumas massas que são algo de comer contemplando, como uma recheado com queijo brie e molho de figo.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Serve algumas massas que são algo de comer contemplando, como uma recheado com queijo brie e molho de figo. : 0.0
# subjetividade
#  Serve algumas massas que são algo de comer contemplando, como uma recheado com queijo brie e molho de figo. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Vale a pena
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale a pena : 0.3
# subjetividade
#  Vale a pena : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70007 x O local é agradável, mas tem que chegar cedo para conseguir lugar. Depois tentam te empurrar as mesas simples, pelo mesmo preço  ($30 / pessoa).
# Conta com boa estrutura, com redes, espreguiçadeiras e tendas, piscina (sem supervisão, cuidado com as crianças sozinhas) e fica localizado de frente pro mar.
# **************
#
# Inglês:  The place is nice, but you have to arrive early to get a seat.
#  Then they try to push you to the simple tables, for the same price ($ 30 / person).
# It has a good structure, with hammocks, sun loungers and tents, a swimming pool (without supervision, care for children alone) and is located facing the sea.
# sentence_br  O local é agradável, mas tem que chegar cedo para conseguir lugar.
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.65
# Polaridade
#  O local é agradável, mas tem que chegar cedo para conseguir lugar. : 0.35
# subjetividade
#  O local é agradável, mas tem que chegar cedo para conseguir lugar. : 0.65
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Depois tentam te empurrar as mesas simples, pelo mesmo preço  ($30 / pessoa).
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.24107142857142858
# Polaridade
#  Depois tentam te empurrar as mesas simples, pelo mesmo preço  ($30 / pessoa). : 0.0
# subjetividade
#  Depois tentam te empurrar as mesas simples, pelo mesmo preço  ($30 / pessoa). : 0.24107142857142858
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Conta com boa estrutura, com redes, espreguiçadeiras e tendas, piscina (sem supervisão, cuidado com as crianças sozinhas) e fica localizado de frente pro mar.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Conta com boa estrutura, com redes, espreguiçadeiras e tendas, piscina (sem supervisão, cuidado com as crianças sozinhas) e fica localizado de frente pro mar. : 0.7
# subjetividade
#  Conta com boa estrutura, com redes, espreguiçadeiras e tendas, piscina (sem supervisão, cuidado com as crianças sozinhas) e fica localizado de frente pro mar. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70008 x Restaurante com ambiente agradável e com bom atendimento, mas o destaque fica para a excelente comida e a variedade de pratos servidos por um preço razoável. Recomendo!!
# **************
#
# Inglês:  Restaurant with pleasant atmosphere and good service, but the highlight is the excellent food and the variety of dishes served at a reasonable price.
#  I recommend!!
# sentence_br  Restaurante com ambiente agradável e com bom atendimento, mas o destaque fica para a excelente comida e a variedade de pratos servidos por um preço razoável.
# sentence.sentiment.polarity:  0.6583333333333333
# sentence.sentiment.subjectivity:  0.7916666666666667
# Polaridade
#  Restaurante com ambiente agradável e com bom atendimento, mas o destaque fica para a excelente comida e a variedade de pratos servidos por um preço razoável. : 0.6583333333333333
# subjetividade
#  Restaurante com ambiente agradável e com bom atendimento, mas o destaque fica para a excelente comida e a variedade de pratos servidos por um preço razoável. : 0.7916666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Recomendo!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo! : 0.0
# subjetividade
#  Recomendo! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70009 x Lugar propício para quem tem filhos  menores em especial no período noturno. é uma gritaria infinita por isso para os maduros não é agradável. A comida é boa por um preço razoável. Lugar de difícil estacionamento mesmo a noite. Agora na hora do almoço se for uma refeição rápida vale a pena pela variedade de opções. Não é um ligar agradável para curtir apenas comer e sair correndo.
# **************
#
# Inglês:  Favorable place for those with minor children, especially at night.
#  it’s an endless shouting so it’s not pleasant for the mature.
#  The food is good at a reasonable price.
#  Difficult parking place even at night.
#  Now at lunchtime if it's a quick meal it's worth it for the variety of options.
#  It's not a pleasant call to just enjoy eating and running.
# sentence_br  Lugar propício para quem tem filhos  menores em especial no período noturno.
# sentence.sentiment.polarity:  -0.025
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Lugar propício para quem tem filhos  menores em especial no período noturno. : -0.025
# subjetividade
#  Lugar propício para quem tem filhos  menores em especial no período noturno. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  é uma gritaria infinita por isso para os maduros não é agradável.
# sentence.sentiment.polarity:  -0.13055555555555554
# sentence.sentiment.subjectivity:  0.6055555555555556
# Polaridade
#  é uma gritaria infinita por isso para os maduros não é agradável. : -0.13055555555555554
# subjetividade
#  é uma gritaria infinita por isso para os maduros não é agradável. : 0.6055555555555556
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  A comida é boa por um preço razoável.
# sentence.sentiment.polarity:  0.44999999999999996
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  A comida é boa por um preço razoável. : 0.44999999999999996
# subjetividade
#  A comida é boa por um preço razoável. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Lugar de difícil estacionamento mesmo a noite.
# sentence.sentiment.polarity:  -0.5
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Lugar de difícil estacionamento mesmo a noite. : -0.5
# subjetividade
#  Lugar de difícil estacionamento mesmo a noite. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Agora na hora do almoço se for uma refeição rápida vale a pena pela variedade de opções.
# sentence.sentiment.polarity:  0.31666666666666665
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Agora na hora do almoço se for uma refeição rápida vale a pena pela variedade de opções. : 0.31666666666666665
# subjetividade
#  Agora na hora do almoço se for uma refeição rápida vale a pena pela variedade de opções. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Não é um ligar agradável para curtir apenas comer e sair correndo.
# sentence.sentiment.polarity:  0.01666666666666669
# sentence.sentiment.subjectivity:  0.7333333333333334
# Polaridade
#  Não é um ligar agradável para curtir apenas comer e sair correndo. : 0.01666666666666669
# subjetividade
#  Não é um ligar agradável para curtir apenas comer e sair correndo. : 0.7333333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70010 x O Nordeste Grill é uma opção para comer em ponta negra, eles tem o serviço de self-service por R$32,80 o quiilo, porem o buffet não tem muitas opções, eu preferi os pratos alacarte, comi o Mixtão que é um prato onde se pode escolher até 3 tipos de carne/peixe e camarão com arroz, feijão, macaxeira e vinagrete de acompanhamento serviu 4 adultos e uma criança por R$99,00.
# **************
# Inglês:  Nordeste Grill is an option to eat in Ponta Negra, they have a self-service service for R $ 32.80 a kilo, but the buffet doesn’t have many options, I preferred the alacarte dishes, I ate the Mixtão which is a dish where you can choose up to 3 types of meat / fish and shrimp with rice, beans, cassava and accompanying vinaigrette served 4 adults and a child for R $ 99.00.
# sentence_br  O Nordeste Grill é uma opção para comer em ponta negra, eles tem o serviço de self-service por R$32,80 o quiilo, porem o buffet não tem muitas opções, eu preferi os pratos alacarte, comi o Mixtão que é um prato onde se pode escolher até 3 tipos de carne/peixe e camarão com arroz, feijão, macaxeira e vinagrete de acompanhamento serviu 4 adultos e uma criança por R$99,00.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  O Nordeste Grill é uma opção para comer em ponta negra, eles tem o serviço de self-service por R$32,80 o quiilo, porem o buffet não tem muitas opções, eu preferi os pratos alacarte, comi o Mixtão que é um prato onde se pode escolher até 3 tipos de carne/peixe e camarão com arroz, feijão, macaxeira e vinagrete de acompanhamento serviu 4 adultos e uma criança por R$99,00. : 0.5
# subjetividade
#  O Nordeste Grill é uma opção para comer em ponta negra, eles tem o serviço de self-service por R$32,80 o quiilo, porem o buffet não tem muitas opções, eu preferi os pratos alacarte, comi o Mixtão que é um prato onde se pode escolher até 3 tipos de carne/peixe e camarão com arroz, feijão, macaxeira e vinagrete de acompanhamento serviu 4 adultos e uma criança por R$99,00. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70011 x Boa opção para refeições em família ou entre amigos, com grande variedade de pizzas e outros pratos. Recomendo o Frango Salute e Risoto de frutos do mar que são deliciosos. O preço também é bastante em conta em relação a outras opções da cidade.
# **************
#
# Inglês:  Good option for meals with family or friends, with a wide variety of pizzas and other dishes.
#  I recommend the Chicken Salute and Seafood Risotto which are delicious.
#  The price is also quite affordable compared to other options in the city.
# sentence_br  Boa opção para refeições em família ou entre amigos, com grande variedade de pizzas e outros pratos.
# sentence.sentiment.polarity:  0.15833333333333333
# sentence.sentiment.subjectivity:  0.4583333333333333
# Polaridade
#  Boa opção para refeições em família ou entre amigos, com grande variedade de pizzas e outros pratos. : 0.15833333333333333
# subjetividade
#  Boa opção para refeições em família ou entre amigos, com grande variedade de pizzas e outros pratos. : 0.4583333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Recomendo o Frango Salute e Risoto de frutos do mar que são deliciosos.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.975
# Polaridade
#  Recomendo o Frango Salute e Risoto de frutos do mar que são deliciosos. : 0.2
# subjetividade
#  Recomendo o Frango Salute e Risoto de frutos do mar que são deliciosos. : 0.975
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O preço também é bastante em conta em relação a outras opções da cidade.
# sentence.sentiment.polarity:  -0.125
# sentence.sentiment.subjectivity:  0.375
# Polaridade
#  O preço também é bastante em conta em relação a outras opções da cidade. : -0.125
# subjetividade
#  O preço também é bastante em conta em relação a outras opções da cidade. : 0.375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70012 x O local é para quem aprecia beber cerveja, já que possui variedade em cervejas Backer. O cardápio para petisco é um pouco fraco.
# **************
#
# Inglês:  The place is for those who enjoy drinking beer, as it has variety in Backer beers.
#  The snack menu is a little weak.
# sentence_br  O local é para quem aprecia beber cerveja, já que possui variedade em cervejas Backer.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  O local é para quem aprecia beber cerveja, já que possui variedade em cervejas Backer. : 0.4
# subjetividade
#  O local é para quem aprecia beber cerveja, já que possui variedade em cervejas Backer. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O cardápio para petisco é um pouco fraco.
# sentence.sentiment.polarity:  -0.28125
# sentence.sentiment.subjectivity:  0.5625
# Polaridade
#  O cardápio para petisco é um pouco fraco. : -0.28125
# subjetividade
#  O cardápio para petisco é um pouco fraco. : 0.5625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70013 x Excelente opção de almoço. Comida á vontade. Sopas, bufet de saladas com frutas, pratos quentes,  ilha de massas e molhos, Grelhados com com vazio na brasa, bife, frango e porco.
# **************
#
# Inglês:  Excellent lunch option.
#  Food at will.
#  Soups, salad buffet with fruits, hot dishes, pasta island and sauces, Grilled with emptied coals, steak, chicken and pork.
# sentence_br  Excelente opção de almoço.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Excelente opção de almoço. : 1.0
# subjetividade
#  Excelente opção de almoço. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Comida á vontade.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Comida á vontade. : 0.0
# subjetividade
#  Comida á vontade. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Sopas, bufet de saladas com frutas, pratos quentes,  ilha de massas e molhos, Grelhados com com vazio na brasa, bife, frango e porco.
# sentence.sentiment.polarity:  -0.175
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Sopas, bufet de saladas com frutas, pratos quentes,  ilha de massas e molhos, Grelhados com com vazio na brasa, bife, frango e porco. : -0.175
# subjetividade
#  Sopas, bufet de saladas com frutas, pratos quentes,  ilha de massas e molhos, Grelhados com com vazio na brasa, bife, frango e porco. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70014 x O restaurante fica no final da minha rua, então sempre que posso vou  com minha família e nunca nos decepcionamos.
# O atendimento é nota 10, pratos excelentes (desde as massas até o "churrasquinho", o qual eu recomendo TOTALMENTE. As carnes são muito saborosas e os acompanhamentos tornam o prato melhor ainda),sobremesas deliciosas e ambiente agradável.
# Recomendado para qualquer ocasião (já houve até casamento no local).
# **************
#
# Inglês:  The restaurant is at the end of my street, so whenever I can I go with my family and we are never disappointed.
#
# The service is grade 10, excellent dishes (from the pasta to the "barbecue", which I TOTALLY recommend.
#  The meats are very tasty and the side dishes make the dish even better), delicious desserts and a pleasant atmosphere.
#
# Recommended for any occasion (there has even been a wedding on site).
# sentence_br  O restaurante fica no final da minha rua, então sempre que posso vou  com minha família e nunca nos decepcionamos.
# sentence.sentiment.polarity:  0.375
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  O restaurante fica no final da minha rua, então sempre que posso vou  com minha família e nunca nos decepcionamos. : 0.375
# subjetividade
#  O restaurante fica no final da minha rua, então sempre que posso vou  com minha família e nunca nos decepcionamos. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O atendimento é nota 10, pratos excelentes (desde as massas até o "churrasquinho", o qual eu recomendo TOTALMENTE.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  O atendimento é nota 10, pratos excelentes (desde as massas até o "churrasquinho", o qual eu recomendo TOTALMENTE. : 0.5
# subjetividade
#  O atendimento é nota 10, pratos excelentes (desde as massas até o "churrasquinho", o qual eu recomendo TOTALMENTE. : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  As carnes são muito saborosas e os acompanhamentos tornam o prato melhor ainda),sobremesas deliciosas e ambiente agradável.
# sentence.sentiment.polarity:  0.6083333333333333
# sentence.sentiment.subjectivity:  0.6916666666666667
# Polaridade
#  As carnes são muito saborosas e os acompanhamentos tornam o prato melhor ainda),sobremesas deliciosas e ambiente agradável. : 0.6083333333333333
# subjetividade
#  As carnes são muito saborosas e os acompanhamentos tornam o prato melhor ainda),sobremesas deliciosas e ambiente agradável. : 0.6916666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Recomendado para qualquer ocasião (já houve até casamento no local).
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendado para qualquer ocasião (já houve até casamento no local). : 0.0
# subjetividade
#  Recomendado para qualquer ocasião (já houve até casamento no local). : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70015 x O cachorro quente é gostoso, mas como tudo o que leva "gourmet" no nome, é caro. Recomendo ir para conhecer, mas não precisa virar cliente.
# **************
# Inglês:  The hot dog is delicious, but like everything that has "gourmet" in its name, it is expensive.
#  I recommend going to meet, but you don't need to become a customer.
# sentence_br  O cachorro quente é gostoso, mas como tudo o que leva "gourmet" no nome, é caro.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.85
# Polaridade
#  O cachorro quente é gostoso, mas como tudo o que leva "gourmet" no nome, é caro. : 0.25
# subjetividade
#  O cachorro quente é gostoso, mas como tudo o que leva "gourmet" no nome, é caro. : 0.85
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Recomendo ir para conhecer, mas não precisa virar cliente.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo ir para conhecer, mas não precisa virar cliente. : 0.0
# subjetividade
#  Recomendo ir para conhecer, mas não precisa virar cliente. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70016 x O ambiente é muito agradável, a comida muito boa, o preço é justo para a qualidade do ambiente e comida, para mim é o melhor restaurante de Fortaleza. Indicaria o prato camarão internacional, que dá até para 4 pessoas, muito bom.
# **************
#
# Inglês:  The atmosphere is very pleasant, the food very good, the price is right for the quality of the environment and food, for me it is the best restaurant in Fortaleza.
#  I would recommend the international shrimp dish, which can even serve 4 people, very good.
# sentence_br  O ambiente é muito agradável, a comida muito boa, o preço é justo para a qualidade do ambiente e comida, para mim é o melhor restaurante de Fortaleza.
# sentence.sentiment.polarity:  0.7872619047619047
# sentence.sentiment.subjectivity:  0.6539285714285714
# Polaridade
#  O ambiente é muito agradável, a comida muito boa, o preço é justo para a qualidade do ambiente e comida, para mim é o melhor restaurante de Fortaleza. : 0.7872619047619047
# subjetividade
#  O ambiente é muito agradável, a comida muito boa, o preço é justo para a qualidade do ambiente e comida, para mim é o melhor restaurante de Fortaleza. : 0.6539285714285714
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Indicaria o prato camarão internacional, que dá até para 4 pessoas, muito bom.
# sentence.sentiment.polarity:  0.45499999999999996
# sentence.sentiment.subjectivity:  0.39000000000000007
# Polaridade
#  Indicaria o prato camarão internacional, que dá até para 4 pessoas, muito bom. : 0.45499999999999996
# subjetividade
#  Indicaria o prato camarão internacional, que dá até para 4 pessoas, muito bom. : 0.39000000000000007
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70017 x Ambiente simples, mas muito agradável. Decorado com fotos do dono do restaurante com algumas pessoas famosas que foram ao estabelecimento. Escolhemos uma moqueca de badejo, a qual estava deliciosa. O atendimento foi impecável também. Recomendo chegar cedo, pois o local fica bem movimentado.
# **************
#
# Inglês:  Simple but very pleasant environment.
#  Decorated with photos of the restaurant owner with some famous people who came to the establishment.
#  We chose a whiting moqueca, which was delicious.
#  The service was impeccable too.
#  I recommend arriving early, as the place is very busy.
# sentence_br  Ambiente simples, mas muito agradável.
# sentence.sentiment.polarity:  0.4766666666666666
# sentence.sentiment.subjectivity:  0.6785714285714286
# Polaridade
#  Ambiente simples, mas muito agradável. : 0.4766666666666666
# subjetividade
#  Ambiente simples, mas muito agradável. : 0.6785714285714286
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Decorado com fotos do dono do restaurante com algumas pessoas famosas que foram ao estabelecimento.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Decorado com fotos do dono do restaurante com algumas pessoas famosas que foram ao estabelecimento. : 0.5
# subjetividade
#  Decorado com fotos do dono do restaurante com algumas pessoas famosas que foram ao estabelecimento. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Escolhemos uma moqueca de badejo, a qual estava deliciosa.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Escolhemos uma moqueca de badejo, a qual estava deliciosa. : 1.0
# subjetividade
#  Escolhemos uma moqueca de badejo, a qual estava deliciosa. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O atendimento foi impecável também.
# sentence.sentiment.polarity:  0.75
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  O atendimento foi impecável também. : 0.75
# subjetividade
#  O atendimento foi impecável também. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Recomendo chegar cedo, pois o local fica bem movimentado.
# sentence.sentiment.polarity:  0.115
# sentence.sentiment.subjectivity:  0.345
# Polaridade
#  Recomendo chegar cedo, pois o local fica bem movimentado. : 0.115
# subjetividade
#  Recomendo chegar cedo, pois o local fica bem movimentado. : 0.345
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70018 x Restaurante com varias opções, serviço atencioso e simpático.
# Pedi bife à parmegiana com purê e salada de entrada.
# Estava delicioso!!!
# E para completar...de sobremesa uma mousse de chocolate, muito boa também.
# Indico e voltarei!!
# **************
#
# Inglês:  Restaurant with several options, attentive and friendly service.
#
# I ordered parmigiana steak with mashed potatoes and starter salad.
#
# It was delicious!!!
# And to complete.
# ..of dessert a chocolate mousse, very good too.
#
# I recommend and will be back !!
# sentence_br  Restaurante com varias opções, serviço atencioso e simpático.
# sentence.sentiment.polarity:  0.25833333333333336
# sentence.sentiment.subjectivity:  0.4666666666666666
# Polaridade
#  Restaurante com varias opções, serviço atencioso e simpático. : 0.25833333333333336
# subjetividade
#  Restaurante com varias opções, serviço atencioso e simpático. : 0.4666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Pedi bife à parmegiana com purê e salada de entrada.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Pedi bife à parmegiana com purê e salada de entrada. : 0.0
# subjetividade
#  Pedi bife à parmegiana com purê e salada de entrada. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Estava delicioso!!!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Estava delicioso!!! : 1.0
# subjetividade
#  Estava delicioso!!! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  E para completar.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  E para completar. : 0.1
# subjetividade
#  E para completar. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  ..de sobremesa uma mousse de chocolate, muito boa também.
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  ..de sobremesa uma mousse de chocolate, muito boa também. : 0.9099999999999999
# subjetividade
#  ..de sobremesa uma mousse de chocolate, muito boa também. : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Indico e voltarei!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Indico e voltarei! : 0.0
# subjetividade
#  Indico e voltarei! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70019 x Local oferece uma ambiente familiar, com área para a recreação das crianças, área fechada com ar refrigerado e uma área aberta. A comida é bem temperada e mantém o padrão da matriz em Recife.
# Nós pedimos casquinha de caranguejo de entrada e um peixe grelhado com legumes na manteiga, servido com arroz de brócolis e purê de macaxeira.
# A casquinha estava uma delícia, apesar de ser bem pequena para o preço.
# O peixe estava bem saboroso e foi suficiente para três pessoas que não estavam com muita fome.
# O preço não é dos menores, mas nada exorbitante.
# **************
# Inglês:  The place offers a family atmosphere, with a children's play area, a closed area with air conditioning and an open area.
#  The food is well seasoned and maintains the pattern of the matrix in Recife.
#
# We ordered crab shell for starter and a grilled fish with vegetables in butter, served with broccoli rice and mashed cassava.
#
# The cone was delicious, despite being very small for the price.
#
# The fish was very tasty and was enough for three people who were not very hungry.
#
# The price is not the lowest, but nothing exorbitant.
# sentence_br  Local oferece uma ambiente familiar, com área para a recreação das crianças, área fechada com ar refrigerado e uma área aberta.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.19999999999999998
# Polaridade
#  Local oferece uma ambiente familiar, com área para a recreação das crianças, área fechada com ar refrigerado e uma área aberta. : 0.0
# subjetividade
#  Local oferece uma ambiente familiar, com área para a recreação das crianças, área fechada com ar refrigerado e uma área aberta. : 0.19999999999999998
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  A comida é bem temperada e mantém o padrão da matriz em Recife.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.25
# Polaridade
#  A comida é bem temperada e mantém o padrão da matriz em Recife. : 0.25
# subjetividade
#  A comida é bem temperada e mantém o padrão da matriz em Recife. : 0.25
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Nós pedimos casquinha de caranguejo de entrada e um peixe grelhado com legumes na manteiga, servido com arroz de brócolis e purê de macaxeira.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Nós pedimos casquinha de caranguejo de entrada e um peixe grelhado com legumes na manteiga, servido com arroz de brócolis e purê de macaxeira. : 0.0
# subjetividade
#  Nós pedimos casquinha de caranguejo de entrada e um peixe grelhado com legumes na manteiga, servido com arroz de brócolis e purê de macaxeira. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  A casquinha estava uma delícia, apesar de ser bem pequena para o preço.
# sentence.sentiment.polarity:  0.3375
# sentence.sentiment.subjectivity:  0.76
# Polaridade
#  A casquinha estava uma delícia, apesar de ser bem pequena para o preço. : 0.3375
# subjetividade
#  A casquinha estava uma delícia, apesar de ser bem pequena para o preço. : 0.76
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O peixe estava bem saboroso e foi suficiente para três pessoas que não estavam com muita fome.
# sentence.sentiment.polarity:  0.03333333333333333
# sentence.sentiment.subjectivity:  0.3666666666666667
# Polaridade
#  O peixe estava bem saboroso e foi suficiente para três pessoas que não estavam com muita fome. : 0.03333333333333333
# subjetividade
#  O peixe estava bem saboroso e foi suficiente para três pessoas que não estavam com muita fome. : 0.3666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O preço não é dos menores, mas nada exorbitante.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  O preço não é dos menores, mas nada exorbitante. : 0.0
# subjetividade
#  O preço não é dos menores, mas nada exorbitante. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70020 x Ao entrar na lanchonete, a garçonete entrega um rolinho de mortadela, que combina muito bem com uma cervejinha gelada. Uma pena que a oferta de cervejas na casa é pequena. O x-salada não deve nada aos melhores da cidade, e vem com molho de tomate, bem suculento.
# **************
#
# Inglês:  Upon entering the cafeteria, the waitress delivers a roll of bologna, which goes well with a cold beer.
#  Too bad the supply of beers in the house is small.
#  The x-salad owes nothing to the best in town, and comes with a very juicy tomato sauce.
# sentence_br  Ao entrar na lanchonete, a garçonete entrega um rolinho de mortadela, que combina muito bem com uma cervejinha gelada.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Ao entrar na lanchonete, a garçonete entrega um rolinho de mortadela, que combina muito bem com uma cervejinha gelada. : -0.6
# subjetividade
#  Ao entrar na lanchonete, a garçonete entrega um rolinho de mortadela, que combina muito bem com uma cervejinha gelada. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Uma pena que a oferta de cervejas na casa é pequena.
# sentence.sentiment.polarity:  -0.4749999999999999
# sentence.sentiment.subjectivity:  0.5333333333333333
# Polaridade
#  Uma pena que a oferta de cervejas na casa é pequena. : -0.4749999999999999
# subjetividade
#  Uma pena que a oferta de cervejas na casa é pequena. : 0.5333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O x-salada não deve nada aos melhores da cidade, e vem com molho de tomate, bem suculento.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  O x-salada não deve nada aos melhores da cidade, e vem com molho de tomate, bem suculento. : 0.6
# subjetividade
#  O x-salada não deve nada aos melhores da cidade, e vem com molho de tomate, bem suculento. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70021 x Adorei desde o ambiente ate a comida, sobremesa maravilhosa.... tem translado do hotel para la. Muito bom recomendo
# **************
#
# Inglês:  I loved everything from the ambience to the food, wonderful dessert.
# ... has a transfer from the hotel to there.
#  Very good, I recommend
# sentence_br  Adorei desde o ambiente ate a comida, sobremesa maravilhosa.
# sentence.sentiment.polarity:  0.85
# sentence.sentiment.subjectivity:  0.9
# Polaridade
# ...
# Polaridade
#  Recomendo! : 0.0
# subjetividade
#  Recomendo! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70700 x O Restaurante o Varandão está embarcado no Othon Palace Hotel, centro de BH, com excelente vista do Parque Municipal, ambiente agradável, comida de boa qualidade, aos sábados tem uma feijoada soberba. ótimo custo-benefício.
# Recomendo!
# **************
#
# Inglês:  The Varandão Restaurant is on board at the Othon Palace Hotel, downtown BH, with an excellent view of the Municipal Park, pleasant atmosphere, good quality food, on Saturdays it has a superb feijoada.
#  great cost-benefit.
#
# I recommend!
# sentence_br  O Restaurante o Varandão está embarcado no Othon Palace Hotel, centro de BH, com excelente vista do Parque Municipal, ambiente agradável, comida de boa qualidade, aos sábados tem uma feijoada soberba.
# sentence.sentiment.polarity:  0.8583333333333334
# sentence.sentiment.subjectivity:  0.8916666666666667
# Polaridade
#  O Restaurante o Varandão está embarcado no Othon Palace Hotel, centro de BH, com excelente vista do Parque Municipal, ambiente agradável, comida de boa qualidade, aos sábados tem uma feijoada soberba. : 0.8583333333333334
# subjetividade
#  O Restaurante o Varandão está embarcado no Othon Palace Hotel, centro de BH, com excelente vista do Parque Municipal, ambiente agradável, comida de boa qualidade, aos sábados tem uma feijoada soberba. : 0.8916666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  ótimo custo-benefício.
# sentence.sentiment.polarity:  0.8
# sentence.sentiment.subjectivity:  0.75
# Polaridade
#  ótimo custo-benefício. : 0.8
# subjetividade
#  ótimo custo-benefício. : 0.75
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Recomendo!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo! : 0.0
# subjetividade
#  Recomendo! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70701 x A Casa Urich é um dos estabelecimentos do tipo Rio Antigo, que sobrevive por sua qualidade e excelência no atendimento, O tipo que o Carioca gosta.  É um restaurante na hora do almoço e ao entardecer é um completo bar. Um ambiente aconchegante e democrático. É daqueles que cativa uma clientela fiel de  longo tempo. O atendimento que se coloca em destaque, se diferencia em muito ao que vemos normalmente no Rio, e que que se pode comparar ao que vemos em São Paulo.
# Além  do excelente chopp, não deixem de experimentarem  o pastel de camarão. Cuidado para não ficarem viciados. O cardápio é vasto e delicioso.
#
# Principalmente  ãs sextas-feiras  é melhor chegar antes das 20:00 h, para poder encontrar mesa vazia
# **************
# Inglês:  Casa Urich is one of the establishments of the type Rio Antigo, which survives for its quality and excellence in service, the type that Carioca likes.
#   It is a restaurant at lunchtime and at dusk it is a complete bar.
#  A warm and democratic environment.
#  It is one of those that captivates a loyal clientele for a long time.
#  The service that stands out is very different from what we normally see in Rio, and that can be compared to what we see in São Paulo.
#
# In addition to the excellent draft beer, be sure to try the shrimp pastry.
#  Be careful not to get addicted.
#  The menu is vast and delicious.
#
#
# Especially on Fridays it is best to arrive before 20:00, in order to find an empty table
# sentence_br  A Casa Urich é um dos estabelecimentos do tipo Rio Antigo, que sobrevive por sua qualidade e excelência no atendimento, O tipo que o Carioca gosta.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  A Casa Urich é um dos estabelecimentos do tipo Rio Antigo, que sobrevive por sua qualidade e excelência no atendimento, O tipo que o Carioca gosta. : 0.0
# subjetividade
#  A Casa Urich é um dos estabelecimentos do tipo Rio Antigo, que sobrevive por sua qualidade e excelência no atendimento, O tipo que o Carioca gosta. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  É um restaurante na hora do almoço e ao entardecer é um completo bar.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  É um restaurante na hora do almoço e ao entardecer é um completo bar. : 0.1
# subjetividade
#  É um restaurante na hora do almoço e ao entardecer é um completo bar. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Um ambiente aconchegante e democrático.
# sentence.sentiment.polarity:  0.6
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Um ambiente aconchegante e democrático. : 0.6
# subjetividade
#  Um ambiente aconchegante e democrático. : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  É daqueles que cativa uma clientela fiel de  longo tempo.
# sentence.sentiment.polarity:  0.14166666666666666
# sentence.sentiment.subjectivity:  0.6166666666666667
# Polaridade
#  É daqueles que cativa uma clientela fiel de  longo tempo. : 0.14166666666666666
# subjetividade
#  É daqueles que cativa uma clientela fiel de  longo tempo. : 0.6166666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O atendimento que se coloca em destaque, se diferencia em muito ao que vemos normalmente no Rio, e que que se pode comparar ao que vemos em São Paulo.
# sentence.sentiment.polarity:  0.075
# sentence.sentiment.subjectivity:  0.715
# Polaridade
#  O atendimento que se coloca em destaque, se diferencia em muito ao que vemos normalmente no Rio, e que que se pode comparar ao que vemos em São Paulo. : 0.075
# subjetividade
#  O atendimento que se coloca em destaque, se diferencia em muito ao que vemos normalmente no Rio, e que que se pode comparar ao que vemos em São Paulo. : 0.715
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Além  do excelente chopp, não deixem de experimentarem  o pastel de camarão.
# sentence.sentiment.polarity:  0.75
# sentence.sentiment.subjectivity:  0.9444444444444444
# Polaridade
#  Além  do excelente chopp, não deixem de experimentarem  o pastel de camarão. : 0.75
# subjetividade
#  Além  do excelente chopp, não deixem de experimentarem  o pastel de camarão. : 0.9444444444444444
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Cuidado para não ficarem viciados.
# sentence.sentiment.polarity:  -0.25
# sentence.sentiment.subjectivity:  0.8
# Polaridade
#  Cuidado para não ficarem viciados. : -0.25
# subjetividade
#  Cuidado para não ficarem viciados. : 0.8
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  O cardápio é vasto e delicioso.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O cardápio é vasto e delicioso. : 0.5
# subjetividade
#  O cardápio é vasto e delicioso. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Principalmente  ãs sextas-feiras  é melhor chegar antes das 20:00 h, para poder encontrar mesa vazia
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.6
# Polaridade
#  Principalmente  ãs sextas-feiras  é melhor chegar antes das 20:00 h, para poder encontrar mesa vazia : 0.3
# subjetividade
#  Principalmente  ãs sextas-feiras  é melhor chegar antes das 20:00 h, para poder encontrar mesa vazia : 0.6
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70702 x Uma casa que atende a vários públicos no sábado uma deliciosa feijoada com preço de R$35,00
# Durante a semana oferece para o trabalhador prato comercial por 9,90
# **************
#
# Inglês:  A house that serves various audiences on Saturday a delicious feijoada priced at R $ 35.00
# During the week offers to the worker commercial dish for 9.90
# sentence_br  Uma casa que atende a vários públicos no sábado uma deliciosa feijoada com preço de R$35,00
# Durante a semana oferece para o trabalhador prato comercial por 9,90
# sentence.sentiment.polarity:  0.275
# sentence.sentiment.subjectivity:  0.375
# Polaridade
#  Uma casa que atende a vários públicos no sábado uma deliciosa feijoada com preço de R$35,00
# Durante a semana oferece para o trabalhador prato comercial por 9,90 : 0.275
# subjetividade
#  Uma casa que atende a vários públicos no sábado uma deliciosa feijoada com preço de R$35,00
# Durante a semana oferece para o trabalhador prato comercial por 9,90 : 0.375
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70703 x Este restaurante é demais! Pedimos a entrada de camarão com molho wasabi e, como pratos principais, pedimos o camarão manary e o matuto metido a besta! Delícia! Recomendo!
# **************
#
# Inglês:  This restaurant is awesome! We ordered the shrimp starter with wasabi sauce and, as main dishes, we ordered the manary shrimp and the stuffed beast! Delicious! I recommend!
# sentence_br  Este restaurante é demais!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Este restaurante é demais! : 1.0
# subjetividade
#  Este restaurante é demais! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Pedimos a entrada de camarão com molho wasabi e, como pratos principais, pedimos o camarão manary e o matuto metido a besta!
# sentence.sentiment.polarity:  0.20833333333333331
# sentence.sentiment.subjectivity:  0.3333333333333333
# Polaridade
#  Pedimos a entrada de camarão com molho wasabi e, como pratos principais, pedimos o camarão manary e o matuto metido a besta! : 0.20833333333333331
# subjetividade
#  Pedimos a entrada de camarão com molho wasabi e, como pratos principais, pedimos o camarão manary e o matuto metido a besta! : 0.3333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Delícia!
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Delícia! : 1.0
# subjetividade
#  Delícia! : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# sentence_br  Recomendo!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo! : 0.0
# subjetividade
#  Recomendo! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-70000-80000.txt
# **************
#
# var 70704 x O Rock Burger é um restaurante com uma decoração bem legal, e um cardápio muito variado, e diferente no almoço e no jantar, eu estive lá pra almoçar e pedimos pratos de refeição e hamburguer, todos gostosos, não saborosos, estilo fast food, entretanto o serviço deixou um pouco a desejar, tivemos que cobrar talheres, um dos pratos foi esquecido e depois de cobrado só chegou quando os outros já tinham terminado sua refeição.
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
