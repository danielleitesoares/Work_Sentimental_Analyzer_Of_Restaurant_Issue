# %%
#importando as bibliotecas 
import pandas as pd
import json
import nltk
import time
import re
from bs4 import BeautifulSoup
nltk.download('punkt')
from textblob import TextBlob
import sys
import os.path
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pcorrea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
inicio = 10000
terminou = 20000

# %%
! git clone https://github.com/paulordie/sentimental_ds
# Out:
# fatal: destination path 'sentimental_ds' already exists and is not an empty directory.

# %%
# %cd sentimental_ds/
# %ls
# Out:
# C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#  Volume in drive C has no label.
#  Volume Serial Number is 7263-ABB2
#
#  Directory of C:\Users\pcorrea\Documents\sentimental_ds\sentimental_ds
#
# 11/22/2020  06:49 PM    <DIR>          .
# 11/22/2020  06:49 PM    <DIR>          ..
# 11/22/2020  06:49 PM    <DIR>          .ipynb_checkpoints
# 11/22/2020  06:49 PM           102,696 dados-curso.csv
# 11/22/2020  06:49 PM        89,873,865 dataset-v2.dat
# 11/22/2020  06:49 PM            36,571 first_code_test.ipynb
# 11/22/2020  06:49 PM                11 main.txt
# 11/22/2020  06:49 PM        55,693,902 pc-dataset-v2.csv
# 11/22/2020  06:49 PM        55,673,923 pc-dataset-v2.dat
# 11/22/2020  06:49 PM           263,029 piloto-2.ipynb
# 11/22/2020  06:49 PM       102,394,250 prototype_sentimental_analyzer.ipynb
# 11/22/2020  06:49 PM                11 README.md
#                9 File(s)    304,038,258 bytes
#                3 Dir(s)  127,709,970,432 bytes free

# %%
import json
import pandas as pd
import time
dados = open('dataset-v2.dat', encoding="utf8") #pandas
print("Tipo do dado: ", type(dados))
# Out:
# Tipo do dado:  <class '_io.TextIOWrapper'>

# %%
! pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\pcorrea\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: requests in c:\users\pcorrea\anaconda3\lib\site-packages (from googletrans) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pcorrea\anaconda3\lib\site-packages (from requests->googletrans) (2020.6.20)

# %%
listOfDataBase = list()
listOfData = []
 
def findKeys(dataBase):
    for register in dataBase:
        try:
            cols = register.split('\n')
            listOfDataBase.append(cols[0])
        except UnicodeDecodeError:
            print("Error on uncode decode findkeys")
    print("Find Keys: ",listOfDataBase)

# %%
def passToJson():
    i=0
    for i in range(100000): ## tem que colocar a array de todo arquivo
        listOfIssue = listOfDataBase[i]
        i+=1
#         time.sleep(1)
        joinList = json.loads(listOfIssue)
        data = pd.json_normalize(joinList)
        listOfData.append(data)
    return listOfData

# %%
def showContent(value, collum):
    i=0
    _data = []
    for i in range(value): ##range que vai trazer todas as colunas
        try:
            res = listOfData[i][collum]
            print(type(res))
            print(listOfData[i][collum]) #averageRating, ratingValue etc
            i = i + 1
            print("line: ", i)
        except KeyError:
            print("Key Error")
            continue

valueFindKeys = findKeys(dados) #valor que vai para def passToJson()
dictionaryOfDate = passToJson()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.concat(objs=dictionaryOfDate,axis=0)

# %%
X = df.iloc[:, 4].values
type(X)
len(X)
# Out:
# 100000

# %%
X
# Out:
# array(['Comida maravilhosa, lugar do verdadeiro chiclete de camarão. \nO garçom Éric Lima nos atendeu muito bem, pretendemos voltar assim que possível.',
#        'Comida boa, drinks legais e um ambiente bem aconchegante. \nProvamos muitas coisas e tudo nos agradou. Principalmente um pato servido em um dos pratos da casa, sensacional!',
#        'Excelente pra ir com a família! Ótima Comida, ambiente agradável, bom atendimento e estacionamento. Vale a pena conhecer',
#        ...,
#        'O Rio Scenarium é uma das baladas mais famosas do Rio de Janeiro. É bem grande e lotada de estrangeiros. A bebida não é tão cara como em outras cidades, por exemplo, São Paulo. O lado negativo é com certeza a fila. Se você não chegar cedo, vai ficar pelo menos 30 minutos esperando para entrar.',
#        'Fui por indicação e com boa expectativa!\n116,00 o kilo de salada... Bem caro, né?\nO alface tava murcho, nada de opções de tempero, buffet pequeno...\n12,00 um copo peq de suco. Aff.\nNao valeu, nem pelo ambiente nem pela comida.',
#        'Experiência fantástica com comida deliciosa e atendimento de excelência prestado pelo Wellington, ambiente agradável, música boa ambiente'],
#       dtype=object)

# %%
def clean_tripadvisor(tweet):
    try:
        tweet = BeautifulSoup(tweet, 'lxml').get_text() # o lxml indica o parse pode ser usado para dados de web por ex
    #     tweet = re.sub(r"\b\.\s\\n", '\n', tweet)
    #     tweet = re.sub(r"\b\.\s[A-Za-z0-9]", '\n', tweet)
        tweet = re.sub(r"\b\.\s\\n", '. \n', tweet)
        tweet = re.sub(r"\b\.", '. \n', tweet)    
        return tweet
    except TyperError:
        print("Errou no tipo no regex")

# %%
arquivoToSave = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/salvo_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocument(var,resultado,nota,polaridade,fim):
    try:
        with open(arquivoToSave, 'a') as toSave:
            toSave.write('{} - {} subj {} pol {} \n'.format(var,resultado,nota, polaridade))
            if fim == "fim":
                toSave.close()
            print('It was created result: ',arquivoToSave)
                
    except Exception as e:
        print("Error did file ", e)

# %%
arquivoToSaveError = "/home/pcorrea/Documents/Ciencia-De-Dados-UEA/programacao-para-ciencia-dedados/scripts/erros_poradiradade_vm2-{}-{}.txt".format(inicio, terminou)

def saveDocumentError(var, item,obj):
    try:
        with open(arquivoToSaveError, 'a') as toSave:
            toSave.write('{} - qtd erro {} : {} \n'.format(var,item,obj))
            
            toSave.close()
            print('It was saver error: ',arquivoToSaveError)
                
    except Exception as e:
        print("Error did file ", e)

# %%
def transTextBlob(sentences):
    ##textblob
    comentario_blob = TextBlob(sentences)
    print(type(comentario_blob))
    comentario_blob_us = comentario_blob.translate(to='us')
    print("textblob traduziu: ",comentario_blob_us)
    return comentario_blob, comentario_blob_us
    ##textblob

# %%
def transGoogle(sentences):
    ##googletrans
    import pandas as pd
    from googletrans import Translator   
    translator = Translator()
    try:
        translations = translator.translate([sentences], dest='en')
        for translation in translations:
            print(type(translation.text))
            print("google traduziu: ", translation.text)
    except AttributeError:
         print("Error googletrans")
    ##googletrans

# %%
var = 0
errou = 0
for x in df['reviewBody']:
    ini 
    var = var + 1
    if var > inicio and var <= terminou:
        print("**************\n")
        print( "var {} x {}".format(var,x))
        print("**************\n")
        out = clean_tripadvisor(x)
        comentario_blob = TextBlob(out)

        comentario_blob_us = comentario_blob.translate(to='us')
        print("Inglês: ",comentario_blob_us)
        time.sleep(5)

        for sentence_br, sentence in zip(comentario_blob.sentences, comentario_blob_us.sentences):
            print("sentence_br ",sentence_br)
            print("sentence.sentiment.polarity: ",sentence.sentiment.polarity)
            print("sentence.sentiment.subjectivity: ",sentence.sentiment.subjectivity)
            if sentence_br is None:
                errou = errou + 1
                print("errou em {} - {} {}".format(var,errou,x))
                saveDocumentError(var,errou,x)

            elif var > inicio and var <= terminou:
                print('Polaridade\n',sentence_br, ':', sentence.sentiment.polarity)
                print('subjetividade\n',sentence_br, ':', sentence.sentiment.subjectivity)
                saveDocument(var,sentence_br,sentence.sentiment.subjectivity,sentence.sentiment.polarity, 'fim')

            else:
                print("algum erro ocorreu em {}".format(var))
    elif var == terminou:
        print("Finalizou em ",var)
        break
    fim = time.time()
    print("tempo final foi ", ini-fim)
# Out:
# **************
#
# var 10001 x Entrada, principal e sobremesa: estava tudo maravilhoso!!!!
# Mirella e Giuseppe, obrigada pela recepção! Tenham a certeza de que voltaremos em breve! 😉
# **************
#
# Inglês:  Starter, main and dessert: everything was wonderful !!!!
# Mirella and Giuseppe, thanks for the reception! Rest assured that we will be back soon! 😉
# sentence_br  Entrada, principal e sobremesa: estava tudo maravilhoso!!!!
# sentence.sentiment.polarity:  0.5833333333333334
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  Entrada, principal e sobremesa: estava tudo maravilhoso!!!! : 0.5833333333333334
# subjetividade
#  Entrada, principal e sobremesa: estava tudo maravilhoso!!!! : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Mirella e Giuseppe, obrigada pela recepção!
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  Mirella e Giuseppe, obrigada pela recepção! : 0.25
# subjetividade
#  Mirella e Giuseppe, obrigada pela recepção! : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Tenham a certeza de que voltaremos em breve!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tenham a certeza de que voltaremos em breve! : 0.0
# subjetividade
#  Tenham a certeza de que voltaremos em breve! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  😉
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  😉 : 0.0
# subjetividade
#  😉 : 0.0
# Error did file  'charmap' codec can't encode character '\U0001f609' in position 8: character maps to <undefined>
# **************
#
# var 10002 x Visitando João Pessoa e após almoçar na praça de alimentação, resolvi tomar uma açaí de verdade. Tinha opção do Calzoni mas preferi apostar numa casa especializada, que no caso seria o Manaçaí. A experiência foi frustrante, a começar pela FARINHA LÁCTEA. Pelo amor de Deus, onde foram buscar essa farinha láctea terrível? Ainda não aprendeu que farinha láctea só existe uma? Para finalizar o açaí era puro gelo. Em resumo, precisa melhorar muito para ser referência como local especializado em Açaí
# **************
#
# Inglês:  Visiting João Pessoa and after having lunch at the food court, I decided to have a real açaí.
#  I had the option of Calzoni but I preferred to bet on a specialized house, which in this case would be Manaçaí.
#  The experience was frustrating, starting with MILK FLOUR.
#  For God's sake, where did you get that terrible milk flour? Haven't you learned that there is only one milk flour? To finish the açaí was pure ice.
#  In short, it needs to improve a lot to be a reference as a specialized place in Açaí
# sentence_br  Visitando João Pessoa e após almoçar na praça de alimentação, resolvi tomar uma açaí de verdade.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.30000000000000004
# Polaridade
#  Visitando João Pessoa e após almoçar na praça de alimentação, resolvi tomar uma açaí de verdade. : 0.2
# subjetividade
#  Visitando João Pessoa e após almoçar na praça de alimentação, resolvi tomar uma açaí de verdade. : 0.30000000000000004
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Tinha opção do Calzoni mas preferi apostar numa casa especializada, que no caso seria o Manaçaí.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Tinha opção do Calzoni mas preferi apostar numa casa especializada, que no caso seria o Manaçaí. : 0.0
# subjetividade
#  Tinha opção do Calzoni mas preferi apostar numa casa especializada, que no caso seria o Manaçaí. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  A experiência foi frustrante, a começar pela FARINHA LÁCTEA.
# sentence.sentiment.polarity:  -0.2
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  A experiência foi frustrante, a começar pela FARINHA LÁCTEA. : -0.2
# subjetividade
#  A experiência foi frustrante, a começar pela FARINHA LÁCTEA. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Pelo amor de Deus, onde foram buscar essa farinha láctea terrível?
# sentence.sentiment.polarity:  -1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Pelo amor de Deus, onde foram buscar essa farinha láctea terrível? : -1.0
# subjetividade
#  Pelo amor de Deus, onde foram buscar essa farinha láctea terrível? : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Ainda não aprendeu que farinha láctea só existe uma?
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Ainda não aprendeu que farinha láctea só existe uma? : 0.0
# subjetividade
#  Ainda não aprendeu que farinha láctea só existe uma? : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Para finalizar o açaí era puro gelo.
# sentence.sentiment.polarity:  0.21428571428571427
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Para finalizar o açaí era puro gelo. : 0.21428571428571427
# subjetividade
#  Para finalizar o açaí era puro gelo. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Em resumo, precisa melhorar muito para ser referência como local especializado em Açaí
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  Em resumo, precisa melhorar muito para ser referência como local especializado em Açaí : 0.0
# subjetividade
#  Em resumo, precisa melhorar muito para ser referência como local especializado em Açaí : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10003 x Bom para ouvir um bom rock, cervejas, tira-gostos e uma partida de sinuca. Nos sábados a noite o publico lota até a calçada e muitas vezes a rua em frente. Música varia de Raimundos, Led Zeppelin  a Artic Monkeys. O ponto já mudou de nome (era o antigo Come Jazz, Bebe Blues), mas mantém a tradição junto ao publico rockeiro da praia. Não espere um excelente atendimento: quer cerveja na hora, vá buscar no balcão.
# **************
#
# Inglês:  Good for listening to good rock, beers, snacks and a game of pool.
#  On Saturdays at night, the public flocks to the sidewalk and often the street in front.
#  Music ranges from Raimundos, Led Zeppelin to Artic Monkeys.
#  The spot has already changed its name (it was the old Come Jazz, Bebe Blues), but maintains the tradition with the rock audience of the beach.
#  Don't expect excellent service: if you want beer on the spot, pick it up at the counter.
# sentence_br  Bom para ouvir um bom rock, cervejas, tira-gostos e uma partida de sinuca.
# sentence.sentiment.polarity:  0.3333333333333333
# sentence.sentiment.subjectivity:  0.5333333333333333
# Polaridade
#  Bom para ouvir um bom rock, cervejas, tira-gostos e uma partida de sinuca. : 0.3333333333333333
# subjetividade
#  Bom para ouvir um bom rock, cervejas, tira-gostos e uma partida de sinuca. : 0.5333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Nos sábados a noite o publico lota até a calçada e muitas vezes a rua em frente.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.06666666666666667
# Polaridade
#  Nos sábados a noite o publico lota até a calçada e muitas vezes a rua em frente. : 0.0
# subjetividade
#  Nos sábados a noite o publico lota até a calçada e muitas vezes a rua em frente. : 0.06666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Música varia de Raimundos, Led Zeppelin  a Artic Monkeys.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Música varia de Raimundos, Led Zeppelin  a Artic Monkeys. : 0.0
# subjetividade
#  Música varia de Raimundos, Led Zeppelin  a Artic Monkeys. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  O ponto já mudou de nome (era o antigo Come Jazz, Bebe Blues), mas mantém a tradição junto ao publico rockeiro da praia.
# sentence.sentiment.polarity:  0.1
# sentence.sentiment.subjectivity:  0.2
# Polaridade
#  O ponto já mudou de nome (era o antigo Come Jazz, Bebe Blues), mas mantém a tradição junto ao publico rockeiro da praia. : 0.1
# subjetividade
#  O ponto já mudou de nome (era o antigo Come Jazz, Bebe Blues), mas mantém a tradição junto ao publico rockeiro da praia. : 0.2
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Não espere um excelente atendimento: quer cerveja na hora, vá buscar no balcão.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Não espere um excelente atendimento: quer cerveja na hora, vá buscar no balcão. : 1.0
# subjetividade
#  Não espere um excelente atendimento: quer cerveja na hora, vá buscar no balcão. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10004 x Sempre fui apaixonada pela pizza da Pizza Hut, o restaurante fica dentro do Mag Shoppinh e tem um ambiente legal, só tivemos problemas com a entrada que pedimos, um garlic bread que estava muito mal feito, porém a pizza estava divina.
# **************
# Inglês:  I've always been passionate about Pizza Hut's pizza, the restaurant is inside the Mag Shoppinh and has a nice atmosphere, we only had problems with the starter we ordered, a garlic bread that was very poorly made, but the pizza was divine.
# sentence_br  Sempre fui apaixonada pela pizza da Pizza Hut, o restaurante fica dentro do Mag Shoppinh e tem um ambiente legal, só tivemos problemas com a entrada que pedimos, um garlic bread que estava muito mal feito, porém a pizza estava divina.
# sentence.sentiment.polarity:  0.007499999999999979
# sentence.sentiment.subjectivity:  0.9075
# Polaridade
#  Sempre fui apaixonada pela pizza da Pizza Hut, o restaurante fica dentro do Mag Shoppinh e tem um ambiente legal, só tivemos problemas com a entrada que pedimos, um garlic bread que estava muito mal feito, porém a pizza estava divina. : 0.007499999999999979
# subjetividade
#  Sempre fui apaixonada pela pizza da Pizza Hut, o restaurante fica dentro do Mag Shoppinh e tem um ambiente legal, só tivemos problemas com a entrada que pedimos, um garlic bread que estava muito mal feito, porém a pizza estava divina. : 0.9075
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10005 x O lugar é muito confortável, na área externa possui cobertores para aquecer os clientes. Os garçons são atenciosos e se dispõem a explicar cada tipo de chopp, cujas opções (diga-se de passagem, muitas! Ótimo lugar para quem quer se aventurar e conhecer chopps diferentes) ficam expostas em uma lousa no bar. Indico Karmeliet!
# **************
#
# Inglês:  The place is very comfortable, the outside area has blankets to warm customers.
#  The waiters are attentive and willing to explain each type of draft beer, whose options (by the way, many! Great place for those who want to venture out and get to know different draft beer) are displayed on a blackboard in the bar.
#  I indicate Karmeliet!
# sentence_br  O lugar é muito confortável, na área externa possui cobertores para aquecer os clientes.
# sentence.sentiment.polarity:  0.37333333333333335
# sentence.sentiment.subjectivity:  0.5499999999999999
# Polaridade
#  O lugar é muito confortável, na área externa possui cobertores para aquecer os clientes. : 0.37333333333333335
# subjetividade
#  O lugar é muito confortável, na área externa possui cobertores para aquecer os clientes. : 0.5499999999999999
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Os garçons são atenciosos e se dispõem a explicar cada tipo de chopp, cujas opções (diga-se de passagem, muitas!
# sentence.sentiment.polarity:  0.425
# sentence.sentiment.subjectivity:  0.7166666666666667
# Polaridade
#  Os garçons são atenciosos e se dispõem a explicar cada tipo de chopp, cujas opções (diga-se de passagem, muitas! : 0.425
# subjetividade
#  Os garçons são atenciosos e se dispõem a explicar cada tipo de chopp, cujas opções (diga-se de passagem, muitas! : 0.7166666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Ótimo lugar para quem quer se aventurar e conhecer chopps diferentes) ficam expostas em uma lousa no bar.
# sentence.sentiment.polarity:  0.4
# sentence.sentiment.subjectivity:  0.675
# Polaridade
#  Ótimo lugar para quem quer se aventurar e conhecer chopps diferentes) ficam expostas em uma lousa no bar. : 0.4
# subjetividade
#  Ótimo lugar para quem quer se aventurar e conhecer chopps diferentes) ficam expostas em uma lousa no bar. : 0.675
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Indico Karmeliet!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Indico Karmeliet! : 0.0
# subjetividade
#  Indico Karmeliet! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10006 x Excelente atendimento, comida deliciosa e muito bem servida, tempero único e boa variedade, todas com sabor especial árabe.
# **************
#
# Inglês:  Excellent service, delicious and very well served food, unique seasoning and good variety, all with a special Arab flavor.
# sentence_br  Excelente atendimento, comida deliciosa e muito bem servida, tempero único e boa variedade, todas com sabor especial árabe.
# sentence.sentiment.polarity:  0.6053571428571429
# sentence.sentiment.subjectivity:  0.7452380952380953
# Polaridade
#  Excelente atendimento, comida deliciosa e muito bem servida, tempero único e boa variedade, todas com sabor especial árabe. : 0.6053571428571429
# subjetividade
#  Excelente atendimento, comida deliciosa e muito bem servida, tempero único e boa variedade, todas com sabor especial árabe. : 0.7452380952380953
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10007 x Sempre com excelentes opções de pratos quentes, além de saladas e boa variedade de sobremesas. O sabor é excelente, além do ambiente que é muito agradável. O serviço é impecável, muito atencioso.
# **************
#
# Inglês:  Always with excellent options of hot dishes, in addition to salads and a good variety of desserts.
#  The taste is excellent, in addition to the atmosphere that is very pleasant.
#  The service is impeccable, very attentive.
# sentence_br  Sempre com excelentes opções de pratos quentes, além de saladas e boa variedade de sobremesas.
# sentence.sentiment.polarity:  0.65
# sentence.sentiment.subjectivity:  0.8166666666666668
# Polaridade
#  Sempre com excelentes opções de pratos quentes, além de saladas e boa variedade de sobremesas. : 0.65
# subjetividade
#  Sempre com excelentes opções de pratos quentes, além de saladas e boa variedade de sobremesas. : 0.8166666666666668
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  O sabor é excelente, além do ambiente que é muito agradável.
# sentence.sentiment.polarity:  0.9766666666666666
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  O sabor é excelente, além do ambiente que é muito agradável. : 0.9766666666666666
# subjetividade
#  O sabor é excelente, além do ambiente que é muito agradável. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  O serviço é impecável, muito atencioso.
# sentence.sentiment.polarity:  0.635
# sentence.sentiment.subjectivity:  0.875
# Polaridade
#  O serviço é impecável, muito atencioso. : 0.635
# subjetividade
#  O serviço é impecável, muito atencioso. : 0.875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10008 x Cheguei ao Pecora Nera atraves de uma postagem em um blog. Na primeira vez que fui, ele ainda não havia completado um ano de funcionamento e ja era um sucesso, mas desses exclusivos, que poucos conhecem e que só atendiam com reserva.
# Achei maravilhoso, desde as entradas até as sobremesas. Boa carta de vinhos, bom atendimento, ambiente gostoso. Os preços não são baixos, mas não considero caro pois o restaurante entrega o que promete. Ja paguei um pouco mais barato em lugares sem a menor qualidade, vale mais a pena poupar para comer bem.
# **************
#
# Inglês:  I arrived at Pecora Nera through a blog post.
#  The first time I went, he had not yet completed a year of operation and was already a success, but of these exclusives, that few know and that only attended with reservation.
#
# I found it wonderful, from the starters to the desserts.
#  Good wine list, good service, tasty atmosphere.
#  Prices are not low, but I don't consider it expensive because the restaurant delivers what it promises.
#  I already paid a little cheaper in places without the lowest quality, it is more worth saving to eat well.
# sentence_br  Cheguei ao Pecora Nera atraves de uma postagem em um blog.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Cheguei ao Pecora Nera atraves de uma postagem em um blog. : 0.0
# subjetividade
#  Cheguei ao Pecora Nera atraves de uma postagem em um blog. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Na primeira vez que fui, ele ainda não havia completado um ano de funcionamento e ja era um sucesso, mas desses exclusivos, que poucos conhecem e que só atendiam com reserva.
# sentence.sentiment.polarity:  0.08750000000000001
# sentence.sentiment.subjectivity:  0.35833333333333334
# Polaridade
#  Na primeira vez que fui, ele ainda não havia completado um ano de funcionamento e ja era um sucesso, mas desses exclusivos, que poucos conhecem e que só atendiam com reserva. : 0.08750000000000001
# subjetividade
#  Na primeira vez que fui, ele ainda não havia completado um ano de funcionamento e ja era um sucesso, mas desses exclusivos, que poucos conhecem e que só atendiam com reserva. : 0.35833333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Achei maravilhoso, desde as entradas até as sobremesas.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Achei maravilhoso, desde as entradas até as sobremesas. : 1.0
# subjetividade
#  Achei maravilhoso, desde as entradas até as sobremesas. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Boa carta de vinhos, bom atendimento, ambiente gostoso.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  Boa carta de vinhos, bom atendimento, ambiente gostoso. : 0.7
# subjetividade
#  Boa carta de vinhos, bom atendimento, ambiente gostoso. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Os preços não são baixos, mas não considero caro pois o restaurante entrega o que promete.
# sentence.sentiment.polarity:  -0.25
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Os preços não são baixos, mas não considero caro pois o restaurante entrega o que promete. : -0.25
# subjetividade
#  Os preços não são baixos, mas não considero caro pois o restaurante entrega o que promete. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Ja paguei um pouco mais barato em lugares sem a menor qualidade, vale mais a pena poupar para comer bem.
# sentence.sentiment.polarity:  0.2041666666666667
# sentence.sentiment.subjectivity:  0.3666666666666667
# Polaridade
#  Ja paguei um pouco mais barato em lugares sem a menor qualidade, vale mais a pena poupar para comer bem. : 0.2041666666666667
# subjetividade
#  Ja paguei um pouco mais barato em lugares sem a menor qualidade, vale mais a pena poupar para comer bem. : 0.3666666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10009 x Atendimento excelente, cardápio variado para todos os gostos e tempero maravilhoso e ótima localização.
# **************
# Inglês:  Excellent service, varied menu for all tastes and wonderful seasoning and great location.
# sentence_br  Atendimento excelente, cardápio variado para todos os gostos e tempero maravilhoso e ótima localização.
# sentence.sentiment.polarity:  0.9333333333333332
# sentence.sentiment.subjectivity:  0.9166666666666666
# Polaridade
#  Atendimento excelente, cardápio variado para todos os gostos e tempero maravilhoso e ótima localização. : 0.9333333333333332
# subjetividade
#  Atendimento excelente, cardápio variado para todos os gostos e tempero maravilhoso e ótima localização. : 0.9166666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10010 x Outra boa opção na região central para quem gosta de um café com muffins de varios sabores. Muito bons
# **************
#
# Inglês:  Another good option in the central region for those who like a coffee with muffins of various flavors.
#  Very good
# sentence_br  Outra boa opção na região central para quem gosta de um café com muffins de varios sabores.
# sentence.sentiment.polarity:  0.2333333333333333
# sentence.sentiment.subjectivity:  0.45
# Polaridade
#  Outra boa opção na região central para quem gosta de um café com muffins de varios sabores. : 0.2333333333333333
# subjetividade
#  Outra boa opção na região central para quem gosta de um café com muffins de varios sabores. : 0.45
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Muito bons
# sentence.sentiment.polarity:  0.9099999999999999
# sentence.sentiment.subjectivity:  0.7800000000000001
# Polaridade
#  Muito bons : 0.9099999999999999
# subjetividade
#  Muito bons : 0.7800000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10011 x Minha namorada e eu chegamos ao restaurante por volta de 20 horas e colocamos o nome na fila. Eram apenas 2 mesas na nossa frente e então resolvemos esperar. Posteriormente a gente, chegou um uma família de 3 pessoas. Passado quase 30 minutos de espera, as mesas que estavam na nossa frente já tinham sido acomodadas e estávamos esperando nossa vez, até que um funcionário do restaurante acomodou a família que chegou depois da gente. Ao ver isto, fui reclamar com a funcionária responsável pela fila de espera que nos disse "são normas da casa" ?????? Normas da casa furar fila??? Então fui reclamar com o funcionário que chamou a família que, ao ver que tinha errado, pediu desculpas e arrumou um local para sentarmos.
#
# O ambiente do restaurante é super agradável. O garçom que nos atendeu também foi muito solícito e educado. E a comida é boa e bem servida.
#
# De modo geral, o estresse inicial quase me fez desistir do restaurante, principalmente quando me deram como desculpas o famoso "normas da casa", mas depois disso foi uma boa experiência.
# **************
#
# Inglês:  My girlfriend and I arrived at the restaurant around 8 pm and put the name in line.
#  There were only 2 tables in front of us and we decided to wait.
#  Afterwards, a family of 3 people arrived.
#  After almost 30 minutes of waiting, the tables in front of us had already been accommodated and we were waiting for our turn, until a restaurant employee accommodated the family who arrived after us.
#  Upon seeing this, I went to complain to the employee responsible for the waiting line who told us "these are house rules" ?????? House rules to skip the line ??? So I went to complain to the employee who called the family, who, seeing that he was wrong, apologized and arranged a place for us to sit.
#
#
# The restaurant's atmosphere is super pleasant.
#  The waiter who served us was also very helpful and polite.
#  And the food is good and well served.
#
#
# In general, the initial stress almost made me give up the restaurant, especially when the famous "house rules" were apologized to me, but after that it was a good experience.
# sentence_br  Minha namorada e eu chegamos ao restaurante por volta de 20 horas e colocamos o nome na fila.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Minha namorada e eu chegamos ao restaurante por volta de 20 horas e colocamos o nome na fila. : 0.0
# subjetividade
#  Minha namorada e eu chegamos ao restaurante por volta de 20 horas e colocamos o nome na fila. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Eram apenas 2 mesas na nossa frente e então resolvemos esperar.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Eram apenas 2 mesas na nossa frente e então resolvemos esperar. : 0.0
# subjetividade
#  Eram apenas 2 mesas na nossa frente e então resolvemos esperar. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Posteriormente a gente, chegou um uma família de 3 pessoas.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Posteriormente a gente, chegou um uma família de 3 pessoas. : 0.0
# subjetividade
#  Posteriormente a gente, chegou um uma família de 3 pessoas. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Passado quase 30 minutos de espera, as mesas que estavam na nossa frente já tinham sido acomodadas e estávamos esperando nossa vez, até que um funcionário do restaurante acomodou a família que chegou depois da gente.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Passado quase 30 minutos de espera, as mesas que estavam na nossa frente já tinham sido acomodadas e estávamos esperando nossa vez, até que um funcionário do restaurante acomodou a família que chegou depois da gente. : 0.0
# subjetividade
#  Passado quase 30 minutos de espera, as mesas que estavam na nossa frente já tinham sido acomodadas e estávamos esperando nossa vez, até que um funcionário do restaurante acomodou a família que chegou depois da gente. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Ao ver isto, fui reclamar com a funcionária responsável pela fila de espera que nos disse "são normas da casa" ??????
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.55
# Polaridade
#  Ao ver isto, fui reclamar com a funcionária responsável pela fila de espera que nos disse "são normas da casa" ?????? : 0.2
# subjetividade
#  Ao ver isto, fui reclamar com a funcionária responsável pela fila de espera que nos disse "são normas da casa" ?????? : 0.55
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Normas da casa furar fila???
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Normas da casa furar fila??? : 0.0
# subjetividade
#  Normas da casa furar fila??? : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Então fui reclamar com o funcionário que chamou a família que, ao ver que tinha errado, pediu desculpas e arrumou um local para sentarmos.
# sentence.sentiment.polarity:  -0.5
# sentence.sentiment.subjectivity:  0.9
# Polaridade
#  Então fui reclamar com o funcionário que chamou a família que, ao ver que tinha errado, pediu desculpas e arrumou um local para sentarmos. : -0.5
# subjetividade
#  Então fui reclamar com o funcionário que chamou a família que, ao ver que tinha errado, pediu desculpas e arrumou um local para sentarmos. : 0.9
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  O ambiente do restaurante é super agradável.
# sentence.sentiment.polarity:  0.5333333333333333
# sentence.sentiment.subjectivity:  0.8166666666666667
# Polaridade
#  O ambiente do restaurante é super agradável. : 0.5333333333333333
# subjetividade
#  O ambiente do restaurante é super agradável. : 0.8166666666666667
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  O garçom que nos atendeu também foi muito solícito e educado.
# sentence.sentiment.polarity:  0.2
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  O garçom que nos atendeu também foi muito solícito e educado. : 0.2
# subjetividade
#  O garçom que nos atendeu também foi muito solícito e educado. : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  E a comida é boa e bem servida.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  E a comida é boa e bem servida. : 0.7
# subjetividade
#  E a comida é boa e bem servida. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  De modo geral, o estresse inicial quase me fez desistir do restaurante, principalmente quando me deram como desculpas o famoso "normas da casa", mas depois disso foi uma boa experiência.
# sentence.sentiment.polarity:  0.25
# sentence.sentiment.subjectivity:  0.62
# Polaridade
#  De modo geral, o estresse inicial quase me fez desistir do restaurante, principalmente quando me deram como desculpas o famoso "normas da casa", mas depois disso foi uma boa experiência. : 0.25
# subjetividade
#  De modo geral, o estresse inicial quase me fez desistir do restaurante, principalmente quando me deram como desculpas o famoso "normas da casa", mas depois disso foi uma boa experiência. : 0.62
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10012 x QueijoTrança , chope gelado e bom atendimento. a decoração dos lustres com garrafões e garrafas dão um ar rebuscado, bons banheiros e o valor esta na média
#
#
# **************
# Inglês:  Cheese, French draft beer and good service.
#  the decoration of the chandeliers with carboys and bottles give a refined air, good bathrooms and the value is on average
# sentence_br  QueijoTrança , chope gelado e bom atendimento.
# sentence.sentiment.polarity:  0.35
# sentence.sentiment.subjectivity:  0.30000000000000004
# Polaridade
#  QueijoTrança , chope gelado e bom atendimento. : 0.35
# subjetividade
#  QueijoTrança , chope gelado e bom atendimento. : 0.30000000000000004
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  a decoração dos lustres com garrafões e garrafas dão um ar rebuscado, bons banheiros e o valor esta na média
# sentence.sentiment.polarity:  0.27499999999999997
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  a decoração dos lustres com garrafões e garrafas dão um ar rebuscado, bons banheiros e o valor esta na média : 0.27499999999999997
# subjetividade
#  a decoração dos lustres com garrafões e garrafas dão um ar rebuscado, bons banheiros e o valor esta na média : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10013 x Comida e ambientes são ótimos para curtir a noite   No Bairro de Boa Viagem.Os preço também são bons,Vale a pena conhecer.
# **************
#
# Inglês:  Food and environments are great to enjoy the night in the neighborhood of Boa Viagem.
# The prices are also good, it is worth knowing.
# sentence_br  Comida e ambientes são ótimos para curtir a noite   No Bairro de Boa Viagem.
# sentence.sentiment.polarity:  0.6000000000000001
# sentence.sentiment.subjectivity:  0.625
# Polaridade
#  Comida e ambientes são ótimos para curtir a noite   No Bairro de Boa Viagem. : 0.6000000000000001
# subjetividade
#  Comida e ambientes são ótimos para curtir a noite   No Bairro de Boa Viagem. : 0.625
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Os preço também são bons,Vale a pena conhecer.
# sentence.sentiment.polarity:  0.5
# sentence.sentiment.subjectivity:  0.35000000000000003
# Polaridade
#  Os preço também são bons,Vale a pena conhecer. : 0.5
# subjetividade
#  Os preço também são bons,Vale a pena conhecer. : 0.35000000000000003
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10014 x um excelente restaurante, localizado a uma quadra do mar da praia de boa viagem, tem um cardapio variadissimo, com preços justos. vale a pena conhecer.
# **************
#
# Inglês:  an excellent restaurant, located one block from the sea from the beach of boa viagem, has a varied menu, with fair prices.
#  worth knowing.
# sentence_br  um excelente restaurante, localizado a uma quadra do mar da praia de boa viagem, tem um cardapio variadissimo, com preços justos.
# sentence.sentiment.polarity:  0.85
# sentence.sentiment.subjectivity:  0.95
# Polaridade
#  um excelente restaurante, localizado a uma quadra do mar da praia de boa viagem, tem um cardapio variadissimo, com preços justos. : 0.85
# subjetividade
#  um excelente restaurante, localizado a uma quadra do mar da praia de boa viagem, tem um cardapio variadissimo, com preços justos. : 0.95
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  vale a pena conhecer.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  vale a pena conhecer. : 0.3
# subjetividade
#  vale a pena conhecer. : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10015 x Muito boa a variedade e o local, o preço bem acessível!!! único problema é  a demora dos pratos, a espera entre uma pizza e outra é grande! o 2 andar é pior ainda!!! tirando isso, eu gostei e sou freguesa!
# **************
#
# Inglês:  Very good variety and location, very affordable price !!! only problem is the delay of the dishes, the wait between one pizza and another is long! the 2nd floor is even worse !!! other than that, I liked it and I'm a customer!
# sentence_br  Muito boa a variedade e o local, o preço bem acessível!!!
# sentence.sentiment.polarity:  0.6503125
# sentence.sentiment.subjectivity:  0.54
# Polaridade
#  Muito boa a variedade e o local, o preço bem acessível!!! : 0.6503125
# subjetividade
#  Muito boa a variedade e o local, o preço bem acessível!!! : 0.54
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  único problema é  a demora dos pratos, a espera entre uma pizza e outra é grande!
# sentence.sentiment.polarity:  -0.03125
# sentence.sentiment.subjectivity:  0.7
# Polaridade
#  único problema é  a demora dos pratos, a espera entre uma pizza e outra é grande! : -0.03125
# subjetividade
#  único problema é  a demora dos pratos, a espera entre uma pizza e outra é grande! : 0.7
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  o 2 andar é pior ainda!!!
# sentence.sentiment.polarity:  -0.390625
# sentence.sentiment.subjectivity:  0.3
# Polaridade
#  o 2 andar é pior ainda!!! : -0.390625
# subjetividade
#  o 2 andar é pior ainda!!! : 0.3
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  tirando isso, eu gostei e sou freguesa!
# sentence.sentiment.polarity:  0.3125
# sentence.sentiment.subjectivity:  0.5875
# Polaridade
#  tirando isso, eu gostei e sou freguesa! : 0.3125
# subjetividade
#  tirando isso, eu gostei e sou freguesa! : 0.5875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10016 x Diferente de outros restaurantes chineses, esse não agradou ao meu paladar... faltou um algo a mais...sabor bem diferente dos chineses tradicionais.
# **************
#
# Inglês:  Unlike other Chinese restaurants, this one did not please my taste.
# .. something more was missing.
# ..tastes very different from traditional Chinese.
# sentence_br  Diferente de outros restaurantes chineses, esse não agradou ao meu paladar.
# sentence.sentiment.polarity:  -0.0625
# sentence.sentiment.subjectivity:  0.1875
# Polaridade
#  Diferente de outros restaurantes chineses, esse não agradou ao meu paladar. : -0.0625
# subjetividade
#  Diferente de outros restaurantes chineses, esse não agradou ao meu paladar. : 0.1875
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  .. faltou um algo a mais.
# sentence.sentiment.polarity:  0.15
# sentence.sentiment.subjectivity:  0.275
# Polaridade
#  .. faltou um algo a mais. : 0.15
# subjetividade
#  .. faltou um algo a mais. : 0.275
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  ..sabor bem diferente dos chineses tradicionais.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.51
# Polaridade
#  ..sabor bem diferente dos chineses tradicionais. : 0.0
# subjetividade
#  ..sabor bem diferente dos chineses tradicionais. : 0.51
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10017 x Se você procura animação principalmente na noite de quarta-feira em Teresina, esse é o lugar!!! Ambiente temático (estilo rústico) com bebidas e comidas regionais. Sempre tem uma banda ou dupla sertaneja se apresentando.
# **************
#
# Inglês:  If you are looking for animation mainly on Wednesday night in Teresina, this is the place !!! Thematic environment (rustic style) with drinks and regional foods.
#  There is always a country band or duo performing.
# sentence_br  Se você procura animação principalmente na noite de quarta-feira em Teresina, esse é o lugar!!!
# sentence.sentiment.polarity:  0.32552083333333326
# sentence.sentiment.subjectivity:  0.3333333333333333
# Polaridade
#  Se você procura animação principalmente na noite de quarta-feira em Teresina, esse é o lugar!!! : 0.32552083333333326
# subjetividade
#  Se você procura animação principalmente na noite de quarta-feira em Teresina, esse é o lugar!!! : 0.3333333333333333
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Ambiente temático (estilo rústico) com bebidas e comidas regionais.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Ambiente temático (estilo rústico) com bebidas e comidas regionais. : 0.0
# subjetividade
#  Ambiente temático (estilo rústico) com bebidas e comidas regionais. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Sempre tem uma banda ou dupla sertaneja se apresentando.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Sempre tem uma banda ou dupla sertaneja se apresentando. : 0.0
# subjetividade
#  Sempre tem uma banda ou dupla sertaneja se apresentando. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10018 x o arroz com camarão cremoso deles é simplesmente maravilhoso e o atendimento bem rápido e o ambiente muito tranquilo, realmente um ótimo preço-muito acessível!!!!!!!!!!!!!!!!!
# **************
# Inglês:  their creamy shrimp rice is just wonderful and the service is very fast and the atmosphere is very peaceful, really a great price-very affordable !!!!!!!!!!!!!!!!!
# sentence_br  o arroz com camarão cremoso deles é simplesmente maravilhoso e o atendimento bem rápido e o ambiente muito tranquilo, realmente um ótimo preço-muito acessível!!!!!!!!!!!!!!!!
# sentence.sentiment.polarity:  0.64625
# sentence.sentiment.subjectivity:  0.795
# Polaridade
#  o arroz com camarão cremoso deles é simplesmente maravilhoso e o atendimento bem rápido e o ambiente muito tranquilo, realmente um ótimo preço-muito acessível!!!!!!!!!!!!!!!! : 0.64625
# subjetividade
#  o arroz com camarão cremoso deles é simplesmente maravilhoso e o atendimento bem rápido e o ambiente muito tranquilo, realmente um ótimo preço-muito acessível!!!!!!!!!!!!!!!! : 0.795
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10019 x O serviço é muito bom.As carnes de boa qualidade.A higiene do local e o local são
# de boa qualidade.Preço compatível com os serviços em geral.Recomendo para quem vai a Aracaju.
# **************
#
# Inglês:  The service is really good.
# Good quality meats.
# The hygiene of the place and the place are
# of good quality.
# Price compatible with services in general.
# I recommend it to anyone going to Aracaju.
# sentence_br  O serviço é muito bom.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  O serviço é muito bom. : 0.7
# subjetividade
#  O serviço é muito bom. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  As carnes de boa qualidade.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  As carnes de boa qualidade. : 0.7
# subjetividade
#  As carnes de boa qualidade. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  A higiene do local e o local são
# de boa qualidade.
# sentence.sentiment.polarity:  0.7
# sentence.sentiment.subjectivity:  0.6000000000000001
# Polaridade
#  A higiene do local e o local são
# de boa qualidade. : 0.7
# subjetividade
#  A higiene do local e o local são
# de boa qualidade. : 0.6000000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Preço compatível com os serviços em geral.
# sentence.sentiment.polarity:  0.05000000000000002
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Preço compatível com os serviços em geral. : 0.05000000000000002
# subjetividade
#  Preço compatível com os serviços em geral. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Recomendo para quem vai a Aracaju.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo para quem vai a Aracaju. : 0.0
# subjetividade
#  Recomendo para quem vai a Aracaju. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10020 x Fui com a minha família em uma sexta à noite e viramos fregueses, somos sempre atendidos pelos donos e as massas são saborosas feitas com farinha Italiana tipo: 00.
# Vale a visita e como dica experimente a fantasia delo chef.
#
# **************
#
# Inglês:  I went with my family on a Friday night and we became customers, we are always attended by the owners and the pasta is tasty made with Italian flour type: 00.
#
# Worth the visit and as a tip try the chef's fantasy.
# sentence_br  Fui com a minha família em uma sexta à noite e viramos fregueses, somos sempre atendidos pelos donos e as massas são saborosas feitas com farinha Italiana tipo: 00.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Fui com a minha família em uma sexta à noite e viramos fregueses, somos sempre atendidos pelos donos e as massas são saborosas feitas com farinha Italiana tipo: 00. : 0.0
# subjetividade
#  Fui com a minha família em uma sexta à noite e viramos fregueses, somos sempre atendidos pelos donos e as massas são saborosas feitas com farinha Italiana tipo: 00. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Vale a visita e como dica experimente a fantasia delo chef.
# sentence.sentiment.polarity:  0.3
# sentence.sentiment.subjectivity:  0.1
# Polaridade
#  Vale a visita e como dica experimente a fantasia delo chef. : 0.3
# subjetividade
#  Vale a visita e como dica experimente a fantasia delo chef. : 0.1
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10021 x Restaurante simples, vale a visita pela comida bem feita
# **************
#
# Inglês:  Simple restaurant, worth the visit for the well done food
# sentence_br  Restaurante simples, vale a visita pela comida bem feita
# sentence.sentiment.polarity:  0.15
# sentence.sentiment.subjectivity:  0.2285714285714286
# Polaridade
#  Restaurante simples, vale a visita pela comida bem feita : 0.15
# subjetividade
#  Restaurante simples, vale a visita pela comida bem feita : 0.2285714285714286
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10022 x Ótima opções de lanches com os mais diversos lanches de belém, recomendo aos bons de boca que adoram lanches.
# **************
#
# Inglês:  Great snack options with the most diverse snacks from Belém, I recommend it to the good ones who love snacks.
# sentence_br  Ótima opções de lanches com os mais diversos lanches de belém, recomendo aos bons de boca que adoram lanches.
# sentence.sentiment.polarity:  0.625
# sentence.sentiment.subjectivity:  0.6125
# Polaridade
#  Ótima opções de lanches com os mais diversos lanches de belém, recomendo aos bons de boca que adoram lanches. : 0.625
# subjetividade
#  Ótima opções de lanches com os mais diversos lanches de belém, recomendo aos bons de boca que adoram lanches. : 0.6125
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10023 x Diversidade no cardápio exclusivamente espanhol, desde entradinhas, comidinhas, tinto de verano, custo x beneficio bom, eles possuem uma outra casa similar que também fui chamada Maripili, peça como entrada jamon
# **************
#
# Inglês:  Diversity in the exclusively Spanish menu, from entradinhas, food, summer red, good cost x benefit, they have another similar house that I was also called Maripili, ask for jamon starter
# sentence_br  Diversidade no cardápio exclusivamente espanhol, desde entradinhas, comidinhas, tinto de verano, custo x beneficio bom, eles possuem uma outra casa similar que também fui chamada Maripili, peça como entrada jamon
# sentence.sentiment.polarity:  0.175
# sentence.sentiment.subjectivity:  0.25
# Polaridade
#  Diversidade no cardápio exclusivamente espanhol, desde entradinhas, comidinhas, tinto de verano, custo x beneficio bom, eles possuem uma outra casa similar que também fui chamada Maripili, peça como entrada jamon : 0.175
# subjetividade
#  Diversidade no cardápio exclusivamente espanhol, desde entradinhas, comidinhas, tinto de verano, custo x beneficio bom, eles possuem uma outra casa similar que também fui chamada Maripili, peça como entrada jamon : 0.25
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 10024 x Pelo preço que pagamos, fiquei impressionada com o buffet. Comida muito gostosa e atendimento atencioso. Mas tem muitas moscas, talvez até pela localização, porque o lugar aparentava ser bastante limpo.
# **************
#
# Inglês:  For the price we paid, I was impressed with the buffet.
#  Very delicious food and attentive service.
# ...
# sentence.sentiment.polarity:  0.47
# sentence.sentiment.subjectivity:  0.5933333333333334
# Polaridade
#  O restaurante em si é muito bom, assim como os outros da chef Morena Leite, com várias opções criativas e saborosas. : 0.47
# subjetividade
#  O restaurante em si é muito bom, assim como os outros da chef Morena Leite, com várias opções criativas e saborosas. : 0.5933333333333334
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Tem vista para o jardim, mas que atualmente está em obras.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.4
# Polaridade
#  Tem vista para o jardim, mas que atualmente está em obras. : 0.0
# subjetividade
#  Tem vista para o jardim, mas que atualmente está em obras. : 0.4
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Achei um inconveniente o fato do restaurante ser dentro do museu, sendo exigido o pagamento da entrada de R$ 10,00 para ter acesso ao restaurante durante a semana.
# sentence.sentiment.polarity:  -0.6
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Achei um inconveniente o fato do restaurante ser dentro do museu, sendo exigido o pagamento da entrada de R$ 10,00 para ter acesso ao restaurante durante a semana. : -0.6
# subjetividade
#  Achei um inconveniente o fato do restaurante ser dentro do museu, sendo exigido o pagamento da entrada de R$ 10,00 para ter acesso ao restaurante durante a semana. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Mesmo que você não tenha interesse em visitar o museu, o pagamento da entrada é obrigatório.
# sentence.sentiment.polarity:  -0.125
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Mesmo que você não tenha interesse em visitar o museu, o pagamento da entrada é obrigatório. : -0.125
# subjetividade
#  Mesmo que você não tenha interesse em visitar o museu, o pagamento da entrada é obrigatório. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Não acho justa essa cobrança apesar do valor não ser alto, as entradas deveriam ser independentes.
# sentence.sentiment.polarity:  0.20666666666666667
# sentence.sentiment.subjectivity:  0.5216666666666666
# Polaridade
#  Não acho justa essa cobrança apesar do valor não ser alto, as entradas deveriam ser independentes. : 0.20666666666666667
# subjetividade
#  Não acho justa essa cobrança apesar do valor não ser alto, as entradas deveriam ser independentes. : 0.5216666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 11206 x O melhor da comida mineira, um local bem aconchegante, com excelente atendimento e muito bem localizado, vale a pena.
# **************
# Inglês:  The best of Minas Gerais food, a very cozy place, with excellent service and very well located, is worth it.
# sentence_br  O melhor da comida mineira, um local bem aconchegante, com excelente atendimento e muito bem localizado, vale a pena.
# sentence.sentiment.polarity:  0.44799999999999995
# sentence.sentiment.subjectivity:  0.535
# Polaridade
#  O melhor da comida mineira, um local bem aconchegante, com excelente atendimento e muito bem localizado, vale a pena. : 0.44799999999999995
# subjetividade
#  O melhor da comida mineira, um local bem aconchegante, com excelente atendimento e muito bem localizado, vale a pena. : 0.535
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 11207 x O ambiente é muito bacana e descontraído,  bom atendimento,  preço mediano.  O filé a parmegiana é o carro chefe,  macio com molho saboroso acompanha arroz branco e deliciosas batatas sequinhas.  Recomendo
# **************
#
# Inglês:  The atmosphere is very nice and relaxed, good service, average price.
#   The parmigiana fillet is the flagship, soft with tasty sauce accompanying white rice and delicious dry potatoes.
#   I recommend
# sentence_br  O ambiente é muito bacana e descontraído,  bom atendimento,  preço mediano.
# sentence.sentiment.polarity:  0.44333333333333336
# sentence.sentiment.subjectivity:  0.6666666666666666
# Polaridade
#  O ambiente é muito bacana e descontraído,  bom atendimento,  preço mediano. : 0.44333333333333336
# subjetividade
#  O ambiente é muito bacana e descontraído,  bom atendimento,  preço mediano. : 0.6666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  O filé a parmegiana é o carro chefe,  macio com molho saboroso acompanha arroz branco e deliciosas batatas sequinhas.
# sentence.sentiment.polarity:  0.25833333333333336
# sentence.sentiment.subjectivity:  0.48750000000000004
# Polaridade
#  O filé a parmegiana é o carro chefe,  macio com molho saboroso acompanha arroz branco e deliciosas batatas sequinhas. : 0.25833333333333336
# subjetividade
#  O filé a parmegiana é o carro chefe,  macio com molho saboroso acompanha arroz branco e deliciosas batatas sequinhas. : 0.48750000000000004
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Recomendo
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Recomendo : 0.0
# subjetividade
#  Recomendo : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 11208 x Ficamos hospedados apenas por um dia na cidade de Recife. Este foi uma das nossas escolhas. Restaurante estava vazio em função do horário em que chegamos. Fomos maravilhosamente atendidos, comemos o bacalhau lagareiro que estava uma delícia.
# **************
#
# Inglês:  We stayed only for one day in the city of Recife.
#  This was one of our choices.
#  Restaurant was empty depending on the time we arrived.
#  We were wonderfully served, we ate the lagareiro cod, which was delicious.
# sentence_br  Ficamos hospedados apenas por um dia na cidade de Recife.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Ficamos hospedados apenas por um dia na cidade de Recife. : 0.0
# subjetividade
#  Ficamos hospedados apenas por um dia na cidade de Recife. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Este foi uma das nossas escolhas.
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Este foi uma das nossas escolhas. : 0.0
# subjetividade
#  Este foi uma das nossas escolhas. : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Restaurante estava vazio em função do horário em que chegamos.
# sentence.sentiment.polarity:  -0.1
# sentence.sentiment.subjectivity:  0.5
# Polaridade
#  Restaurante estava vazio em função do horário em que chegamos. : -0.1
# subjetividade
#  Restaurante estava vazio em função do horário em que chegamos. : 0.5
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Fomos maravilhosamente atendidos, comemos o bacalhau lagareiro que estava uma delícia.
# sentence.sentiment.polarity:  1.0
# sentence.sentiment.subjectivity:  1.0
# Polaridade
#  Fomos maravilhosamente atendidos, comemos o bacalhau lagareiro que estava uma delícia. : 1.0
# subjetividade
#  Fomos maravilhosamente atendidos, comemos o bacalhau lagareiro que estava uma delícia. : 1.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 11209 x Com uma decoração única, regional e comida Boa
# O cardápio é variado com tapiocas e cuscuz, o atendimento é bom e o lugar  é limpo e divertido.
# Os pregos são médios, uma tapioca custa em média 25,00 mas ela satisfaz!!!
#
#
# **************
#
# Inglês:  With unique, regional decor and good food
# The menu is varied with tapioca and couscous, the service is good and the place is clean and fun.
#
# The nails are medium, a tapioca costs on average 25.00 but it satisfies !!!
# sentence_br  Com uma decoração única, regional e comida Boa
# O cardápio é variado com tapiocas e cuscuz, o atendimento é bom e o lugar  é limpo e divertido.
# sentence.sentiment.polarity:  0.4883333333333333
# sentence.sentiment.subjectivity:  0.6200000000000001
# Polaridade
#  Com uma decoração única, regional e comida Boa
# O cardápio é variado com tapiocas e cuscuz, o atendimento é bom e o lugar  é limpo e divertido. : 0.4883333333333333
# subjetividade
#  Com uma decoração única, regional e comida Boa
# O cardápio é variado com tapiocas e cuscuz, o atendimento é bom e o lugar  é limpo e divertido. : 0.6200000000000001
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Os pregos são médios, uma tapioca custa em média 25,00 mas ela satisfaz!!
# sentence.sentiment.polarity:  -0.234375
# sentence.sentiment.subjectivity:  0.39999999999999997
# Polaridade
#  Os pregos são médios, uma tapioca custa em média 25,00 mas ela satisfaz!! : -0.234375
# subjetividade
#  Os pregos são médios, uma tapioca custa em média 25,00 mas ela satisfaz!! : 0.39999999999999997
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 11210 x Adorei o peixe (robalo) ao molho de camarões acompanhado com arroz e um pirão delicioso!!!
# Eu voltaria lá com certeza!!!
# **************
#
# Inglês:  I loved the fish (sea bass) with shrimp sauce accompanied with rice and a delicious mush !!!
# I would definitely go back there !!!
# sentence_br  Adorei o peixe (robalo) ao molho de camarões acompanhado com arroz e um pirão delicioso!!!
# sentence.sentiment.polarity:  0.5166666666666666
# sentence.sentiment.subjectivity:  0.7666666666666666
# Polaridade
#  Adorei o peixe (robalo) ao molho de camarões acompanhado com arroz e um pirão delicioso!!! : 0.5166666666666666
# subjetividade
#  Adorei o peixe (robalo) ao molho de camarões acompanhado com arroz e um pirão delicioso!!! : 0.7666666666666666
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  Eu voltaria lá com certeza!!
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  Eu voltaria lá com certeza!! : 0.0
# subjetividade
#  Eu voltaria lá com certeza!! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# sentence_br  !
# sentence.sentiment.polarity:  0.0
# sentence.sentiment.subjectivity:  0.0
# Polaridade
#  ! : 0.0
# subjetividade
#  ! : 0.0
# It was created result:  C:\Users\pcorrea\Documents\projeto_ds\salvo_poradiradade_vm2-10000-20000.txt
# **************
#
# var 11211 x Outback é Outback! Despensa comentários. Vou com mais frequência no Shopping Boulevard, atendimento é ótimo. Uma dica: chegue cedo, costuma lotar no happy hour e almoço. Aceita o Alelo alimentação.
# **************
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-19-cdb3c0846720> in <module>
#      11         comentario_blob = TextBlob(out)
#      12
# ---> 13         comentario_blob_us = comentario_blob.translate(to='us')
#      14         print("Inglês: ",comentario_blob_us)
#      15         time.sleep(5)
#
# ~\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     544         :rtype: :class:`BaseBlob <BaseBlob>`
#     545         """
# --> 546         return self.__class__(self.translator.translate(self.raw,
#     547                               from_lang=from_lang, to_lang=to))
#     548
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ~\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
